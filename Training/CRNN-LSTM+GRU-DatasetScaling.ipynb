# %% [markdown]
# # Test tensorflow gpu #

# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
  except RuntimeError as e:
    print(e)

# %% [markdown]
# # Dataset #

# %%
import os
import codecs

data = {}
classes_file = './TextData/classes.txt'
with codecs.open(classes_file, 'r', encoding='utf-8') as cF:
    data = cF.read().split('\r\n')
len(data)
# Out:
# 94

# %%
import os
from PIL import Image, ImageDraw, ImageFont

text_source = './TextData/source.txt'
fonts_path = './TextData/Fonts'
fonts = [f'{fonts_path}/{f}' for f in os.listdir(fonts_path)]
fonts
# Out:
# ['./TextData/Fonts/arial.ttf',
#  './TextData/Fonts/arialbd.ttf',
#  './TextData/Fonts/arialbi.ttf',
#  './TextData/Fonts/ariali.ttf',
#  './TextData/Fonts/calibri.ttf',
#  './TextData/Fonts/calibrib.ttf',
#  './TextData/Fonts/calibrii.ttf',
#  './TextData/Fonts/calibriz.ttf',
#  './TextData/Fonts/cambria.ttc',
#  './TextData/Fonts/cambriab.ttf',
#  './TextData/Fonts/cambriai.ttf',
#  './TextData/Fonts/cambriaz.ttf',
#  './TextData/Fonts/consola.ttf',
#  './TextData/Fonts/consolab.ttf',
#  './TextData/Fonts/consolai.ttf',
#  './TextData/Fonts/consolaz.ttf',
#  './TextData/Fonts/constan.ttf',
#  './TextData/Fonts/constanb.ttf',
#  './TextData/Fonts/constani.ttf',
#  './TextData/Fonts/constanz.ttf',
#  './TextData/Fonts/corbel.ttf',
#  './TextData/Fonts/cour.ttf',
#  './TextData/Fonts/courbd.ttf',
#  './TextData/Fonts/courbi.ttf',
#  './TextData/Fonts/couri.ttf',
#  './TextData/Fonts/impact.ttf',
#  './TextData/Fonts/Roboto-Black.ttf',
#  './TextData/Fonts/Roboto-BlackItalic.ttf',
#  './TextData/Fonts/Roboto-Bold.ttf',
#  './TextData/Fonts/Roboto-BoldItalic.ttf',
#  './TextData/Fonts/Roboto-Italic.ttf',
#  './TextData/Fonts/Roboto-Regular.ttf',
#  './TextData/Fonts/tahoma.ttf',
#  './TextData/Fonts/tahomabd.ttf',
#  './TextData/Fonts/times.ttf',
#  './TextData/Fonts/timesbd.ttf',
#  './TextData/Fonts/timesbi.ttf',
#  './TextData/Fonts/timesi.ttf',
#  './TextData/Fonts/trebuc.ttf',
#  './TextData/Fonts/verdana.ttf',
#  './TextData/Fonts/verdanab.ttf',
#  './TextData/Fonts/verdanai.ttf',
#  './TextData/Fonts/verdanaz.ttf']

# %%
dataset = []
sequence_len = 20

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import cv2

def draw_img(img):
    plt.imshow(np.asarray(img), cmap='gray', vmin=0, vmax=255)
    plt.show()

def load_img(img):
    return cv2.imread(img, cv2.IMREAD_GRAYSCALE)

def dilate_img(img):
    return cv2.dilate(img, np.ones((2,2), np.uint8))

def otsu_thresholding(img):
    norm_img = np.zeros(img.shape)
    img = cv2.normalize(img, norm_img, 0, 255, cv2.NORM_MINMAX)
    blur = cv2.GaussianBlur(img, (3,3), 0)
    _, img = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    img = dilate_img(img)
    return img

# %% [markdown]
# ## Load dataset ##

# %%
with open(text_source) as txt:
    word_count = 0
    sequence = ''
    dataset = []
    for i, line in enumerate(txt):
        words = line.split(' ')
        for single_word in words:
            word = ''.join([c for c in single_word if c in data])
            
#             if word[-1:] == '\n':
#                 word = word[:-1]
            
            if len(word) < 1:
                continue
            
            if len(word) > 30:
                split_count = len(word) // 30 + 1
                for i in range(split_count):
                    start = i * split_count
                    end = start + len(word) // split_count
                    dataset.append(word[start:end])          
                continue
                
            sequence = sequence + word + ' ' * random.randrange(1, 4)
            word_count = (word_count + 1) % sequence_len
            if word_count == 0 or len(sequence) > 85:
                dataset.append(sequence[:-1])
                sequence = ''
                
dataset = list(set(dataset))
len(dataset)
# Out:
# 34783

# %% [markdown]
# ## Shuffle dataset ##

# %%
sorted_data = sorted(dataset, key=len)
longest_label = len(sorted_data[-1])
longest_label
# Out:
# 116

# %%
import random

random.seed = 123456

random.shuffle(dataset)
# dataset = dataset[:3000]
dataset
# Out:
# ['has been a  great   success for the   town,',
#  'new artists and   animators.   At   the   Ballyfermot Senior  ',
#  "Under-21   Under-19   Under-17  FutsalWomen'sNational team   Official  website   (in Albanian  ",
#  'constructor)   for triple-based management of an ',
#  'involve  striking   deep into the   enemy  territory   and  typically  ',
#  "tries  to  convince   Lori,  Rick's",
#  'voices  and   organ. This   Is The Month  Tonic  Vox  Dicentis  -   motet written in 1911.',
#  'Theoretical Physics  (ICTP),  both  in   Trieste, Italy. He ',
#  'in relation  to other minds with   shared meanings."   The   two most   important  roots',
#  'Guards.   23855279  Sergeant   Joseph   Andrew Jenkins, The   Royal   Irish ',
#  'apply.   The  effect   is more  pronounced   in  doubly-fed  induction generators   (DFIG),',
#  'raid  on  Lawrence   was led   by William  Quantrill, a Confederate   guerrilla born  ',
#  'phenomenon is  something real   and   not visionary or',
#  'architect   of the time  in Ireland.   Among  buildings  in Dublin   that  he   decorated',
#  'suggested   that   the  move was  primarily motivated by financial considerations,  with',
#  'of   its  inventors.   The current challenge of  fundamental  index   managers   is to',
#  'Boots   (1997) Super Bowl   XXXIII  (1999)  (The  Simpsons ',
#  'Beach,   California Cooper, William   John. 1929.   Address   before  the National',
#  'Australian position as  a   previously   unseen  group   of  militia joined   in  the',
#  'possession.   He   said,  "OK   so Flower ',
#  'with  quoted  statements  (in a  formula named _:a)   Finally, these statements   would  ',
#  'The  studio went  on   to  grow',
#  'inception,  is  named  in  his   honor. John Mack   at   Find a   Grave John  W.   Mack  ',
#  'name   Lotte  (the   object   of the   affections of Werther  in  that  novel).  Sondra',
#  'the subject of the entire   third  verse.   In   episode  13  of   the third   season  ',
#  'former   Disney animators, left  Disney on  September 13,   1979  to form   Don Bluth',
#  'Cool   from  Cedar   Key while treating   a cabin boy.  He   carried   the disease   to ',
#  'at   Yorkshire  Water.   She is also a non-executive director of   the  Financial   Reporting  ',
#  'Frustrated he   confronted   Louisa,   since she   was  ',
#  'battery   electric vehicles. These unique green  vehicle  plates  allow ',
#  'other  TV credits   include   The Befrienders, Couples,  Jack  ',
#  'had  recently  made   attempts to   garner  support   for',
#  'Strathclyde',
#  'and the School House   Gallery   (a   replica   of  a  schoolhouse that was  built   at',
#  'played one league game.The club returned  for the ',
#  '2020.   For all   Hastings  United   and  Hastings   Town  managers  with a Wikipedia',
#  'president   of  Dura  Capital Limited,  a   company  that he   founded in  2006,  at  ',
#  'Department of   the   Environment,   Northern   Ireland.  James Lorimer,   Principal, ',
#  'Ling Chapman,   D1281S1G. Marine Vincent   Clay,   P01705GJ,  Royal Marines. Chief   Petty',
#  'but  the   Southern   League  had   refused   their attempt to  ',
#  'of   greater   complexity. The  Stanford Artificial   Intelligence   Laboratory  ',
#  'necropolis, attested   to predate the  gardens,   have',
#  'employees buy coverage  at   the  group rate. ',
#  "of Cook   County on  December 17,  1936   to  replace   Michael J.   O'Connor,  who  ",
#  'Washington Fraga  from  the  Socialism  and  Liberty  Party (PSOL)  and   Marta Jane  ',
#  'heart,  liver,  muscle,  and   skin.  Lafora   disease   is  also a  neurodegenerative  ',
#  'in all its   aspects,   particularly   reconstruction,   roughening  and melting,  also  ',
#  'that  gate  and   road  on   both  ',
#  'cello,   vocals   (19711972)   Rick  Curtis   guitar,  banjo,  vocals  (1972)  Michael  ',
#  'role was  as  Heli Mets   in   the  1986  Peeter  ',
#  '19,  2008. Busted   and   Disgusted is  an  original   series bringing viewers clips  ',
#  'The agreed  conditions  that allow   military  attachs ',
#  'For dental services to the  community  in   Belize. Thomas  ',
#  'the  late   1940s,  Daley   became   Democratic',
#  'retrospective  review, saying  that it  "makes   one  realise  how accomplished  these  ',
#  'weighted  indices.Response:  Fundamentally  based   indices   do   have  a  higher  ',
#  'the   19th   century,   and   were  ancestors to   the',
#  'Secretary to  the  Delegates  and   Chief Executive   of  the   Oxford   University  ',
#  'shelling by  Pakistani  Rangers in  RS   Pura',
#  'to the  economy  by  spending at   local   businesses. This  adds  about  $85 million',
#  'Other   Sounds"  by Esquivel  "Skin Diver Suite"   by   Leo  Diamond   "Persuasive  Percussion"',
#  '2010.In  March  2018, Hartman & Tyner   sold   the   property to  Delaware   North,  the  ',
#  'adulthood expressing his  sentiment about the   world',
#  'of higher education.  Founded  in 1855   and  was named   after  American  judge William',
#  'reddish coloured  spine.   When  it  blooms it  produces   inflorescences   that occur ',
#  'Hobarts  Eastern Shore.   Rosny   Cottage  (now  a   Museum)',
#  'nights. On one night the  deputy base commander, Colonel Charles   I.   Halt,  and other',
#  'included   in   the  list  of  "100 Essential  Rock  ',
#  'and  blocks  and   steals   until  the 198586  season,',
#  'the   Mag) was   a  British   chemical company  which   produces   magnesium  and  zirconium',
#  'in   2003   by John   and  Lizza   Lundin  as  a',
#  "Rica,   Panama) Odontoglossum  lindleyanum   Rchb.f.   &   Warsz.   1854  : Lindley's ",
#  'of   1960 and  of  Hubert  Humphrey   in the   presidential election   of 1968.  He  ',
#  "Mahler,  he   assessed Mahler's  estate   for probate  after   his  death. He  later won  ",
#  'his   studies   by  selling clothing, Kamien graduated from City',
#  'Neil  Young   and   Crazy  Horse   toured   throughout 2012  and 2013  in support  of ',
#  "Game Freak's   2019  RPG Little Town   Hero, the   last  of   which  was  arranged   by  ",
#  '(380648), late   Royal Regiment  of  Artillery. Reverend   David   Brian   Dougall, , ',
#  'the  methodology   in  mid-2004.  However,  the   method  is  in practice ',
#  'Roy',
#  'Pakistani  civilians  were  killed and   22 were   injured  in firing by Indian   forces ',
#  'and various silanes.  Nickel  has found widespread  use in ',
#  'administrator   Bump   Hadley   (19041963),   American  Major League   Baseball  pitcher  ',
#  'hide  various  panes   for   focused   writing, and   the page  thumbnails  pane   does',
#  'his family  (Maddie Lomax  and  Noah',
#  'inscription  in the  center.   81 stars   are encircled   around  the coat   of   arms',
#  'retained  for the next  twelve years.In   1888, Wrexham ',
#  'be  in   violation   of   the Administrative  Procedure   Act   having  been issued  ',
#  'Moozhikkal  is  administered by Kozhikode  Corporation which is  a   local  city council',
#  "Garfield   (1988)   Garfield: His  9   Lives (1988) Garfield's Babes   and   Bullets ",
#  'in   1966  in   Ghana)   is a   Ghanaian   retired   footballer. Los   ojos   ms   lindos ',
#  'for  "We   Fight",   directed by  David  ',
#  'was  released   on   CD  individually and in',
#  'shopping and civic center   for Haddam.   It   has   a ',
#  'Region, the   Kiev  Region,  in   Podolia  and   the Voronezh Province   (over   70,000  ',
#  'Mennonite Brethren  Church   emerged  among   Russian Mennonites  who   accepted Radical  ',
#  'first  appears  on  page   108   of  the  paperback copy   of  City   Of  Light and  ',
#  'Old Order  River  Brethren   separated  from   other  streams   of the  River Brethren ',
#  'World  Championship medals   including   a   gold   medal  ',
#  'to cut their   losses.  The   decision   came not ',
#  ': Ada   x   Odontoglossum  x   Miltonia  xOdontioda :   Odontoglossum x  ',
#  'of   our soldiers   embraced martyrdom" and   claimed:  "they  [Indian Army]',
#  'the  big   leagues  when the   Dodgers  called ',
#  'Race points   systemPoints  are   awarded to   the top   10  ',
#  'Turok: Son  of  Stone  (2008, co-production   with   Classic  Media and Starz Media)  ',
#  'in  the  4th  century, that  is,   some 400   years  ',
#  'research   activity   can be   found  here. Born  of ',
#  'sanctuary   in Grass   Valley.Once the Grass Valley   site was',
#  'plane  was to continue flying   another  50 miles ',
#  're-mastered and  re-mixed   tracks  from  the   HipRockSoul   album as  well  as  ',
#  'Margaret no   longer  wanted to   attend  college, but disregarded',
#  "and longs  for the  comforts of her family's  palatial   mansion.   One day,  she receives  ",
#  'Board.  Douglas Watson,   Rough  Rounder/Riveter,   Frank   Wright Shoes Ltd.,   Kettering. ',
#  'honors   the  integration  of diversity awareness   into educator   preparation',
#  'demethylation   (addition or  removal of   a   methyl group). Mercury  can  enter  ',
#  'founded  in  1349. It  is   a   part ',
#  'Volunteers   Territorial  and  Army  Volunteer Reserve.   The Venerable  Archdeacon Peter ',
#  'or year when   the   genre  was   born,  producer ',
#  'Madcap Business Adventure of   the Truly  Oddest  Couple Paul  Newman  ',
#  'at the   centre,   followed  by   a   broad band ',
#  'to a  binary   number  11:   This  binary number  representation  is similar to  that  ',
#  'released 29   June 2011.  Haunted   was  released as a digital  download  on February  ',
#  'to Brian  Clough  by naming  Jimmy  Armfield of  ',
#  'served   as  a  personnel  director for the  Chicago   Bears  from   1968-1975,   overseeing ',
#  'the   direction it  travels;  this  puts whatever is in   front   of   the  helicopter ',
#  'various   countries. From   1955 he was   on   the',
#  'a   key   stratigraphic site.This site is in   three areas, and there   is  public   access ',
#  "When   it  was   acquired  by  BrownForman  in   1956,  Motlow served   on   the   company's",
#  'and   Gaviiformes,   respectively.  "Colymbiformes".   Encyclopdia   Britannica. 2005. ',
#  'the last  3040  years  so  it   is not   strange  that they  might  beat  the  market. ',
#  'ntertainment.timesonline.',
#  'After some  years  of   small-scale  furniture  manufacturing  to ',
#  'teacher,   improviser  and composer.  His   unique   rich ',
#  'Bono  region,   the  Japekrom  Health centre.  ',
#  'the   best  possible  musical  training,  being   a  chorister of ',
#  'Military   Forces). Warrant Officer Class  One  Peter  George   Cowan (53419),  Royal',
#  'toward including the  guitarist in   his new   touring   band, the Stray  Gators.  However, ',
#  'set featured Wat  Arun Ratchawararam   Ratchawora   Mahavihara seen   from ',
#  'troops   attempted  to  cut off  and  encircle  retreating   Russian forces,   while securing',
#  'Aspen, Colorado  is   his   home during   the',
#  'they had   killed 11 Indian soldiers on the ',
#  'century BC Crazy  Horse is   an',
#  'Mini-Moog synthesizer; piano   on  "Gospel  Truth" Clive  ',
#  'Interest east   of Dartford   in   Kent.This   ancient  semi-natural',
#  'They   say   that   breeding of  hairless   with  hairless (and  common but   unacknowledged ',
#  'is   ejected  from her first question   time   when',
#  'groups;  he   just  drones   on,   preaching to   the ',
#  'on  the  same  day   that 4   Pakistani  civilians  were  ',
#  'US President Donald  Trump and the candidacy   of   Marion ',
#  'around 1961,   Downton had an important  part  to  ',
#  'bus  generally   used at  quiet   times)Buses undergoing repair  or  ',
#  "of  only  three  programs to   win   more than   2,000   games.  In   Street  &   Smith's  ",
#  '1931,   and the memorial   was   dedicated   by President Herbert  Hoover  on November ',
#  'Douglas',
#  'as   President of the  Pharmacy  Guild,  and   was   involved   in  the  founding of the  ',
#  'that a small   bomb   would   be   detonated at',
#  '-   Low  (Myon   Tales   From   Another',
#  'instead of   small   and   medium-sized businesses, including  help',
#  'He   took   on   military   tasks   such  as   ordering the taking of  control  of  Fort  ',
#  'was the album   A  Guided  ',
#  'to changes  of   existing   calls,   novel   calls',
#  'Steele   References M -  exclusion  for exceeding   two  minute ',
#  'Officer,  London  Fire  Brigade.  Peter   Robinson,   Divisional   Officer  Grade 1, ',
#  'in  2000  where he ran   in   the   100m and  200m,  winning a silver medal  in   the',
#  'In  addition to his other  works,  on June   22,   1916 Lewis   hosted what was   announced ',
#  "trust  on   Snepp's profits.  In   this   country,",
#  "Ed,  Carol's  husband  and  first victim  of",
#  'while   themselves   being  seen.   Horace,  Satires i.8.14  -   "nunc   licet Esquiliis  ',
#  'a painting  by  Palma   Vecchio, another',
#  'Analog,   and was   expanded as a  novel   in 1988)Short  fiction"The Geas   Ingenerate"',
#  'the  romance  rather than  the  western  setting,',
#  'of Radical   Pietism   teach the   necessity of the',
#  'The   Beat Becomes   A   Sound, through  iTunes  on   January   29, 2013.   The   first',
#  'a 1977 poll   taken  just nine  months ',
#  'block  bounded  by  Worcester,   Rolleston,  Hereford  and   Montreal Streets.   Llanmaes ',
#  'Proposed   facilities   include   a   3,000 capacity  stadium for  Hastings',
#  'on  pion-nucleon  phase  shift dispersion  relations,  a   subject suggested by  Daniele  ',
#  'Rhode Island   State  College   in   1931,   an honorary  Doctor  of  Science  in  Education  ',
#  'Harvey   Spencer   Lewis   (F.R.C.,   S..I..,  336695)  Self  Mastery and   Fate with',
#  'he declined.   He  also   got   the  President to  accept an   offer  to   either stay  ',
#  'DAPI, a   more sensitive   dye,   revealed the DNA   running ',
#  'be prescribed.   The  court   will   have regard  ',
#  'forests  and  hills. The  Mourne  Mountains is   the  setting   for   many  local   myths ',
#  'also   acted   as  an expert witness in several',
#  'corners   of   modern   society...wistful  and witty poems"  and as ',
#  'Tunisia"  (July   30,  2008),  Gould  wrote  a   firsthand  account   of   Tunisian  journalists ',
#  'head   coach  of all  sports   at the  athletic club. He was named  the  coach   of  ',
#  'Planning Scheme  in 1960 and   it  was  furthermore   amongst   the  first fifty  places ',
#  'Major  League   Soccer  Camilo  Sanvezzo K   League  stats  at kleague.com  ',
#  'moral  law  summarized   in   the  Ten   Commandments. Consequently, they  work   for',
#  'and  the  current   President   and CEO',
#  'St. John\'s   team  were  led  by senior caption   Andrew   "Fuzzy"   Levane   and  sophomore',
#  'Roseneath   Cottage. E.M.   was   Elizabeth  Mary   Bobart, ',
#  'Head   was   irredeemable  and ungrateful. On   his return to   Texas,   Iron   Head was',
#  'drums and percussion).   The horn  section   in  "Hang  Up  Your   Hang-Ups"   plays  ',
#  "the type site for  the  'Creeting   Sands', which   are  ",
#  'commonly   seen   in  combination with   these  NiX2',
#  'watchtower   in   the  historic   city  wall  ',
#  'pledged a   battalion (a force  between 770 and  1,100   troops)   to  join  the  Somali ',
#  '(CDU) and former member  of   the German   Bundestag.   Berger already joined  the   CDU  ',
#  'and   dance were all   elements   of  performance that were   developed  early on as Grosse',
#  'remarking  that  they were   very impressive  given  the limitations of Game   Boy   cartridges. ',
#  'the  Vice-Chancellor   upheld by the  Court ',
#  'they   should  "not be   considered   as   pets   in  the  accepted  sense  of the  word. ',
#  'cricket for one year from  10 February',
#  'Navy  alleged   that  its  warship   had   intercepted and',
#  'The   coast of  San   Jorge   Gulf  marks   the   start',
#  'C.  isabelae Diaphus depressifrons   Umbrina bananensis, U.   sublima   List   of',
#  'center.Another   area   under   research  is   the production  of   biofuel  from   algae ',
#  'to service in  disaster relief   efforts   and  participated  with  ',
#  'a minor  Indian   poet.   Features   by   Walker',
#  'of  the  battle.  The  romance  with  Lafitte  is   complete   fiction.  The interactions ',
#  'her career), is  cited   to the effect ',
#  'aided   the   money   laundering  of  over $420 million in   profits made by  Pablo  ',
#  "2  enabled   the   Court   of  Chancery,  sitting  at   Lincoln's ",
#  'chief financial   officer (1991-1995,  19961997)   and   president of  Disney  Stores',
#  'Florida  in   September   1836.He  was   educated by private  tutors, began   the  study',
#  'recommended immediate consideration   for  CITES   protection,   given its   likely demand ',
#  "perception  is   in   terms of   action.   Mead's theory   of  perception is  similar",
#  'Ms   Mary   Talbert (mother of ',
#  'Appellation wine   evaluations   for AppellationAmerica.com,   writes   a   monthly  ',
#  'Stanislav Karlovich   Osten-Saken  (17891863).  According to  a  contemporary,  Troshchinsky ',
#  'subtle social coordination.   In the social act  of economic   exchange,  for example,',
#  'from   an   open-world  assumption.For the  sake   of',
#  "maintained   budget  surpluses   and has   extensive  foreign-exchange   reserves.Botswana's  ",
#  'like  "fetch".   The  lack of hair  leads  to  a   reputation for   being easy  to   wash',
#  'December 1861), who   married Queen ',
#  'Warrant Officer Class   2  John   Joseph Carr  (53873),   Papua  New   Guinea  Defence  ',
#  "star players,  the  St.   John's   team   managed to",
#  'While the   Geographic  Names Information  System   considers   Lake Jefferson   to  ',
#  '23   March  2010.   As  of  1  August 2011, female  contraception  was added to a   list  ',
#  'after  his   death by  Jack Adrian in The Independent:   His   first  book,  The Blessing',
#  'of  General  Medicine Department   of Paediatrics   Department   of  Dentistry Department  ',
#  'UFOs" from  the Government Information   Library at  the  University   of  ',
#  'service  delivery;  and   Pacific   Architects & Engineers.  * The reason  why   troops',
#  "the aircraft's course   and   speed for a   time  before accelerating away and disappearing.  ",
#  "is  particularly  early  for Alsace  and   is explained  by   the Morimonts'  close links ",
#  'Literature Prize  of   Vienna 1999: Anton   Wildgans   Prize  ',
#  'Football  League   in 1985. They  became  Hastings  ',
#  'perspectives,   then it  might   be   that  by moving between  roles ',
#  'advantage by beating  Wolverhampton   Wanderers 10   to  move two  points   clear at ',
#  "April   - Natasha  Ryan is   found   hiding  in  a   wardrobe   at her  26-year-old boyfriend's ",
#  'Materials and   Industries.In 1958,  Tille was appointed as ',
#  'for  invertebrates,   including   two  protected under',
#  'firing.On 22   September,   the   Pakistan  military  said',
#  'Hoffman,   Jerry  Rubin,   and  three other   members  of  the   "Chicago',
#  'British  Virgin   Islands.  Percy Andrew  Turnbull,   Commercial  Officer,   British ',
#  'the  death  of Councillor  Bill  Bleasdale of  the   Conservative  Party.  By-election ',
#  'immediate experience is replaced  by   theoretical   constructs.  The ultimate   in  ',
#  'D.C.:   Government   Printing Office, 1957).  Wright,   Larry   and Wright,  Patricia. ',
#  "while with convoy WS  17  Keppel  D/F'ed  a U-boat   later   identified  as U-587, which",
#  'said   that Indian  troops   "retaliated   effectively". That  same   day,   the   Pakistan',
#  'Grade I,  Department   of   the Environment.  Henry  Paton   Fowler Crawford,  Secretary,',
#  'but the present building   was built   for   the   10th Viscount  Falkland  and   his ',
#  'Buenos   Aires,  Argentina  from  6   October to 18   October 2018.   KVDW   (branded  ',
#  '- 600   1973-1980   -   400-350  1980-2000   - ',
#  'streaming  media,   it is   more  important  to  deliver   recent  packets   quickly than  ',
#  'his   body but   they find  themselves   surrounded  by  an   army of Sam  clones, who',
#  'on  Alcohol   and   Other Drug Prevention  and Education.WPSC  88.7 Brave  New Radio, ',
#  'Construction of the   memorial  began   in  the   spring  of  ',
#  'closed   on 29  October   1967.The   Ekeberg  Line  was',
#  '1981.   Before   moving   to   Europe, ',
#  'stands   beside  the   tidal section of   the   River  Lynher   (a   tributary   of  the  ',
#  'shed,   late  19th  century,  from   Petersfield,  Hampshire  Fairmile  Caf, ',
#  'the British  community   in   Saudi Arabia. Donald   Gumming, HM ',
#  'The Leibniz  Review   is  a peer-reviewed   academic   journal   devoted   to  scholarly  ',
#  'a   hat-trick   against Msida   St. Joseph,   and   another  hat-trick against  reigning ',
#  'of  number-one albums   of 1971 (U.S.)  List  of number-one R&B albums   of   1971   (U.S.)  ',
#  'attachable  assets   to  pay  off   a  significant   portion',
#  'Written  by:   Neil Sedaka   &   Phil  Cody  / Produced  by:   Cliff   Magness &   Steve ',
#  'official  naval museum  located   in   Bremerton, Washington,   United   States.  The',
#  'East  Asia. 1972-   Four  year  degree  ',
#  'field of  law.  Louis William Bircham   Engledow,   of  Deakin,  Australian Capital Territory. ',
#  'El  Salvador   Politics of  El Salvador Elections   in  El Salvador  List  of political',
#  'Ukrainian   builder,  electrical   engineer,  politician.   Borysovsky  was from Donetsk  ',
#  'standards   which   take   into account the  special  characteristics  of  home  work,',
#  'The  series  premiered  on  September  11,  2005 to   7.2  million ',
#  'Cubs.   He   hit   his   first  home run ',
#  '(2003).   He  was  also   author of   the  short   story "The   Cold  Solution"  (Analog,  ',
#  'for   My Love"  and   the Fleetwood  Mac-inspired  "Lotta   Love".   In 1978, Crazy  Horse',
#  'being   endemic   to  South Africa. The   wetlands   of  the region shelter  all   of',
#  'Xingu corydoras is of  commercial  importance  in  the   aquarium trade   industry.  As',
#  'On  25 October   a  Ugandan  soldier and two   civilians   were reported killed   by  ',
#  'who played  as   a  winger.   Kenny played   for',
#  'wearing jewellery  for   Pirate   Treasures "Stage  Style"   collection   also  ',
#  'Chairman, Burmah   Oil  Co. Ltd.  Denis Follows,  CBE.  ',
#  'Officer   Grade   I, RAF  Cosford,   Wolverhampton,  Ministry  of  Defence. Brenda Pittaway, ',
#  '[2000]  IRLR 471,   where  an   employee was ',
#  'Park   (North  Carolina)   are examples  of government  initiated  Megasites in   America.',
#  'Salomon  Smith, born   19 June  1895   in   Stockholm, ',
#  '- Tom Keaton Zachery   Ty   Bryan  -  Val',
#  'through   the  marriage of  Louis  XIII  with Anne',
#  'Hemisphere  Hertelidea   eucalypti  Kantvilas  &  Printzen  (2004)  Australia  ',
#  "to   arrange Arnold Schoenberg's  release  from active military service   in   the First  ",
#  'Conduct. The   ACS   describes  itself as   "the   professional  association  for  Australia\'s',
#  'more behavioral variations,   including   a  decrease  in  both  ',
#  'located   at   Banyuwangi,   East Java,   Indonesia.   North   Sea Boats  was founded ',
#  'Djibouti   City  being   the only   other.  Only  freight trains   continue  northwards ',
#  'improvisation   and  has performed   at   several   improvisation  festivals  ',
#  'the   works   between  the   five   remaining members (besides   Killa   Sin)  with  ',
#  'the   first   European  since the   Norse colonization',
#  '1993  (Bolivia)  Odontoglossum mirandum  Rchb.f.  1882   : Grand   Odontoglossum  (Colombia',
#  'which,  ',
#  'such  as   W   and   VIBE, for   which he was  photographed by   Walter Chin, and   chosen',
#  '(uncredited)  Robert  Parrish as  Boy (uncredited)  Lon  ',
#  'relegation   places, finishing in   fourteenth  place.  ',
#  "Isabella   de'   Medici,  was strangled by  ",
#  'Press.   2008.  Mead and  Modernity:   Science,   Selfhood  and  Democratic   Politics.  ',
#  'for the  Symposium on   Computational Geometry   (2018),  International Colloquium',
#  'Novelda, Agost  and Petrel.  The population is   21 ',
#  'rejected,  but   on  21   February   1997,   the   latest   in a number   of   appeals  ',
#  'Guyana-born   but   moving to Ottawa   at  age   11, Hooper   turned   professional  ',
#  '25  May   -   Peter Hollingworth  bows to pressure',
#  'to seek   out  the Toys   himself,   and banish  ',
#  'Drainage ',
#  'and documented a   series  of  UFO ',
#  'the   size  of the   game   sprites resemble   toys.   Posehn   contacted his   friend,',
#  "this  plan   was   abandoned after   a   negative  public reaction.   Ham's   remains,  ",
#  'Birth Control.   Oxford   University Press.   Luis  ngel  ',
#  'a  record of   17731  for  an  .850  winning  percentage.  Joe Lapchick,  a former player ',
#  'line,  including   4.3%   of   those  under  age',
#  "and  'V/W' Class Destroyers.   Windsor,   UK: World Ship  Society. ISBN   978-0-9650769-8-4.CS1",
#  'of   the fairgrounds;   parking space  is   limited.',
#  'Officer ',
#  '4.3,  including   mail   merge,   non-contiguous selection   of   text,   advanced ',
#  'all   quarters   of  the   globe, and in  due  course  obtain Home Rule.  Curiously  ',
#  'in   this program  between  30  May   and   1',
#  '14, 1982,  Meacham  was   traded   to  the   New York   Yankees   with   outfielder Stan  ',
#  'obtained."   While MESS  was available in both   binary and source  code forms,  the restrictions',
#  'Keith   James  Rodda, of Mount   Eliza,  Victoria.  For public service   to  construction.',
#  '(ex   Coronation   Stakes).  ifhaonline.org   International   Federation of   Horseracing  ',
#  'in   their hotels; the  same group had  ',
#  'and   Dr  A.  L.   Geyer,  who  was  a guest of   Taoiseach  amon   de  Valera  in  1952.',
#  'the arts,   literature,  science,   and business  to  campus.   The',
#  'the   babbling   gradually  changes   to  resemble and eventually   become adult   vocalization.  ',
#  'and  the   median income  for a family was $31,784. Males   had   a   median   income ',
#  'succumbed  to   her  wounds   on   28  January.On   28   January, Pakistan   claimed  ',
#  '6  RAR  The  Major  Arena Soccer League   (MASL) is',
#  'the   Crown   did   not   apply  for   an injunction  at the time it   would   have  done',
#  'Mead, existence in  community  comes  before   individual   consciousness.  First one  ',
#  'crysoleucas)   in the wild  as  well  as   the   goldfish  ',
#  "who   has  become   the museum's  curator. Though  Sam  is   able to break-up   the  alliance  ",
#  'cruenta (Peckham &  Peckham, 1894)   (type)  Brazil  Ceriomura  damborskyae   Rubio  & ',
#  'stay,   it   included the American  ',
#  'Bridges   (Blue  Note, 1999)   In  the  Moment  Live  in   Concert   (Blue  Note,  2000) ',
#  'years provides a concise  summary of  the previous   twenty:   One  of the  best editors',
#  'retirement   homes.   Downton  Business  Centre,  on  the  A338,   is home   to  a variety',
#  'to  Magee.  Jason Campbell, football player  Eric   Clark,   Mississippi Secretary of',
#  'architecture  and animals  with  fully   scored  classical   music and  world  music.  ',
#  'Florida You  Make   Me   Feel   is the   third  studio album by American rhythm   and',
#  'exchange of fire  between   both  countries,   while   nine  Indian civilians   were  ',
#  'and   deliberate; the fact that the  breach  enabled   the   defendant   to   enter  into ',
#  'age   composers,  but almost  always arranged   in   a   lighter',
#  'Somali-Kenyan-U.S. base  2 km north  of  the  town   of  Sanguni  led to the deaths of ',
#  '717791.  (1885)   Payne   v Cave   (1789) 3 TR  148   is   an old  English  contract law',
#  'that   of   diamond.  Alumina  particle  sizes   in   the   10   to   150 micron   range  ',
#  'its   estimated  budget of  $75   million; Fox Animation  ',
#  'Jenner,  one of the few   remaining  medical   personnel',
#  "missions   and  promotes  social justice.   Summerfield's  congregation  formed in",
#  'in the   1960s  and   1970s,  "Chicago  always  had   a   double-A bond  rating."  According ',
#  "in   the Arba'ow  area, near Elasha   Biyahawas on   the  outskirts   of Mogadishu,  was ",
#  '-   Volume  I   (in   Italian).  Roma.   p.   417,  no  1517. Gyrodactylus   elegans ',
#  'Journal   of the  Canadian Society   for  Mesopotamian   Studies, 2018  [11]   R. M. ',
#  'War between  Rome and  the Proto-Germanic tribe  of',
#  'honour  of   their 20th   birthday.  The  single  is  dedicated   to the  Dux   de   Lux',
#  'used, the   laser   parameters  of power,   frequency, and pattern   can be tailored to  ',
#  'Mayor Pat McMahon.  He  was re-elected by   acclamation in the  2003 Northwest Territories ',
#  'new  health insurance plans   effective August 2012. ',
#  'and  60th   Anniversary of   Accession to the   Throne  ',
#  'Five   Jercules  Tangkay   (Welcoat)  Chester Tolomia   (Welcoat) Arwind Santos ',
#  'is   a public community   college   with three campuses  in Illinois:  Sugar Grove, Aurora,',
#  'Investments paid 1.4  million   and   took  responsibility   for the repayment   of  ',
#  'jammed.  Werther   suddenly   turns  towards   her   and  cuts her left   wrist  slightly, ',
#  'in   1935,   the  Cyprus Military  Police   lost their   quasi-military  ',
#  'aimed at an AMISOM  base',
#  'of Philosophy  George  Herbert Mead Mitchell   Aboulafia, Stanford   Encyclopedia ',
#  'species  are  found:   P. apacheanus   and',
#  'in 1909.  The  draw for  the   opening   fixtures took  place  on 16 December  2007.  ',
#  "for   Leonora's  murder, despite the protests of  her brother Pedro  lvarez  de  Toledo",
#  'the   incurring Indian submarine once   it was ',
#  'while  attached  to   Imperial Japanese Army   regiments as  ',
#  'in   San Francisco.  Douglas  Graham   Frazer. For services   to   British   commercial ',
#  'Just Another  Day  in  the   Homeland (2004)   Running ',
#  'rather than true  leaves.   The   crowded   but scattered   evergreen  phyllodes are ',
#  '(60  mi)   course. Rivers   of New  South  Wales  List  of rivers  of Australia Proust ',
#  'On April 14,  1561,  residents  of Nuremberg  described   the',
#  '52  testimonies of the  case  from other   people   were   collected.In 2021, a   woman  ',
#  'He   was  then   transferred   to race   in the United States  where   he   ran consistently ',
#  'its trunk.  A  large   Californian   desert   palm   (Washingtonia   robusta)   dates',
#  'fewer than   five  advisers, including   planners ',
#  'industry.   Cheryl  Gould grew   up in  Burlington   County,   New  Jersey.  She  was ',
#  'Bjelke-Petersen   had   some   days earlier convinced  the ',
#  'all  lands   North  of Pemaquid. This resulted  in  all   the  French  interests in Acadia',
#  'aircraft  carrier  USS   John C.   Stennis.   Outside  the museum,   the   sail of the  ',
#  'today.   Invitatio   ad offerendum  Upgrade   & ',
#  'leads by  a large   margin   (172-95   KU),  in ',
#  'race  consisted  of  two lengths   of  the  pool,   both  lengths being   in   freestyle.',
#  'for   Diana Ross.After   graduating   from   the   Ramaz  School   in  Manhattan, Gold',
#  'opinion, which the  George   W. Bush  administration did nothing   to alter   or withdraw',
#  'guitar  with an open wah pedal.   The ',
#  'cited as  5432 troops,   which  would   align  with   a  contingent  of   six   battalions ',
#  'with  Sarah  Cracknell) Red Hot  + ',
#  "the   wake of   the   STCC  promoter's bankruptcy in 2018.   Formula Nordic  continues  ",
#  '//web.archive.org/web/2007123',
#  'Gall to  mark his  75th  ',
#  "and  said of the band's   2001 release  Sin ",
#  'summarizes   consensus   opinions  on   medical  standards  and   educational  bulletins.',
#  'game   against Necaxa playing the   full   90   minutes,   the match  ended  in   a  ',
#  'the band  was   ordered  to   pay costs. As of   March  2010,   the  lawsuit   has  been',
#  'charter operations under African   Airlines.   The  business   model was   not  working',
#  'since the Vietnam  War.   22 February - Cricketer   Shane  Warne   is  suspended from ',
#  'to  veterans   and  the   aged.  Frederick  Edward   Gavin, of   West Wollogong,   New',
#  'yet any   evidence   known  of economic   significance.  The  traditional  method of ',
#  'information  and  players,  with Austin  acting as  a   potential',
#  'Dolby departed once more   and   Jason Hopkinson was ',
#  'was a precursor  to new  wave music and Les   Rita  Mitsouko.   Edith Nylon obtained  ',
#  'the   upper Xingu   River basin  in Brazil.  It is  named   for the  river   in   which  ',
#  'into Spanish  as  "Monforte" and   in   1916,',
#  "served as   Philip's commander at   the Battle of  Lepanto in   1571.  He   was  the ",
#  'reported  was   not an   uncommon  feature  of   their ',
#  'iTunes  YouTube   Channel Shin Kyuk-ho  (3   November  1921 ',
#  'The  summer ahead  of the  2003-04 season   saw many changes   at  the club,  with  most  ',
#  'Cayman   Islands.   Peter  Robin Jenkins, Warden,   Meru  National  Park, ',
#  'Personnel   Counsellor,  IBM United Kingdom   Ltd.,   Greenock.   Sydney  Waller, lately ',
#  'then  as   the  population  grew  and   churches were   built,  ',
#  'Hobart Bus  Station   and  Glenorchy.   The   Jazz',
#  'Calcutta (Kolkata), the son of  Dr.   Simeon ',
#  'Carmel Guerra, Samina Yasmeen,   and   Talal  Yassine, and   two  ex ',
#  'of   Subways  series   and City  Bus   Simulator',
#  'Region,',
#  'withdraw  their   resignation   from the League.  A   consortium led by  another  local',
#  'died  suddenly  in   1925 and his  contribution  to   the   success  of  the settlement ',
#  'championships,   one Big 12 Championship,  six  conference  tournament   championships,  ',
#  'history  of  the   Rosicrucian   Order,   with names ',
#  'all coming  from  his  tomb   at ',
#  'David  Beaty  was  announced as   the  next head  football   coach.  Kansas   baseball ',
#  'that conversation   at a  City   Hall press  conference   as  follows:   I ',
#  'rebate was  kept at   $8,000, but a   graded  scale was ',
#  "government-ordered slaughter of the entire herd  in  Botswana's north-west   Ngamiland",
#  "flowing   rivers  and reach  a maximum length of 9.7  cm.   All the Devil's  Men is  ",
#  'the Sydney   Roosters  18-6   to  ',
#  'a 30 defeat away  to bottom-places Carlisle United,  ',
#  'Commons   Amberley   Museum  is  an   open-air ',
#  'are threatened  by habitat  loss in   some  areas   of its  range,  and   by  the pet',
#  'before  by  the Zionist  Federation of   Great Britain   and Ireland   to  work  on  ',
#  'five   children. NWA   Mid-America   NWA ',
#  'a  household  in   the   county was $26,754, ',
#  'Planning Civil Engineering   Geomatics   Engineering   Architecture Environmental   Engineering',
#  'on a  short   tour  of Japan.In  2019 Jones  toured   the UK   with Peter Doherty   and ',
#  'book  was  later  republished   as   part   of  the',
#  'but sentenced to   ninety-nine   years  as   a  repeat   offender.  Iron   Head was a  ',
#  'has   been preserved over a length ',
#  'Cavendish  Laboratory,   University of   Cambridge.  Jean   Bruce  ',
#  'first   came  to  prominence  during   her extended  reign   (1946-1980)  at Harper  ',
#  'Stanford  Peters. For   services   to Association  Football.  Mary Gwenllian',
#  'in Bangui,  Central African   Republic.  It operates scheduled  passenger  services  to ',
#  "was built  near  All  Saints'  church   in  1864.   It  was   decommissioned   and  converted ",
#  'of firing   the   Cockerill  Falarick  105 Gun  Launched  Anti-Tank  Guided Missile (GLATGM). ',
#  'the  New  York  Giants   of   the   National   Football ',
#  'Inc to   claim   the   phone had   been  delivered. ',
#  'bathroom vending   machines."Dry   Bones in  ',
#  'other. After catching the   relay throw from shortstop   Ozzie Guilln,   catcher  Carlton  ',
#  'their former  denominations and came together   because   of  perceived   equivocation  ',
#  'new  allies,  once France   was at   war with  Germany  in  1914. Newfoundland,   Canada,  ',
#  'Row   channel,  as  well as  stream TV  shows and ',
#  '2007  Lumberg   received death threats   after   criticizing  ',
#  'to the British  community  in Belgium. Donald Gordon Ellis. For  services to   British  ',
#  'Director,  Clinical   Section, Toxicology Unit,   Medical  Research Council. Professor ',
#  'feature of  Lafora  disease  is  seizures   that  have  ',
#  'perimeter  fence north  and   rear  of the house  and   over   the   trellis  fence including  ',
#  'a  frequent  guest speaker   at   science fiction  conventions. When   asked   about  ',
#  'public service. Vernon   Ernest Hollyock,  of Kew,  Victoria.  For  service to health',
#  'Annali Braul,  Lottie   Enns, Gail  Zacharias,  Karin Kliewer   Leave   a Little  Light',
#  'hall  and a new  conference hall.  College   of   Nursing,  Trivandrum,  Kerala,   India',
#  '32,482   wards  in   England,  where  1   was  the  most deprived  LSOA   and   32,482',
#  '1880  (Gulf Stream  flounder)  Citharichthys arenaceus Evermann   &   M.   C.   Marsh, ',
#  'at   the   house,   keeping  his   disguise. After  ',
#  'in  1724. He   married Anne   Anderson,',
#  'His  father, Nittoor  Shamanna,   was  a  school  teacher and   the  head  master of a',
#  "of the   battalion   mobilised to  relieve   the  beleaguered   'D'  Company,   a   patrol ",
#  'suspected  terror   suspects, including  that of  35-year-old ',
#  'marbles,  wooden animals and  a piece  from a  ',
#  'of   1843.   There  is   one post-primary   school   in Newcastle, Shimna Integrated ',
#  'and books.   Under the pen   name of   Jivan  Bhakar  ',
#  'reinsurance corporation traded  on   the New  York  Stock Exchange,  from 1992   until ',
#  'when the  sails   were   damaged   in a storm.   The swing-pot neck bearing was removed  ',
#  'to build up  a  charge, a glow  was  visible  if he  placed   his hand on   the outside  ',
#  'i:10.1016/S1364-6',
#  'training  teachers  for New Jersey  schools',
#  'in  one  zone.   Likewise,  the outermost',
#  'Rail system. The station is part',
#  "Murphy, Caroline  P.   Isabella  de'  Medici: The Glorious  Life and  ",
#  "the  Air  Force's investigation   into   the   green   fireballs  and",
#  'weight is just over  ',
#  'rise   of  the  Akkadian   Empire.  The   first king of ',
#  'Thornely.  Received a   500 prize   "offered   by Messrs.   Ricordi   &  Co. for   an ',
#  'my desk. As  I   drove  away,  I   was in  tears. It   had   been  my   life,   and I  ',
#  "worship   in   the town. John   Tillotson, 'The  people's  ",
#  'as   Future  Cop:   LAPD,   a  mech-based shooter   game.Fatima   Al  Qadiri,  a producer  ',
#  'Occupation until May  16, 1919,  when  he   sailed  for   the U.S.  He   was  assigned ',
#  'old.   Palur   is  a village  in  the Srirangam   taluk   of Tiruchirappalli   district ',
#  'Cathedral.On   16  March   2016 it  was  announced',
#  'woman  in   her   family to attend ',
#  'graphs  support   an   additional extension   of  RDF  semantics for formulae.  For the',
#  'narrow gauge railway  and  railway  exhibition  hall  devoted   to  British   industrial ',
#  'an   early  age  he  worked various   jobs   including  driving  a tractor,  milking cows,  ',
#  'wanted  her  to  be fluent in   English.  Her  younger   brother, Sverre   Magnus,   was ',
#  "good winners  including Rock City (Gimcrack Stakes),   Rafferty's ",
#  "'QuotedGraph'(_st",
#  'particularly innovative,  but praised   its open-ended gameplay,',
#  'it   back.   "I was   petrified,"  he would  later tell a   reporter,  "I   was   terrified." ',
#  'Intelligence Service (MI6) from 1944  to  1961.  For  his   employment  contract,  he ',
#  'the shares   in   the firm  to  the   public, receiving ',
#  '"Midnight Special"  (traditional) 2:45   "Beside   You"  6:05   "It\'s  All   Right" 4:58  ',
#  'Grosse also  made  appearances   in The Inheritance (2011), and ',
#  'safety  in 2011-12   and would go onto   lead  ',
#  'have   been  liable  as   a   fiduciary.   That  would   be   so  despite   the   fact ',
#  'Invitational was a  golf tournament   on the   LPGA  Tour  from  1965  to  1970.  It ',
#  'Oregon.   He was raised   in   a  single-parent home  ',
#  'things   up  on  the last  tour  during   the early  songs  in the   set.   I  just couldnt ',
#  'Short" had   the  distinction   in   1973 of ',
#  'Kopp, DFC, of  Mount Waverley,   Victoria. For public  service   in the field of   social ',
#  'Arte   Contemporneo,   Sevilla  Cincinnati Art  Museum,   Cincinnati,  Ohio   Coleccin ',
#  'character of  time;   the  historicity   of  reason;  the dialogical ',
#  "Wahl, as President   and Bill   Schultz,   Marvel's   Director of   Development, to  ",
#  '1867. His father, John   Naylor,  was organist of York  Minster.   He won a  choral  scholarship ',
#  'the   auctioneer  brought down his   hammer. ',
#  'co-production with   Electronic Arts)  Tom and Jerry:   The  Movie ',
#  'Devon  in 1911  at  the  age of  ',
#  'publication,  Jeff  Jensen stated that "Wildfire" was   a  commentary   on humanity, and  ',
#  'US government, and paid   his  salary during   his incarcerationdespite Federal  rules ',
#  'recognize   Jesus as king and  supreme lawgiver ',
#  "the   time was   against women   in politics, but  the Ladies'  Land League  was founded ",
#  'the  NHLRC1  gene  that ',
#  'severe  rheumatoid  arthritis) following   an incapacitated performance  at   one of',
#  'in studies that demonstrated   the  relevance   of neural  synchrony, in  particular of ',
#  "part  of  the Middle  East.   UNYOM's  commanders:  Major  General ",
#  'but played   in   the  first   three',
#  'manager, Ordnance  Factory Bendigo.  Laurence Stanley Mulhall,   of  Orange,',
#  'power  and   influence   within  the  Democratic   Party  ',
#  'Division. He  was  a   prominent  Canadian  international.',
#  'straight line east of  Baqubah.  It   was   first   located  by  Henri Pognon  in 1892',
#  'which  ought  to   be   returned or  transferred',
#  'and since   1999   musical   host on   "Folkemusikklubben  Columbi Egg"   in   Bergen.',
#  'Marlon   Ritter at   Soccerway  The   Alabama  State   Defense Force ',
#  'According to  Persian   inscription   on   mosque   Ibrahim',
#  'was supported   by  Mexican  conservatives  who resented the ',
#  'Lomaxes that  he   was  given   the name  because he   killed  three people   by  throwing',
#  'city, Canada is a  beautiful   country  and  if  I get the opportunity  I   will  decide',
#  'After controlling  for   FamaFrench   risk factors,  fundamentally based  indices exhibit  ',
#  "that took place   after   King's assassination.   Displeased with  what he   saw  as an",
#  'using anti-epileptic   drugs, the symptoms will  progress   and  patients lose  their  ',
#  'raid, during   which   they   went ',
#  'simpler  songs so  I   could play  them")  and   desire  to   see Young  "rockin\'  and  ',
#  'groups are  located   in the  area   including  ',
#  'dominated by  the  roots   rock  stylings of   Rick   and   Mike  Curtis, formerly of  ',
#  'attractive, strongly  colored,   thick  shells. The generic name Nodipecten',
#  'and  Betrayal.   Toronto: University   of Toronto  Press, 2007. ISBN 978-0-8020-9526-8.',
#  'helped  maintain  neutral buoyancy  once   the',
#  'In  1978, two  young  hikers,  while walking   on   Monte  Musin near   Turin,  saw  a  ',
#  'to save   cost, touch   times,   and the need  for mechanical fasteners. In   the   past,',
#  'Die Soziett  der   Mutter   Eva (Buttlarsche  Rotte)   und   der  ',
#  'Squire, OBE.   For services to  local government   in Mid-Glamorgan. Henry   George Stewart,  ',
#  'Brown, Honorary   British Consul, Nouakchott,  Mauritania.   Arthur Stanley  Bryant.',
#  "Gaviria, the   day   after   Colombian Minister   of   Justice  Rodrigo  Lara  Bonilla's",
#  'song   (written by  Sanger  D.  Shafer)   became   a  major  hit  on   the  Country  ',
#  "1980,  1982Women's   outdoor  track   &   field   2013Men's   cross   country  1928, 1947, ",
#  '7" "Independent   Type /  Joint of   Lamb" Split  ',
#  'just   received from Herbert  Samuel  a  ',
#  'October, she  escorted  troop   transports  in  the  Baltic.  She then   returned  to  ',
#  'Sundance Film Festival. The film  received  almost  unanimous   critical   praise  and  ',
#  'Makohe,   and  in   his   reaching   Patagonia,  Johnson meeting  with Chouinard and  ',
#  'Ontario),   and   New York air traffic  control centres;   to ',
#  '(or  NiCl2-glyme)   is   used due to ',
#  'time he   worked  in   the  field   of youth  pastoral   care for  the   Claretian  province ',
#  'years   in   the position. Scaffidi and   the  rest   of  the City of Perth council were',
#  'in the   fall  of 1972   with a   view  ',
#  'refers  to   "Burra"  -  eel   and   "matta" - creek.',
#  'Avon and  an 82  kW',
#  '(R)/Grover Jackson (where   "Jackson"   is   large  toothpaste logo',
#  'of   study is   the   art   of   the   medieval  and Renaissance periods.  She has a  ',
#  'including   Roger  Waters  who  acted   as  narrator   to ',
#  'American  Buildings Survey  (2005), No.  HABS DC-857 http://www.ww1cc.org/memorial  U.S.',
#  'of back-tested  Indices  weighted  by any of   several  fundamental',
#  '12.   The school is   operated  by the  New   South Wales   Department  of   Education; ',
#  "collar,  the corpus  from Tolton's ",
#  'is located at  752 Bluffview   Circle,   with   its   other  sister',
#  'extracted   and processed   for lime   on site  for ',
#  'BSF  constable   was killed in an  accident   while retaliating  to fire by Pakistani  ',
#  'killed   and   three  others   wounded   in  Indian  shelling of Badwal post  in Charwah  ',
#  'were   married  couples  living   together,  7.4%   had a  female  householder   with ',
#  'has  the duty   to legislate   in  conformity   with   Gods',
#  'Fire Engineers. Margaret Lydia  Rankin, Secretary,   Vic-Wells   Association.   Wilfred',
#  '(Colombia)   Odontoglossum  gramazuense   D.E.Benn. & Christenson, 2001   (Peru)  Odontoglossum',
#  'During October   2014 it  was   announced   the  second  contingent   had been in  isolation ',
#  'welcomed  the   advent of the African  Union',
#  'settlement   of Witherington.   The   Trafalgar   Park   estate   erased ',
#  'Professional  and Technology Officer  Grade  II, Ministry  of Defence. Rowland   Waite,  ',
#  'MegaTech magazine  praised  the  graphics and   gameplay, ',
#  'It   has  eight  compulsory  subjects: systems analysis,  programming,   computer organisation,  ',
#  'nickname Clear  Rock. He told   the ',
#  "Donald   L.  O'Toole.   In July  1944, ",
#  'for adoption   when   he   was a  baby,   and she proceeds to call him  Shane, the  name',
#  'others,  with diglyme showing increased  solubility.   Empirically,   NiBr2-glyme   has',
#  'music   within the choir  which  included  among others   the   young  Luciano Pavarotti. ',
#  'General   entertainment channels   were  below  20  which   included  ',
#  'elements   of 6   RAR   were deployed to  Timor',
#  'College   Art Gallery.  Reading was a   notable   organist,   composer   and teacher,',
#  'Perez weighed   in at 126.5   pounds, ',
#  'Vienna,  Austria and   worked   in the  paleontology department',
#  'the  replacement   engineer. She',
#  '-  Sousaphone,  Sam Spoons  -   Drums,   "Evil   John"   Gieves  Watson ',
#  'announced the   2010   calendar  in   co-ordinance with  the FIA   GT1   World  Championship. ',
#  "the Devil's  Toybox. After  interrogating   several   suspects, ",
#  'the family   Gyrodactylidae.   It   is reported parasiting  the golden shiner  (Notemigonus',
#  'string)  already  exists   or   that  there   is   no  ',
#  'inside of   the  room   was   doubly   secluded,  with  an  ancient ramp   leading   visitors',
#  'Football   League   1950s All-Decade  Team  not yet   inducted in the  Pro   Football',
#  "of   the First  World  War. The   company's  formal  establishment",
#  'with  distinctions  in   English  and   Urdu   in  ',
#  "School, founded in  1962,  and   St.  Joseph's Primary ",
#  'their mantelpieces   had  flat,  fluted   supports.  There  ',
#  'Garca lvarez  de   Toledo, 4th  Marquis   of   Villafranca,  Duke   of   Fernandina. ',
#  'Robert  Skelly  218  David   Stupich 147  Margaret Birrell 134Birrell  ',
#  'Borough Council   election  1986 Barrow-in-Furness   Borough Council election 1987  Barrow-in-Furness  ',
#  'South Camac   Street.   He operated  this  studio   for  the  remainder  of his   life,',
#  'when   he was retired. Jan ',
# ...
#  'Jerzy  (George)  Zubrzycki,  MBE,   of   Yarralumla, Australian Capital  ',
#  'had  to maintain  a  very   high ',
#  'are   near',
#  'of  Industry. Maurice ',
#  'sometimes  from  multiple  sites.   These  have   included  military ',
#  'Centre  that occupies  that whole   block  and  is   thus located  in the cultural  precinct.',
#  'Allied   Trades  and  Technicians.   Robert   Vincent  Hughes,  lately',
#  'improvements,   including video cameras   in squad   cars   to increase   accountability  ',
#  'University   of   Health  Sciences   (KUHS) 2011One   year   Post Basic Diploma  Programmes  ',
#  'the  help   of  forces loyal to  the Somali  government.  17 March   Six  AU soldiers',
#  'and other TV   programs. On  October  24, 2011,  the Wounded   Bird label reissued the  ',
#  'Inn,  to   award  damages  when   declining to  grant equitable  relief   rather than, ',
#  'titled "Another Swansea  Poet"   broadcast   in 2019.   He was born   in  Swansea and ',
#  'O 9-class   submarine   consisted   of   three   submarines,  built for   the  Royal Netherlands',
#  'switch  to  ISO 160  when   under Auto  ',
#  'Trump and   his  participation   in the  state',
#  "also assassinated  in June   1968,  thus   hurting  Daley's earlier   plan to  make  Johnson,  ",
#  'Medici  heir in  this  generation   until  his   death   three  years   later,  in August',
#  'asoma  I Afrodites   trdgrd   (2008)  The website   of ',
#  '31   August   2019,  Ingrid   Alexandra was   confirmed  in ',
#  'as   well as  a  power   plant.   According ',
#  'in Vienna on 30   October  1930),   which  became   known',
#  'It  nests  in   a hole   in a dead  tree',
#  'in  a primer solution  and   cured. ',
#  'for Advanced  Studies  (SISSA), and  at the  Abdus   Salam International  Centre   for ',
#  'animation   cels. Around this time,   Sullivan   Bluth was   contracted  by Hanna-Barbera ',
#  '"ObamaCare   Facts" page   explicitly   states  that   "Plans  aren\'t   required to cover ',
#  'in   2007,   of   a   unique   high   altitude   site ',
#  'six  other  first-class  matches. The manager   was  Neil  ',
#  'is  a   charter member of   the   Mid-America   Intercollegiate  Athletics',
#  'tournament   at  Holmenkollen in Oslo.On   4   May   2015,',
#  'to  the Tower Hamlets Rifles and  9th   &  10th  Battalions,   The   Rifle  Brigade  ',
#  'that   is  outside  the Alpine  areas.',
#  'was 81   when he died of cancer   on  ',
#  'is   similar   to  that of   venture   capital  investors.   Capital is used   for  company',
#  'Cricket   Club committee and  took charge of the  ',
#  'Woodfalls were taken   to  form  a new   civil parish.  Finally,  in   1934  Standlynch',
#  'interior,   construction  in 19551956 added  a dining room  and   three meeting rooms. ',
#  'micron   range.   They  are   a  6  on ',
#  'Consortium.   Lieutenant   Colonel  Andrew  Jardine,  Chairman,  Hounslow,   Hammersmith  ',
#  'as  a   computer program. Walker,   Adrian. "Understandability and  Semantic   Interoperability  ',
#  'solo   shows at   the end  of   2016, Kazoopa   Festival,   Leeds  in   November   and',
#  'son   of  the  Rev.  William Fausset ',
#  'Phill Marr   and  directed   by  Mastorakis,  starring   Nastassja   Kinski,   Nicollette ',
#  'bufferbloat   which  has  its  own  impact   on   latency and ',
#  'Publication   Society   of  America.  pp.  81.  ISBN 978-0-8276-0083-6.   Huneidi,   Sahar',
#  'DeStefano,  took over  the head  coaching duties of  the St. ',
#  'in  their  area of   operations had been   so badly   weakened that  they were  forced ',
#  'which by  performance, aerodynamic  characteristics, or   unusual  features,',
#  "throttle  wireless networks even when they aren't",
#  'to  marry?" He   writes,  "You   reach your limit',
#  'have been   responsible for the   introduction   of   merino  sheep into  Victoria (of',
#  'hostages and   capture enemy  personnel,  while managing  supplies   of   fuel  and ammunition. ',
#  'it was stipulated  that   clubs and   representative   teams  of   the Football  Federation  ',
#  'Freeview television service.  Igloo was founded  ',
#  'questions.   The Mystical Life   of  Jesus A   retelling of',
#  'Kumluca,  Antalya Province, Turkey.   The Delta   Upsilon Chapter   House   is  a  historic',
#  'No Mercy (1977). Following  the  commercial failure  of Crazy  Horse,   Lofgren   and ',
#  'International   Centre  for   Theoretical  Physics the  ICTP  Condensed   Matter  Theory  ',
#  'of Her  Royal Highness  Princess  Ingrid Alexandra Firmino ',
#  'elections".   Election Commission   of India. Archived  from   the  original  ',
#  'will be   the  7th  FIM   Team   Under-21 World Championship  season.  The Final  took  ',
#  'route, taking   convoys   to  and   from Freetown in Sierra   Leone.  In January 1942  ',
#  'Army Air Corps  as a  journalist,   attaining  the   rank  of  major. When the  war was  ',
#  'On   April 15,  2010, game  developer   Valve  announced  ',
#  'the   attack,   it  was  immediately sealed   off.   Of  the  device causing the   explosion,  ',
#  "marmoset  is   one   of the  world's   smallest ",
#  'Concert itself has  not been   cleaned.  It ',
#  'one   using an automatic   weapon, fired   indiscriminately into   5  Lawford Street, ',
#  'had  been  re-roled   as an infantry   company.  Elements of   6  RAR  have  deployed ',
#  'and  the  subsequent election   of son   Richard  as  mayor   in   1989, the first Mayor  ',
#  'It   is not transparent.  And it  is not replicable.   Fundamentally based   indices are ',
#  'electric car segment  grew   from 0.03% in ',
#  'of Defence.  Mabel  Pauline Hall. For  services to  the  ',
#  'but a  poor run   of  form  ',
#  'referred   to  as simply  KU or  Kansas,   are ',
#  'Attorney-General, Amanda   Vanstone became Immigration Minister   and  Tony Abbott   became',
#  'Miles   Davis,   Thelonious Monk, Wayne  Shorter   and  Charles',
#  'the  Galpagos   Marine Reserve   is the   largest  marine reserve in a developing country',
#  'Beni   causes  widespread flooding   and damage  ',
#  'mid-20th Century.  1:  A-K.   New   York,   NY:  Routledge. ISBN  0-415-92039-6. Emmanuel ',
#  'side  missions in  addition to main   objectives.',
#  'attacked   the rear   guards of   the   Frankish   army   on their',
#  'music.  The  vision for  the   band   was   conceived  in  1997   when  Ahmad Jones  ',
#  'de  las  Heras   Berzal joined  the  Missionary Sons of  the Immaculate   Heart   of ',
#  '1989. Ulf-Michael  Schneider: Propheten  der Goethezeit.   Sprache,  Literatur  und  ',
#  'significant   social   progress  or acknowledge  the   suffering   of  ',
#  'mandate  by  arts  and   crafts retailer, Hobby',
#  'Champlain initiated  the  first   important French involvement in ',
#  '-Players  in  bold   are   currently  playing  for  Bosnia   and Herzegovina  -Last  ',
#  'pets,  a  baby   pygmy marmoset   needs to be  ',
#  'was   mistakenly  registered  as  "Merbein"   instead. The  ',
#  '-  configured  for   diving,  or   as a  work',
#  'Donovan  to   the   San  Diego   Sockers, Jermaine Jones to  the  Ontario  Fury,   and',
#  'Xiomara   Larios.  She  was  re-elected  in December  2012.   FNA   was founded in   1954. ',
#  'Funtastic  World  of   Hanna-Barbera ride  at   Universal   Studios Florida.In January',
#  'the especially  radical pietism in Kierkegaard,   especially  in his critique   of Hegel.  ',
#  "Vienna's  judiciary   and  close   friend  of Gustav",
#  'https://www.fdb.cz/lidi-',
#  'brownish-yellow, with  a   dark  stripe   running   from',
#  'Services  Commission.  John Rankin   Christie,  lately   Deputy  Master  and',
#  'Davey   retained  the residue   and   the  resultant allotment   of Roseneath  ',
#  'of  those services.   This  distinction  ',
#  'their   home  games at The   Pilot Field  since  ',
#  'To   the   south it is about',
#  'that   are  facing  this  nation",   for  which  some  in  the  crowd   booed  Ribicoff. ',
#  'Gen.   Andrew  Jackson Lorne   Greene   as  Mercier   Ted   de Corsia   as Capt.   Rumbo  ',
#  '1931  to work at the Natural History  Museum (German:  Naturhistorisches   Museum) in',
#  '"Jayhawks"   comes from  the  Kansas   Jayhawker   freedom fighter   and   pro-Unionist  ',
#  'Taylorsville.  It   was  the moving   of   the ',
#  'to  some reports   the base,  manned  by',
#  'quarterly,   which   came  to  fruition   and  was ',
#  'Freemen   of   the City  of Newcastle  upon  Tyne. Margaret ',
#  'the initial  Ugandan   AMISOM contingent of   400  soldiers   who   had   arrived  several',
#  'of   an  RDF graph is the   set of  ',
#  'they   are   regularly   poisoned,   trapped  or   hunted by trout  fly-fishing   resorts ',
#  'extra   innings  victory  over  ',
#  'refused;  then,  on  October ',
#  'Association  (13) 1908, 1909,  1910,  1911,   1912,  1914, 1915,  1922,   1923, 1924,  ',
#  '2021.   In   2020, Michael Harrison,   ( Publisher,   Talkers.Com,  and   a   legendary ',
#  "at   Post  War English   &  Scottish  Football   League   AZ Player's ",
#  'website   Taylorsville  Chamber of  Commerce  Growth  capital (also   called expansion',
#  'attack  on government forces. On 1 ',
#  "Valium.After  Whitten's  death  and  the  tepid  reception   accorded  to both  albums,  ",
#  'USA.  Grove Township   was established   in 1870.   The Cayo  Agua Formation is  a  geologic  ',
#  'on September 22, 2009.  ',
#  'culling  of   coated  pups  from litters to  maintain  ',
#  'Timothy Miles  (4232415).  Royal  Air   ForceL4141822 Flight Sergeant   David  Ross. ',
#  'Mad  Henry   Davis  Clive  Fenton  Tim   Phillips  Fred',
#  '(amongst   others  in Tallinn,  Estonia). New  Techniques for  the   Bass Clarinet   (www.shoepair.com), ',
#  'Keep   It   To  Yourself   is  the debut   album  by MullMuzzler (a band  formed by Dream',
#  'his new  deputy,  fellow  "ginger   group" member  Angus Innes,  made their way to Bjelke-Petersen\'s  ',
#  'Air Commodore  David   McLagan   Scrimgeour, . Acting  Air   Commodore   Norman   Jackson, ',
#  'form   Sullivan  Studios   (later   becoming   Sullivan Bluth   Studios).  Moving out  ',
#  'food  packets  and old  cigarette butts,   confirming the  presence of militia in the',
#  'with  the impression  ',
#  'to the  mainland   via a   passenger  ferry service ',
#  'laid for  the existing  hospital   the   Pretoria',
#  'judges for whom   the attainment   of   practical justice   was a   major objective of  ',
#  'Anna   felt  stifled by upper  class   society   rules imposed  upon  her.   She   was ',
#  'transfer saga   came  to  an  end as   Vancouver  received   a  then   club  record  $2.1 ',
#  'From   1687  to 1703,  he   may have  ',
#  "Trampolene's   appearance  at   BBC Music's  Biggest  Weekend",
#  'a   browser,  there is   no  program  that  can ',
#  'Academy of Film and Television  Arts. John   Edward',
#  'of unnecessary  violence  in the  apprehension   of the Blues Brothers has been   approved"  ',
#  "St   John's beat Kentucky,   6457.   They   later  ",
#  'San Francisco on  Lorna  Records  (a subsidiary   of Autumn   Records);   however,   it',
#  'versus West   Ham   United,   require  replays   after ending in',
#  'of  ceasefire  violation.On 4 December,   a   Pakistani  soldier  was killed as   result',
#  'days after  the  first  match   at Old Trafford ended   in a  goalless draw.   11 January ',
#  'sanjuanensis is believed  to  be endemic  to the upper  San Juan River   in Colombia.  ',
#  'Division,',
#  'the  first   day on 163 for   1. It  rained   overnight and  Muddiah   took  six   wickets ',
#  'awareness".   Trends   in  Cognitive  Sciences.   5  (1): 1625. PMID  ',
#  'appearance and  it was  5846 loss to   the',
#  'change   from Shenyang  Institute of  Aeronautical   Engineering   (SYIAE)  to   Shenyang',
#  '16   in downtown  Strawn,   and   travels   east   out of   town on Housley   Street. ',
#  'December 6, 2018. Claude Jean   Migeon (1923   March 4,  2018)  ',
#  'a  second-team   All-American pick by   the International  News  ',
#  'Bench,  near   the   lower   end  of  Boulder   Creek',
#  'Migeon became   the  sole director   when  Blizzard   left in  1974,  and  held   the  ',
#  'Fisherman,  Crown   Estate  Commissioners.  John  Martin   Camm,  Supervisor,   Aero Engine  ',
#  'and   is   3   miles   (4.8  km)  west of  ',
#  'of UFOs,  including   astronaut   Gordon   Cooper and   a Brigadier General.In 2007, ',
#  'the  Web   of   Days   (2004),  and   A  Rose   From   Old   Terra (2007); and  dark  ',
#  'Janette Hill  Knox (Wahpeton).   Alma   Lutz  (Jamestown).  Emma   Murray  ',
#  'ref   duplicates   default (link)   The Norwegian  Union  of  ',
#  "(insects   in  the family Mydidae). The Kosovo  women's   national   under-19   football ",
#  'M.A.   in 1846,  proceeding  B.D.   and   D.D.  in 1886.On  ',
#  'by David North,   Part  1  (1991)',
#  'Gordon  Allen, General   Manager,   Covent Garden   Market   Authority. William   Alwyn,  ',
#  'ended up  losing 3644. The 1951  ',
#  'Van.   After  finding footage   of the 1968   expedition,   Johnson decided to   make  ',
#  'Scottish  Rugby  Union. Charles Harry   Lawrence,  MBE,   Director,  James Purdey ',
#  'of up  to $8,000   beginning on   January  1,  2012,   for  the purchase of   new   plug-in  ',
#  'and   Campus   Martius,  which were   the   largest  and   richest   in the Roman world.  ',
#  ".  On Nov. 22,  1898,  Fullon's   forces  captured   San   Jose ",
#  'and abroad)  to   participate   and   witness  the  events. It',
#  'and the Premo-Porretta Power   Poll as   national ',
#  'enemy weapons and   installations. These critics   considered   the ',
#  'the   dying   stages of  the match  and  scored',
#  "and   The   Hills Have  Eyes. Band  Website BBC's   review  of  Howl  On   The  Haunted  ",
#  'Upland Management  Officer, Lake District   Special   Planning  Board.   Thomas  Douglas',
#  'Desert  Strike a year   after the ',
#  'the  approval of   the United  Nations  Security   Council. ',
#  'if   a  user wanted to send one letter  to',
#  'Clement  retired   to   his   home  in Rosemont, Pennsylvania,  where he   died  on August  ',
#  'and  butterflies.   Delphinium  scopulorum  is   heat tolerant   and   deer  resistant.  ',
#  'posts  along the Line   of Control   (LoC)  in Rajouri ',
#  'Best   International Act   at the  2018 BET Awards.   He is  currently considered one',
#  'leadership in the   Archdiocese   of  Chicago. The Father ',
#  'Anselm   ("Anshelmus"),  Count   Palatine; and Roland ("Hruodlandus"),  Governor',
#  'Adrian  Partington (507343).   Squadron   Leader  William  Stanley  Price   (2434688). ',
#  'the  richest  families in   Europe   and allowed   her   to remain   at   a  court  where ',
#  'and  Drink Machinery  Sector  Working  Party.  Professor   Patrick  Joseph   Lawther,  ',
#  'Battalion.  Returned   home in   November  2015;   replaced   by 35',
#  'the  newly   acquired Sports   and   Social   Club,  such  ',
#  'Gas   Corporation. Elizabeth Hassells. For   services to the  community   in   Market ',
#  'fact that  by   entering into   a new and more profitable   contract   the  defendant ',
#  'which enables   you   to  set  manual shutter ',
#  'Barker   as Clara (uncredited)   Joby Blanshard   as Health  Inspector   Matthews  (uncredited)',
#  'generation  facility  to the   dam,',
#  '(Snellen,   1895)   Cnaphalocrocis trapezalis ',
#  'excluding   critical   voices.  In   2008   Vuolasranta  was  forced   to  pay  a  fine  ',
#  'the  viceroyal   family of Toledo,   a   marriage   was  arranged  between  Leonora  and',
#  'Prices  range from   $1,000   to   $4,000.',
#  'Creek   The   Curse of  the Bronze Lamp  ',
#  'Works  ',
#  'players   squad  numbers,   playing positions, nationalities   and  statistics   are based',
#  '(played by  Mollie  Sugden)  who   turns out   to  ',
#  'V0685502   Chief  Technician  Roger  Henry  Harris,   Royal Air Force.  William   Hudson.  ',
#  'retained during  the   export   process.  List  of word   processors Comparison  of word  ',
#  'shelling by Pakistan. She   was reported  to   have',
#  "of  a  company's intrinsic  value,   rather than  the listed market value   of",
#  "John's  because he   reached   the mandatory  ",
#  ...]

# %% [markdown]
# # Split data #

# %%
train_split = int(0.9 * len(dataset))
val_split = int(train_split + 0.09 * len(dataset))
# test_split = int(train_split + 0.1 * len(dataset))

train_labels = dataset[:train_split]
val_labels = dataset[train_split:val_split]
test_labels = dataset[val_split:]

# val_labels = dataset[train_split:val_split]
# test_labels = dataset[val_split:]

print('Len train: ' + str(len(train_labels)))
print('Len val: ' + str(len(val_labels)))
print('Len test: ' + str(len(test_labels)))
# Out:
# Len train: 31304
# Len val: 3130
# Len test: 349

# %% [markdown]
# # Model #

# %%
timesteps = 256

width = 4096
height = 64

max_label_len = longest_label + 2
max_label_len
# Out:
# 118

# %%
from tensorflow.keras import applications, backend as K
from tensorflow.keras import models, losses, optimizers, Model, utils
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, MaxPooling2D, Dropout
from tensorflow.keras.layers import Flatten, Dense, Lambda, Reshape, Bidirectional, LSTM, GRU
from tensorflow.keras.layers import Activation, add, concatenate

def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

def build_model(num_classes=94, timesteps=256, max_label_len=max_label_len, input_shape=(4096, 64, 1), training=False):
    inputs = Input(name='the_inputs', shape=input_shape, dtype='float32')
    
    # Convolution layer (VGG)
    inner = Conv2D(32, (3, 3), padding='same', name='conv1-1', kernel_initializer='he_normal')(inputs)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(32, (3, 3), padding='same', name='conv1-2', kernel_initializer='he_normal')(inputs)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(2, 2), name='max1')(inner)

    inner = Conv2D(64, (3, 3), padding='same', name='conv2-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(64, (3, 3), padding='same', name='conv2-2', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(2, 2), name='max2')(inner)

    inner = Conv2D(128, (3, 3), padding='same', name='conv3-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(128, (3, 3), padding='same', name='conv3-2', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(4, 2), name='max3')(inner)

    inner = Conv2D(256, (3, 3), padding='same', name='conv4-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(256, (3, 3), padding='same', name='conv4-2')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(1, 2), name='max4')(inner)

    inner = Conv2D(512, (2, 2), padding='same', kernel_initializer='he_normal', name='con5-1')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(512, (2, 2), padding='same', kernel_initializer='he_normal', name='con5-2')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)

    # CNN to RNN
    inner = Reshape(target_shape=((timesteps, 2048)), name='reshape')(inner)
    inner = Dense(64, activation='relu', kernel_initializer='he_normal', name='dense1')(inner)

    # RNN
    gru1 = Bidirectional(GRU(512, return_sequences=True, kernel_initializer='he_normal'))(inner)
    lstm1 = Bidirectional(LSTM(512, return_sequences=True, kernel_initializer='he_normal', 
                               name='lstm1'))(inner)
    
    gru2 = Bidirectional(GRU(256, return_sequences=True, kernel_initializer='he_normal'))(lstm1)
    lstm2 = Bidirectional(LSTM(256, return_sequences=True, kernel_initializer='he_normal', 
                               name='lstm2'))(gru1)
    
    lstm_block = concatenate([lstm1, lstm2])
    gru_block = concatenate([gru1, gru2])
    rnn_out = concatenate([lstm_block, gru_block])

    # RNN output -> character activations:
    outer = Dense(num_classes + 1, kernel_initializer='he_normal', name='dense2')(rnn_out)
    y_pred = Activation('softmax', name='softmax')(outer)

    labels = Input(name='the_labels', shape=[max_label_len], dtype='float32')
    input_length = Input(name='input_length', shape=[1], dtype='int64')
    label_length = Input(name='label_length', shape=[1], dtype='int64')

    # Keras doesn't currently support loss funcs with extra parameters
    # so CTC loss is implemented in a lambda layer
    loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([y_pred, labels, input_length, label_length]) #(None, 1)
    
    y_func = K.function([inputs], [y_pred])
    if training:
        return Model(inputs=[inputs, labels, input_length, label_length], outputs=loss_out), y_func
    else:
        return Model(inputs=[inputs], outputs=y_pred)

# %%
model, y_func = build_model(timesteps=timesteps, max_label_len=max_label_len, training=True)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_inputs (InputLayer)         [(None, 4096, 64, 1) 0
# __________________________________________________________________________________________________
# conv1-2 (Conv2D)                (None, 4096, 64, 32) 320         the_inputs[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 4096, 64, 32) 128         conv1-2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 4096, 64, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max1 (MaxPooling2D)             (None, 2048, 32, 32) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2-1 (Conv2D)                (None, 2048, 32, 64) 18496       max1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 2048, 32, 64) 256         conv2-1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 2048, 32, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2-2 (Conv2D)                (None, 2048, 32, 64) 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 2048, 32, 64) 256         conv2-2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 2048, 32, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max2 (MaxPooling2D)             (None, 1024, 16, 64) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv3-1 (Conv2D)                (None, 1024, 16, 128 73856       max2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1024, 16, 128 512         conv3-1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1024, 16, 128 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv3-2 (Conv2D)                (None, 1024, 16, 128 147584      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 1024, 16, 128 512         conv3-2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1024, 16, 128 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max3 (MaxPooling2D)             (None, 256, 8, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv4-1 (Conv2D)                (None, 256, 8, 256)  295168      max3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 256, 8, 256)  1024        conv4-1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 256, 8, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv4-2 (Conv2D)                (None, 256, 8, 256)  590080      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 256, 8, 256)  1024        conv4-2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 256, 8, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max4 (MaxPooling2D)             (None, 256, 4, 256)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# con5-1 (Conv2D)                 (None, 256, 4, 512)  524800      max4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 256, 4, 512)  2048        con5-1[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256, 4, 512)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# con5-2 (Conv2D)                 (None, 256, 4, 512)  1049088     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 256, 4, 512)  2048        con5-2[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 256, 4, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 256, 2048)    0           activation_9[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 256, 64)      131136      reshape[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 256, 1024)    2363392     dense1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 256, 1024)    1775616     dense1[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 256, 512)     2623488     bidirectional[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 256, 512)     1969152     bidirectional_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 256, 1536)    0           bidirectional_1[0][0]
#                                                                  bidirectional_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256, 1536)    0           bidirectional[0][0]
#                                                                  bidirectional_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 3072)    0           concatenate[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 256, 95)      291935      concatenate_2[0][0]
# __________________________________________________________________________________________________
# softmax (Activation)            (None, 256, 95)      0           dense2[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         [(None, 118)]        0
# __________________________________________________________________________________________________
# input_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# label_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           softmax[0][0]
#                                                                  the_labels[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 11,898,847
# Trainable params: 11,894,943
# Non-trainable params: 3,904
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

plot_model(model=model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %% [markdown]
# # Data generator #

# %%
import itertools

def return_classes(string):
    text = [' '] + list(string) + [' ']
    classes = [data.index(x) if x in data else 1 for x in text]
    return np.asarray(classes)

def return_text(classes):
    text = ''
    for c in classes:
        if 0 <= c < len(data) and c != 1:
            text += data[c]
    return text

def decode_batch(out, callback=False):
    ret = []
    for i in range(out.shape[0]):
        out_best = list(np.argmax(out[i, 2:], 1))
        out_best2 = [k for k, g in itertools.groupby(out_best)]
        outstr = return_text(out_best2)
        if callback:
            print(f'{out_best} -> {outstr}')
        ret.append(outstr)
    return ret

def gen_text_image(text, padding=16):
    font = random.choice(fonts)
    font_size = random.randrange(30, 61)
    fnt = ImageFont.truetype(font, font_size)
    width, _ = fnt.getsize(text)
    img = Image.new('L', (width + (padding + 1) * 2, 64), color=255)
    d = ImageDraw.Draw(img)

    if 'calibri' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'verdana' in font:
        d.text((padding + 2,-8), text, font=fnt, fill=0)
    elif 'constan' in font:
        d.text((padding + 2,0), text, font=fnt, fill=0)
    elif 'corbel' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'consola' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'cour' in font:
        d.text((padding + 2,-4), text, font=fnt, fill=0)
    elif 'tahoma' in font:
        d.text((padding + 2,-8), text, font=fnt, fill=0)
    else:
        d.text((padding + 2,-6), text, font=fnt, fill=0)
        
    image = np.array(img)
    image = add_salt_and_pepper(image, 0.2)
    image = otsu_thresholding(image)
    image = inverse(image)
    image = (image / 255.) * 2. - 1.
    return image

def inverse(image):
    return cv2.bitwise_not(image)

def add_salt_and_pepper(image, amount):
    output = np.copy(np.array(image))
    # add salt
    nb_salt = np.ceil(amount * output.size * 0.5)
    coords = [np.random.randint(0, i - 1, int(nb_salt)) for i in output.shape]
    output[coords] = random.randint(50,200)

    # add pepper
    nb_pepper = np.ceil(amount * output.size * 0.5)
    coords = [np.random.randint(0, i - 1, int(nb_pepper)) for i in output.shape]
    output[coords] = random.randint(0,100)
    return np.asarray(Image.fromarray(output))

# %%
class TextImageGenerator:
    def __init__(self, labels, img_w=4096, img_h=64,
                 batch_size=64, timesteps=500, training=True, max_text_len=max_label_len):
        self.dim = (img_w, img_h, 1)
        self.batch_size = batch_size
        self.max_text_len = max_text_len
        self.labels = labels
        self.n = len(self.labels)
        self.indexes = list(range(self.n))
        self.training = training
        self.cur_index = 0
        
    def next_sample(self):
        self.cur_index += 1
        if self.cur_index >= self.n:
            self.cur_index = 0
            random.shuffle(self.indexes)
        return self.labels[self.indexes[self.cur_index]]
            
    
    def next_batch(self):
        while True:
            X = np.zeros((self.batch_size, *self.dim))
            y = np.zeros((self.batch_size, self.max_text_len), dtype=int)
            input_length = np.full((self.batch_size, 1), timesteps, dtype=np.float32)
            label_length = np.zeros((self.batch_size, 1), dtype=np.float32)
            
            for i in range(self.batch_size):
                label = self.next_sample()
                # Store sample
                image = np.swapaxes(gen_text_image(label), 0, 1)
                image = np.expand_dims(image, -1)
                X[i, 0:image.shape[0], :] = image

                # Store class
                label_classes = return_classes(label)
                y[i, :len(label_classes)] = label_classes
                label_length[i] = len(label_classes)

            inputs = {
                'the_inputs': X,  # (bs, 2000, 64, 1)
                'the_labels': y,  # (bs, 51)
                'input_length': input_length,  # (bs, 1)
                'label_length': label_length  # (bs, 1)
            }
            outputs = {'ctc': np.zeros([self.batch_size])}   # (bs, 1)
            yield (inputs, outputs)

# %% [markdown]
# # Callbacks #

# %%
import editdistance
from datetime import datetime
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.callbacks import TensorBoard, ReduceLROnPlateau, Callback

class VizCallback(Callback):
    def __init__(self, y_func, text_img_gen, text_size, num_display_words=10):
        self.y_func = y_func
        self.text_img_gen = text_img_gen
        self.num_display_words = num_display_words
        self.text_size = text_size

    def show_edit_distance(self, num):
        num_left = num
        mean_norm_ed = 0.0
        mean_ed = 0.0
        while num_left > 0:
            word_batch = next(self.text_img_gen.next_batch())[0]
            num_proc = min(word_batch['the_inputs'].shape[0], num_left)
            # predict
            inputs = word_batch['the_inputs'][0:num_proc]
            pred = self.y_func([inputs])[0]
            decoded_res = decode_batch(pred)
            # label
            labels = word_batch['the_labels'][:num_proc].astype(np.int32)
            labels = [return_text(label) for label in labels]
            
            for j in range(num_proc):
                edit_dist = editdistance.eval(decoded_res[j], labels[j])
                mean_ed += float(edit_dist)
                mean_norm_ed += float(edit_dist) / len(labels[j])

            num_left -= num_proc
        mean_norm_ed = mean_norm_ed / num
        mean_ed = mean_ed / num
        print('\nOut of %d samples: \nMean edit distance:'
              '%.3f \nMean normalized edit distance: %0.3f \n'
              % (num, mean_ed, mean_norm_ed))

    def on_epoch_end(self, epoch, logs={}):
        batch = next(self.text_img_gen.next_batch())[0]
        inputs = batch['the_inputs'][:self.num_display_words]
        labels = batch['the_labels'][:self.num_display_words].astype(np.int32)
        labels = [return_text(label) for label in labels]
         
        pred = self.y_func([inputs])[0]
        pred_texts = decode_batch(pred)
        
        for i in range(min(self.num_display_words, len(inputs))):
            print("label: {} - predict: {}".format(labels[i], pred_texts[i]))

        self.show_edit_distance(self.text_size)

# %%
batch_size = 16
train_generator = TextImageGenerator(train_labels, training=True, batch_size=batch_size)
val_generator = TextImageGenerator(val_labels, training=False, batch_size=batch_size)
test_generator = TextImageGenerator(test_labels, training=False, batch_size=batch_size)

log_dir = "logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
output_dir = './models/VGG'
weight_path = f'{output_dir}/ocr_model_{datetime.now().strftime("%Y%m%d-%H%M%S")}' + '_epoch_{epoch:02d}.h5'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

tensorboard = TensorBoard(log_dir=log_dir)
checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
vis = VizCallback(y_func, test_generator, len(test_labels))
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='min')

initial_learning_rate = 0.001
epochs = 100

callbacks = [early_stop, tensorboard, vis, checkpoint]
# callbacks = [early_stop, tensorboard, vis, LearningRateScheduler(lr_time_based_decay, verbose=1)]

# %% [markdown]
# # Training #

# %%
def train(callbacks, batch_size, epochs, initial_epoch=0):
    print('Training process starting...')
    H = model.fit(train_generator.next_batch(),
                  steps_per_epoch=train_len//batch_size,
                  validation_data=val_generator.next_batch(),
                  validation_steps=val_len//batch_size,
                  epochs=epochs, 
                  initial_epoch=initial_epoch,
                  callbacks=callbacks,
                  verbose=1)
    return H

# %%
train_len = len(train_labels)
val_len = len(val_labels)

# %%
from tensorflow.keras import optimizers

opt = optimizers.Adam(learning_rate=initial_learning_rate)

# %%
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer='adam')

train(callbacks, batch_size, epochs)
# Out:
# Training process starting...
# C:\Users\lukas\AppData\Local\Temp/ipykernel_9392/3188806586.py:66: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   output[coords] = random.randint(50,200)
# C:\Users\lukas\AppData\Local\Temp/ipykernel_9392/3188806586.py:71: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   output[coords] = random.randint(0,100)
# Epoch 1/100
#    6/1956 [..............................] - ETA: 19:14 - loss: 436.9456WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2195s vs `on_train_batch_end` time: 0.3104s). Check your callbacks.
#   90/1956 [>.............................] - ETA: 15:45 - loss: 238.0054
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9392/4115887673.py in <module>
#       1 model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer='adam')
#       2
# ----> 3 train(callbacks, batch_size, epochs)
#
# ~\AppData\Local\Temp/ipykernel_9392/1605591345.py in train(callbacks, batch_size, epochs, initial_epoch)
#       1 def train(callbacks, batch_size, epochs, initial_epoch=0):
#       2     print('Training process starting...')
# ----> 3     H = model.fit(train_generator.next_batch(),
#       4                   steps_per_epoch=train_len//batch_size,
#       5                   validation_data=val_generator.next_batch(),
#
# ~\anaconda3\envs\ML\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1187               logs = tmp_logs  # No error, now safe to assign to logs.
#    1188               end_step = step + data_handler.step_increment
# -> 1189               callbacks.on_train_batch_end(end_step, logs)
#    1190               if self.stop_training:
#    1191                 break
#
# ~\anaconda3\envs\ML\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#     433     """
#     434     if self._should_call_train_batch_hooks:
# --> 435       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     436
#     437   def on_test_batch_begin(self, batch, logs=None):
#
# ~\anaconda3\envs\ML\lib\site-packages\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# ~\anaconda3\envs\ML\lib\site-packages\keras\callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     313       self._batch_times.append(batch_time)
#     314
# --> 315     self._call_batch_hook_helper(hook_name, batch, logs)
#     316
#     317     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# ~\anaconda3\envs\ML\lib\site-packages\keras\callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     351     for callback in self.callbacks:
#     352       hook = getattr(callback, hook_name)
# --> 353       hook(batch, logs)
#     354
#     355     if self._check_timing:
#
# ~\anaconda3\envs\ML\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#    1026
#    1027   def on_train_batch_end(self, batch, logs=None):
# -> 1028     self._batch_update_progbar(batch, logs)
#    1029
#    1030   def on_test_batch_end(self, batch, logs=None):
#
# ~\anaconda3\envs\ML\lib\site-packages\keras\callbacks.py in _batch_update_progbar(self, batch, logs)
#    1098     if self.verbose == 1:
#    1099       # Only block async when verbose = 1.
# -> 1100       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1101       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1102
#
# ~\anaconda3\envs\ML\lib\site-packages\keras\utils\tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#     515
# --> 516   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     517
#     518
#
# ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~\anaconda3\envs\ML\lib\site-packages\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     510   def _to_single_numpy_or_python_type(t):
#     511     if isinstance(t, tf.Tensor):
# --> 512       x = t.numpy()
#     513       return x.item() if np.ndim(x) == 0 else x
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1092     """
#    1093     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1096
#
# ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1058   def _numpy(self):
#    1059     try:
# -> 1060       return self._numpy_internal()
#    1061     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %% [markdown]
# # Testing #
