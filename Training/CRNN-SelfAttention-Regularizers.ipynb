# %% [markdown]
# # Test tensorflow gpu #

# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
  except RuntimeError as e:
    print(e)

# %% [markdown]
# # Dataset #

# %%
import os
import codecs

data = {}
classes_file = '../Dataset/classes.txt'
with codecs.open(classes_file, 'r', encoding='utf-8') as cF:
    data = cF.read().split('\r\n')
len(data)
# Out:
# 94

# %%
import os
from PIL import Image, ImageDraw, ImageFont

text_source = '../Dataset/source.txt'
fonts_path = '../Dataset/Fonts'
fonts = [f'{fonts_path}/{f}' for f in os.listdir(fonts_path)]
fonts
# Out:
# ['../Dataset/Fonts/arial.ttf',
#  '../Dataset/Fonts/arialbd.ttf',
#  '../Dataset/Fonts/arialbi.ttf',
#  '../Dataset/Fonts/ariali.ttf',
#  '../Dataset/Fonts/calibri.ttf',
#  '../Dataset/Fonts/calibrib.ttf',
#  '../Dataset/Fonts/calibrii.ttf',
#  '../Dataset/Fonts/calibriz.ttf',
#  '../Dataset/Fonts/cambria.ttc',
#  '../Dataset/Fonts/cambriab.ttf',
#  '../Dataset/Fonts/cambriai.ttf',
#  '../Dataset/Fonts/cambriaz.ttf',
#  '../Dataset/Fonts/consola.ttf',
#  '../Dataset/Fonts/consolab.ttf',
#  '../Dataset/Fonts/consolai.ttf',
#  '../Dataset/Fonts/consolaz.ttf',
#  '../Dataset/Fonts/constan.ttf',
#  '../Dataset/Fonts/constanb.ttf',
#  '../Dataset/Fonts/constani.ttf',
#  '../Dataset/Fonts/constanz.ttf',
#  '../Dataset/Fonts/corbel.ttf',
#  '../Dataset/Fonts/cour.ttf',
#  '../Dataset/Fonts/courbd.ttf',
#  '../Dataset/Fonts/courbi.ttf',
#  '../Dataset/Fonts/couri.ttf',
#  '../Dataset/Fonts/impact.ttf',
#  '../Dataset/Fonts/Roboto-Black.ttf',
#  '../Dataset/Fonts/Roboto-BlackItalic.ttf',
#  '../Dataset/Fonts/Roboto-Bold.ttf',
#  '../Dataset/Fonts/Roboto-BoldItalic.ttf',
#  '../Dataset/Fonts/Roboto-Italic.ttf',
#  '../Dataset/Fonts/Roboto-Regular.ttf',
#  '../Dataset/Fonts/tahoma.ttf',
#  '../Dataset/Fonts/tahomabd.ttf',
#  '../Dataset/Fonts/times.ttf',
#  '../Dataset/Fonts/timesbd.ttf',
#  '../Dataset/Fonts/timesbi.ttf',
#  '../Dataset/Fonts/timesi.ttf',
#  '../Dataset/Fonts/trebuc.ttf',
#  '../Dataset/Fonts/verdana.ttf',
#  '../Dataset/Fonts/verdanab.ttf',
#  '../Dataset/Fonts/verdanai.ttf',
#  '../Dataset/Fonts/verdanaz.ttf']

# %%
dataset = []
sequence_len = 20

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import cv2

def draw_img(img):
    plt.imshow(np.asarray(img), cmap='gray', vmin=0, vmax=255)
    plt.show()

def load_img(img):
    return cv2.imread(img, cv2.IMREAD_GRAYSCALE)

def dilate_img(img):
    return cv2.dilate(img, np.ones((2,2), np.uint8))

def otsu_thresholding(img):
    norm_img = np.zeros(img.shape)
    img = cv2.normalize(img, norm_img, 0, 255, cv2.NORM_MINMAX)
    blur = cv2.GaussianBlur(img, (3,3), 0)
    _, img = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    img = dilate_img(img)
    return img

# %% [markdown]
# ## Load dataset ##

# %%
with open(text_source) as txt:
    word_count = 0
    sequence = ''
    dataset = []
    for i, line in enumerate(txt):
        words = line.split(' ')
        for single_word in words:
            word = ''.join([c for c in single_word if c in data])
            word.replace('\n', ' ')
            
            if len(word) < 1:
                continue
            
            if len(word) > 30:
                split_count = len(word) // 30 + 1
                for i in range(split_count):
                    start = i * split_count
                    end = start + len(word) // split_count
                    dataset.append(word[start:end])          
                continue
                
            sequence = sequence + word + ' '
            word_count = (word_count + 1) % sequence_len
            if word_count == 0 or len(sequence) > 85:
                dataset.append(sequence[:-1])
                sequence = ''
                
dataset = list(set(dataset))
len(dataset)
# Out:
# 34354

# %% [markdown]
# ## Shuffle dataset ##

# %%
sorted_data = sorted(dataset, key=len)
longest_label = len(sorted_data[-1])
longest_label
# Out:
# 109

# %%
import random

random.seed = 1234567

random.shuffle(dataset)
# dataset = dataset[:20000]
dataset
# Out:
# ['iron ; chain works for the manufacture of chain ; and steel works for the manufacture',
#  'Google.In the run-up to launch Stephen',
#  'Males have been observed to initially',
#  'any game supported by Mame/Mess, including past versions. There',
#  'of the book in Publishers Weekly concluded,',
#  '(in Italian) Byrrhodes incomptus is a species of',
#  'A Pack-Tracker (1968) Joan & Betty Rayner : Strolling Players (1972) biography The Boy',
#  'life to working to improve conditions and salaries for working women and campaigning for',
#  'with yellow and white. Its head',
#  'software development industry as judged by SD Times magazine. AutomatedQA was one of only',
#  'Sword of Storms (2006) Hellboy: Blood and Iron (2007)',
#  'of the',
#  'Golden Mountain (1973) Wildfire (1973) The Sky is Free (1974) The Hundred Islands (1976)',
#  'and captured some of the earliest photographs',
#  '1954, followed by a fall',
#  'South branch service. The latter originates from Ormskirk but runs in the opposite direction',
#  'first team to repeat as',
#  'Ireland Office. Dennis Smales, Senior Executive Officer, Department of Health',
#  'Macdonald. For service to the community in Skye. David Matthew,',
#  'comprise an initial three battalions, growing to a total of nine battalions of 850 troops',
#  "Sir James Long, 2nd Baronet. According to historian John Aubrey, Long's father-in-law",
#  'South and North, Hillside Hall, White Hall, Matelson',
#  'developed his cartooning style by working as',
#  'involved in the Somali mission, to work',
#  'a publisher to do the same. For example,',
#  "Music Awards and received the approval of the Allen Ginsberg Foundation for Harlow's musical",
#  'Bruce, Chief Operating Manager (Railways), London Transport Executive. Alexander Campbell,',
#  'of firing and shelling. Nine',
#  'This is a perennial mat-forming grass',
#  'clarinet, Eli Herskovitch clarinet, Dave Lawton Trumpet, Sasha Boychouk soprano saxophone,',
#  'term as leader of',
#  'AL and a public affairs office in Washington, DC. Founded in 1944 by a small group of',
#  'by Hans Persson and Stefan Meier Rendezvous with',
#  'and 47 errors was far worse than the organization that employed Ozzie Smith at short was',
#  'recitation hall or a sumptuously decorated triclinium were not mutually exclusive, but',
#  'can also have the condition. In canines, Lafora disease can spontaneously occur in any',
#  'and A Quiet Fire (2009). On Banshee,',
#  'more than five hundred bass clarinetists from all over the world.Following his first piece',
#  'the Holiday Festival',
#  'primarily in the visual arts; aside from being a published author, Kahn was both a painter',
#  'In 2003, Human Rights Watch visited the camp, finding that some residents had lived there',
#  'in Arabic language.',
#  'including three green fireballs, supported the Extraterrestrial hypothesis for UFOs and',
#  'Authority. Eric Whittaker, Assistant Works Manager, 748 & 801, Manchester, British Aerospace',
#  'streaming media, it is more important to deliver recent packets quickly than to ensure',
#  'flower children. The term later became generalized as a modern reference to the hippie',
#  'Downton had an important part to',
#  'and players, with Austin acting as a potential',
#  "FIA's efforts to slow down the Callaway Competition-entered Chevrolet Corvette of Christian",
#  'based on the MAME core. It used',
#  "1974: Don Revie's first",
#  'and includes the Great Dividing Range. Major towns of the highlands include Castlemaine,',
#  '1946 "Closing the Gap in National Defense". Saturday Evening Post "I Had a Talk with the',
#  'trimaran hullform. The mockup was built in approximately six',
#  'MinnesotaDuluth game. Sir',
#  'Band 4, Duncker & Humblot, Berlin 1959, ISBN 3-428-00185-0, pp. 620. Heide Schulz: Freue',
#  'Airways. England and WalesAdrian Fraser Canning Clissitt, Chief Constable,',
#  'S-Bahn railway cars, 164 light',
#  'brandishing a shotgun and shouting',
#  'footage and interviews with contestants who have',
#  'a trucking accident. Now a widow with a 12-year-old son to care for, she sets off for',
#  'Rosei (born in Vienna on 17 June 1946) is an Austrian literary writer. Rosei attended',
#  'Highways and Transportation Department, Northants County Council. David Robertson, Senior',
#  'Coach Carnesecca would',
#  'season, which are held at',
#  'in the form of a 47-foot',
#  'although they also had to cover the Liquica, Ermera, Ainaro, Cova Lima and Oecussi districts.',
#  'US from Sydney, Australia, and Belle Stanley (Leary) Cooper. Miss Leary was from San Francisco.',
#  'Tournament. All players participating have',
#  'Great Lakes Lighthouses, (Gwinn, Michigan: Avery Color Studios, Inc.,',
#  'Wit and Humour in the Art of the Middle Ages (2004, ISBN 978-0750927734) Janetta Rebold',
#  'Atlantic in 1943, Enchantress continued escort',
#  'a senior police official of Poonch',
#  'commenced large-scale',
#  'Laureate is an American company that',
#  "He died at his home in Philadelphia on November 19, 1920. Rau's photographs span a wide",
#  'while noting that several sources refer',
#  'the King Mongkut the 50th Anniversary of',
#  'of the Preston to Blackpool electrification scheme. As part of GNRP - Great North Rail',
#  'Schrader: Literaturproduktion und Bchermarkt des radikalen Pietismus: Johann Heinrich',
#  'a French documentary made in',
#  'mayor following the October 2007 council elections, after the retirement of her predecessor,',
#  'of Victoria within dedicated reserves. Any rainforest that is',
#  'Merseyside Regional Health Authority. Geoffrey Alan Robinson, Secretary, Board of Governors,',
#  'that the gate is',
#  'themes given their situations. "Andrea feels guilty about',
#  'River, also called Meroo Creek, a watercourse that is part of the Macquarie catchment',
#  'he also privately had at times tense',
#  'and the Town of Erin in Wellington County.',
#  'won the bronze',
#  "Company opened a mine in Lerala, Botswana's",
#  '2020 The Security Council reauthorised',
#  'to win the Mid-America version',
#  "Society's weekly demonstrations.Hauksbee was an instrument maker and appointed as chief",
#  'Indian civilians and injured 9 others',
#  'where for one day a week the poor were treated and given medication free. In total they',
#  'fuel cell vehicles and plug-in hybrids with battery capacity of 15.0 kWh and above are',
#  'series The Mountain. The series',
#  "Kerr's Whoopee Band are",
#  'at Starz Plaza on Hollywood',
#  'Tail may also have influenced the decision',
#  '1974 at the Anaheim Convention',
#  'Guy. Phil Roman, veteran alumnus of MGM Animation/Visual Arts and Bill Melendez Productions,',
#  'Award for the role.',
#  'short stories, newspaper serials and non-fiction.',
#  'Karinou Airlines began operating scheduled passenger flights to ten destinations across',
#  'did not become a Detroit or a Cleveland." Robert Remini pointed out that while other cities',
#  'law to require contraceptive coverage for students at institutions controlled by religious',
#  'Assin Central is one of the constituencies',
#  'in automated software testing tools and developer tools.',
#  'In 1989 he received',
#  'Website Official Myspace Artist Page at',
#  '2000) .... Woman / Miss Avalona Third Watch (1 episode, "Journey to the Himalayas", 2000)',
#  'and the median income for a family was $31,784. Males had a median income of $30,299 versus',
#  'J. Daley Library, the primary',
#  'was subdivided into two separate residences,',
#  'himself and chosen the texts, some',
#  'Avery, Royal Corps of Transport. 24092690 Sergeant Roy Bernard Bartram,',
#  'George Stapleton (born Dublin, Ireland, in 1777, died 1841, in Dublin) was a prominent',
#  'In nanophysics, he and his group predicted helical structures of metal',
#  "links) is probably a good read. Formulae are represented formally by the 'QuotedGraph'",
#  'no right to the royalty and does not now assert one. The law, including equity, provides',
#  'argument is interpreted by formula-aware stores to indicate this statement is quoted/hypothetical.',
#  'Tony Harris) (1999) Official Paul Chadwick site GCD: Paul Chadwick Interview with Paul',
#  'NCVO; 2005 The role of kindness in public policy; Julia Unwin; Carnegie UK Trust jrf.com',
#  'second time that Heston played Jackson,',
#  'over command to Lieutenant Colonel Mark Jennings on 21 June. MTF-1 operated throughout',
#  'mother was a schoolteacher.Hawes graduated from Stanford University. He received a master',
#  'event or entity. For example, a corporate entity may provide equipment for a famous band',
#  'Seiden was',
#  'who won the BCS national championship and their second consecutive basketball national',
#  'of the 5th century BC, together with the statue of Marsyas, are examples of a successful',
#  'In the 1950s MEL developed',
#  "'in drink', and his son",
#  'under the guise of a "survey".',
#  'significantly in all seven auditory parameters analyzed for each type of call. Behavioral',
#  'to the female P.',
#  'by UFC. After being released from',
#  'August 2010 at Janslkka elementary school, a local state school attended by her half-brother.',
#  'In April 2015 he was appointed to a two-year term as Poet Laureate of Kansas by the Kansas',
#  'Odontoglossum sceptrum var. sceptrum (Colombia) Odontoglossum schillerianum Rchb.f. 1854',
#  'the male nude paintings',
#  'finished 19th. Carlisle United',
#  'they analyzed the ends of chromosomes and identified the',
#  'wheel weighed 2 tons 13 cwt (2,693 kg) and cost 32. 0 .0 new in 1860. Isaac Clover 1815-44',
#  'west are another jacaranda tree, a bird-of-paradise flower (Strelitzia sp.), river lilies',
#  'Leveson-Gower, Chairman, North Yorkshire Probation and After-Care',
#  'Stjernstrm. In 1860, she was',
#  'departure from Harper & Row in early 1980 remain unclear; contemporary press accounts',
#  'shiny surface, one',
#  'himself becomes a hunted person as officials find suspicious e-mails sent from his laptop',
#  'due to the increase in petty crimes.Newcastle',
#  'the end of her life, Kahn received two',
#  '( SOR-bi) is a village',
#  'Belluton during his childhood. His father was a small landowner and attorney at the local',
#  'as "the only black man in the band."Shortly after beginning work on his third solo album',
#  'Shabaab militants near the',
#  'operated by Nav Canada. The Toronto Area Control Centre is based near Toronto Pearson',
#  'a colony at the mouth',
#  'possible. A recent example',
#  'the richest sugar colony in the Caribbean. On 21 September 1711, in an 11-day battle,',
#  'less than the last time that',
#  'Palmer took an extended break from writing and recording. The album was recorded in February',
#  'district in Buckinghamshire, England. It is near the boundary with Oxfordshire, about',
#  'Delphinium scopulorum',
#  'pathways."',
#  'and the 11.3 m X2K RHIB (Rigid Hull Inflatable Boat) Range of models incorporate a double',
#  "Fox's most well-known",
#  'than 400 species. Many have now been reclassified in other genera such as Amparoa, Aspasia,',
#  'http://www.sagebud.com/',
#  'From 1996-2000, Engel headed a research',
#  'designated on March 16, 1925',
#  'of Princess Mother Srinagarindra for her public',
#  'year until a maximum of $3,000 in 2015, but the rebates would continue until the fund',
#  'and philanthropist. He was the owner of',
#  'midges in the family Cecidomyiidae. Stig Kleven',
#  'organization is also known as the',
#  'Vivian Allan Boyse. Robert George Emberson. Frank Reginald Francis, MBE. Captain Roland',
#  "including a cheese shop, Creeler's seafood restaurant and Arran Aromatics. This was the",
#  'border skirmish 2013 IndiaPakistan border skirmishes IndiaPakistan border skirmishes (20142015)',
#  'not known, but he was baptised on 30 June 1679. He married Abigail Bayly, the daughter',
#  'Gordon Chaloner Olive, MBE, DFC, of Runcorn. For services',
#  'economies, averaging about 5% per annum over the past decade. Growth in private sector',
#  'the album, staff',
#  'Gaylaxicons, Albacon, Arisia, and Boskone. Sakers was born in Yokosuka, Japan, but grew',
#  'by forbidding insurance companies from charging part of the cost to the patient. In 2017,',
#  'the season, Camilo tallied 6 assists. Additionally, Camilo closed the 2013 season with',
#  'roads and tracks, steeplechase and cross-country portions.',
#  'as obsessive and moody as he was in America, and his behavior causes Noroko to suspect',
#  'car. Bob Sweeney and Raylan approach the hardware store, Bob having tracked down Errol',
#  'Gttingen',
#  'Puget Sound Navy Museum is an',
#  'in the Central State Prison Farm in Sugar',
#  'as well as the',
#  'the early 1990s, leading to the release in 1994 of the signature CD compilation of the',
#  'their bodies were shown in a video posted by the insurgents. 19 September Two AMISOM troops',
#  'of Mikk Mikiver, graduating in 1984. Among',
#  'completely extracted from an',
#  'and Stranger #1-4 (1999-2000) Dazzler #38-42 (198586) Deadpool #46-48 (2000) Doctor Strange:',
#  'the staff moved to',
#  'LOVE, being attacked and beaten by bystanders. In',
#  'have a major recurring arc in both the fourth and fifth seasons of Gossip Girl. DeFer',
#  "that aren't formula-aware would only persist those terms core to the RDF Model, and those",
#  'in Baramulla district as result of ceasefire violation.On 2 November, a BSF constable',
#  'Australia (IAPA), incorporating business data analytics, business intelligence, data mining',
#  '"Anomalous aerial vehicle" (AAV) or "unidentified aerial',
#  'parties initially envisaged The Rockets continuing as a separate concern, the older band',
#  "Borough of Hammersmith, Women's Royal Voluntary Service. Harry Drawer Steven, Technical",
#  'market, the financial sector has attracted a host of global investors seeking better returns.',
#  '15 September 1847 Quid.fr (French language online encyclopedia) web.genealogie: les militaires',
#  'for one another. The new name is in reference',
#  'along the Line of Control.On 17',
#  "but she never forgave Charles. After her brother's death in 1891 Anna lived the rest of",
#  'know whether a message is best retransmitted in whole or in part, whether or not the need',
#  'of Social Media/Other and Best College Radio Station in the Nation for the second year',
#  'telegraph office when John J. Albright saw his potential and decided to sponsor him through',
#  'Another decision by the Sixth Circuit in',
#  'New York City and in Europe, which she used as an excuse to hide her pregnancy. During',
#  'it hanging in thick festoons',
#  'Museum, Cairo. He also held multiple exhibitions in Japan, first in 1988, based in galleries',
#  "Stax Records' Enterprise label as the",
#  'and are mottled with brown or black,',
#  'France. Communes of the Lozre',
#  'York, 1978, ISBN 0-8128-1900-4. Encyclopedia of Metaphysical Medicine, Routledge and Kegan',
#  'to have only been stirred out',
#  'Himrod (November 4, 1842 January 26, 1920) was an American politician who served as mayor',
#  'an Official Secrets Act 1911 declaration',
#  'diocese is Our Lady of',
#  'on the Spanish side and from Saint-Jean-Pied-de-Port',
#  'in their entirety on the first disc, with the second disc containing nine rarities and',
#  'Peter John Grimshaw, of Farrer, Australian Capital Territory. For service to university',
#  'entitled "Miracle in Chicago" portrays Mayor Daley (played by John Belushi) appearing',
#  "lion's paw scallop Nodipecten subnodosus (Sowerby I, 1835) The economy of Botswana is",
#  'Moreover, he has driven folk-bar in Bergen (1988)',
#  'and William John Cooper. 1932. Faculty inbreeding in',
#  'KDF raids on two bases.',
#  'letter to Tom, asking for a divorce. Soon after, Tom arrives at the estate and explains',
#  'For conspicuous gallantry and devotion',
#  'Love In preceded by the single',
#  '1997.On September 27, 2010, a group of six former USAF officers and one former enlisted',
#  'Writer. Eric Dale, Member, Irvine New Town Development Corporation.',
#  'Warrant Officer Class 2) William Lawrence Hutton, 5th Royal Inniskilling Dragoon Guards.',
#  'dates back to the 1950s. Usually, Chantilly',
#  'spread out, with 22.4% under the age of 18, 5.3% from 18 to 24, 31.1% from 25 to 44, 28.8%',
#  'track listing. In contrast',
#  'on 1996 demo Shannon Hamm vocals on 1996 demoProductionChuck Schuldiner producer Jim Morris',
#  'million copies in the first month',
#  'Owens Corning and H.J. Heinz, made',
#  "role as President of the Local Government Board. According to Weizmann's memoirs, Samuel",
#  'Joseph Winston Chapter of the',
#  'residence, like other horti. Several',
#  'at the sun-temple of king Niuserre. Nykara is known from a number of monuments all coming',
#  "Chadwick re: The Matrix Online Paul Chadwick's",
#  'than it is permissible to expropriate property rights. [...] The Wrotham Park case, therefore,',
#  'expedition of Giovanni da',
#  'from 1989 to 1992. Dianne Elizabeth Reeves (born',
#  'by Jeff, who took care of Ham',
#  "George Layton, Leader, Dosthill Boys' Club, Tamworth, Staffordshire. Kenneth Owen Levers,",
#  'poignant points he makes',
#  'The Worcestershire & Sherwood Foresters Regiment (29th/45th Foot).Royal Air',
#  'as the New Level Furnaces) where blast furnaces, owned by the Dudley Estate could supply',
#  'Sir Claude (2008). Titian. Parkstone International. pp.4952. ISBN 9781844844364.',
#  'an important steel production plant in Brierley Hill, West Midlands (formerly Staffordshire),',
#  'conservative religious institutions, and no women. Some people see the matter as primarily',
#  "Huntington, helped to establish the Soldiers Aid Society and was a patron of Milwaukee's",
#  'as Collector of the Port',
#  'player for Astralis. He has won 3 majors in a',
#  'election 2019 Barrow-in-Furness Borough Council election The by-election was triggered',
#  'from mid-morning until dusk, and can be seen in',
#  'Andrew Robert". Dictionary of National Biography (2nd',
#  'to stop the payment of the royalty to Blake and procure its payment to the Crown instead.',
#  'attachment order debtor, or garnishee, and the actual judgment debtor. Emoluments attachment',
#  'to the left screen edge. Earlier versions featured mail merge, which automatically populated',
#  'the National Trust (NSW). During the Marjory Davey (married then to Arthur Gates), Roseneath',
#  'Angie (Jennifer Lonsdale), she moves into their London flat and soon discovers that Robert',
#  'TAFE NSW Northern Sydney Institute Freshwater facility and',
#  'the Legislature. Oklahoma Tax Commission Oklahoma Office of State Finance Oklahoma Office',
#  'to free them. Piper, an animated short film that is based on the famous Pied Piper of',
#  'film directed by Luis Saslavsky and starring Pedro Lpez Lagar, Amelia Bence and Roberto',
#  'were nationalized in 1951,',
#  'Princeton University, where she majored in History, graduating with honors in 1974. She',
#  'scandal, and her husband David Potter, who founded software company Psion. Initial funding',
#  'has a group of seven',
#  'Strathclyde Police. Frederick Arthur Hale, Deputy Manager, Plaistow Wharf,',
#  'Sebastin Aguilar serving as co-consecrators.On 21 October 2020 it was announced that Pope',
#  'Indian Director General of Military Operations (DGMO), said that',
#  'radar blips, to indicate possible hostile forces that might be roaming in the area.In',
#  'naked dog, or Chim dog is one of several',
#  'singer Xuxa Meneghel. It was released',
#  'film concludes with his attempt to climb',
#  'Saxon sheep; a novel based on the activities of the Templeton and Forlong families in',
#  'on September 22, 2019. NY Times Bobby Walston at Find a Grave Winding around the inferior',
#  '12. The school is operated by the New South Wales Department of Education; the principal',
#  'on LP and CD (These',
#  '(Ecuador to Peru) (occasionally terrestrial) Odontoglossum crocidipterum Rchb.f., 1871',
#  'Crosdale, Corps Superintendent, Bromley, St. John Ambulance Brigade. Ronald Victor George',
#  'and trying to cut its own losses, froze fees and royalties of over US$3 million to Bluth',
#  '1960s portal Bennett M. Berger, "Hippie moralitymore old',
#  'Djibouti City being the only other. Only freight trains continue northwards from Nagad',
#  'are the local GAA team. Newcastle railway station began operating on 25 March 1869 and',
#  "Cardinals, ending his college career as SDSU's all-time leader in runs (214), hits (277),",
#  'and then Huddersfield Town. He left in 1998 and made a return to Hartlepool United playing',
#  'cause for canonization by the Diocese of Springfield (archived) Lasname Airfield (Estonian:',
#  'Henderson, Annlaug Brsheim and Olav Christer',
#  'to his better known contemporary Wilhelm Kienzl.',
#  'film Newport South (executive produced by',
#  "Senior's night in Allen Field House.In addition to the 61 Conference Championships, the",
#  'turn carnivorous plants into sentient man-eating creatures. Based on a 1950s screenplay',
#  'October 1978 when the Stuttgarter Vorortverkehr was replaced',
#  'Richelieu: the parish municipality of Saint-Roch-de-Richelieu; in the County of Laprairie:',
#  'See information box for standard issue, and see below for commemorative issues. the 25th',
#  'Chancellor of the University of Cape Coast. Charles',
#  'mexicanus (Smith, 1859) Neivamyrmex pilosus pilosus (Smith, 1858) John Reading',
#  'find work by Ruby Lomax. Within a year, he was caught burglaring again and returned to',
#  'services to journalism in Surrey. James Hardie Binnie, Group Personnel Manager, Bridon',
#  'I Take This',
#  '(Late Night Alumni Mix) 2013 - Polytype "Cyclone" (Late Night Alumni Remix) 2014 - Ivan',
#  'the series, putting an emphasis on silence, which McCreary felt that the music was more',
#  'lyrics and songs focused on the themes of military combat and war, terrorism and conspiracy',
#  'So the name of Town is Ashti and now days Ashti is called as shahid Ashti due freedom',
#  'Air Corps.Royal Air ForceWing Commander Neil Roger Hayward (608081). Wing Commander Roy',
#  'prominence, and he held various roles',
#  'companies Science and technology in Botswana United Nations Economic Commission for Africa',
#  'of 16 onwards, there',
#  'neighborhood of Chicago. He was the',
#  'the encouragement of Cartan she continued her research, publishing her first paper in',
#  'and his participation in the state',
#  'Publishing". The Bend Bulletin. October 7, 1982. Blades, John. "Editors at the Scene of',
#  "Electronic Arts' highest",
#  'that do not rely primarily on members of the',
#  "Federal Government's Telstra privatisation bill fails to pass the Senate. 6 November -",
#  '1996 Italian historical drama film directed by Carlo Lizzani from a screenplay by Furio',
#  'at Harper was as a manuscript reader, only',
#  "is made by the male inside the females' genital atrium, which is rejected by her multiple",
#  'smock mill. It was powered by a beam engine and drove two pairs of millstones. a third',
#  'supplementary broadcaster to existing solus broadcaster Central GTS/BKN in the Spencer',
#  'Hugo F. Sonnenschein were among his classmates. After his PhD in 1964, he first joined',
#  'used to report anomalies in',
#  'and "Clash of the Titans." In 1997, the group\'s manager "General Wise" was shot dead in',
#  'Guitars official website Grover Jackson Interview - NAMM Oral History Library (2008) Jon',
#  'with Friedman Amplification and manufacture',
#  'Frederick H. Brooke, with Horace W. Peaslee',
#  'a mall white star bred in Ireland by Mrs V McAlmont. The colt was sent into training with',
#  'in the group. The ideal',
#  "Ginsberg's methods, the protest received positive attention and the",
#  '18 for 1934-35) list Cooper as being a member of the Cosmos and Torch clubs, as well as',
#  'to consist of the town of Longueuil,',
#  'predominate. The sector is plagued',
#  'the Continental Navy and the commanding officer of the Revenue Marine cutter Scammel.',
#  'will be the 7th FIM Team Under-21 World Championship season. The Final took place on September',
#  'April 1918) Clasp to the Iron Cross (1939) 2nd Class (12 May 1940) & 1st Class (13 May',
#  'Terry White was appointed Board Chairman of Metro South Hospital and Health Service (HHS),',
#  'as an anthem for',
#  'dot along a white wall, and',
#  'of Siemens-Martin steel in',
#  'CD2) Delta State (Soundtrack) (2004)',
#  'of being heard". "When you don\'t have ambient beds going through your whole score," he',
#  'August 1844 the Sydney Herald carried a further advertisement this time advertising Roseneath',
#  "Men's Basketball program in various categories, including points,",
#  'Coleccin Comunidad de Madrid, Madrid Coleccin Fundesco, Madrid Collecci Testimoni de La',
#  'Julia Unwin; Published by the Baring',
#  'and a higher castle ("Haut Morimont"). The former is located at the present Morimont farm',
#  'with his photo. He also worked with',
#  'Sugar Creek near Franklin, North Carolina. When his land was usurped by white settlers,',
#  'In addition to his other works, on June 22, 1916 Lewis hosted what was announced as a',
#  'guard sooner than most states." By using an existing private organization as the framework',
#  'industry. He is largely respected for his contributions to winemakers and the wine industry',
#  'pattern. The pattern is specified by providing explicit statement terms (which are used',
#  'e.g. add() methods that search triples and',
#  'for Lafora Disease with funding from the National Institutes of Health (NIH) led by Dr.',
#  'a slightly higher figure: "Depending on the data used to calculate the number of ICT professionals',
#  'under moist and',
#  'of 2020, it remains unreleased. Crazy Horse remained on hiatus for eight years following',
#  'cult favorite Jem providing vocals for the song "A Father Should Be..." by Starlight Girl',
#  'novel Wer war Edgar Allan (Who was Edgar Allan) in 1977, which was filmed by the Austrian',
#  'Chalk Pits Museum, and Amberley Museum',
#  'al Mukarama Street. On',
#  "the state's first senator, its second governor, and a United States Supreme Court Justice",
#  'Jutra nomination for Best Supporting Actor in 2006.Brillant is also a musician and songwriter.',
#  'origin. Neighborhood Website',
#  'Burns is a Canadian musician known as KASHKA and',
#  'and Pan Pacific records were as follows: All times are in minutes and seconds. The first',
#  'to start during the first half',
#  'that electricity',
#  'Texans. Fulton was drafted by',
#  'the original buyer. Since courts regularly make orders for the specific performance of',
#  'from Stortorvet to Ster. The company also built a line to Simensbrten that was closed',
#  '(Controlled, IFR/IFR, IFR/VFR and VFR/VFR separation, VFR: Mode C and ATC clearance required)',
#  '(when the shower was installed in the back, under the floor; and a circle of bricks in',
#  'earliest government studies to come to a secret extraterrestrial conclusion. In August',
#  'as a suspect for the rape',
#  '1991 toured in Norway and internationally.',
#  'laser printer controllers at',
#  '57 states that if an auction is held without any reserve, then the auctioneer must accept',
#  'and Betrayal. Toronto: University of Toronto Press, 2007. ISBN 978-0-8020-9526-8. Murphy,',
#  'johnsoni). Between the black and red areas on the posterior part of the dorsal abdomen',
#  '(addition or removal of a methyl group). Mercury can enter',
#  '.... George Mixed Blessings (197880) TV Series .... Thomas Simpson (22 episodes) A Ghost',
#  'incidents in their ongoing examinations." In May 2021, military pilots recalled their',
#  'the brother of the Russian Tsar. Ernest married Princess Louise of Saxe-Gotha-Altenburg',
#  'Borders Health Board. Roderick James Rogers Armstrong, Chief Engineer',
#  'goal. Both teams traded punches until Illinois freshman Chris Richardson kicked a 27-yard',
#  'South-Eastern Australia Central Highlands at the Department of Agriculture, Fisheries',
#  '1 football field 1 Olympic-sized swimming pool and 1 regular Pool Official website Kreativum',
#  'the limelight until the Fitzgerald Inquiry. During 1988, he was subjected to numerous',
#  'Japan in the 1950s demonstrated the frightening effects of exposure to extremely high',
#  'Arte Moderno, Gran Canaria and Mohamed Mahmoud Khalil',
#  'and they responded to',
#  'For service to veterans and to youth. Peter',
#  'well as the railway line Stuttgart-Bad',
#  '2010 and re-elected in 2012. He was term-limited in 2016 and was succeeded by fellow Republican',
#  'Backed by Aurora Productions, The Secret',
#  'For services to the community. Richard Chapman Hope',
#  'and "Grover Jackson" portion is attached small letters) From 1993 - 94: Jackson /Grover',
#  'From 1295 to 1832, Downton was a',
#  "agency Centre national d'tudes spatiales (CNES) since 1977; the government of Uruguay",
#  'on 12 May a bomb in a market',
#  'brought an action for all the profits he made on the book including those that he had',
#  'would join the MASL as',
#  'Midland. It provides river transportation, including barges and a shipyard; it also operates',
#  'but later returning as goalkeeping coach.',
#  'Clough by naming Jimmy Armfield of',
#  'Human Wrecking Balls.',
#  'Signals. 24062650 Sergeant Roy Anthony Coe, Royal Army Ordnance Corps. 23687883 Corporal',
#  'Roncevaux Pass or a spot nearby). The battle resulted in the defeat of the Carolingian',
#  'the virtuous youth. Valerius Maximus and Cicero both say that Lusius was a military tribune.',
#  'indispensable reference for students and educators". Dennis Drabelle of The Washington',
#  'who, now unarmed, spurred his horse towards his friends, and, to avoid the threatened',
#  "in as Australia's Governor-General. 20",
#  'to filmmaking. Bluth, Pomeroy and Goldman had been working for four years prior to leaving',
#  'the release of these pheromonal signals',
#  'the road with both of my hands in ice buckets and one foot in an ice bucket, every night.',
#  'Michael James Watts, Royal Corps of Transport.Royal Air',
#  'facility has a Mardi Gras theme. The track expanded its casino offerings in 2008, as casino',
#  'Roncesvalles Pass, Ronceval Pass or Roncevaux Pass',
#  'William Paterson, who was',
#  'for monkeys near Moozhikkal. Moozhikkal junction has become prominent because it forks',
#  'The diocese has 91 parishes, seven missions and five chapels. The mother church for the',
#  'Athletics. Meacham, meanwhile, earned a major league promotion by June of his first season',
#  'Jaume Ulled - stage actor (born 1978) Josep',
#  'make the headlines. For these merits the Spirit of Abdus Salam award was also bestowed',
#  'Junior in the hope that he will be played with again. With the help of Dr. Norrington',
#  'he reported he was still at work on the story, describing it as Concrete being "hit by',
#  'Council election',
#  'methods, recurrent drought, erosion, and',
#  'Arthur Clark Griffith. For services',
#  'of Spain, on whose favour his title depended: "Although in the letter I had told you of',
#  'gesture on the part of the first individual evokes a preparatory movement on the part',
#  'in 1953, and it',
#  'is an English language monthly lifestyle and luxury magazine published from Manama, Bahrain,',
#  "their reliance upon Werkzeuge who are men and women inspired by the Holy Spirit. The Inspirationists'",
#  'Vincent. When Vincent died, the building was purchased by the University in 1926. For',
#  'means "nodular scallop", because in this genus the shell is usually sculpted with regular,',
#  'Mary Gray. For service to the British Cycling',
#  'Division covering Bhutan, Sikkim,',
#  'nerve and disappear into the',
#  'that a bomb had been placed near',
#  'to the church, was built by Josiah Horton in 1650 and the Rawson family, who owned the',
#  'very young',
#  'Distribution Department, British Tourist Authority. Florence Vera Wooton, Senior Messenger,',
#  "large and sophisticated new animation studio near Dublin's Phoenix Park. The studio opened",
#  'identified Charles E. Roberts as the father of Oak Park Studio architect Isabel Roberts,',
#  "Andy McConnell. The team's primary logo is the traditional Kansas Jayhawk logo, with the",
#  'his abdomen to the other',
#  'First Division under new manager Bob Paisley, one point ahead of Ipswich Town, Everton',
#  'of Hygiene & Tropical Medicine. Professor Ben Atkinson Wortley,',
#  'The Story of the',
#  'man held several terrified shoppers at bay with a gun. When the manager tried to intervene,',
#  'Lepidoptera generic names catalog Eric McHenry (born April 12, 1972 Topeka, Kansas) is',
#  'their history. 10 August: On a rainswept Arena Joondalup, East Perth score only 0.9 (9)',
#  'successfully defended and put their death toll at nine. On 2 February a civilian was injured',
#  'craps, three card poker,',
#  'by a car bomb.',
#  'the actual laws were composed is unknown. They are similar to the Code of Hammurabi. During',
#  'birth, at any level. In July 2013, it was revealed that Camilo was considering representing',
#  'All-American in 1981',
#  '21st-century high-concept disaster thriller".Published in German in 2012, as of 2016 it',
#  'Narcotic Drugs Revocation or Suspension of Licenses',
#  'preventing loggers from',
#  'Guard Cyprus Police Hellenic Gendarmerie Zapti (Italian colonial',
#  'respect, does not fully examine why this is so, drawing the necessary conclusions. The',
#  'tps://en.sif.it/acti',
#  '- northeast Heath - northeast Licking Township - east Thorn Township, Perry County - southeast',
#  'Division I Softball Tournament.Oklahoma, Oklahoma State,',
#  'All the products are tightly integrated. TestComplete: TestComplete is an automated testing',
#  'St Leonards Stamcroft, became involved ahead of the 1997-98',
#  'Daley was a strong proponent of Illinois having',
#  'to have nonlinear gameplay, and Manley felt',
#  'rural roads in twos. A detachment of mounted zaptiehs',
#  'for My Love" and the Fleetwood Mac-inspired "Lotta Love". In 1978, Crazy Horse released',
#  'continent, with Saaremaa. Construction of the causeway cut the sea crossing between the',
#  'ariasii Dalstrm 2001 (Peru) Odontoglossum armatum Rchb.f. 1876 : Armed',
#  'Keith James Rodda, of Mount Eliza, Victoria. For public service to construction. Alan',
#  'at purchase. Investment returns are primarily',
#  'for the purpose of tax assessment',
#  'teacher at Maculay, who lures him onto the thin ice of the ornamental lake at Delaware',
#  'and purple tipped. The lower petal blades have',
#  'Bark Hide and Horn, a folk-rock band from Portland, Oregon, released a song titled "Ham',
#  'to Ecuador) Odontoglossum cristatellum subsp. lehmannii Rchb.f. Bockemhl 1989 (Colombia',
#  '1909 and named for President',
#  "Muse d'Art Moderne et la Cration Museo Extremeo Iberoamericano de Arte Espaol Contemporneo,",
#  'he returned to Antique to continue fighting. On March 22, 1901 Fallon and the other resistance',
#  'bare physical objects which psychological behaviourists',
#  'operations.Shortly after the rebranding, in early 2013,',
#  'has been a partner of an authorized Harley-Davidson dealership in Pavia. He is a great',
#  'Drag City.The album cover is Wasserstiefel (Water Boots) by Swiss artist Roman Signer.',
#  'Little Bit of Soul" CD/12 inch (2001, Yellow / Royal Belleville Music) "Paralysed" 7 inch',
#  "older sister, Isabella d'Este, the",
#  'the others are at Grade II, the lowest grade. The parish contains the villages of Hodnet,',
#  'due to the decline of',
#  'a good product choice to soften and moisturize cleansed skin. The dogs seem to prefer',
#  'had its name changed in summer of 2019. The reasoning behind the name change was due to',
#  'version of the album',
#  'Lusafrica 362502 Memoria (2004) - CD Lusafrica 462222 El Guajiro (2005) - DVD Lusafrica',
#  'the apps SSB Move, Moovel and the DB Navigator. The mobile phone tickets are partly discounted',
#  'at first as a secondary modern, then becoming a comprehensive called Downton School in',
#  'immediate aftermath of the murder, not',
#  'reporting that the deal was already completed. However, Whitecaps management quickly stated',
#  "St. Monica's was made a mission of St. Elizabeth's Church. In 1924 it was closed as a",
#  'the last best-of-three NBL Grand Final series. 7 April The Crawford Report delivers recommendations',
#  'Olympics in mixed doubles with',
#  "by design, Kahn's career change was, in",
#  'cars sold in the country). Ranking',
#  '"the necessity of a crisis-conversion experience" as well as the existence of a second',
#  'Shropshire, England. It contains 59 listed buildings that are recorded in the National',
#  'deposition in the mud reaches as well as dilution by marine sands from the Southern North',
#  'led by Jesse Bushyhead. About seven weeks',
#  'teaches parenting skills to the juvenile marmosets. Members of the group, usually female,',
#  'the chromic acid anodizing process. Statistics',
#  'Connie Smith lead vocals Bobby Thompson banjo',
#  'the public would be astonished if it was',
#  'of overshadowed." Shortly thereafter, Young enlisted Whitten, Talbot, and Molina to back',
#  '1931, a branch line from Jomfrubrten to Simensbrten was opened, officially named Simensbrten',
#  'had the power to disqualify her',
#  'Wiener, of Nedlands, Western Australia. For service to migrants. Stanley Thomas Williams,',
#  '1998) ISBN 0-932212-98-0. U.S. Coast Guard. Historically Famous Lighthouses (Washington,',
#  'affairs; among his many activities include his',
#  'at the International Ski Federation I Take This Woman is a 1931 American pre-Code romance',
#  'and the Cobbler (1993; additional visual effects',
#  'movies, and photos directly into Pages documents from the Media Browser window.Each document',
#  'for 18 months on plans',
#  'easier to procure fuel, compared to gasoline buses. One of the buses was rebuilt to a',
#  'with which Hancock had toured and recorded for the previous three years. This was their',
#  'by Pakistan Army while 6 soldiers were injured. Pakistani authorities stated on 14 November',
#  'a 1982 schoolwide reorganization. By 1984, it was broadcasting 18 hours a day and known',
#  'seat for the remainder of the 17th Congress and was seated on December 10, 1822, serving',
#  'economics. He was a professor of entrepreneurship at',
#  'which are based around the destruction of enemy weapons and installations, as well as',
#  'by males is emitted through secretions. A close relationship is known to exist between',
#  'structure by examining amphibian lampbrush',
#  'initial story treatment. The movie',
#  'wait for insects, especially butterflies, which are attracted to the sap holes. It supplements',
#  'and chemical methods are not biocompatible and cannot be employed when the device will',
#  '"Fire and Ice" and "Disco Inferno",',
#  'In 2011, Lord & Taylor renovated and',
#  '2018 she received a second Fulbright award',
#  'Burwell, Geneva College v. Burwell, Roman Catholic Archbishop',
#  'produced albums for Burger Records, Lizard King,',
#  'mid-20th Century. 1: A-K. New York, NY: Routledge. ISBN 0-415-92039-6. Emmanuel Kwesi',
#  'of the Centre',
#  'Creatures edited by Elektra Hammond. Official',
#  'written by Carolyn See was critical, observing, "Savage fails to note any significant',
#  "football defensive back for the American Football League's Houston Oilers from 19641969,",
#  "was commissioned as a probationary second lieutenant.He finished pilot's training in summer",
#  'own design. In this she',
#  "is home to Northern Ireland's highest mountain, Slieve Donard, which is in the Mourne",
#  'portions of the township.',
#  'to residential accommodation. There',
#  'Younger contended with the legacy of Maecenas through the lens of decadence-despising',
#  '7 December while he was performing his job at Marzano, in the municipality of Torriglia',
#  'Harold Naylor, lately Chairman, Steering Group for the Quality of Life Experiment in Stoke-on-Trent.',
#  "Iron Works at Brierley Hill under the supervision of the estate's mineral agent, Richard",
#  'the request from the federation',
#  'guitar Jon Robinson -',
#  'Gibraltar. Titi Beniata Rimon, Principal, Tarawa Teachers College, Gilbert Islands. James',
#  'married her first cousin William Forlonge. This is the first published use of the name',
#  'Somerset and is located due south of the city of Bristol and due west of the city of Bath.',
#  'Harris died in New York in the early',
#  'Line. The service on this branch line',
#  'Hard 21989 How To Get Ahead in Advertising1988 The Adventures of Baron Mnchausen Rick',
#  'hamlet of Pierrement. A former military headquarters building and thirteenth-century chapel',
#  'established himself in the first team,',
#  'Managing Director, Conference Services Ltd. For services to Export. Harry Parkin, Director,',
#  'land that belonged to the king in the marshes that were once common in this part of the',
#  'Historic Places in 1976. The Bridgewater Mill complex occupies more than 6 acres (2.4',
#  '(1977) M.A. Tulane University (1986) The Wealth of the Poor, Abilene, Texas: Abilene Christian',
#  'typical representative of late Romantic opera in the tradition of Richard Wagner, he was',
#  'to give a total score. Scores from the top',
#  'Ronald Eugene Usher (015711). Squadron Leader Peter Sydney Wilkins (0225757).Civil',
#  'and being an assistant to Bears president George Halas, Jr. He resigned on December 7,',
#  'With the club under a new wave',
#  'service north',
#  'Doherty and the Puta Madres. He',
#  'as number four on',
#  'reached No. 14 in',
#  '1970s.In the Official Gazette of Guyana',
#  'to African Union Mission to Somalia at Wikimedia Commons Point of View is an art installation,',
#  'of the store. On Heroes, Grosse portrayed recurring character Baron Samedi. "Baron Samedi"',
#  'or another and avoided causing a potentially harmful dispute through that part of the',
#  'Hollywood" 1:00 "Freaky If',
#  'the U.S. Paralympic National Team in 2010. As a World Champion medal winning para-alpine',
#  'The scheme for classifying buildings in Scotland is: Category A: "buildings of national',
#  'when he was three years old and Samuel John, born on January 16, 1846. As her sons became',
#  'he retired and moved to',
#  "neighbor, Hotchner founded Newman's Own, Inc in 1982. All profits from this line of food",
#  'often caused by too little generation for the load in a distribution grid, removing generation',
#  'A columnist for the same',
#  'jitter during congestion. In cases where quality of service is rate limiting a connection,',
#  'areas along with several Metropolitan Statistical Areas to make a Combined Statistical',
#  'made from its use of the wire for commercial purposes. In British Motor Trade Association',
#  'to Salisbury and south to Bournemouth. It also runs the more local routes 40 and 44 through',
#  'Night: Werdum vs. Tybura. He won the fight via unanimous decision to earn his first UFC',
#  'and deemed to be "real',
#  'contacts with the',
#  'guitars and lack of',
#  'from settlements on both sides of the main road leading towards the district center. Casualties',
#  'regions, she was mayor of Copenhagen County. Vibeke Storm Rasmussen is the daughter of',
#  'Richard Moody viola, Larry Roy guitar, Veronique Potvin viola,',
#  'on the CD',
#  'a trend which carried on after becoming Hastings United. Though in more recent years,',
#  'tracks are written by',
#  "1965. The battalion's complement of platoon",
#  'South Camac Street. He operated this studio for the remainder of his life, producing stereo',
#  'Medici Women: Portraits of Power, Love,',
#  "in Australia's case, the British",
#  'York: J.J. Little & Ives Company.',
#  'Magisk (formerly Magiskb0Y), is a Danish professional Counter-Strike: Global Offensive',
#  'Cedar Hill Cemetery. United States Congress. "David Fullerton (id: F000416)". Biographical',
#  'acclaim, Fox wrote that his personal opinion was that the game was still "niche" and deserved',
#  'Legal challenges to the Patient Protection and Affordable Care Act Sandra Fluke on Wikiquote',
#  'Highway on the waterside of North Platte',
#  'of Rouville: the parish municipalities of Notre-Dame-de-Bon-Secours and Saint-Mathias.In',
#  'its increased solubility in comparison to the hexahydrate. NiBr2-glyme, and NiBr2-diglyme',
#  'as a free or slave state. In',
#  "Pakistan also rejected India's claims that there had been additional casualties. Following",
#  'diverged in terms of body-mass from typical primates,',
#  'N. La Nouvelle France: the making of French Canada: a cultural history (2000). Roberts,',
#  'spoke of her interest in the ocean and climate change, which motivated her in christening',
#  'Barry Conway Brown, Science Officer, British Council, Paris. Robert',
#  'be a candidate for reelection in 1884. He also served as chairman of the Michigan Republican',
#  'the military and various government agencies of',
#  'The Politics of the Pill: Gender, Framing, and Policymaking in the Battle over Birth Control.',
#  'Track Classic, Victoria on Saturday 1',
#  'at the Max Planck Institute, Engel was involved',
#  'it developed during the later 19th to early 20th centuries.Karl Barth, who initially supported',
#  "a researcher position of Italy's National Research Council (CNR) . That position allowed",
#  'and cousins Michael and Vincent Hickey. They came to the attention of police working on',
#  'the book as, "a witty, ribald memoir with his trademark zingers". Marshall commented,',
#  'Nicaragua). This is one of the few Bromelioideae species',
#  'For Yourself" 1:20',
#  '9 December 2018, the following',
#  'Evelyn Malcolm. For services to the community',
#  'colony of Cuban and Spanish cigar makers in what is now part of Ybor City, and helped',
#  '- Kaskade "Sometimes" (Late Night Alumni Mix) 2009 - Late Night Alumni "Finally Found"',
#  'class during the annual Julian Menndez',
#  'and the Library Company of Philadelphia. The New United States Navy written by Charles',
#  'Bjrn Eric Lindh, 1984. (Swedish language only). ISBN 91-86442-06-6 Title: Volvo Gteborg',
#  'de Buenavista. He formed a Revolutionary Provincial Government with Angel Salazar (Governor),',
#  'coaching career with',
#  'and 1510; the exact date of its creation is unknown. This period also represents a turbulent',
#  'he was driven by a desire to keep the American states divided. Through 1862, Napoleon',
#  'Python. This mapping is used by the toPython() method defined on all Literal instances.',
#  'average family size was 2.72.',
#  "Peter's Church is of architectural interest and the main focus of religious worship in",
#  'the economic exchange occur. (Mead was',
#  'Blandick as Sue Barnes Gerald Fielding as Bill Wentworth Al Hart as Jake Mallory Guy Oliver',
#  'Chinese President Hu Jintao visits Australia simultaneously. U.S. President Bush gives',
#  '& Gynecological Nursing & Community Health Nursing) were started with 4 students per speciality.',
#  'https://web.archive.or',
#  'on 29 June 1868.On 30 January',
#  "hectares (105 acres) 'near",
#  'it reached the eighth spot on',
#  'easily trick the viewer into thinking this is',
#  "structural pattern. The ASDF is under the control of the Governor of Alabama, as the state's",
#  'Chargehand of Skilled Labourers, Bickleigh Barracks, Ministry of Defence.',
#  'film was released in March 1994. Critical reception was generally indifferent to mixed,',
#  'a popular hotel',
#  'in 1989 and as well',
#  'the Crown did not apply for an injunction at the time it would have done some good and',
#  'Pimlico. pp. 15. ISBN 978-1-84595-079-8. Lorenzo Kamel (2015). Imperial Perceptions of',
#  'to save Chicago from the declines that other rust belt cities such as Cleveland, Buffalo,',
#  'was the daughter of',
#  'for a Sinn Fin candidate in a 1907 by-election. She drowned at Ilfracombe, Devon in 1911',
#  'they rejoined the league for the 201718 season.',
#  'Ipswich beat high-flying Middlesbrough',
#  'est parfait) - 2008',
#  'work) The Magic Voyage (1992; ink/paint, production camera and',
#  '195); Mojo, in',
#  'had become a war aim in a speech for the Lord Mayor\'s Banquet at the Mansion House, "It',
#  'total production to 26 million carats. In 2003, Debswana opened the Damtshaa diamond mine',
#  'remember anything of what he',
#  'at least in part, by local Democratic politicians. Daley made his mark there, not in sports,',
#  'and its Implications to Biosemiotics, Semiotics Matrix Theory, and Ecological Ethics."',
#  'in an al-Shebaab suicide',
#  'deep breast, broad back, and',
#  'as Black',
#  'Literary Criticism (1987) A Reply',
#  "Esotericism Hinduism Kamboj Valmiki Kamboja Aupamanyava Kamboja Kingdom Occult Who's Who",
#  'For example, with live',
#  'Burundi over delays in EU payments in support of AMISOM and the suggestion by the EU that',
#  'through the merger and restructure of six',
#  'All-electric vehicles with high-capacity',
#  'Carolina. Junaluska married Ni-suh and had three children,',
# ...
#  'Olive Mary Harrison, Editor, British Medical Bulletin, British',
#  'a Mogadishu hotel before assaulting the building and killing civilians. Up to 23 people',
#  'Western, the Bearcats clinched their fourth straight conference title. Entering postseason',
#  'Region], are incursions',
#  'Their Diplomatic Relation, 17891914 (1970). Boucher, Philip P.',
#  'South African Nelson Mandela, then a dissident, later president, was awarded the Freedom',
#  'Regional Council. Robert Grieve Duthie, Chairman, Black & Edgington Ltd., Port Glasgow.',
#  'skeptic Mick West suggested the',
#  'economic processes that tend to bolster the activities of state welfare provision, rather',
#  "Homer's Iliad, i.viii. (1846), influenced by criticisms",
#  'During her stay in London she',
#  'replacement property, dubbed the Rescue Ranch 2.0, was purchased in Petaluma. Animal Place',
#  'South, Heartland Conference, Mountain North, Mountain South, Southwest, Pacific North,',
#  '(SB278), which added clarification to the',
#  'costs which remain unpaid, and',
#  'Airport) at 7:30pm on July 26, fly in a designated straight line and drop a money bundle',
#  'services to Manchester Airport,',
#  'South Wales. For service to health, veterans and the aged. Matron Priscilla Bevan, of',
#  'stem nodes (usually associated with physical',
#  '(uncredited) Graham Moffatt as Fat Man in Vaccination',
#  'quantitatively in 10 minutes at room temperature upon the addition of 2-thienyl boronic',
#  'attached two-storey block to the north. The tower housed the offices of the various municipal',
#  'reported or recorded. Typical categories include: Saucer, toy-top, or disk-shaped "craft"',
#  'after it was converted in 2013 from',
#  'Sergeant Jack William Lee Donaldson, Special Air Service Regiment,',
#  'of the United States invasion of Afghanistan in 2001, the Alabama State Defense Force',
#  'including members of the Macushi, Carib and Patamona tribes, who have maintained much',
#  'down as it comes near the prey. Within 5 centimetres (2.0 in) of the prey, it presses',
#  'graduate from Iowa State as he',
#  "Recipe for Hawaiian Chantilly Cake Frosting Ono Kine Grindz Review of Liliha Bakery's",
#  'Variety gave the film a negative review and wrote, "Theres a lot of double- and triple-crossing,',
#  '2003, she moved',
#  'to manage a',
#  'PFA Young Player of the Year along',
#  'every law student knows, is',
#  'Commission (BMC) has a monopoly on beef production. The national herd was about 2.5 million',
#  'Township, southwest of Chicago. Daley',
#  'chairman and new manager Steve Lovell, having',
#  'ATIC [Air Technical Intelligence Center] will analyze the data is worthy of release, due',
#  'killed while two other soldiers and a woman were reported to be injured in firing by Pakistan',
#  'proposal is Lloyd George, who I need not say, does not care a damn for the Jews or their',
#  'Immature birds',
#  'Robert Strachan acclaimed (Held on',
#  'Evanston, Illinois and is interred in Maple Hill Cemetery, in Charlotte, Michigan. United',
#  'Pensnett Railway, a mineral line owned by the Dudley Estate itself. Also nearby were the',
#  "of the 1st Cavalry Regiment, King's Guard the Centenary of Siam Commercial Bank the 50th",
#  'There are a few high-level APIs that extend RDFLib graphs into other Pythonic idioms.',
#  'the null hypothesis, UFO enthusiasts tend',
#  'in 2009). 1973: Rauris Literature Prize 1980: Literature of the Cultural Fund of the City',
#  'out the syndicates. Tom',
#  'parents in Poland, Kamien and his family escaped',
#  'Gold for AXM magazine, Boy',
#  "St. Cuthbert's Co-operative Association Ltd. James Chattley George, Principal Professional",
#  'lessons to Grace Sinclair. She is',
#  'first EP, A Cursive Memory. It featured the original version of The Piano Song. In 2005',
#  'Trust as "at risk", the',
#  'born at Norwich, probably about 1670.',
#  'most famous journal articles in',
#  'and Technology Officer, Department of the Environment. Archibald John Campbell Mitchell,',
#  'The Viennese premiere, conducted by Bruno',
#  'July 25, 2015. On April',
#  'of the memorial began in the spring of',
#  'known for college rankings based on how students rate their schools. William Paterson',
#  'Rain Parade lead guitarist Matt Piucci and recruited songwriter Sonny Mone from Hanover,',
#  'the Fencepost limestone is quite durable in the ground, so, the Fencepost can be seen',
#  'thirty-one improvised nonsense songs Morrison recorded in order',
#  'importance in understanding the origin of life, received several international honours',
#  '"serious misconduct" but believed she had not acted corruptly.In 2016, Scaffidi insulted',
#  '& field (3): 1966, 1969, 1970 Outdoor track & field (3): 1959, 1960, 1970 Women (1) Outdoor',
#  'he had served on the board since',
#  'Irati on the south. In 778 Roland, the warden of the Breton March, had accompanied Charlemagne',
#  'Sergeant of Police, Royal St. Lucia Police Force. Joseph Frank',
#  'in the County of Verchres: the Village Municipality of McMasterville; in the County',
#  'the number of teams to 12 with',
#  'contract. Further, in certain circumstances an account of profits is ordered in preference',
#  '/www.momh.org.uk/exhibit',
#  'of seizures. Over time those affected with Lafora disease have brain changes that cause',
#  'Yellow = draw; Red = opponents win. Players Nationality Competitions Designations The',
#  'found in the rain forest,',
#  'think that interbreeding with coated (Peruvian) dogs is required to maintain functional',
#  'also spelled',
#  'in a',
#  'wherein is indicated the amount of the judgment debt on the date of the order laying down',
#  'is too wet or too deep, will result in inefficient germination. The recommended sowing',
#  'had 8,754 aircraft operations, an average of 23 per day: 97% general aviation and 3% military.',
#  'special awards from the Mystery Writers of America first, in 1985, the Ellery Queen Award',
#  "For services to the London Federation of Boys' Clubs. Gilbert Coates, lately Higher Executive",
#  'is constraining the',
#  '25 poll, ranking Northwest Missouri State 1st. Along with Dorrel, there are 12 assistants.',
#  'from or to the VVS area. The use of buses in the district of Gppingen is possible with',
#  'have to have a National Guard."',
#  'King Bhumibol Adulyadej the 80th Anniversary',
#  'quadraplegic rehabilitation. Military DivisionAdmiral Sir Henry Leach, KCB. Military DivisionRoyal',
#  'in brick to designs of',
#  'and festivals in Europe',
#  '.... Richard Love For Lydia (1977) TV Series .... Richardson Anne of Avonlea (1975) TV',
#  'of Oxford, University of Cambridge College',
#  'history teaching in Berkeley, California for',
#  'by Kat Burns. Vichada (2012) directed by Kat',
#  'Rodrigo Lara Bonilla as a means of funneling large sums of cash outside of Colombia with',
#  'their home games at',
#  'Life, Vol. 18, No. 5. Cooper, William John. 1933. The Office of Education. The Scientific',
#  'it is the second longest played',
#  'and particularly to young people in Derby.',
#  "The following table lists what details are known of the Ugandan battle groups, or 'Ugabag',",
#  'on a mobile device or on another TV without the need of a set-top box. In February 2014,',
#  'broadcast 30 April 2019.',
#  'Gould was a keynote speaker in Beirut for the Samir Kassir Foundation on the topic of',
#  'Kamaladevi Chattopadhyay, R. R. Diwakar, and U. S. Mallya. In the early 1920s, he was',
#  'mysterious objects were possibly Russian tests of captured German V1 or V2 rockets. Although',
#  'Jazeera and Channel 4 to analyse the documents which detail torture, summary executions,',
#  'in Kenya and Uganda. Four of 31',
#  'Change. The name was changed to the Solomon',
#  'Cambridge University, 10. Both',
#  '1987 release date, a very tight schedule for a feature-length animated film. However,',
#  'the 1890s, the team was referred to as the',
#  'pilot UFO sightings, of',
#  'Tudrick. Under the management of Howard Hertz, the band signed with Lizard King Records.',
#  'that the vocabulary must be narrowly restricted to obtain a useful level of understanding.',
#  'further and "gave the American Legion of Alabama',
#  'to alter his original design',
#  'Elliott family, though, Stephen Elliott freed',
#  'team (for',
#  'possible, using its head and pronotum, allowing',
#  'Pardue, and Elizabeth Blackburn. One of his students',
#  'Lasname lennuvli) was an airfield in Tallinn, Estonia.',
#  'C. Drury School for the Deaf is a provincial school in Milton, Ontario, Canada with residential',
#  'the jayhawkers: Confederated at first for defense against pro-slavery',
#  'it took off from there! Finn had already been working in the studio with Ryan Raddon (aka',
#  'Creeting St Mary Pits is a 5.4 hectare geological Site of Special Scientific Interest',
#  'on 9 November 1979. The fourth,',
#  'receivers are placed within close proximity of each other, they do not exhibit similar',
#  'a group of three militiamen patrolling along the creek bed and interpreting this as an',
#  'in retaliatory firing this year, while suffering',
#  'system" (UAS) are also sometimes used in a military aviation context to describe unidentified',
#  'Institute (where he learned clerical skills) and took night classes at DePaul University',
#  'and Heritage Centre, a not-for-profit company and registered charity, and has the support',
#  'was accepted in FIFA during their 66th congress in Mexico with 141 votes in favour and',
#  'have longer chains that have clustered arrangement of branch points that form crystalline',
#  'occasionally even the theremin for that out-of-this-world sound. The arrangements of the',
#  'of Martin Luther King Jr.). On one occasion, Judge Hatchett ran an intervention herself,',
#  'Woolchurch Haw in the City of London. In addition he took up the post of organist at St',
#  'Research Centre. Oswald Summers, Senior Principal, Department of Health & Social Security.',
#  'a plasterer and his mother, Elizabeth, a dressmaker and housewife. They went on to have',
#  'the Reindeer in Close Encounters of',
#  'with Peter Doherty on BBC Radio',
#  'family to attend',
#  'has never had her',
#  'cachiai (Mifsud, 1998) Mifsud C. (1998). Pseudographis cachiai n. gen. & n. sp. , and',
#  'the southern edge of the town, had overflown its banks four days earlier". Sir Walter',
#  'the Pilot Field, facilities were very basic, until the construction of the main stand',
#  "officer Lawrence O'Neill as American at airport Al Ricketts as Gas station owner Atsuko",
#  'pragmatists. He is regarded as one of the founders of symbolic interactionism and of what',
#  'occurred. The Inter-Services Public Relations said that there had been only "cross border',
#  'else on California, crackling a little in the middle range." Brandon Friederich, staff',
#  'by acting',
#  'Four year degree',
#  'jointly with fellow biologist Giorgos Catsadorakis. The Central Highlands is a region',
#  'and moisture stable, inexpensive to make,',
#  'US Hot 100),(#1 U.S. Top R&B) Music.aol.com Not So Dusty is a compilation album of Slim',
#  'the UK and paid off; she was disarmed and sold into merchant service as Lady Enchantress.',
#  'Olympics in Montreal, Twombly broke a major story exposing Russian cheating at the games.',
#  'County Council instead.Since the',
#  'of the French armies, in the days when a Marshal of France usually governed only one army.',
#  'Grand Haven. The first',
#  'and Gaming Center before the addition of',
#  'Director, The Press Council. Leslie Rundell Pincott, lately Managing',
#  'save Sybil and the Super-Ego decides that he has been wrong and that he will save the',
#  'Jayhawkers by the student body. Over time, the name was gradually supplanted by its shorter',
#  'km northwest of Afmadow, close to Subow centre using artillery fire and supported by helicopter',
#  "of the 2010 television series It's Effin' Science.Zdenek is the eldest of five siblings.",
#  'largest herds of',
#  'which consisted of lead',
#  'an elected',
#  'Paul Burke described',
#  '300 neglected farmed animals at one time. In addition to the permanent sanctuary, Animal',
#  'most successful coaches (including Phog Allen, Adolph Rupp, Ralph Miller, Dutch Lonborg,',
#  'out to be either a',
#  'Wales April The North',
#  'Indian tribal dress, colours, and textiles. Persian Pageant: A Cultural History of Iran,',
#  'in Vietnam. News coverage captured',
#  '1912, also in George Street.From 1890-99 Sands Directory records "R. C. Thorp, surgeon"',
#  'Casualty .... Alan /',
#  'the coalition. A division was',
#  'Roundtree spent 2005 on the coaching',
#  'via Darwin, Northern Territory. For',
#  'release in fake stereo, despite the availability of several tracks with official true',
#  'openness on the part of the',
#  'Corrections The stock of plug-in electric passenger cars in Canada in use totaled 141,060',
#  'She was a stalwart on CBC Radio from the 1940s to the 1960s, working with such notables',
#  '(SAIL) had pioneered personal display terminals, but the 1971 system was showing its age.',
#  'of city bus driving',
#  'services) The Chipmunk Adventure (1987; additional animation) The Wind in the Willows',
#  'reform, her status was not affected by the subsequent birth of her brother, Prince Sverre',
#  'gave the album 3 out of 5 stars saying that "The beauty of A Hundred Days Off is that',
#  'to upgrade democracy for the Internet era" (TEDGlobal 2014) Cirsium mohavense',
#  'outside musicians. The band released two',
#  'is that references are made to things moving through the sky. These have been interpreted',
#  'Senior Steward to the Lord Mayor of London. Gavin Nisbet Dryden, lately Lorry Driver,',
#  'ring zone 5. As the prices for the zones remained constant, some journeys in the tariff',
#  'directed 2007 feature-film Klass about school bullying and violence.Notable film roles',
#  'threatened by mercury pollution in the',
#  'awareness is critical in achieving this',
#  'that the ETA is not accredited in the Netherlands. However, ETA students were able to',
#  'than 10% of reported sightings remain',
#  'by Bergen Nordhordland',
#  'the year and the 24th',
#  'working at a Pennsylvania railroad',
#  'This coat of arms had been "borne and used by his family" for some time and can be described',
#  'Tears". On Justified, Grosse portrayed recurring character Errol Butler who is Ellstin',
#  'of the State, their 1999 breakthrough LP. Barker drums in a fast and syncopated pattern,',
#  'of Aeronautical Engineering, is a comprehensive research university in',
#  'a son, Keerthi. A Materialist Study of Literature (1982) A Marxist Study of Modern Sinhala',
#  'flute, saxophone Dewayne McKnight, David T. Walker',
#  '(headquartered at Fort Sam Houston, Texas). Hagood requested a meeting with Roosevelt',
#  'opposition rather',
#  'the Great Depression in the',
#  'are former Governors Iris Rezende',
#  'his 1973 science fiction',
#  'the land on which most of Roseneath Cottage is now sited. After the death of her husband,',
#  'second operation, "Hobart", was a search',
#  'like the town, is pronounced "Redding"a',
#  'Union of Engineering Workers. Lucy Emily Rose Blackwell, Executive Officer, Department',
#  'each constituency, and a total of 324',
#  'Lesbian and Gay Archives Australian Archives of the Dance Australian Data Archive Australian',
#  'Lance Fitzgerald Studdert. For services to the community. Marta Sybaczynskyj. For services',
#  'December 31, 1999) was an American',
#  'poetry as a solo artist. Dr John Cooper Clarke has described his writing as "...exceptional',
#  'are Grade I listed., Downton village',
#  '16mm print. A single surviving 35mm nitrate studio print became the basis for a restoration,',
#  'who served in the Great',
#  'present) BG Erastus B. Tyler June 9, 1862 - Battle of Port Republic, Va. The War of the',
#  'International Series Gold of the',
#  'services to education. Mae Valentine Clarke.',
#  'in 2015. It',
#  'such as the Super',
#  'Sierra Leone in',
#  'x Oncidium xBaumannara : Comparettia x',
#  'his family business,',
#  'CYYZ - Toronto Pearson International Airport in',
#  'else is going to do in order to carry out his own play. He has to take all of these',
#  '(the first run in over 2',
#  ...]

# %% [markdown]
# # Split data #

# %%
train_split = int(0.9 * len(dataset))
val_split = int(train_split + 0.09 * len(dataset))
# test_split = int(train_split + 0.1 * len(dataset))

train_labels = dataset[:train_split]
val_labels = dataset[train_split:val_split]
test_labels = dataset[val_split:]

# val_labels = dataset[train_split:val_split]
# test_labels = dataset[val_split:]

print('Len train: ' + str(len(train_labels)))
print('Len val: ' + str(len(val_labels)))
print('Len test: ' + str(len(test_labels)))
# Out:
# Len train: 30918
# Len val: 3091
# Len test: 345

# %% [markdown]
# # Model #

# %%
timesteps = 256

width = 4096
height = 64

max_label_len = longest_label + 2
max_label_len
# Out:
# 111

# %%
from tensorflow.keras import applications, backend as K
from tensorflow.keras import models, losses, optimizers, Model, utils
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, MaxPooling2D, Dropout
from tensorflow.keras.layers import Flatten, Dense, Lambda, Reshape, Bidirectional, LSTM, GRU
from tensorflow.keras.layers import Activation, add, Concatenate, Attention, Embedding
from keras_self_attention import SeqSelfAttention


def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

def build_model(num_classes=94, timesteps=timesteps, max_label_len=max_label_len, input_shape=(4096, 64, 1), training=False):
    inputs = Input(name='the_inputs', shape=input_shape, dtype='float32')
    
    # Convolution layer (VGG)
    inner = Conv2D(32, (3, 3), padding='same', name='conv1-1', kernel_initializer='he_normal')(inputs)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(32, (3, 3), padding='same', name='conv1-2', kernel_initializer='he_normal')(inputs)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(2, 2), name='max1')(inner)

    inner = Conv2D(64, (3, 3), padding='same', name='conv2-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(64, (3, 3), padding='same', name='conv2-2', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(2, 2), name='max2')(inner)

    inner = Conv2D(128, (3, 3), padding='same', name='conv3-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(128, (3, 3), padding='same', name='conv3-2', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(4, 2), name='max3')(inner)

    inner = Conv2D(256, (3, 3), padding='same', name='conv4-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(256, (3, 3), padding='same', name='conv4-2')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(1, 2), name='max4')(inner)

    inner = Conv2D(512, (2, 2), padding='same', kernel_initializer='he_normal', name='con5-1')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(512, (2, 2), padding='same', kernel_initializer='he_normal', name='con5-2')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)

    # CNN to RNN
    inner = Reshape(target_shape=((timesteps, 2048)), name='reshape')(inner)
    inner = Dense(128, activation='relu', kernel_initializer='he_normal', name='dense1')(inner)
    inner = Dropout(0.2)(inner)

    # RNN
    lstm1 = Bidirectional(LSTM(256, return_sequences=True, kernel_initializer='he_normal', 
                               name='lstm1'))(inner)
    lstm2 = Bidirectional(LSTM(512, return_sequences=True, kernel_initializer='he_normal', 
                               name='lstm2'))(lstm1)
    
    attention = SeqSelfAttention(attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL,
                                 kernel_regularizer=tf.keras.regularizers.l2(1e-4),
                                 bias_regularizer=tf.keras.regularizers.l1(1e-4),
                                 attention_regularizer_weight=1e-4,
                                 name='Attention')(lstm2)
#     attention = Dropout(0.2)(attention)
    
    # RNN output -> character activations:
    outer = Dense(num_classes + 1, kernel_initializer='he_normal', name='dense2')(attention)
    y_pred = Activation('softmax', name='softmax')(outer)

    labels = Input(name='the_labels', shape=[max_label_len], dtype='float32')
    input_length = Input(name='input_length', shape=[1], dtype='int64')
    label_length = Input(name='label_length', shape=[1], dtype='int64')

    # Keras doesn't currently support loss funcs with extra parameters
    # so CTC loss is implemented in a lambda layer
    loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([y_pred, labels, input_length, label_length]) #(None, 1)
    
    y_func = K.function([inputs], [y_pred])
    if training:
        return Model(inputs=[inputs, labels, input_length, label_length], outputs=loss_out), y_func
    else:
        return Model(inputs=[inputs], outputs=y_pred)

# %%
model, y_func = build_model(timesteps=timesteps, max_label_len=max_label_len, training=True)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_inputs (InputLayer)         [(None, 4096, 64, 1) 0
# __________________________________________________________________________________________________
# conv1-2 (Conv2D)                (None, 4096, 64, 32) 320         the_inputs[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4096, 64, 32) 128         conv1-2[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4096, 64, 32) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# max1 (MaxPooling2D)             (None, 2048, 32, 32) 0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv2-1 (Conv2D)                (None, 2048, 32, 64) 18496       max1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 2048, 32, 64) 256         conv2-1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 2048, 32, 64) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2-2 (Conv2D)                (None, 2048, 32, 64) 36928       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 2048, 32, 64) 256         conv2-2[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 2048, 32, 64) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# max2 (MaxPooling2D)             (None, 1024, 16, 64) 0           activation_13[0][0]
# __________________________________________________________________________________________________
# conv3-1 (Conv2D)                (None, 1024, 16, 128 73856       max2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 1024, 16, 128 512         conv3-1[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 1024, 16, 128 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv3-2 (Conv2D)                (None, 1024, 16, 128 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 1024, 16, 128 512         conv3-2[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 1024, 16, 128 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# max3 (MaxPooling2D)             (None, 256, 8, 128)  0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv4-1 (Conv2D)                (None, 256, 8, 256)  295168      max3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 256, 8, 256)  1024        conv4-1[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 256, 8, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv4-2 (Conv2D)                (None, 256, 8, 256)  590080      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 256, 8, 256)  1024        conv4-2[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 256, 8, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# max4 (MaxPooling2D)             (None, 256, 4, 256)  0           activation_17[0][0]
# __________________________________________________________________________________________________
# con5-1 (Conv2D)                 (None, 256, 4, 512)  524800      max4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 256, 4, 512)  2048        con5-1[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 256, 4, 512)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# con5-2 (Conv2D)                 (None, 256, 4, 512)  1049088     activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 256, 4, 512)  2048        con5-2[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 256, 4, 512)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 256, 2048)    0           activation_19[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 256, 128)     262272      reshape[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 128)     0           dense1[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 256, 512)     788480      dropout_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 256, 1024)    4198400     bidirectional_2[0][0]
# __________________________________________________________________________________________________
# Attention (SeqSelfAttention)    (None, 256, 1024)    1048577     bidirectional_3[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 256, 95)      97375       Attention[0][0]
# __________________________________________________________________________________________________
# softmax (Activation)            (None, 256, 95)      0           dense2[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         [(None, 111)]        0
# __________________________________________________________________________________________________
# input_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# label_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           softmax[0][0]
#                                                                  the_labels[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 9,139,232
# Trainable params: 9,135,328
# Non-trainable params: 3,904
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

plot_model(model=model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %% [markdown]
# # Data generator #

# %%
import itertools

def return_classes(string):
    text = [' '] + list(string) + [' ']
    classes = [data.index(x) if x in data else 1 for x in text]
    return np.asarray(classes)

def return_text(classes):
    text = ''
    for c in classes:
        if 0 <= c < len(data) and c != 1:
            text += data[c]
    return text

def decode_batch(out, callback=False):
    ret = []
    for i in range(out.shape[0]):
        out_best = list(np.argmax(out[i, 2:], 1))
        out_best2 = [k for k, g in itertools.groupby(out_best)]
        outstr = return_text(out_best2)
        if callback:
            print(f'{out_best} -> {outstr}')
        ret.append(outstr)
    return ret

def gen_text_image(text, padding=16):
    font = random.choice(fonts)
    font_size = random.randrange(30, 61)
    fnt = ImageFont.truetype(font, font_size)
    width, _ = fnt.getsize(text)
    img = Image.new('L', (width + (padding + 1) * 2, 64), color=255)
    d = ImageDraw.Draw(img)

    if 'calibri' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'verdana' in font:
        d.text((padding + 2,-8), text, font=fnt, fill=0)
    elif 'constan' in font:
        d.text((padding + 2,0), text, font=fnt, fill=0)
    elif 'corbel' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'consola' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'cour' in font:
        d.text((padding + 2,-4), text, font=fnt, fill=0)
    elif 'tahoma' in font:
        d.text((padding + 2,-8), text, font=fnt, fill=0)
    else:
        d.text((padding + 2,-6), text, font=fnt, fill=0)
        
    image = np.array(img)
    image = add_salt_and_pepper(image, 0.2)
    image = otsu_thresholding(image)
    image = inverse(image)
    image = (image / 255.) * 2. - 1.
    return image

def inverse(image):
    return cv2.bitwise_not(image)

def add_salt_and_pepper(image, amount):
    output = np.copy(np.array(image))
    # add salt
    nb_salt = np.ceil(amount * output.size * 0.5)
    coords = [np.random.randint(0, i - 1, int(nb_salt)) for i in output.shape]
    output[coords] = random.randint(50,200)

    # add pepper
    nb_pepper = np.ceil(amount * output.size * 0.5)
    coords = [np.random.randint(0, i - 1, int(nb_pepper)) for i in output.shape]
    output[coords] = random.randint(0,100)
    return np.asarray(Image.fromarray(output))

# %%
class TextImageGenerator:
    def __init__(self, labels, img_w=4096, img_h=64,
                 batch_size=16, timesteps=timesteps, training=True, max_text_len=max_label_len):
        self.dim = (img_w, img_h, 1)
        self.batch_size = batch_size
        self.max_text_len = max_text_len
        self.labels = labels
        self.n = len(self.labels)
        self.indexes = list(range(self.n))
        self.training = training
        self.cur_index = 0
        
    def next_sample(self):
        self.cur_index += 1
        if self.cur_index >= self.n:
            self.cur_index = 0
            random.shuffle(self.indexes)
        return self.labels[self.indexes[self.cur_index]]
            
    
    def next_batch(self):
        while True:
            X = np.zeros((self.batch_size, *self.dim))
            y = np.zeros((self.batch_size, self.max_text_len), dtype=int)
            input_length = np.full((self.batch_size, 1), timesteps, dtype=np.float32)
            label_length = np.zeros((self.batch_size, 1), dtype=np.float32)
            
            for i in range(self.batch_size):
                label = self.next_sample()
                # Store sample
                image = np.swapaxes(gen_text_image(label), 0, 1)
                image = np.expand_dims(image, -1)
                X[i, 0:image.shape[0], :] = image

                # Store class
                label_classes = return_classes(label)
                y[i, :len(label_classes)] = label_classes
                label_length[i] = len(label_classes)

            inputs = {
                'the_inputs': X,  # (bs, 4096, 64, 1)
                'the_labels': y,  # (bs, max_label_len)
                'input_length': input_length,  # (bs, 1)
                'label_length': label_length  # (bs, 1)
            }
            outputs = {'ctc': np.zeros([self.batch_size])}   # (bs, 1)
            yield (inputs, outputs)

# %% [markdown]
# # Callbacks #

# %%
import editdistance
from datetime import datetime
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.callbacks import TensorBoard, ReduceLROnPlateau, Callback

class VizCallback(Callback):
    def __init__(self, y_func, text_img_gen, text_size, num_display_words=10):
        self.y_func = y_func
        self.text_img_gen = text_img_gen
        self.num_display_words = num_display_words
        self.text_size = text_size

    def show_edit_distance(self, num):
        num_left = num
        mean_norm_ed = 0.0
        mean_ed = 0.0
        while num_left > 0:
            word_batch = next(self.text_img_gen.next_batch())[0]
            num_proc = min(word_batch['the_inputs'].shape[0], num_left)
            # predict
            inputs = word_batch['the_inputs'][0:num_proc]
            pred = self.y_func([inputs])[0]
            decoded_res = decode_batch(pred)
            # label
            labels = word_batch['the_labels'][:num_proc].astype(np.int32)
            labels = [return_text(label) for label in labels]
            
            for j in range(num_proc):
                edit_dist = editdistance.eval(decoded_res[j], labels[j])
                mean_ed += float(edit_dist)
                mean_norm_ed += float(edit_dist) / len(labels[j])

            num_left -= num_proc
        mean_norm_ed = mean_norm_ed / num
        mean_ed = mean_ed / num
        print('\nOut of %d samples: \nMean edit distance:'
              '%.3f \nMean normalized edit distance: %0.3f \n'
              % (num, mean_ed, mean_norm_ed))

    def on_epoch_end(self, epoch, logs={}):
        batch = next(self.text_img_gen.next_batch())[0]
        inputs = batch['the_inputs'][:self.num_display_words]
        labels = batch['the_labels'][:self.num_display_words].astype(np.int32)
        labels = [return_text(label) for label in labels]
         
        pred = self.y_func([inputs])[0]
        pred_texts = decode_batch(pred)
        
        for i in range(min(self.num_display_words, len(inputs))):
            print("label: {} - predict: {}".format(labels[i], pred_texts[i]))

        self.show_edit_distance(self.text_size)

# %%
batch_size = 16
train_generator = TextImageGenerator(train_labels, training=True, batch_size=batch_size)
val_generator = TextImageGenerator(val_labels, training=False, batch_size=batch_size)
test_generator = TextImageGenerator(test_labels, training=False, batch_size=batch_size)

log_dir = "logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
output_dir = './models/VGG/AttentionRegularizers'
weight_path = f'{output_dir}/ocr_model_{datetime.now().strftime("%Y%m%d-%H%M%S")}' + '_epoch_{epoch:02d}.h5'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

tensorboard = TensorBoard(log_dir=log_dir)
checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
vis = VizCallback(y_func, test_generator, len(test_labels))
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='min')

initial_learning_rate = 0.001
epochs = 100

callbacks = [early_stop, tensorboard, vis, checkpoint]
# callbacks = [early_stop, tensorboard, vis]
# callbacks = [early_stop, tensorboard, vis, LearningRateScheduler(lr_time_based_decay, verbose=1)]

# %% [markdown]
# # Training #

# %%
def train(callbacks, batch_size, epochs, initial_epoch=0):
    print('Training process starting...')
    H = model.fit(train_generator.next_batch(),
                  steps_per_epoch=train_len//batch_size,
                  validation_data=val_generator.next_batch(),
                  validation_steps=val_len//batch_size,
                  epochs=epochs, 
                  initial_epoch=initial_epoch,
                  callbacks=callbacks,
                  verbose=1)
    return H

# %%
train_len = len(train_labels)
val_len = len(val_labels)

# %%
from tensorflow.keras import optimizers

opt = optimizers.Adam(learning_rate=initial_learning_rate)

# %%
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer='adam')

train(callbacks, batch_size, epochs)

# %% [markdown]
# # Testing #
