# %% [markdown]
# # Test tensorflow gpu #

# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
  except RuntimeError as e:
    print(e)

# %% [markdown]
# # Dataset #

# %%
import os
import codecs

data = {}
classes_file = '../Dataset/classes.txt'
with codecs.open(classes_file, 'r', encoding='utf-8') as cF:
    data = cF.read().split('\r\n')
len(data)
# Out:
# 94

# %%
import os
from PIL import Image, ImageDraw, ImageFont

text_source = '../Dataset/source.txt'
fonts_path = '../Dataset/Fonts'
fonts = [f'{fonts_path}/{f}' for f in os.listdir(fonts_path)]
fonts
# Out:
# ['../Dataset/Fonts/arial.ttf',
#  '../Dataset/Fonts/arialbd.ttf',
#  '../Dataset/Fonts/arialbi.ttf',
#  '../Dataset/Fonts/ariali.ttf',
#  '../Dataset/Fonts/calibri.ttf',
#  '../Dataset/Fonts/calibrib.ttf',
#  '../Dataset/Fonts/calibrii.ttf',
#  '../Dataset/Fonts/calibriz.ttf',
#  '../Dataset/Fonts/cambria.ttc',
#  '../Dataset/Fonts/cambriab.ttf',
#  '../Dataset/Fonts/cambriai.ttf',
#  '../Dataset/Fonts/cambriaz.ttf',
#  '../Dataset/Fonts/consola.ttf',
#  '../Dataset/Fonts/consolab.ttf',
#  '../Dataset/Fonts/consolai.ttf',
#  '../Dataset/Fonts/consolaz.ttf',
#  '../Dataset/Fonts/constan.ttf',
#  '../Dataset/Fonts/constanb.ttf',
#  '../Dataset/Fonts/constani.ttf',
#  '../Dataset/Fonts/constanz.ttf',
#  '../Dataset/Fonts/corbel.ttf',
#  '../Dataset/Fonts/cour.ttf',
#  '../Dataset/Fonts/courbd.ttf',
#  '../Dataset/Fonts/courbi.ttf',
#  '../Dataset/Fonts/couri.ttf',
#  '../Dataset/Fonts/impact.ttf',
#  '../Dataset/Fonts/Roboto-Black.ttf',
#  '../Dataset/Fonts/Roboto-BlackItalic.ttf',
#  '../Dataset/Fonts/Roboto-Bold.ttf',
#  '../Dataset/Fonts/Roboto-BoldItalic.ttf',
#  '../Dataset/Fonts/Roboto-Italic.ttf',
#  '../Dataset/Fonts/Roboto-Regular.ttf',
#  '../Dataset/Fonts/tahoma.ttf',
#  '../Dataset/Fonts/tahomabd.ttf',
#  '../Dataset/Fonts/times.ttf',
#  '../Dataset/Fonts/timesbd.ttf',
#  '../Dataset/Fonts/timesbi.ttf',
#  '../Dataset/Fonts/timesi.ttf',
#  '../Dataset/Fonts/trebuc.ttf',
#  '../Dataset/Fonts/verdana.ttf',
#  '../Dataset/Fonts/verdanab.ttf',
#  '../Dataset/Fonts/verdanai.ttf',
#  '../Dataset/Fonts/verdanaz.ttf']

# %%
dataset = []
sequence_len = 20

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import cv2

def draw_img(img):
    plt.imshow(np.asarray(img), cmap='gray', vmin=0, vmax=255)
    plt.show()

def load_img(img):
    return cv2.imread(img, cv2.IMREAD_GRAYSCALE)

def dilate_img(img):
    return cv2.dilate(img, np.ones((2,2), np.uint8))

def otsu_thresholding(img):
    norm_img = np.zeros(img.shape)
    img = cv2.normalize(img, norm_img, 0, 255, cv2.NORM_MINMAX)
    blur = cv2.GaussianBlur(img, (3,3), 0)
    _, img = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    img = dilate_img(img)
    return img

# %% [markdown]
# ## Load dataset ##

# %%
with open(text_source) as txt:
    word_count = 0
    sequence = ''
    dataset = []
    for i, line in enumerate(txt):
        words = line.split(' ')
        for single_word in words:
            word = ''.join([c for c in single_word if c in data])
            word.replace('\n', ' ')
            
            if len(word) < 1:
                continue
            
            if len(word) > 30:
                split_count = len(word) // 30 + 1
                for i in range(split_count):
                    start = i * split_count
                    end = start + len(word) // split_count
                    dataset.append(word[start:end])          
                continue
                
            sequence = sequence + word + ' '
            word_count = (word_count + 1) % sequence_len
            if word_count == 0 or len(sequence) > 85:
                dataset.append(sequence[:-1])
                sequence = ''
                
dataset = list(set(dataset))
len(dataset)
# Out:
# 34354

# %% [markdown]
# ## Shuffle dataset ##

# %%
sorted_data = sorted(dataset, key=len)
longest_label = len(sorted_data[-1])
longest_label
# Out:
# 109

# %%
import random

random.seed = 1234567

random.shuffle(dataset)
# dataset = dataset[:20000]
dataset
# Out:
# ['school for freed slave men and also played a major role in local and state suffrage movements.',
#  'but almost always arranged in a lighter',
#  'were killed, along with two of',
#  'and restitution casesRuxley Electronics &',
#  'Phyllodineae native to eastern Australia. The shrub typically grows to a height of 1.5',
#  'for Murray, who he',
#  'in an application',
#  'Fiorello LaGuardia to the Municipal Court',
#  '13th century and the chancel from',
#  'of singers, Sally Matthews, Bryan Hymel, Owen Gradus and Christian Van Horn including',
#  'of Cremorne, New South Wales. For service to banking. Brigadier John Gilbert McKinna,',
#  'Ingrid Alexandra christened the research vessel',
#  'long term lease with Hastings Borough Council',
#  'section at St Kilda Cemetery in Melbourne. There is a 933 granite memorial (in the form',
#  'video. "The Real Me" was originally',
#  'of principal and interest in the judgment below, to the time of affirmance, but no further.."',
#  'an outstanding tackle on the Oregon State Aggies football team. Locey lettered in 1915',
#  'it had killed 2 Pakistani soldiers and destroyed 14 military posts in retaliation. 2 Indian',
#  'and two civilian contractors dead as well as five others who escaped wounded. Two hours',
#  'a successor program named the Unidentified Aerial Phenomena Task Force is currently operational.',
#  'religions was in conflict with the French crown, attempted to colonize the New World to',
#  'the poverty line, including 26.40% of those under age 18 and 10.80% of those age 65 or',
#  'service. Horace Clive Miller, of Nedlands, Western Australia. For service to aviation.',
#  'site contributes original',
#  'with humorous anecdotes." The Commitment recounts the author\'s experiences along with',
#  'and the church has been',
#  'is that references are made to things moving through the sky. These have been interpreted',
#  'Region, Central Electricity Generating Board. Grace Beatrice Hasler, Personal',
#  'camera system to help maintain what he felt was the right balance between the size of',
#  'Only four Republicans were to win the county in the seventeen Presidential elections between',
#  'April 17, 1996) was',
#  'military case over Tehran, recorded in CIA and',
#  'The gulf measures approximately 142 miles (229 km) at its mouth and covers approximately',
#  "to Hastings Town in 1976 and took Hastings United's place in the Southern Football League",
#  'and redrew the graphics and added additional sound effects taken from military training',
#  'Hertfordshire Constabulary. Albert Laugharne, Chief Constable, Warwickshire Constabulary.',
#  'Australia announced its Indoor Australian Championships will be held in Wollongong in',
#  "1978, 1980, 1981, 1982, 1983Women's",
#  'Rugby Union. Charles Harry Lawrence, MBE, Director, James Purdey',
#  'The game began development some time before',
#  'Works by or about Johann Nikolaus',
#  'one hundred and eighteen children,',
#  'In 1931 Lewis, under the pen name Wisar Spenle',
#  'performance earned them their third black',
#  'Lomax and helped to',
#  'problems. These include Inflammatory',
#  'Howard Roberts, OBE, of Balwyn. For services to the handicapped.',
#  'game for Birmingham City was',
#  'a good product choice to soften and moisturize cleansed skin. The dogs seem to prefer',
#  'in spite of creating the iconic',
#  'was not sharing everything',
#  "affiliates' projects, non-Wu-Tang Clan related albums such as ONYX Shut 'Em Down, Vordul",
#  'most groups consist of family',
#  'priests; she was interred as if she were a commoner. The diarist Agostino Lapini recorded',
#  'none of his compositions for Control Denied had been used to fill space for a Death album.',
#  'Wilderness. This is thought to be the largest such stand this far northwest of the crest',
#  'Man #16-17 (2004) Concrete #1-10 (198788) Concrete Color Special (1989) Concrete: Fragile',
#  'Caravan and Autumn Leaves. Classical pieces are also popular among space age composers,',
#  'a.k.a. Kid Loco is a French electronic musician, DJ, remixer and producer. He was born',
#  'in Canada as of December 2015, of which, 10,034 (54%) are all-electric cars and 8,417',
#  'it was not until 2013 that',
#  'a North American professional indoor soccer league. The MASL features teams across North',
#  '10,000 was paid in cash and the remainder by a mortgage provided by the Dudley estate',
#  'al-Shebaab attacked government forces in a position 50 km southwest of Mogadishu. In response',
#  "sixth term in the penitentiary. John Lomax, attempting to depict Iron Head's dialect,",
#  'poetry was created to move the reader triangularly through the canvas, hopping from subject',
#  'made by Disney. He has also done storyboards for many non-Disney animated films with Toronto-based',
#  '1963 Lieutenant General P.S. Gyani (India) SeptemberNovember 1963',
#  'Governor of New Jersey in 1946. Hansen was born in 1891 in Jersey City, New Jersey. He',
#  'Science and Applied Mathematics and Sessional',
#  'the box-office record for a',
#  'that ensemble (initially billed as Crazy Horse for the inaugural concerts at the Roxy',
#  'regular season consisted of 95',
#  'in the slave trade with Africa, sugar trade with plantations of the Antilles, and fur',
#  'are three schools in the district: Union Local Elementary School, Union Local Middle School,',
#  'heat. Many in Peru use the dogs as living hot-water bottles for warmth at night, or pain',
#  'far as the appropriate remedy is the payment of money or the delivery up of a chattel',
#  "Delaware Fightin' Blue Hens basketball",
#  'the two drivers involved in the destruction of the Stupa had met with accidents at different',
#  'upon him in August 2020.',
#  'Shaukat Kiani was killed due to Indian shelling in Abbaspur sector along with a civilian.On',
#  'external research project of top-level scientists,',
#  'Bolton Wanderers as their new manager.5 October 1974: Leeds United beat Arsenal 20 at',
#  'geographical barriers, including large rivers in South America.The evolution of this genus',
#  'Z as codes for the names of the French diplomats. The XYZ Affair ignited a wave of nationalist',
#  'and Jacob K. White. "Tell It',
#  '5 June 1944 as Generalleutnant and commander of 1. Panzer-Division During the 19992000',
#  'left the band on good terms to',
#  'phones, said that they never received them, with only tech influencers actually receiving',
#  'and Culture: An Introduction to the Humanities (2012,',
#  'It is a tributary of the Paran River. List of rivers of Gois Brazilian Ministry of Transport',
#  'dire consequences for the oversubscribed fishing sector in Galpagos, likely causing local',
#  'East sculpture. The',
#  'in the Abu Temple at',
#  'Joni Mitchell\'s 1970 single "Big Yellow Taxi", which uses a similar lyric in a close key',
#  'and rodeo held every August in Douglas',
#  "Thomas's work. It is both a personal story and an account of the origin of the industrialised",
#  "and his wife Catherine Thynne of Longleat. He succeeded to his father's estates, including",
#  'that she was "deposited',
#  'the Leaf River, which passes under Mississippi Highway 28 about 1 mile outside of the',
#  'the ABL followed by the ABA created professional opportunities for the players the AAU',
#  'be listed under the',
#  'any game supported by Mame/Mess, including past versions. There',
#  'Himrod (November 4, 1842 January 26, 1920) was an American politician who served as mayor',
#  'those remedies are inadequate,',
#  'remaining contenders. Carlisle United are relegated after losing at Anfield.16 April 1975:',
#  'on 9 November 1979. The fourth,',
#  'the A338 Poole-Oxfordshire road, which accompanies the river northsouth through the parish.',
#  '4:15 "Chick-A-Boom" (Bert Berns, Morrison) 3:12 "I',
#  'Harper Collins, New Delhi,',
#  'median sulcus.: stria medullaris are axons of arcuate neurons. Courses in the floor of',
#  'patch, vaginal contraceptive ring, diaphragm, sponge, cervical cap, female condom, spermicide,',
#  'products and other ventures are',
#  'the wording of the law(s) passed by Congress. The mandate applies to all new health insurance',
#  'of Social Media/Other and Best College Radio Station in the Nation for the second year',
#  'for his work, Sondra accesses his intelligent house computer Hal, and discovers that Ben',
#  'Although he practiced law with partner William J. Lynch, he dedicated the majority of',
#  'location was sold because local',
#  'Twombly (October 24, 1935 May 30, 1977) was an American sportswriter and author based',
#  'Control and Prevention. Producers of the show were not allowed to photograph the interior',
#  'level of success in',
#  'men gathering in the',
#  'from three marriages. His first wife, Noh Soon-hwa, died in 1949. They had one daughter,',
#  'outstanding armed robbery charge against him. Hickey said, "My conviction has been quashed,',
#  '201011 regular season consisted of',
#  'Jesse L. Lasky Jr. said that',
#  'in their entirety on the first disc, with the second disc containing nine rarities and',
#  'drums David Travers-Smith trumpet Ani DiFranco record',
#  'all his slaves at the outbreak of the American Civil War and allowed them to move North.',
#  'Hall of Fame in',
#  'one of the UFOs, which had landed in the forest, and even gone up to and touched it. The',
#  'such as the Super',
#  '(c. 90 aft. 132 AD), Roman politician Quintus Tineius Rufus (consul 182), Roman politician',
#  'Anna Catherine Parnell (13 May 1852 20 September 1911) was an Irish nationalist and younger',
#  'lifestyle magazine. It covers lifestyle, luxury, fashion and dining, as well as local',
#  'while it was still known',
#  'pygmy marmoset, Cebuella pygmaea pygmaea, occurs',
#  'up a copy of the press',
#  'prototype underwent testing. The prototype',
#  "Chicago's mayor. Daley became chairman",
#  "found little success, and in early January, Magisk was signed by Denmark's #1 team at",
#  'Literary Criticism (1987) A Reply',
#  'create the game\'s sandbox format, which they nicknamed "SNAFU". Posehn wanted the game',
#  'his 85th birthday iBioMagazine: In Situ Hybridization iBioMicroscopy course: Early History',
#  'singer Clay Aiken. It is part of a series of similar series of Playlist albums issued',
#  'Point. For services to the Church of England in Australia. Margaret Mary Kelman, of Buderim.',
#  'significant decrease in sedimentary Hg',
#  '21, many local volunteers joined',
#  'explores gay marriage and the meaning of',
#  '1921. Clint Bowen was named interim head coach after Charlie Weis was fired September',
#  'Johnstone, Superintendent.',
#  '"Beggar\'s Day" appeared on Hair of the Dog (1975), while Nitzsche\'s "Gone Dead Train"',
#  'Sudden Impact: Dondon Villamin (Sunkist-UST) Mythical Five Peter',
#  'and political results. The control scheme',
#  'working as senior engineers or executives. The recent employment of the graduates has',
#  'of 20.He later related that',
#  'of families and 16.1% of',
#  'Bluth and Goldman were so dissatisfied at the enforced changes that they insisted on their',
#  '23 March 2010. As of 1 August 2011, female contraception was added to a list of preventive',
#  'the symptoms and seizures can be controlled for a long period by',
#  'Isabella, her brother did not look upon her lifestyle as indulgently as Cosimo. While',
#  'to the development of the Gold Coast area. Ailsa Ruby Dawson, of Gympie. For humanitarian',
#  'and Scopus. List of philosophy journals Official website Alto Long is a municipality in',
#  '1,305 similar sightings catalogued by NARCAP, took place in 1916 and 1926. On January',
#  'Ray, National Secretary, Food Drink Tobacco Agriculture Group, Transport',
#  'around the world, and',
#  'in Saint-Domingue (now',
#  '(VVS; English: Stuttgart Transport and Tariff Association LLC)',
#  'on other Wu-Tang Clan projects, Wu-Tang',
#  'Appellation wine evaluations for AppellationAmerica.com, writes a monthly column, The',
#  'of the posts. However, the Indian Army denied the claim. "No casualties have been caused',
#  'in popularity since debuting in 2015. The series aims to showcase the lives of the LGBTQ',
#  '"Sullen Soul" "Blessed Salvation" "Has He Got A Friend For Me" (Richard Thompson) "Backstreets"',
#  'of the local economy',
#  'joined the Suffragette movement and met Emmeline Pankhurst. They married in 1906, and',
#  'with female Salticus scenicus, was able to initiate hunting behavior by moving a black',
#  'on 12 April 1972 by Dr.K.Balaraman Nair, the then Director of Health Services. 1987-Started',
#  'ICU towards the proposed IGASOM mission.Though IGAD and the ICU met and published a cordial',
#  'automobile industry and returned',
#  'in the Premier League and the collapse of ITV Digital with the resulting loss of television',
#  'Hilder, of Castlecrag, New South Wales. For',
#  'reform movements as the founder of a',
#  'just and equitable for the court to make an order for specific performance or grant an',
#  'Council. William George Hart, Assistant Secretary (Estates & Wayleaves), South Eastern',
#  'candidate in the presidential election, and was re-elected unopposed. For the first time',
#  'selected by Team Benavidez. In',
#  "and another associate of Leonora's,",
#  "Englishman's Critical and Expository Bible Cyclopdia, originally",
#  'passengers to travel to Key West without using the busy U.S. 1 Overseas Highway Corridor.',
#  "best game released for the console that month. Computer and Video Games felt the game's",
#  'in the wake of Don',
#  'Yankees acquired Tim Foli to play short in 1984. The Yankees ended up having something',
#  'for Foreign Affairs, promised South African President',
#  'competed in a three-game series with the',
#  'to Aboriginal education. Captain Harold Geeves',
#  'Christchurch venue. As',
#  'It is not transparent. And it is not replicable. Fundamentally based indices are exposed',
#  'joined the Free German Trade Union Federation (FDGB) and the Socialist Unity Party of',
#  'on a mobile device or on another TV without the need of a set-top box. In February 2014,',
#  'census. Statistics Canada. 2012. Retrieved 2011-03-03. Riding history from',
#  'The Time Machine only',
#  'pages of UFO reports, letters and drawings from members of the public, as well as questions',
#  'organize the March on the Pentagon using',
#  'club during his time at Deepdale. In 1982, he scored the winning goal during a 21 victory',
#  'unlikely they were conquered by them. The city was later sacked, possibly by Anum-Muttabbil',
#  'Less Laforin means more',
#  'Junior A Hurling Championship Glen Rovers OverallIn a single game Andrew A. Wiederhorn',
#  'more recent discoveries from Harper, including Jack S. Scott, Richard Bulliet, E. Richard',
#  'plan, train the Somali security forces, and to',
#  'The Making of a World Faith, Peter Owen Publishers, London and New York, 1978, ISBN 0-7206-1038-9;',
#  'could threaten its success in the',
#  'release was postponed due to the COVID-19 pandemic, and it is now expected to be released',
#  'restaurants, including Catfish Cabin, 28 Diner and Los Charros. It also has a junior college',
#  'reached number',
#  'Objective Reality of Perspectives" (1926); "The Nature',
#  'was reunited with The Mountain castmate Penn Badgley. She reprised her role of Ivy in',
#  'event in 2011, the town asked the University of Kansas to remove the Jayhawk as its mascot.',
#  'sides. Ivy, passion flowers, bignonia,',
#  'have copied this painting are Edgar Degas',
#  'Leicester without reply, and sit',
#  'achieved through the use of a blasting nozzle propelled by compressed air. The focus and',
#  'up and who was of a similar age. The couple were betrothed in 1568 when Leonora was 15,',
#  'shelter. That is to say,',
#  'households were made up of individuals,',
#  'Wall and north of the via Tiburtina vetus. Probably the horti extended north from that',
#  'Following procedures laid out in canon law,',
#  'a 1999 direct-to-video prequel Bartok the Magnificent and',
#  'Axel Neistle : German U-Boat Losses during World War II (1998). ISBN 1-85367-352-8 Warlow,',
#  'own studio was unable to work on both',
#  'into the journey, Junaluska and approximately 50 other Cherokee escaped. He and his band',
#  'and relinquish top spot in the First Division to Liverpool.31 March 1975: Everton beat',
#  'In 1937 it was transferred from',
#  "gunships'. On 12 March a",
#  'naked dog, or Chim dog is one of several',
#  'a loss',
#  'First Cut Is',
#  'Multibus and ECAD. ECAD (Electronic Computer Assisted Design, now known',
#  'our religious liberty". The regulations issued under',
#  'Advanced Youth Leadership course',
#  'For conspicuous gallantry and devotion',
#  'largest electric cooperatives in the United States with nearly 10,000 miles of energized',
#  'You Come',
#  'during the summers. He',
#  'and was elected a Democrat to the United States House of Representatives in 1882, serving',
#  'the use of an uninterruptible power supply',
#  'progressive agenda." American Journal of Sociology 93:91351. Works',
#  'pragmatists. He is regarded as one of the founders of symbolic interactionism and of what',
#  'of Jazz: Live in New',
#  'for Accreditation of Teacher Education,',
#  'wooden huts to shelter evicted tenant families and by the beginning of 1882 they had 500',
#  'the European competitions. Newcastle United retain the Texaco Cup after beating ten-man',
#  'economics. He was a professor of entrepreneurship at',
#  'parents. Kwesi is the second of 4 kids. He has two brothers, one of which is also a musician',
#  'and are more frequently heard than seen. The yellow-fronted tinkerbird eats insects and',
#  'a film distribution company to distribute',
#  'marriage, his heir,',
#  'wounded. On 10 May a second explosion in Wanlaweyn killed seven Somali soldiers and wounded',
#  "Bandon's Darren Crowley was the championship's top scorer with 0-36. Promoted from the",
#  'display the lab sessions, one-way mirrors to allow viewing by professors, and editing',
#  "The first disc presents material already available on Blowin' Your Mind! and on the previous",
#  'movie Molly: An',
#  'but unofficial estimates place it closer to 40%. The Orapa 2000 project doubled the capacity',
#  'the world.',
#  "her husband, she also followed Isabella's",
#  'association with Animal Planet, HamAstrochimp #65, tells the story of Ham as witnessed',
#  '14-nation Southern African Development Community (SADC). A',
#  'located along the banks of',
#  "against Sporting Kansas City, contributing the team's second and third goals in a 33 comeback",
#  'DNA or RNA. Although the Feulgen stain for DNA was not sensitive enough to stain the DNA',
#  'to the big picture rather than our dumb ideas) and the whole thing kind of languished,',
#  'early 2008, the song "Love Wasn\'t Built',
#  '1139 pp., 194 pls. 1924 Family: Hesperiidae in',
#  'Fine Arts, Bachelor of Music, Master of Fine Arts, Master of Arts, and Master of Music',
#  'vote, beating Republican Nick Fountain. PA',
#  'with yellow and white. Its head',
#  'Huddersfield Town, who had become',
#  'and a tail of 172 to 229 mm (6.8 to 9.0 in). The average adult body weight is just over',
#  '2019. Kaylee DeFer at IMDb PopGurls Interview: Kaylee Defer Eswatini Airlink was formed',
#  "elected in 14 multi-seat constituencies, corresponding to the country's 14 departments,",
#  "interviewing Spencer's former wife, who had not spoken",
#  'was level, the away',
#  'executive producer Steve Waterman. As such, it now does',
#  'relieved by',
#  'Savings Committee. John Owen Jenkins, Member, (Physiotherapy), Council for Professions',
#  'in the Premontane Wet Forest and Lower Montane Wet',
#  'administrative purposes) was determined by an additional draw held after the semi-final',
#  'Boziz was shown to have fled to the',
#  'to many players who wished to remain eligible for the Olympics. Several AAU teams were',
#  'Irish immigrant who worked most of his young life in a glass bottle factory. Born into',
#  'different exotic styles, such as samba, Latin, and calypso jazz. Space Age pop is related',
#  'France to lead the pro-Confederate European powers. For a time, Napoleon III inched steadily',
#  'Kinski as Sondra Brummel Nicollette Sheridan',
#  'have proposed could serve to help promote',
#  'in Every Wind (2003), Weaving',
#  'he was chosen to write the',
#  'band. After supporting',
#  'identify enemies or even see the bullets the player character fires.GamePro gave the Game',
#  'to British commercial interests in Nigeria. Barrie Nicholas',
#  'Regional Health Authority. Hugh Montgomerie Lang, Chairman, Food',
#  'Habsburgs. A war with',
#  'School, founded in 1838. There is also a Technical College in the town. Newcastle F.C.',
#  'Corky Evans. Labour activist Len',
#  'of Ceremonies (Pete Murray, the',
#  'stores that are formula-aware) interchangeably. def contexts(self, triple=None) - Generator',
#  "Woman at AllMovie The 1997 Men's Asian Basketball Confederation Championship was held",
#  'Greuter, 1917 Setopus lemnicola Schwank, 1990 Setopus primus Grnspan, 1908 Setopus tongiorgii',
#  "its first ECAC Holiday Festival title with a 9079 victory over St. Joseph's in the final",
#  'presidency in April 1935 by his retiring predecessor, William Wallace Atterbury, in whose',
#  'was adopted through House Resolution No.',
#  'local zoos, where they exist',
#  'and found predominantly in upper-elevation moist meadows. D. scopulorum is a non-woody',
#  'between 1862 and 1877 and later became known for his role in coaching young cricketers',
#  'Dr Pealmutter, the Sinclair family doctor, who would bring the child to Tom and Margaret,',
#  'an adoption. Margaret accepted once she',
#  'use of "flower power" became an integral symbol in the counterculture movement. By late',
#  'second and third base, both runners ended up approaching home plate in synchronized fashion,',
#  'The following year featured the',
#  "members' entrance to the Council House contains a mural depicting local scenes painted",
#  'regarded as the founder of Historical',
#  "and a couple of other friends - Wilcox, Miss Love, knew Louisa's secret. Mr. Rumsey was",
#  'forward. A property right has',
#  'at the age of 16, joining local',
#  'of California\'s "Wonder Team" their first loss in five seasons. In 1928, Locey took over',
#  'South and North Carolina and',
#  'animation) Dragon and Slippers (1990; ink/paint, additional visual',
#  'where the Church is known as',
#  'in a second-place',
#  '//www.legis.state.pa.us/cf',
#  'goals.The imperial tutor and consul Marcus Cornelius Fronto',
#  'It is',
#  'Aiken The chocolate gourami (Sphaerichthys osphromenoides) is a species of gourami native',
#  'Rolfe 1892 (Colombia) Odontoglossum blandum Rchb.f. 1870 : Charming Odontoglossum (Ecuador',
#  'Ulpha Cooper, Writer. John Cordrey, Manager, Personnel Development, Littlewoods Ltd. John',
#  'to lack of complete information or',
#  'species of Acmanthera (Malpighiaceae). Systematic Botany 5: 438441. Malpighiaceae Malpighiaceae',
#  'Trevor William Plumb, of Yarralumla, Australian Capital Territory. For public service',
#  'Operation Albion, as German bicycle',
#  'with other individuals. They are',
#  'American Buildings Survey (2005), No. HABS DC-857 http://www.ww1cc.org/memorial U.S. World',
#  'Being listed on this register meant firstly that alterations/demolition required the consent',
#  'an example of Venetian painting, a sub-genre of Italian',
#  'Lumberg, real name Kirsti Leila Annikki Lumberg (born May 27, 1956), is a Finnish artist',
#  'of the Capital Region',
#  'community. Ernest Philip Preston Younger. For services to the community.State of VictoriaMalcolm',
#  'over the Prospeed Competition Porsche of Paul van',
#  'Hungary, Italy, Latvia, Macedonia, Netherlands, Poland, Portugal, Romania, Russia, Slovakia,',
#  'Seton Hall Pirates in the NIT Finals who were led by All-American center Walter Dukes.',
#  'Barrett 375Berger stepped down as party leader after the NDP lost the provincial election',
#  'Apsey, of Randwick, New South Wales. For service',
#  'had died after being forcibly restrained whilst in police custody was higher than official',
#  'killed in firing and shelling by Pakistan Rangers while 23 were injured on 1 November.',
#  'which was adopted in the period 20062007.',
#  'of Jihad. Arun Kundnani, How',
#  'from ballooning spiders or chaff. Ufology is a neologism describing the collective efforts',
#  'March 12, 1978 in Tullahoma, Tennessee. All Things',
#  'the Review of',
#  'http://planetgreen.disco',
#  'enclosed. Roseneath sits',
#  'consists of mistbelt forests The length',
#  'find that social acts (e.g. games',
#  'The Viennese premiere, conducted by Bruno',
#  'Colonel Julian Howard Atherden Thompson, Royal Marines. Commander',
#  'of Buff Point, New South Wales. For services to the pig industry. Ian Castles, of Narrabundah,',
#  'grade, and',
#  'documented a series of UFO',
#  'clock and a spring mechanism. Minx',
#  'the online Computer Professional Education Program (CPEP) for',
#  'Krger (23 March 1892 11 July 1973) was a German general during World War II who commanded',
#  'Cairo, Tokyo, Naples, Nablus, St. Pierre,',
#  'my son to be a',
#  'Among them are the Charles Darwin Foundation and',
#  'well as the railway line Stuttgart-Bad',
#  'models along a single axis. Calvin added colour to the sprites to meet the production',
#  'Man) 2009: I Can Forgive You 2010: Mr. Mistress 2010: Make My Body Rock 2011: Sparkle',
#  'legs were',
#  'described less than 1% packet loss as "good" for streaming audio or video, and 1-2.5%',
#  'castle turned into the S. Seventeenth Parish Church. Among the most important mountain',
#  'Hairless Dogs are now a symbol',
#  'Weapons Have Been Compromised by',
#  'UFOs, whereas only 92 percent had heard of U.S. President Gerald Ford in a 1977 poll taken',
#  'methods, recurrent drought, erosion, and',
#  'freedom that will maintain',
#  'Ohio ESC Official website Union Local School Report',
#  'of tropical America". Palaeo Ichthyologica. 14: 790. Bernard Landau; Richard E. Petit;',
#  'of comics fans, and in',
#  'on the matter.This explanation did',
#  "the famous Greek legend Jason. Devil's Island, where you play a shipwreck passenger trying",
#  'Bechtolsheim. The third board was an interface to the 2.94 Mbits/second experimental Ethernet',
#  'guttata).To the south west are a number',
#  'the Capital Region of Denmark from 2007 to 2014, elected for the Social Democrats. Prior',
#  'the most important moments in your life can happen in a parking lot." Musically, the song',
#  'Medley Keep the',
#  'he is going mad,',
#  'opportunities in education, law',
#  'attachment order debtor, or garnishee, and the actual judgment debtor. Emoluments attachment',
#  'scores were level at',
#  'PMID 22233726. S2CID 8756808. Hipp JF, Hawellek DJ, Corbetta',
#  'Guerrero, Mexico". The preferred habitats',
#  'Foreign and Commonwealth Office. Timothy John Everard, Counsellor (Economic) HM Embassy,',
#  '(2nd edition August 2008). More detailed testing procedures are stated in the German guideline',
#  'built. Many years later, in 1946, it was burned down in an arson fire. The town of Taylorsville',
#  'in the Eastern province of the country.',
#  'administration. It is the home of the Clarence City Council, a local court chambers, and',
#  'August - Prime Minister,',
#  'OBE, Board Member, National Coal Board. Peter',
#  'Police. Colonel Commandant Royal Army Veterinary Corps. Lieutenant General John Wilfred',
#  'the Maccabees." According to Friedman,',
#  'Technician George Arthur Young. F0594139 Sergeant Geoffrey Ralph Bunce. F4250930 Sergeant',
#  'and wings and a white rump. The tail is black with some white barring, and the underparts',
#  "tactics in the streets of Chicago. And with George McGovern as president, we wouldn't",
#  'subject to disconnection at under voltage,',
#  'of Thammasat Universary the 120th Anniversary of',
#  'death, he was named to the Philadelphia Sports Hall of Fame. He was inducted into the',
#  'ROM to a data file. Removal of a soldered chip is often far easier than reinstalling it,',
#  'slip of the tongue: "The confrontation',
#  'Baseball-Reference (Minors) Wilfrid Airey (27 September 1907 19 July 1980) was a New Zealand',
#  "World War. The company's formal establishment",
#  'traditional Hollywood types Aiken hired everyday people to play the couples shown in this',
#  'Picture Company. At',
#  'Officer Rod E. Geiger Massimo Ciavarro',
#  'Pacific. In August she',
#  'Gardens and also played home fixtures on the Central Recreation Ground throughout the',
#  'region. In response, Ethiopia',
#  'World. After three years as Sofia, Salem decided to pursue a career in primetime television',
#  '1975: West Ham United win',
#  'also a ceiling for the maximum number of eligible vehicles: 10,000 for all-electric vehicles',
#  'season he',
#  "12 regular season co-championSoftball 2006 Big 12 tournament championMen's indoor track",
#  'and Czech Republic. Anticipating cost and visa problems, Great Britain declined to enter',
#  'of the Saint Barthlemy valley, south-west of Mex. The mountain includes several secondary',
#  'male literacy is 53%, and',
#  'that year, Hayes became the first African-American to win an Oscar for a non-acting category',
#  'Carlisle United and Luton Town.5 April 1975:',
#  'Herbarium 11: 4150. Anderson, W. R. 1981 ["1980"]. A new',
#  "Parramatta' and included the present site of Roseneath Cottage. Bligh's grant was rescinded",
#  '(1974) Now Hear This Ork/Cherry Red (2007) re-release Junior Marvin Hanson press release',
#  'On November 1, Fox shared more details regarding the game, including that the rest of',
#  'the winners were the teams ranked',
#  'of Talbot who began to play',
#  'convictions. In the United States, contraceptive use saves about $21 million in direct',
#  '300 neglected farmed animals at one time. In addition to the permanent sanctuary, Animal',
#  "downplayed the event (officially termed 'Unexplained Lights') to avoid damaging his career.",
#  'warfare." NDTV stated that, analysis',
#  'joint venture between ICI (48%), I.G. Farbenindustrie (30%) and F.A. Hughes & Co (22%).',
#  'combined with 6 other similar challenges to the contraceptive mandate. The case is titled',
#  'of Mogadishu, and most hopes',
#  '0 C for at least two weeks. The authors investigated the reduction of [(dppf)Ni(cinnamyl)Cl)]',
#  'specimens. Revell died by falling or jumping from his bathroom window on the 9th floor',
#  'the six-year Atlantic campaign Enchantress escorted more than 100 trade convoys, mostly',
#  'Kenneth John Winfield, Senior Executive Officer, Office of the Director of Public Prosecutions.',
#  'being a candidate for renomination in 1890. Afterwards, he resumed practicing law in Tiffin,',
#  'album was released weeks later under the WuMusic Group label. In March 2019, Killarmy',
#  'April 1935 and commissioned four days later. At the outbreak of hostilities in September',
#  'Terry White was appointed Board Chairman of Metro South Hospital and Health Service (HHS),',
#  'Director, Mullard Ltd. For services to Export. Colin Mervyn',
#  'calling posture. The male touches the',
#  "as Tolton's godmother. How the members of the Tolton family gained their freedom remains",
#  'Medicine (ASRM) is a non-profit, multidisciplinary',
#  'is a retired Latvian tennis player.',
#  'like the Rolling Stones,',
#  'Grey Cup that year. A versatile two way player, in 1955 he joined the Hamilton Tiger-Cats',
#  'Papua New Guinea. The Honourable Kingsford Dibela, MP, Speaker of the National Parliament.',
#  'on 29 September 1957 on the HaarlemUitgeest railway. The station has 2 platforms. As of',
#  'and distributed their first full album No Plan B. Their persistence paid off as their',
#  "Count of Reuss-Gera, who had died on 3 December 1635, it is Schtz's most famous work of",
#  'Park, Pa.: Pennsylvania State University Press. ISBN 0-271-01876-3. Charles Kolb, Review',
#  'season. Meacham was the Yankees',
#  'in annual expenses. In comparison, the Vanguard 500 Index Fund "Investor shares" ($3,000,',
#  'Claremont, served as the first British military attach',
#  'and is included in their online listing at MilitaryFriendlySchools.com. There are nearly',
#  'to a banned substance and the',
#  'to their first European Cup final,',
#  'Enoggera from Singapore, received a new commanding officer Lieutenant Colonel Tony Hammett',
#  'Air Force (RAF) reconnaissance aircraft returning from a mission in France or Germany',
#  'annual accounts for public scrutiny. The',
#  'lost the fight',
#  'from Russian gangsters and disappears. Together, Collins, Brennan and Samuelson find themselves',
#  'Dehradun/Department of Law-',
#  'income of $30,776',
#  "predicate, object)) RDFLib 'Literal's essentially behave like",
#  'the UFO acronym include "flying flapjack", "flying disc", "unexplained flying discs",',
#  'Research Library National Library of Australia Archives Office of Tasmania J.S. Battye',
#  'such as Kentucky Fried Chicken and Remax, are',
#  'the Sale of Goods Act, e.g. UK 1979 s57(2). The court held that Mr Cave was entitled to',
#  'is a lieutenant colonel in the Army. Rajan Bala, "In the shadow of Ghulam Ahmed", Crickettalk',
#  'Rau described as the most "pleasurable" branch of photography. For his railroad company',
#  "Louisa Barrett - Grace's godmother and real mother. Louisa's enthusiasm for Grace reinforces",
#  'the celebration of the annual Munufie',
#  'a form of street theater',
#  "rapid shuddering, shaking, or jerking of the canine's head backwards, high pitched vocalizations",
#  '2 days later it stated that an',
#  'place from 1876 to 1880. However, some adjoining remains were minimally described and',
#  'at the 2005',
#  'for the band. Several of the songs feature',
#  'Wadada received his first',
#  'written by Melanie Newman exposed the "real wolves of Wall Street" involved in binary',
#  "at Methodist Ladies' College in Melbourne and published her first work in the school's",
#  "sequence in the musical Xanadu, and the video games Dragon's Lair and Space Ace. And Bluth",
#  'different from most of Gwyn',
#  'Professor George Grenfell-Baines, OBE. For services to Architecture. Terence',
#  'of government investment and incentives',
#  'from the club, with several key',
#  'were 534 households, out of',
#  'said that four Indian soldiers including an army major were killed in Keri sector in unprovoked',
#  'well as other exams worldwide. Previous year question papers are to assess students brilliancy',
#  'Leader of the United Kingdom Delegation to the',
#  'Television. The series premiered on September 4, 2000',
#  'Life, Vol. 18, No. 5. Cooper, William John. 1933. The Office of Education. The Scientific',
#  'believed to have been painted',
#  'Royds resigned the seat, and his brother Charles won the resulting by-election in Leichhardt',
#  'This is a perennial mat-forming grass',
#  'community in the southern',
#  'shortcomings in the capability of the Australian Defence Force were highlighted in the',
#  'Arthur Stroud, lately Higher Executive Officer, Ministry of Defence. George',
#  'also performs music and spoken word poetry as a solo artist, being the subject of a BBC',
#  'civil parish in Aylesbury Vale',
#  'southern Patagonia, Argentina. It is an ocean basin opening to the Atlantic. Its shoreline',
#  'Edgar Allan Poe (1974) - Joseph Zebra Force (1976) - Peter High Rolling (1977) - Country',
#  '"He had these amazing all-star bands, but I had no idea who they all were! The thing I',
#  'a runaway convict was indicted',
#  'in the third replay',
#  'now known as the Robertson Panel to analyze the problem of UFOs. The OS/I investigation',
#  'announced the Project Light Rail scheme to',
#  '1974) was a Swiss Nordic combined',
#  'runs out. There was',
#  'a No.',
#  'world. Much of the artwork was not claimed by artists and remains anonymous. Because the',
#  'Johann Nikolaus Forkel (1802). New York:',
#  'performed by escort ships; protecting',
#  'of Engagement1993 Between The Lines (13 hour',
#  'English school (Julian Symons, Andrew Garve, Michael Gilbert, etc.), who taught John Creasey',
#  'March 2003. The 10,000 metres (men and women) were conducted at the Runaway Bay Grand',
#  'stmarkaruten was transferred to Oslo Sporveier, which numbered it Line 71. The buses continued',
#  'from 1969 to',
#  'in the collections of the Smithsonian, the Getty Museum,',
#  'was also released in the',
#  "timing device.'' Colonel",
#  'at its annual general meeting held in 2006. Old Kentucky Chocolates Old Kentucky Chocolates,',
#  'them. For that he',
#  'Gilbert Islands. John Edwin Graham, Building Supervisor, Public Works Department, Belize.',
#  'its power resources through the Southern African Power Pool, with most of its capacity',
#  'won 31 on aggregate. Zvezda Perm won 83 on aggregate. Frankfurt won 62 on aggregate. Wolfsburg',
#  'in 1907. The Jayhawks have belonged to the Big 12 Conference since it was formed, before',
#  'Shrewsbury, who took him abroad and gave him the rectory of Heythorpe, Oxfordshire. On',
#  'On 25 October a Ugandan soldier and two civilians were reported killed by al-Shebaab insurgents',
#  'family, whilst Terry remains in their house and takes care of their son. A chapter of',
#  'a federal agency of the Government of India. The Institute was established in 1975. The',
#  'after he taunted her. Disguising herself as a boy with the help of her friends, Frank',
#  'space agency), the longest ongoing government-sponsored investigation. About 22% of the',
#  'on the voyage back to Australia aboard HMAS Sydney, 6 RAR arrived back in Brisbane on',
#  'in the loops',
#  'Lincoln County, where it flows out of Montana and into Idaho. Upstream, Libby Dam backs',
#  'series The Walking Dead. It originally aired on AMC in the United States on November 28,',
#  'arms on it,',
#  'Old Fort Hays Blockhouse). In contrast,',
#  'Department of Health & Social Security. Frank Thomas Stephenson,',
#  'man held several terrified shoppers at bay with a gun. When the manager tried to intervene,',
#  '"great band and their singer Jack is a wonder" when sharing the video for Artwork of Youth',
#  'director), Lord Hill-Norton (former British Chief of Defense Staff and NATO head), the',
#  'faced criticism for deterring',
#  'in 1923. He was',
#  'normally compel him to vote against',
#  'findings against a member of the Legislative',
#  'in 1990 to introduce absolute primogeniture,',
#  'June 2000, by the then Minister for Education and Training, the Hon. John Aquilina, under',
#  'recitation hall or a sumptuously decorated triclinium were not mutually exclusive, but',
#  'New American Cinema Award for best editing. Matthew Modine as Bartender Ben Gazzara as',
#  'up in Venezuela and began wrestling',
#  '29 May 2017, the Indian',
#  'Rufus, an officer of',
#  "in Botswana's infrastructure. However, despite their preeminent",
#  'Unitary Authority which has wider responsibilities for services such as education, refuse,',
#  'similar to the Apple II',
#  'insurgents while losing six of their',
#  'became engaged to Edna Curtis of Sacramento 10 days before the San Francisco earthquake',
#  'Renaissance painting unique to Venice. Venetian paintings are characterized as having',
#  'was initially buried in the Morizkirche but later reinterred in the newly built mausoleum',
#  'and 7 assists in 28 matches during the 2012 Major League Soccer season, compared to 12',
#  'by Aiken from his albums. The album was released on March 31, 2009. A PDF file included',
#  'as Dominique You Inger Stevens',
#  'design and continued with the original style',
#  'You" (Dorothy Fields, Jimmy',
#  'blocks were established in Birdwoodton',
#  'the American Army in replying to',
#  'after his death by Jack Adrian in The Independent: His first book, The Blessing Way (1970),',
#  "In 2006, the mall's original",
#  'suffragan Roman Catholic Diocese of OranExempt(Immediately',
#  'Linkping won 53 on aggregate. Rosengrd',
#  'League (NFL). He was drafted by the Kansas City Chiefs in the sixth round of the 2014',
#  'was buried in Robbinsville. His grave was',
#  "breed).Although Macquarie nullified Governor Bligh's Parramatta",
#  'scheduled to take place each year in late May or early June. The event was established',
#  'sector.On 16 April, India claimed',
#  'Pietism. Translated by Gerald MacDonald. Lanham, MD 2007. Douglas',
#  'as unrealistic and complained of poor enemy artificial intelligence. The magazine however',
#  'Pauline Hanson, and David Ettridge are refused bail. 3 September - Radical cleric Abu',
#  '"Nec timeo',
#  'why the court',
#  'is an order for',
#  'in The Sydney Morning Herald',
#  "ISBN 0-304-35260-8. Clay Blair : Hitler's",
#  '[1974] 1 W.L.R. 1073. In Reid-Newfoundland Co. v. Anglo-American Telegraph Co., Ltd. [1912]',
#  '(born Thomas Williams; January 6, 1975 in Brooklyn, United States) is a reggae artist',
#  'decision in the',
#  'problems. Primary Application 15392 shows that',
#  'Manufacturer Cups were open to',
#  'contained triples (asserted or quoted): def add(self,',
#  'last quarter of every year and brings',
#  'organizations. He currently serves in a coaching capacity for the Philadelphia Phillies.',
#  'to the California Corporation',
#  'Yorkshire.) West Langton is near Kibworth and Market Harborough, and the parish according',
#  'St. Louis Magazine biography Short bio at Washington University Bio at St. Louis Walk',
#  'In all four stories, aliens draw naive conclusions from little information about humans',
#  "demolished in 1966). St. John's Church was also opened on 'The Rock' in 1832 to accommodate",
#  'seizures, and as the disease progresses dementia, blindness, and loss of balance. Lafora',
#  'the first phase of',
#  "Word 2007's Office Open XML format). Pages 4 and earlier could also import AppleWorks",
#  'had 32 head coaches since its first recorded football game in 1897. The last head coach',
#  '44.2 (1989) 7080. Julius Bittner in the',
#  'City beat Leicester City 10 to move to the top of the First Division, but just three points',
#  'white Catholics (many of whom',
#  'religion in general and Christianity in particular. In 1937 Walker joined the British',
#  'sighting in Italy dates back to April 11, 1933, to Varese. Documents of the time show',
#  'there are insufficient means available',
#  'on Beatport & iTunes.',
#  'Molina and Talbot as the Santa',
#  "his gain. In order to achieve this result the court 'imposed' a constructive trust on",
#  "Students and faculty study in Arabic, French, and English. The university's vice-chancellor's",
#  'the child taking one role must be ready to take the role of everyone else. If he gets',
#  'army claimed that a soldier',
#  'graphics display. Sometimes the $10,000',
#  'T. D. (1961). The British Destroyer. London: Putnam. Manning, T. D.; Walker, C. F. (1959).',
#  'capture of Janaa Cabdalla town located 50 kilometres to the west of the port city of Kismayo',
#  'who are ACS members. The issue has been discussed in the press since at least 2004, and',
#  "the Women's Peace Council and Britain's first female",
#  'by a variety of sources. The types of investors that provide growth capital to companies',
#  'success until the late 50s.',
#  'barns, a smoke house, wellhouse',
#  'Video Series of All Time,"',
#  'of Indooroopilly. For services to the Metropolitan',
#  "spoon called Mel's Diner, which is run by Mel Sharples (Vic Tayback). She struggles with",
#  'history teaching in Berkeley, California for',
#  "younger, Mitch, at Carlton. Andrew McGovern's playing statistics from AFL Tables Bump",
#  'game was played at Kennington Oval, home',
#  '+ 1139 pp., 203 pl. Franz, E. 1953:',
#  'sightings in France include the Valensole UFO incident',
#  'Kansas and Missouri began with open',
#  'year after the election, which is held in November of the year before the presidential',
#  'that these reports are simply other more prosaic phenomena that cannot be identified due',
#  'rights, property rights may survive against',
#  '(SH 108) is a state highway that runs from Strawn to Stephenville. SH 108 begins at an',
#  'Best (1992) (TV) ....',
#  "decision, stating that the move would galvanize AMISOM's campaign",
#  'this song at MetroLyrics David',
#  'the attacking style of play',
#  'He played all the six games in the 2018 World Cup qualifiers against Egypt, Ghana and',
#  'Aeronautical Industry. Since 1999, SAU has been under the administration of the Liaoning',
#  'Anne Kirkpatrick & David Kirkpatrick Highway Fever Don Walker Plains Of Peppimenarti James',
#  'they portray the old plantation as',
#  'Benton and Robert DiYanni, Handbook for',
#  'lines. The rebuffed Hecker proclaimed a German Republic',
#  '30, 2019. He won the fight via unanimous decision. With the win, Shelton earned a title',
#  'abandoned luxury resort to',
#  'giving/receiving, asking/helping, winning/losing, hiding/seeking, talking/listening).',
#  "but their chance at a rematch with George Mikan's DePaul squad and a third consecutive",
#  'sheriff. Lillian wanted more than this for her son, telling a friend, "I didn\'t raise',
#  'and Maximus managed to stop Mr. Papierwaite by tricking him into saying the summoning',
#  'area studying the long-term ecological effects of the fire. List of old growth forests',
#  'to all the circumstances, including the subject matter of the contract, the purpose of',
#  'to a tax deduction of',
#  'is the daughter of',
#  'prominent roads in Bangalore after',
#  'indicate national team as has been defined under FIFA eligibility rules. Players may hold',
#  'oversaw the introduction of more streamlined locomotives, new and',
#  'Corinthian League before becoming founder members of Division Two of the Sussex County',
#  'used on Grade 5 titanium it will',
#  'as desert springs. It is most',
#  'Land Before Time was notably greater than',
#  'long sought after as opening acts, working with George Carlin, Robert Klein, Poco, Harry',
#  'in 2005 by In',
#  'whiff) Citharichthys cornutus (Gnther, 1880) (horned whiff)',
#  'fighter were forced to',
#  'U.S. General Dwight D. Eisenhower discussed how to deal with the UFO encounter. The files',
#  'The mill',
#  "a believer's church, free access to read and study Scripture, the importance of prayer",
#  'businessman from Portland, Oregon. He founded Wilshire Credit Corporation and served as',
#  'Abraham Elton, 2nd Baronet (baptised 30 June 1679 20 October 1742) of Bristol and Clevedon',
#  'mainly chalk grassland on the steep slope of the South Downs. It is important for invertebrates,',
#  'Deployed November 2015, replacing 30 Battalion? 37',
#  'Biscuits (2008, Village Vert / PIAS / FLOR ) The Man I Love (performed with Sarah Cracknell)',
#  'and potatoes. Services provide employment for 2%',
#  'packets reduces the throughput of the connection as receivers wait for retransmissions',
#  'dates back to the 1950s. Usually, Chantilly',
#  'Qualifying Draw Freja Ryberg (Ludvigsborg, 5 October 1832 - 1 June 1920, Paris), was a',
#  'son, Richard M. Daley, was',
#  'world. According to Debswana,',
#  'Mississippi Highway 28 for the car',
#  'original songs about real life in the Wine Industry. He resides in Santa Rosa, California.',
#  'the waving of the forelegs.Female P. californicus and P. apacheanus are unusual in that',
#  '2016, replacing 32 Battalion 39 Battalion, 850 personnel. Deployed July 2016, replacing',
#  'band continued to rehearse several times a year and more intermittently with Young during',
#  'who operated from the Phoenix Lodge stable in Newmarket, Suffolk. Boss had ridden for',
#  'Gammon, Director, Southern Science and Technology Forum, University of',
#  "- Brisbane's Festival Hall",
#  'Like the previous season, the use',
#  'and create regions of',
#  '1978, 1981, 1984, 1986, 1992, 1997, 1998,',
#  'wanted her to be fluent in English. Her younger brother, Sverre Magnus, was to transfer',
#  'as a base for the insurgent group. Witnesses indicate that the Al-Shabaab fighters gave',
#  'November 1929',
#  "Stoke City's title challenge ends with defeat to Sheffield United, leaving Derby County,",
#  'November 1930. In: A symposium on',
#  'Kebbay (born 1986, in Freetown) is a Sierra Leonean model and beauty queen who won Miss',
#  'a spiritual and intellectual',
#  'manipulation. Cosmic Mission Fulfilled, 1966, Lewis, Ralph Maxwell,',
#  'Riding of Yorkshire, Sowerby appears in the Domesday Book of 1086, and was an important',
#  'as priest, as well as the Diocese',
#  'has national educational accreditation. Graduates of the ETA have found employment at',
#  'English football season, Hartlepool United Football Club',
#  'the same time, SSB gave',
#  'femur foreleg was transplanted to a proximal level of a hindleg tibia. This discovery',
#  'The second generation was released in 2013 with improved charging time and an auto-sleep',
#  'to homeworkers, and to supplement them by',
#  'ratio for all air carrier,',
#  'as well as to the romantic',
# ...
#  'A Soundstage Special Event (c.',
#  'For services to the British community in Kenya. John Willoughby Breadalbane Annesley.',
#  '- credited to Neil Young; "Oh Lonesome Me", "When You Dance I Can Really Love" and "I',
#  "(formerly Kahn's colleague at",
#  'Secretary to Members of Parliament. George Henry',
#  'to the sport of motor racing. Jean Lewis Malor (Mrs. Mullin), of Darling Point, New South',
#  'movie helped persuade the Byrds, then folksingers,',
#  'two shows in Winnipeg. Its',
#  'A Pack-Tracker (1968) Joan & Betty Rayner : Strolling Players (1972) biography The Boy',
#  'of Zachary Bayly of',
#  'the next stage, the game stage,',
#  'spending',
#  'illegal in England but is still common in the British West Indies. Things are fine but',
#  "Vintage Wireless and Communications exhibition and Amateur radio station Ockenden's",
#  'in sociology from Georgia. After',
#  'all in the same highly simplified',
#  'under Lawson Wilkins at the',
#  'is too wet or too deep, will result in inefficient germination. The recommended sowing',
#  'killed while three were others were injured in shelling by Indian troops according to',
#  'are often used: in water features; for structural,',
#  'hospital in Pichari. The government responded with helicopters being called in to respond',
#  'has not been electrified. The work',
#  'exact mass: 182.1096 u) may',
#  'For services to the community. Yick',
#  '2018. The streak of 14',
#  'of 162.4 per square mile (62.7/km2).',
#  'One Hockey One 2019-Present (Men & Women) National',
#  'that the incident involved a Royal',
#  'Hugh\'s hit "Talk It',
#  'Kennedy in-law) Sargent Shriver on his',
#  'San Francisco Giants. He was a switch-hitter and threw right-handed. Abreu was signed',
#  'four Acts", performed at Covent Garden in 1909, revived by the Carl Rosa Opera Company',
#  'animation studio. There, Kammerud began working on',
#  'ready for deployment, as well as rescuing',
#  'from a ticket machine or the bus driver. Tickets for 4 persons must be validated before',
#  'in 1989 and as well',
#  'service. It granted him state citizenship and land near present-day Robbinsville, North',
#  'He had no professional training nor musical knowledge, apart from listening the countryside',
#  '(1988). Anthony Salvin: Pioneer of',
#  'thing changed in its direction from south to southwest. And we saw how it disappeared',
#  'the wild mainly because they fall off of trees.Another expense for these creatures as',
#  'In 2017-2018 it was given',
#  'En Vogue (1992) "Love No Limit"',
#  'of vegetable; 17 thousand tons of sorghum; 13 thousand tons of maize; 8 thousand tons',
#  'in the Americas to keep',
#  'one year from 10 February',
#  'with the land and naval forces of Russia and',
#  'that',
#  'enforcement was the procuring by',
#  'goals. 201718, Wadada lifted',
#  'as the city had long outgrown the defensive fortifications, and on top of the agger. Verse',
#  'connected with the incident. Sagama Seya Mottagala Gamini Tissa Monastery Packet loss',
#  'in a Day" won in The 7th Annual Independent Music Awards for Best R&B Song. In 2010, Gold',
#  'are standard to most database management systems (Oracle, MySQL, Berkeley DB, Postgres,',
#  'services to Manchester Airport,',
#  'Nordeman, Mark Hammond / Produced by: Kipper 3:44 ^ "A Thousand Days" Written by: Christian',
#  '2009. The Merbein irrigation settlement, originally known as White Cliffs for its river',
#  'by the geographer Ptolemy',
#  'and non-commissioned officers (NCOs) and two',
#  'Bailey, Superintendent Caretaker, Dinnington Comprehensive School, Sheffield. Alexander',
#  'folk-rock explosion of',
#  'War II, the majority of the National Guard was mobilized, leaving governors without troops',
#  'he was employed by ASEA in',
#  'over IP traffic, one commentator reckoned that "[m]issing one or two packets every now',
#  '195); Mojo, in',
#  'nests, and the sparrow',
#  'Line is a 6.6-kilometre',
#  'standards which take into account the special characteristics of home work, and The Convention',
#  'common-law marriage system. They had one daughter, Shin Yu-mi (born 1982). Because of',
#  "was commissioned as a probationary second lieutenant.He finished pilot's training in summer",
#  'duPont-Columbia award, one',
#  'as "the only black man in the band."Shortly after beginning work on his third solo album',
#  'Park, with sculptures made for children and by children. The Princess takes active part',
#  'and they responded to',
#  'of Vicente Martinez Ybor and a large',
#  'and spent most of her childhood',
#  'be retransmitted and this can',
#  'to that of Castile. In punishment, Pedro IV demoted it back to the "village", returned',
#  'thus declining, making products from outside',
#  'golf championship). Founded in 1964, Kansas Jayhawks Rugby Football Club plays college',
#  'May 20, 2021 Official Website: http://prattvilleairport.com/',
#  "feet'. This event is recorded by a plaque on the promenade. The town's history is poorly",
#  'process was a waste of resources and attempted to create sprites on the pixel level himself',
#  'the Columbus Clippers. He spent all of 1988 with the big league club, but injuries and',
#  'it is uncertain if it was privately leased or still run as a school in those years. A',
#  'armed with carbines and sabres, were portrayed in contemporary illustrations patrolling',
#  '"Straighten Up and Fly',
#  'to the community. Henry George Judkins, of',
#  'der deutschen Konsumgenossenschaften, or ZDK (English: The Central',
#  'station is currently owned by Magnum',
#  'politics of which he had never been particularly enamoured. In 1950 while in Saigon (now',
#  'The Portuguese soon managed to expel',
#  'matter what your sexual orientation might be." In a review for the Wisconsin State Journal,',
#  "and understated instrumentation. According to Pitchfork's Tom Ewing, the lack of rock",
#  'University in New York City. Benton received a Bachelor of Fine Arts from Cornell University',
#  'the heating up of Europa brings native animals to the stage of human cavemen in just 20,000',
#  'communication required) CYHM - John C. Munro Hamilton International Airport in Hamilton,',
#  'considering sending forces. Following the',
#  'also handled DNA paternity tests and out of control teens. Originally, gentle and compassionate,',
#  'the case of Doyles catalyst above where two nickel complexes transmetalate, half of the',
#  'Harry Truman when he was',
#  'Before joining the faculty at TU Eindhoven, she did postdoctoral research with Emo Welzl',
#  'of what attracted fans. As',
#  'of jobs to the local area',
#  "away kits. The club's former club crest is a variation of the Hastings coat of arms, the",
#  'is the set of',
#  'Fales Cooper (19121988), and John Stanley Cooper',
#  'consisting of a central doorway with an elliptical fanlight, two twelve panelled shuttered',
#  'Cross of the Iron Cross',
#  'the presidential elections unit, and was a producer for Tom Brokaws documentary D-Day',
#  'well as a power plant. According',
#  '1929. At school, as a keen young Scout, he was Patrol Leader in the 9th First Calcutta',
#  'defence at his trial, as well as his unwavering affirmation of Lusiuss attempts to seduce',
#  'landed a guest starring role in',
#  'She was the wife of',
#  'Farrier as his assistant. Lambert only lasted until February 2009, when he was suddenly',
#  'South African Nelson Mandela, then a dissident, later president, was awarded the Freedom',
#  'decision in Todd v. Gee (1810) 17 Ves. 273, sending suitors across London to the common',
#  'tourism industry and local populations means this',
#  '//www.variety.com/revi',
#  "part of the implementation of the Master Plan for Acceleration and Expansion on Indonesia's",
#  'erect with the possibility to lay',
#  'him to decide to sell Louisiana to the young United States. This was done on April 30,',
#  "and Curator in 1714, by invitation from Isaac Newton, who was still President. Hauksbee's",
#  'Main, Senior Tutor, Faculty of Agriculture,',
#  "during the Scammel's patrols, as was this practice was permitted by the Treasury Department",
#  'the Northwest Territories Legislature in the 1999 Northwest Territories general election.',
#  'Lomaxes that he was given the name because he killed three people by throwing rocks at',
#  'whiskey distillery. His great-uncle was Jack Daniel. He graduated from Vanderbilt University,',
#  'decades, Gould has been an active board member of',
#  'in South America, and is found in',
#  'times for the removal',
#  'also known as',
#  'Risers were dropped from M3 and replaced by the Springfield Demize and Wichita Wings 2.',
#  'Store in 2011. In 2011, MiNT released',
#  'Ron Saunders guided Aston Villa',
#  'Aztex purchased the 2008 USL PDL expansion side',
#  'triangular or pyramidal due to the shape of the aperture of some lenses. While technically',
#  'in time to classical music. The series is',
#  'includes a restaurant and Function',
#  'Komponisten 10. Munich: Drei Masken, 1921. Julius Korngold.',
#  'wounded when a suicide bomber',
#  'jet interceptor as it was about to fire a missile on one of the UFOs. Apparent remote',
#  'heritage in Walk of History Yeaton biographical',
#  'Howarth, Headmaster, Danecourt School, Gillingham. Ralph William Howes,',
#  'would be willing to testify under oath to a Congressional committee. According to a 2002',
#  'same day in retaliatory firing. The Indian Army rejected the claim. On 17 November, Northern',
#  'India also claimed to had carried out',
#  'heroic virtue.On December 10,',
#  'a brief stay in the',
#  '(i.e. Ecuador).',
#  'million copies in the first month',
#  'and assisted in the destruction',
#  'States on December 7, 2018. It',
#  'produced by Isaac Hayes. "Theme from',
#  'album Space Under Sun was released on his label GOLD18 Records. It debuted at No. 1 on',
#  'on November 23, 2003.) First ballot: Carole James 325 Nils Jensen 169 Leonard Krog 150',
#  'Festival title.',
#  '1997-1998 Daimler-Benz Fellowship at the Berlin Institute for Advanced Study, Germany',
#  'was absorbed into the LSWR in 1883. It was closed in 1964 and the track was lifted the',
#  'who have been in the First Division since 1919, to the bottom of the table.22 October',
#  'the game. Desert Strike was followed by four sequels Jungle Strike, Urban Strike, Soviet',
#  "of Americans supported Daley's tactics. Daley was historically re-elected",
#  "job cuts began and the plant's future was thrown into serious doubt.[1] At its peak, up",
#  'Till full scope is granted, as Macaulay said in the House of Commons, "let us not presume',
#  'forest. Al-Shabaab also attack AMISOM troops that are',
#  'Hard 21989 How To Get Ahead in Advertising1988 The Adventures of Baron Mnchausen Rick',
#  'band to the stage in',
#  'College and subsequently, from 1890 to 1900, serving as president of Mount Holyoke College',
#  'are displayed in this article. Marshal General of France, originally "Marshal General',
#  'was the last deployment under Operation',
#  'from 1355, it already mentions the town with the name of "Monfort". After the conflict',
#  'work for his future father-in-law, William Bell, who was a medical and survey photographer',
#  'Heavyweight Championship (1 time) NWA Austra-Asian Tag Team Championship (2 times) - with',
#  'Reproductive Medicine, Society for Reproductive Endocrinology and Infertility, Society',
#  'its heavy dependence on mining and its',
#  'these are the standard screening tests.',
#  'interests and the British community in Karachi. John',
#  'tour to the tournament; this change was reverted the following year as results were mixed.',
#  'L Kathariner, 1904 Home Work Convention, 1996 is',
#  "Pietism's role in the emergence of",
#  'Illinois Fighting Illini and the University of California, Los Angeles on December 31,',
#  'so violates their religious beliefs or',
#  'of the Venetian Renaissance. Reaktion Books, Limited. pp.3031. ISBN 9781780231860. Phillips,',
#  'him and Melendez for his already-established studio, Roman was offered the opportunity',
#  'coastal town of Barawe and Qoryoley. 18 March 2014 At least three Dijiboutian soldiers',
#  'manual control over shutter speed. MiNT re-designed the camera motherboard to provide',
#  'biography of Hemingway, Papa Hemingway',
#  'wounded at least another 64 and captured a further 51. Members from the battalion received',
#  'subfamily Harpalinae. It was described by Geoffory in 1785. Cymindis humeralis can reach',
#  'quantities of cowpeas, beans, and other pulses',
#  'Empire and the Creation of the Modern Middle East. Avon Books. ISBN 978-0-380-71300-4.',
#  "The treatment is usually based on the individual's specific symptoms and the severity",
#  'worthy of scientific pursuit (e.g., 1951 Flying Saucer Working Party, 1953 CIA Robertson',
#  'Fog", a track on the',
#  '10, vol. I Cooper, William John. 1932. The Third Commission: International Justice and',
#  'were a black Portuguese cook who spoke',
#  'who tells to the audience',
#  'Chemical Engineering Physics Engineering Material Engineering Telecommunications Engineering',
#  "animosity originating from Ethiopia's heavy handed",
#  'Free State, South',
#  'johnsoni). Between the black and red areas on the posterior part of the dorsal abdomen',
#  'President of the World',
#  'report was revealed by several insiders who had read it, such as astronomer and USAF consultant',
#  'US-backed, Western means to',
#  'do that. However, in a 2011 obituary for editor Ruth Cavin, a recollection by Thomas McCormack',
#  'be asserted in the partition associated',
#  'audio-visual technology. With a confident voice well suited to public speaking and broadcasting,',
#  'kicked high towards the goal. Kinnaird caught',
#  'keyboard. Emblem Music Group Paul',
#  "remained unreleased until 1991. During Bluth Group's period working with Cinematronics,",
#  'of a 750-strong combined',
#  'Mix) 2018 -',
#  'of Constantine; united with the titular see of Hippo (Regius) (Ancient bishopric at Constantine)',
#  'Florida Alabama Georgia Tennessee South Carolona Delaware (1997) CD Deep River Of Song:',
#  'Quellen zur Familienforschung Band 3). Stuttgart 2005. Hans Schneider: Radical German',
#  'info Georgia Tribe of Eastern Cherokee page Junaluska at Find a Grave 1916 book about',
#  'naturelle and the Museum fr Naturkunde. Partial list of publications1919. Family: Lycaenidae,',
#  'occasionally even the theremin for that out-of-this-world sound. The arrangements of the',
#  "Love's Labour's Lost (1985) (TV) .... Longaville Alexa (1982) TV Series .... Paul Tales",
#  'births 8% of the time. The pygmy marmoset is usually monogamous though there is some variation',
#  'the 2001 provincial election and resigned. On June 4, 2003 she announced her intention',
#  "engines for the Apollo spacecraft. Clark's early life years were spent growing up on the",
#  'live. Simon Thornton, professional',
#  'units of Alabama militia, with most',
#  'and South starting in',
#  'the Queen Sirikit the 75th Anniversary of World Scout the Centenary of Thai Post the 700th',
#  'Ramgoolam, MLA, Prime Minister of Mauritius. Ramkwar Gopaul, Chairman,',
#  'when he was three years old and Samuel John, born on January 16, 1846. As her sons became',
#  '1994, 2006, 2009, 2014)',
#  'Like It T-I-Is" was the third single by the B-52\'s released from their sixth studio album,',
#  'wilt." On the following Sunday, WIN activists declared Armed Forces Day as "Flower Power',
#  'hotel near the presidential',
#  'smaller animation studios were set',
#  'also translated into',
#  'inscription: " Bandusian Spring, more',
#  'go in early August 2007, but equipment promised by the United States and France had not',
#  'of Brig. General William McIntosh, a "friendly" Creek from Georgia.',
#  'them into a recreation area. In',
#  'frustrated novelists, but also introduced two groundbreaking American',
#  'closest town in France is Saint-Jean-Pied-de-Port, at a',
#  'a period of high artistic, cultural and architectural achievements for these cities. In',
#  'the beginning of 2018 he was selected to represent the U.S. Paralympic Team during the',
#  'organization (NGO) with the World Health',
#  'two years in preparation for the',
#  'of Patagonia\'s wilderness we come to feel at home there". Official website 180 South at',
#  'the house and kill',
#  ...]

# %% [markdown]
# # Split data #

# %%
train_split = int(0.9 * len(dataset))
val_split = int(train_split + 0.09 * len(dataset))
# test_split = int(train_split + 0.1 * len(dataset))

train_labels = dataset[:train_split]
val_labels = dataset[train_split:val_split]
test_labels = dataset[val_split:]

# val_labels = dataset[train_split:val_split]
# test_labels = dataset[val_split:]

print('Len train: ' + str(len(train_labels)))
print('Len val: ' + str(len(val_labels)))
print('Len test: ' + str(len(test_labels)))
# Out:
# Len train: 30918
# Len val: 3091
# Len test: 345

# %% [markdown]
# # Model #

# %%
timesteps = 256

width = 4096
height = 64

max_label_len = longest_label + 2
max_label_len
# Out:
# 111

# %%
from tensorflow.keras import applications, backend as K
from tensorflow.keras import models, losses, optimizers, Model, utils
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, MaxPooling2D, Dropout
from tensorflow.keras.layers import Flatten, Dense, Lambda, Reshape, Bidirectional, LSTM, GRU
from tensorflow.keras.layers import Activation, add, Concatenate, Attention, Embedding
from keras_self_attention import SeqSelfAttention


def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

def build_model(num_classes=94, timesteps=timesteps, max_label_len=max_label_len, input_shape=(4096, 64, 1), training=False):
    inputs = Input(name='the_inputs', shape=input_shape, dtype='float32')
    
    # Convolution layer (VGG)
    inner = Conv2D(32, (3, 3), padding='same', name='conv1-1', kernel_initializer='he_normal')(inputs)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(32, (3, 3), padding='same', name='conv1-2', kernel_initializer='he_normal')(inputs)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(2, 2), name='max1')(inner)

    inner = Conv2D(64, (3, 3), padding='same', name='conv2-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(64, (3, 3), padding='same', name='conv2-2', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(2, 2), name='max2')(inner)

    inner = Conv2D(128, (3, 3), padding='same', name='conv3-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(128, (3, 3), padding='same', name='conv3-2', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(4, 2), name='max3')(inner)

    inner = Conv2D(256, (3, 3), padding='same', name='conv4-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(256, (3, 3), padding='same', name='conv4-2')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(1, 2), name='max4')(inner)

    inner = Conv2D(512, (2, 2), padding='same', kernel_initializer='he_normal', name='con5-1')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(512, (2, 2), padding='same', kernel_initializer='he_normal', name='con5-2')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)

    # CNN to RNN
    inner = Reshape(target_shape=((timesteps, 2048)), name='reshape')(inner)
    inner = Dense(128, activation='relu', kernel_initializer='he_normal', name='dense1')(inner)
    inner = Dropout(0.2)(inner)

    # RNN
    lstm1 = Bidirectional(LSTM(256, return_sequences=True, kernel_initializer='he_normal', 
                               name='lstm1'))(inner)
    lstm2 = Bidirectional(LSTM(512, return_sequences=True, kernel_initializer='he_normal', 
                               name='lstm2'))(lstm1)
    
    attention = SeqSelfAttention(attention_width=15,
                                 attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL,
                                 attention_activation=None,
                                 kernel_regularizer=tf.keras.regularizers.l2(1e-6),
                                 use_attention_bias=False,
                                 name='Attention')(lstm2)
#     attention = Dropout(0.2)(attention)
    
    # RNN output -> character activations:
    outer = Dense(num_classes + 1, kernel_initializer='he_normal', name='dense2')(attention)
    y_pred = Activation('softmax', name='softmax')(outer)

    labels = Input(name='the_labels', shape=[max_label_len], dtype='float32')
    input_length = Input(name='input_length', shape=[1], dtype='int64')
    label_length = Input(name='label_length', shape=[1], dtype='int64')

    # Keras doesn't currently support loss funcs with extra parameters
    # so CTC loss is implemented in a lambda layer
    loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([y_pred, labels, input_length, label_length]) #(None, 1)
    
    y_func = K.function([inputs], [y_pred])
    if training:
        return Model(inputs=[inputs, labels, input_length, label_length], outputs=loss_out), y_func
    else:
        return Model(inputs=[inputs], outputs=y_pred)

# %%
model, y_func = build_model(timesteps=timesteps, max_label_len=max_label_len, training=True)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_inputs (InputLayer)         [(None, 4096, 64, 1) 0
# __________________________________________________________________________________________________
# conv1-2 (Conv2D)                (None, 4096, 64, 32) 320         the_inputs[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 4096, 64, 32) 128         conv1-2[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 4096, 64, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# max1 (MaxPooling2D)             (None, 2048, 32, 32) 0           activation_21[0][0]
# __________________________________________________________________________________________________
# conv2-1 (Conv2D)                (None, 2048, 32, 64) 18496       max1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 2048, 32, 64) 256         conv2-1[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 2048, 32, 64) 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2-2 (Conv2D)                (None, 2048, 32, 64) 36928       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 2048, 32, 64) 256         conv2-2[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 2048, 32, 64) 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# max2 (MaxPooling2D)             (None, 1024, 16, 64) 0           activation_23[0][0]
# __________________________________________________________________________________________________
# conv3-1 (Conv2D)                (None, 1024, 16, 128 73856       max2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 1024, 16, 128 512         conv3-1[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 1024, 16, 128 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv3-2 (Conv2D)                (None, 1024, 16, 128 147584      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 1024, 16, 128 512         conv3-2[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 1024, 16, 128 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# max3 (MaxPooling2D)             (None, 256, 8, 128)  0           activation_25[0][0]
# __________________________________________________________________________________________________
# conv4-1 (Conv2D)                (None, 256, 8, 256)  295168      max3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 256, 8, 256)  1024        conv4-1[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 256, 8, 256)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv4-2 (Conv2D)                (None, 256, 8, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 256, 8, 256)  1024        conv4-2[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 256, 8, 256)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# max4 (MaxPooling2D)             (None, 256, 4, 256)  0           activation_27[0][0]
# __________________________________________________________________________________________________
# con5-1 (Conv2D)                 (None, 256, 4, 512)  524800      max4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 256, 4, 512)  2048        con5-1[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 256, 4, 512)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# con5-2 (Conv2D)                 (None, 256, 4, 512)  1049088     activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 256, 4, 512)  2048        con5-2[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 256, 4, 512)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 256, 2048)    0           activation_29[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 256, 128)     262272      reshape[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256, 128)     0           dense1[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 256, 512)     788480      dropout_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 256, 1024)    4198400     bidirectional_4[0][0]
# __________________________________________________________________________________________________
# Attention (SeqSelfAttention)    (None, 256, 1024)    1048576     bidirectional_5[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 256, 95)      97375       Attention[0][0]
# __________________________________________________________________________________________________
# softmax (Activation)            (None, 256, 95)      0           dense2[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         [(None, 111)]        0
# __________________________________________________________________________________________________
# input_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# label_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           softmax[0][0]
#                                                                  the_labels[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 9,139,231
# Trainable params: 9,135,327
# Non-trainable params: 3,904
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

plot_model(model=model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %% [markdown]
# # Data generator #

# %%
import itertools

def return_classes(string):
    text = [' '] + list(string) + [' ']
    classes = [data.index(x) if x in data else 1 for x in text]
    return np.asarray(classes)

def return_text(classes):
    text = ''
    for c in classes:
        if 0 <= c < len(data) and c != 1:
            text += data[c]
    return text

def decode_batch(out, callback=False):
    ret = []
    for i in range(out.shape[0]):
        out_best = list(np.argmax(out[i, 2:], 1))
        out_best2 = [k for k, g in itertools.groupby(out_best)]
        outstr = return_text(out_best2)
        if callback:
            print(f'{out_best} -> {outstr}')
        ret.append(outstr)
    return ret

def gen_text_image(text, padding=16):
    font = random.choice(fonts)
    font_size = random.randrange(30, 61)
    fnt = ImageFont.truetype(font, font_size)
    width, _ = fnt.getsize(text)
    img = Image.new('L', (width + (padding + 1) * 2, 64), color=255)
    d = ImageDraw.Draw(img)

    if 'calibri' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'verdana' in font:
        d.text((padding + 2,-8), text, font=fnt, fill=0)
    elif 'constan' in font:
        d.text((padding + 2,0), text, font=fnt, fill=0)
    elif 'corbel' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'consola' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'cour' in font:
        d.text((padding + 2,-4), text, font=fnt, fill=0)
    elif 'tahoma' in font:
        d.text((padding + 2,-8), text, font=fnt, fill=0)
    else:
        d.text((padding + 2,-6), text, font=fnt, fill=0)
        
    image = np.array(img)
    image = add_salt_and_pepper(image, 0.2)
    image = otsu_thresholding(image)
    image = inverse(image)
    image = (image / 255.) * 2. - 1.
    return image

def inverse(image):
    return cv2.bitwise_not(image)

def add_salt_and_pepper(image, amount):
    output = np.copy(np.array(image))
    # add salt
    nb_salt = np.ceil(amount * output.size * 0.5)
    coords = [np.random.randint(0, i - 1, int(nb_salt)) for i in output.shape]
    output[coords] = random.randint(50,200)

    # add pepper
    nb_pepper = np.ceil(amount * output.size * 0.5)
    coords = [np.random.randint(0, i - 1, int(nb_pepper)) for i in output.shape]
    output[coords] = random.randint(0,100)
    return np.asarray(Image.fromarray(output))

# %%
class TextImageGenerator:
    def __init__(self, labels, img_w=4096, img_h=64,
                 batch_size=16, timesteps=timesteps, training=True, max_text_len=max_label_len):
        self.dim = (img_w, img_h, 1)
        self.batch_size = batch_size
        self.max_text_len = max_text_len
        self.labels = labels
        self.n = len(self.labels)
        self.indexes = list(range(self.n))
        self.training = training
        self.cur_index = 0
        
    def next_sample(self):
        self.cur_index += 1
        if self.cur_index >= self.n:
            self.cur_index = 0
            random.shuffle(self.indexes)
        return self.labels[self.indexes[self.cur_index]]
            
    
    def next_batch(self):
        while True:
            X = np.zeros((self.batch_size, *self.dim))
            y = np.zeros((self.batch_size, self.max_text_len), dtype=int)
            input_length = np.full((self.batch_size, 1), timesteps, dtype=np.float32)
            label_length = np.zeros((self.batch_size, 1), dtype=np.float32)
            
            for i in range(self.batch_size):
                label = self.next_sample()
                # Store sample
                image = np.swapaxes(gen_text_image(label), 0, 1)
                image = np.expand_dims(image, -1)
                X[i, 0:image.shape[0], :] = image

                # Store class
                label_classes = return_classes(label)
                y[i, :len(label_classes)] = label_classes
                label_length[i] = len(label_classes)

            inputs = {
                'the_inputs': X,  # (bs, 4096, 64, 1)
                'the_labels': y,  # (bs, max_label_len)
                'input_length': input_length,  # (bs, 1)
                'label_length': label_length  # (bs, 1)
            }
            outputs = {'ctc': np.zeros([self.batch_size])}   # (bs, 1)
            yield (inputs, outputs)

# %% [markdown]
# # Callbacks #

# %%
import editdistance
from datetime import datetime
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.callbacks import TensorBoard, ReduceLROnPlateau, Callback

class VizCallback(Callback):
    def __init__(self, y_func, text_img_gen, text_size, num_display_words=10):
        self.y_func = y_func
        self.text_img_gen = text_img_gen
        self.num_display_words = num_display_words
        self.text_size = text_size

    def show_edit_distance(self, num):
        num_left = num
        mean_norm_ed = 0.0
        mean_ed = 0.0
        while num_left > 0:
            word_batch = next(self.text_img_gen.next_batch())[0]
            num_proc = min(word_batch['the_inputs'].shape[0], num_left)
            # predict
            inputs = word_batch['the_inputs'][0:num_proc]
            pred = self.y_func([inputs])[0]
            decoded_res = decode_batch(pred)
            # label
            labels = word_batch['the_labels'][:num_proc].astype(np.int32)
            labels = [return_text(label) for label in labels]
            
            for j in range(num_proc):
                edit_dist = editdistance.eval(decoded_res[j], labels[j])
                mean_ed += float(edit_dist)
                mean_norm_ed += float(edit_dist) / len(labels[j])

            num_left -= num_proc
        mean_norm_ed = mean_norm_ed / num
        mean_ed = mean_ed / num
        print('\nOut of %d samples: \nMean edit distance:'
              '%.3f \nMean normalized edit distance: %0.3f \n'
              % (num, mean_ed, mean_norm_ed))

    def on_epoch_end(self, epoch, logs={}):
        batch = next(self.text_img_gen.next_batch())[0]
        inputs = batch['the_inputs'][:self.num_display_words]
        labels = batch['the_labels'][:self.num_display_words].astype(np.int32)
        labels = [return_text(label) for label in labels]
         
        pred = self.y_func([inputs])[0]
        pred_texts = decode_batch(pred)
        
        for i in range(min(self.num_display_words, len(inputs))):
            print("label: {} - predict: {}".format(labels[i], pred_texts[i]))

        self.show_edit_distance(self.text_size)

# %%
batch_size = 16
train_generator = TextImageGenerator(train_labels, training=True, batch_size=batch_size)
val_generator = TextImageGenerator(val_labels, training=False, batch_size=batch_size)
test_generator = TextImageGenerator(test_labels, training=False, batch_size=batch_size)

log_dir = "logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
output_dir = './models/VGG/MultiplicativeAttention'
weight_path = f'{output_dir}/ocr_model_{datetime.now().strftime("%Y%m%d-%H%M%S")}' + '_epoch_{epoch:02d}.h5'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

tensorboard = TensorBoard(log_dir=log_dir)
checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
vis = VizCallback(y_func, test_generator, len(test_labels))
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='min')

initial_learning_rate = 0.001
epochs = 100

callbacks = [early_stop, tensorboard, vis, checkpoint]
# callbacks = [early_stop, tensorboard, vis]
# callbacks = [early_stop, tensorboard, vis, LearningRateScheduler(lr_time_based_decay, verbose=1)]

# %% [markdown]
# # Training #

# %%
def train(callbacks, batch_size, epochs, initial_epoch=0):
    print('Training process starting...')
    H = model.fit(train_generator.next_batch(),
                  steps_per_epoch=train_len//batch_size,
                  validation_data=val_generator.next_batch(),
                  validation_steps=val_len//batch_size,
                  epochs=epochs, 
                  initial_epoch=initial_epoch,
                  callbacks=callbacks,
                  verbose=1)
    return H

# %%
train_len = len(train_labels)
val_len = len(val_labels)

# %%
from tensorflow.keras import optimizers

opt = optimizers.Adam(learning_rate=initial_learning_rate)

# %%
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer='adam')

train(callbacks, batch_size, epochs)

# %% [markdown]
# # Testing #
