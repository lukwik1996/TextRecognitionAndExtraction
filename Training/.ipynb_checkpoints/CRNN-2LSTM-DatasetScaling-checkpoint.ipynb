# %% [markdown]
# # Test tensorflow gpu #

# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
  except RuntimeError as e:
    print(e)

# %% [markdown]
# # Dataset #

# %%
import os
import codecs

data = {}
classes_file = '../Dataset/classes.txt'
with codecs.open(classes_file, 'r', encoding='utf-8') as cF:
    data = cF.read().split('\r\n')
len(data)
# Out:
# 94

# %%
import os
from PIL import Image, ImageDraw, ImageFont

text_source = '../Dataset/source.txt'
fonts_path = '../Dataset/Fonts'
fonts = [f'{fonts_path}/{f}' for f in os.listdir(fonts_path)]
fonts
# Out:
# ['../Dataset/Fonts/arial.ttf',
#  '../Dataset/Fonts/arialbd.ttf',
#  '../Dataset/Fonts/arialbi.ttf',
#  '../Dataset/Fonts/ariali.ttf',
#  '../Dataset/Fonts/calibri.ttf',
#  '../Dataset/Fonts/calibrib.ttf',
#  '../Dataset/Fonts/calibrii.ttf',
#  '../Dataset/Fonts/calibriz.ttf',
#  '../Dataset/Fonts/cambria.ttc',
#  '../Dataset/Fonts/cambriab.ttf',
#  '../Dataset/Fonts/cambriai.ttf',
#  '../Dataset/Fonts/cambriaz.ttf',
#  '../Dataset/Fonts/consola.ttf',
#  '../Dataset/Fonts/consolab.ttf',
#  '../Dataset/Fonts/consolai.ttf',
#  '../Dataset/Fonts/consolaz.ttf',
#  '../Dataset/Fonts/constan.ttf',
#  '../Dataset/Fonts/constanb.ttf',
#  '../Dataset/Fonts/constani.ttf',
#  '../Dataset/Fonts/constanz.ttf',
#  '../Dataset/Fonts/corbel.ttf',
#  '../Dataset/Fonts/cour.ttf',
#  '../Dataset/Fonts/courbd.ttf',
#  '../Dataset/Fonts/courbi.ttf',
#  '../Dataset/Fonts/couri.ttf',
#  '../Dataset/Fonts/impact.ttf',
#  '../Dataset/Fonts/Roboto-Black.ttf',
#  '../Dataset/Fonts/Roboto-BlackItalic.ttf',
#  '../Dataset/Fonts/Roboto-Bold.ttf',
#  '../Dataset/Fonts/Roboto-BoldItalic.ttf',
#  '../Dataset/Fonts/Roboto-Italic.ttf',
#  '../Dataset/Fonts/Roboto-Regular.ttf',
#  '../Dataset/Fonts/tahoma.ttf',
#  '../Dataset/Fonts/tahomabd.ttf',
#  '../Dataset/Fonts/times.ttf',
#  '../Dataset/Fonts/timesbd.ttf',
#  '../Dataset/Fonts/timesbi.ttf',
#  '../Dataset/Fonts/timesi.ttf',
#  '../Dataset/Fonts/trebuc.ttf',
#  '../Dataset/Fonts/verdana.ttf',
#  '../Dataset/Fonts/verdanab.ttf',
#  '../Dataset/Fonts/verdanai.ttf',
#  '../Dataset/Fonts/verdanaz.ttf']

# %%
dataset = []
sequence_len = 20

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import cv2

def draw_img(img):
    plt.imshow(np.asarray(img), cmap='gray', vmin=0, vmax=255)
    plt.show()

def load_img(img):
    return cv2.imread(img, cv2.IMREAD_GRAYSCALE)

def dilate_img(img):
    return cv2.dilate(img, np.ones((2,2), np.uint8))

def otsu_thresholding(img):
    norm_img = np.zeros(img.shape)
    img = cv2.normalize(img, norm_img, 0, 255, cv2.NORM_MINMAX)
    blur = cv2.GaussianBlur(img, (3,3), 0)
    _, img = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    img = dilate_img(img)
    return img

# %% [markdown]
# ## Load dataset ##

# %%
with open(text_source) as txt:
    word_count = 0
    sequence = ''
    dataset = []
    for i, line in enumerate(txt):
        words = line.split(' ')
        for single_word in words:
            word = ''.join([c for c in single_word if c in data])
            
#             if word[-1:] == '\n':
#                 word = word[:-1]
            
            if len(word) < 1:
                continue
            
            if len(word) > 30:
                split_count = len(word) // 30 + 1
                for i in range(split_count):
                    start = i * split_count
                    end = start + len(word) // split_count
                    dataset.append(word[start:end])          
                continue
                
            sequence = sequence + word + ' ' * random.randrange(1, 4)
            word_count = (word_count + 1) % sequence_len
            if word_count == 0 or len(sequence) > 85:
                dataset.append(sequence[:-1])
                sequence = ''
                
dataset = list(set(dataset))
len(dataset)
# Out:
# 34793

# %% [markdown]
# ## Shuffle dataset ##

# %%
sorted_data = sorted(dataset, key=len)
longest_label = len(sorted_data[-1])
longest_label
# Out:
# 115

# %%
import random

random.seed = 123456

random.shuffle(dataset)
# dataset = dataset[:3000]
dataset
# Out:
# ['with the   Severn.The  Swilgate gained  some  notoriety  ',
#  'Savings   Group  Collector,  Margate.  James Perkins,  Constable,  Metropolitan  Police.',
#  'gum  holes.Pygmy marmosets   have  adapted insect-like   claws,  known  as ',
#  'breeds  of  dogs   in  the  empire),  they   were   also kept   as  pets   in   pre-Inca ',
#  'in   2014.   The team  played  its   home  games at   Nelson Field,   and   House Park ',
#  'and then in  1962,  separated ',
#  'Skiba   refers   to  it  by  its  former   name,  the Cabaret   Metro.   Hoppus begins  ',
#  'guilty  for  his involvement in  the 2002  ',
#  'because   of her   position  in society. A   conservative',
#  'serious  investigation  except   as a  cultural  artifact. UFOs  have been the subject ',
#  'Portal,   a  location scout   from   Netflix,  was found   assassinated  in   his  car  ',
#  'it   may   take a curved  course   in  order to jump  on it   from   behind.Immature ',
#  'a  twin  lens reflex   instant camera   called  ',
#  'UCD.  The  Amateur  Athletic   Association   is',
#  'payment  by   the  judgment debtor   of the ',
#  'Area Health Authority   (Teaching).   Professor   Tom Keightley  Ewer,   lately  Professor  ',
#  'a   direct  way  whereas  RA evaluates   weight',
#  '"bantering   speech"  against  the  proposed   Excise Bill of 1733.Elton   topped the ',
#  '"Beggar\'s  Day"   appeared on   Hair  of  the  Dog   (1975), while  Nitzsche\'s "Gone ',
#  'not be able  to maintain  its delivery  ',
#  "are visible   in  the  images matches   the   mast   of   either   India's   Shishumar-class  ",
#  'the   Mozilla  VR   team   during mid-to-late  2015.   A-Frame  ',
#  'Small  Industries  in   Rural Areas.  Thomas  Pratt  Barlow,   Consultant,   Rolls-Royce  ',
#  'as   "responsible democratic   government".   In  Queensland,  the',
#  'A History  and  Analysis of   the  African   Union  Mission   (AMISOM),   2007-2017. ',
#  'the  NHL  and   one   season for  the  Seattle   Metropolitans (192223)   of  the   PCHA. ',
#  'Wales.  Cyril   Beard, Clerical  Officer,  Ministry   of Defence.  Elsie   Lilian   Rosa ',
#  'again assigned   "A" grade  credit   ratings   by  Moody\'s   and Standard &  Poor\'s.  ',
#  'Works,  Imperial  Chemical  Industries Ltd.   Cyril  George William  Edwards, Works  ',
#  'Mogadishu.  10 October One   AMISOM  soldier  ',
#  'Cerro Corcovado  (the  Corcovado  volcano),  an attempt  that   was  halted  200  feet',
#  'For  services   to British commercial interests and the   British community in the  Netherlands.  ',
#  '1949 through 1950, the   year  he',
#  "Character'  International   Journal of  Psychoanalysis XI 1930  Acting  out Psychological",
#  'We   promised  ourselves   that  our ',
#  'of   control.  On   2   June  2017,   Indian   military',
#  'to   be  soluble, there must be short  chains ',
#  '(Visvesvara,   1964)  Setopus aequatorialis   Kisielewski,  1991   Setopus  bisetosus  ',
#  'Secret. 200  files   are set  to be   made  public  by  2012.  The files   are correspondence',
#  'Space  age   pop   was inspired',
#  '1971   and   December   1973  as  part   of the ',
#  'New   Jersey  National  History  Day   since 1988,   and   the ',
#  'from  Somalia   altogether,  arguing  that these   were  a   national  contingent   and',
#  '(most   parts  of   which   still   exist)   is   being held  for the  most  leaning tower  ',
#  'in   Indian Territory to   become  allies',
#  'paper in 1949,  leaving her  school  for  a   research',
#  'was  made  between   Singapore Government and  Government of   India which recognized',
#  'Watt  as   his   assistant. Players  with  Football  ',
#  'name   originated  from ',
#  'behaviorist   interpretation  of the   Meadian \'I\'." American Journal of  Sociology  85:26187.',
#  'John Chalmers, General  Secretary, Amalgamated Society of Boilermakers,  Shipwrights, ',
#  'of a  Man album)   "Bridge  Over  Troubled  Water"[4]   (from   "Bridge  Over  Troubled ',
#  'and inadequate for   their   needs.   Plans  to   demolish  the   building   were  scrapped  ',
#  "Royal Far West  Children's Health Scheme.  Eric John   Cooper,   of  Castle  Hill,  New",
#  "the city's Near  North  Side  while on his way to lunch.   He was   rushed  to  the  ",
#  'to  their   coaching staff, serving as  a   coaching  assistant   to   new Phillies  ',
#  '15   and temporal/spatial at   25. Demetrius  Grosse  at   IMDb  Demetrius Grosse   at',
#  'longtime   Bitter  End  owner   Paul  Colby.   In ',
#  'platynaris Dalstrm  2001  (Peru)  Odontoglossum   portillae   Bockemhl  1985  (Ecuador)',
#  'forces   in  order   to enhance   their  capacity and  to   promote peace  and  security  ',
#  'anthem  using   power   chords   predominantly.  Alex Robert  Ross   from   Vice   compared',
#  'Police,  Royal  Hong  Kong   Auxiliary   Police   Force. Hon-ming  Chu, Chief   Inspector  ',
#  'stage.  The previous year the   ABC  had   broadcast  a   TV revue.  Arthur   Wyndham  ',
#  'College,   New Mexico,   Army, and  top-seeded Villanova  to win   Lapchick   his   fourth ',
#  'compared   to   sunlight   driven  processes  above.  Inorganic   mercury   Hg2+ and methyl  ',
#  'made  its   long-awaited  announcement  on the   excise   rate for   fuel   alternatives  ',
#  'reduced with   a  single   treatment   using  this polymer.In addition   to   the  cleaning  ',
#  'States has  provided   extensive   training for  contingents headed  for Somalia.   In',
#  'Year   12;   and Manly   Selective  Campus,   a  co-educational,  selective secondary',
#  'with   Republican William  S.   Finucane taking the   third   spot. ',
#  'Taylor   Kilbourn Zachary  Bennett   -   Zack Pamela Wallin  -  Herself  Jean   Yoon -  ',
#  'is known   for farming and   is part what  is  informally  called the   "fruit  bowl"',
#  'bodies are  aggregates  of   polyglucosans or abnormally shaped  glycogen   molecules.  ',
#  'archive.org/web/201406',
#  'and  Sainte-Angle-de-Monnoir;   in  the County  ',
#  '3   September  1936)   is   an Australian   pharmacist,   businessman, and',
#  'had   persuaded   most  of  the  Cherokee and other nations of the   Five Civilized Tribes  ',
#  'seabed,   vertical  rock   faces,   sandy beaches,   mangrove',
#  'the 14th.   Restoration   was  carried  out   in the 17th  century,  then  in  1812  ',
#  'from parliamentary   scrutiny   and the  threat   of a   no confidence motion.At   the',
#  'in  1532, under  Habsburg   auspices.   She went ',
#  '(2006). Overleven  in   een  Grensgebied:   Veranderingsprocessen  ',
#  "impulses.   The   'I'  is  self as subject;",
#  'record   for  points scored,   with 881. After  working  in   the   front   office   with ',
#  'father, Charles (known   as Harry),   was ',
#  'Council  election 1999 Barrow-in-Furness Borough Council election   (New   ward  boundaries) ',
#  'were   first  released   on May  14,  2008,   to The   National  Archives by   the  Ministry',
#  'on  a blue   shield   three   golden  stags  inside  a   gold   border. Above the shield  ',
#  'the  postseason   every   year   and   twice   reached   the  NBA Finals, but   lost  ',
#  'in 1892. In 1891,  he  captained  his   team   to ',
#  "IBF  World  Championships  in  mixed   doubles.  Mixed   doubles   Mixed   doubles   Men's  ",
#  'Goods  at   the  end,   and  the   entrance',
#  'ability to perform   daily  activities leading to   the survival ',
#  'of  the   best   known   and  most performed   Austrian   opera  composers  in   the  ',
#  '2016  CECAFA:   2013,  2016   Ray   Franz is a   former  member  of   the   Michigan ',
#  'reflex instant   camera  that   uses   Fuji instax  mini   film.  MiNT  started   as ',
#  'naturelle   and   the   Museum   fr   Naturkunde. Partial  list of  publications1919.',
#  'take   over   Tesla.   No  action  has been   taken   since.  On August 28,  2019, Escobar  ',
#  "supervisor.  The   interpretation  of a   person's   acting  ",
#  'The sponsor earns  popularity   this way while  the sponsored   can earn a   lot  of ',
#  "court agreed   with the  EEOC's   reasoning.  Reproductive ",
#  'Keep  It  To  Yourself   is  the  debut   album  by   MullMuzzler (a  band formed   by ',
#  'later  to Pembroke Dockyard,  where   she  was  finally  completed  in April  1925.  After  ',
#  'as the  city had   long  outgrown the  defensive  fortifications,  and  on   top of  the  ',
#  'be   life on  other   planets   but  "the ',
#  'is   an English   former  professional  footballer  who  played  as ',
#  'Stuttgart, 1139   pp.,   194   pls.   1924   Family:  Hesperiidae   in ',
#  'The initial   phase  of an  act   constitutes a   gesture.   A  gesture   is a  preparatory',
#  'services  to   British commercial   interests  in   Seychelles.   Patrick   Ferrer  Hawkins.  ',
#  'however,   the track   order is   changed;  "Little   Speaker"   is   omitted;  "Mo  Move"',
#  'signs   of   life.  The   response   noted   "odds  are  pretty high"  that  there may',
#  'process can  be  followed   by   a   chemical   etch ',
#  'were  violating   the Civil  Rights   Act  of  1964. President   Obama signed the  Patient',
#  'Army  forces   and al-Shebaab  when the   insurgents  attacked the',
#  'new director of French UFO   research  organization  GEIPAN).It  has ',
#  'to   be  approximately   13,000 in 2001  commune ',
#  'outlays."   The  Associated Press   reports that Bancroft  has been   paid   $12.5 million  ',
#  'heavenly   signs   proclaiming the  return of   Christ.   As   for  the   social barriers,',
#  'club for ten years and making  over  ',
#  'Draughtsman,  Cabinet ',
#  'of   Jerusalem  and   his officers   and   attendants',
#  'website Discography   at Discogs The 1991   John Hancock ',
#  'Battle of   Baidoa).  On   1   January  2007, after  the',
#  "Mazepa.  Dmitry's  father,  Prokofy   Troshchinsky,  was a   Bunchuk  comrade  in  the  ",
#  'Shockers football program  was  a   college  football team that  represented   Wichita',
#  'territory to   Babylon,  Ekallatum, and  Ashur.   In 1780 BCE  ',
#  "metropolitan  area.   Throughout   the next  three years, St.   John's would  go 5818 ",
#  'was   targeted,  leaving   six  dead.  On  21 March ten   people  were killed   and 12  ',
#  'late  2018. Unwin  was   appointed  Officer of  the ',
#  "'subgraph' is just barely  beyond the scope   of   the",
#  'time  in  infant   care  and  predator   vigilance.  Such   males  have less time to  ',
#  'conformation   showing.   The  color  of skin  can   be  chocolate-brown,  elephant-grey,  ',
#  'The  book  received   a  positive  reception  from  Publishers  Weekly;  the  review  ',
#  'reason",  ultimately  leading to the   demise   of  Kantianism. This   is   then  seen  ',
#  'that Pope   Francis   had   chosen  de  las  Heras   Berzal ',
#  'the original conc-tree  paper.   It  was shown that ',
#  'on   14  November   1967  in  Pavia,  Italy.   His parents   owned  a  florist shop  near ',
#  'the Rhein   River  and established  headquarters  ',
#  "in  groups.   Finger  monkeys'  (pygmy marmoset) value  is  associated   with  them being",
#  'programmes in nursing  since   1987.   The   college has  ',
#  'cover   versions   of  Harlan  Howard\'s  "The   Key\'s  ',
#  'an  audience   of   over  ten  thousand.  Wentworth also  orchestrated  and  conducted  ',
#  'French.  As  in   the   last  ',
#  'water  channels  (a rill   or stylized   qanat)  where water reflects  and   flows,  set  ',
#  '1992,   Sullivan  Bluth Studios renamed  itself to   Don   Bluth Entertainment.',
#  'being elected  only  in   1869 and   1870.   The  winner ',
#  'much  as  it deals   only  with   the   present   at   the expense  of concealing the  ',
#  'the  self\'s   "perception  and meaning"  deeply   and   sociologically in  "a common ',
#  'Security Council   African Union   United  Nations-African Union Mission ',
#  'with the  description of   seven  new  species".  Journal',
#  'ten   SUN  workstations   were  built during   1981  and   1982,   after ',
#  'portillae is  a species of plant  in the family  ',
#  "to Ballyfermot's traditional   animation  approach.The   closure  of Sullivan Bluth  Studios  ",
#  'is  generally found   in   evergreen',
#  'dq=what+is+Delphinium+Scopul',
#  'the  packet has been corrupted. Packet loss can  ',
#  'at Holloman   Air  Force   Base Aero Medical  Field   Laboratory  ',
#  'workshop and  fuel   station at  Holtet.During',
#  'trade.  He   founded   the  Tampa Board of  Trade and  the Tampa   Chamber of  Commerce, ',
#  'of actions.  The  Indian   Navy   strongly rejected the  ',
#  '90 members  of   the nobility were   in  the   learned  ',
#  "are 1:1. The  breed's   bald  bodies   radiate ",
#  "island',  referring  to  a  piece  of dry",
#  'Charles  Boyer  as   Dominique  You  Inger   Stevens ',
#  'track   listing  includes fan   favorites,   the No. 1  single  This  Is The Night,  ',
#  'Civil  DivisionEverette  Wakefield  Evans,  Sr.  For services   to  the community.   John ',
#  "reality   is   restored. Sam  returns   Max's  brain  to  ",
#  'Bayfield  Street   Medical   Centre,  as well as',
#  'in  Sweden. The  denomination  emerged  among  Radical  Pietists   who   separated from  ',
#  'It   gnaws  holes in  the  bark of appropriate trees  and vines   with   its   specialized',
#  'Nakamura   with Dr.   Noriko   Hanamura (Kami),  the lovely daughter  of his  coworker  ',
#  'Queensland team.   From  2010   onwards,',
#  'in many  communities   as   extension  site locations. At these nearly   forty  sites, ',
#  "original  music at   Joe's   Pub,  Fez,  China Club,  Barracuda,   Metronome,   Avalon,",
#  'composers,   but  almost always  arranged  in  a   lighter ',
#  'compositions, which  are  numerous, little  interest  is  to   be   attached  today.  ',
#  'influence  him greatly. In  1894,   Mead  ',
#  'same  routing since that   time.  State   Highway   108A   was   a  spur   routing   of ',
#  'Taylor,   lately Senior Adviser  for   Infant Education,   Clwyd. The Reverend Prebendary',
#  "for  women's right to   vote.  In 1906,  ",
#  'Missouri  State  at  #1.On August   22,   D2football.com  released its  Top  ',
#  'such  as  Singapore  publish   past examination   papers   from  various sources and ',
#  "also   pacifists. The Women's  Peace   Council   was ",
#  '"Hello   Stranger"  (Barbara Lewis)  2:40   "Just One   Look"  (Gregory   Carroll, Doris',
#  'Egyptology. London;   Boston:  Kegan  Paul International.   ISBN   978-0-7103-0107-9.  ',
#  'There are a  few  high-level APIs that extend   RDFLib graphs  into other Pythonic  idioms.',
#  'Rosengrtlein  1928 Mondnacht   1934   Das  VeilchenJulius  Bittner   also  composed  two  ',
#  'the band. They  let  the Crazy  Horse  name   go unused while resolving  not  to   retire ',
#  'linked  to   the  skin color.   It',
#  'He   continued   raising  petitions   on  mercantile  issues,   and   voted with the Opposition ',
#  'successfully  contesting  the  lord-mayoralty.  In  October 2015,',
#  'as  the  new   bishop   of  Len, succeeding the retiring Julin  Lpez   Martn.   San  ',
#  "developers,  however, preferred   the  sprites   created from  the  models  over   Calvin's",
#  "In   early   1980,  'D'   Company   was reorganised  as",
#  'who  is   better known   for the  design  of  ',
#  'an American   rock   band from Detroit, Michigan. Founded   in ',
#  'The  tower  of  Buxhall  Mill  is   three storeys, built   on a   three-storey base  ',
#  'White  continued   to   have   frequent   differences  of  opinion  with  Edwards. Matters  ',
#  '(2003) The   Fallen  Ones   (2003)  I, Robot   (2004)  Demon Hunter  (2005)  All   Souls',
#  'pheromone,   which stimulates  loco-motor activity   in   the  male   to  approach the  ',
#  'out,   but   the  preparation takes   place   in  ',
#  'de las Heras   Berzal  joined   the Missionary  Sons of the Immaculate Heart  of  Mary  ',
#  'win   for  England   the lasting   gratitude of  ',
#  'described   Astralis as  the  greatest CS:GO team  of all  time. For Magisk,  who  was ',
#  'pairs.  Species accepted  as  of   June   2014:   Media  related  to  Ponthieva  at  Wikimedia ',
#  'were also  featured on   Iggy  Pops  ',
#  'years.  After   the  liberation  of Paris  ',
#  'only, from  Year  7   to  Year   12;   Cromer  Campus,',
#  'where the  source can  be ',
#  'then  appointed   by Governor   A.   Harry Moore  ',
#  'the town of   Pittsfield,   while  the Shawano   County  portion is   in  the town of ',
#  'information, such  as   failing   to   mention that "I  Can\'t Give  You   Anything but  ',
#  'Antony  village. Media   related  to   Antony   Passage at  Wikimedia   Commons   Adewale',
#  '33  feet   6 inches  (10.21  m)  long   and 8 feet 6  inches (2.59 m)  long.  They were  ',
#  'their  first  game under   new   head',
#  'from  Bennett  High  School.   Sievers   received   his',
#  'engaged  in  the production  of a  CD  of  ',
#  "to  his  parents' relationship  described",
#  'are   growing rapidly.   Company   is  cash   flow   positive,   profitable  or approaching  ',
#  'He\'s  dead,   sir." Later  in  the film,',
#  'Uganda   Super League.  In 201213 Wadada   played 20  league games  while Bunamwaya  finished',
#  'murder   convictions.  Its managing editor is  Rachel',
#  "is  an   hour's drive   south,   skiing   is 30   miles  (48   km) north, and the  Meadowlands ",
#  'honey-suckle   and   may   others  all growing most luxuriantly -  while   the beds  are ',
#  'Ena   Mary Richardson, Principal   Lecturer   in  Art   Education,   Preston Polytechnic.  ',
#  'is   to be calculated  on the aggregate   sum',
#  'a  35-minute  composite   of   feedback,  guitar noise, and   vocal fragments culled  ',
#  'the path  to  the  semantic web and   most   of its   value  is in  (corporate/enterprise)',
#  'their clients   within   24 hours, and ',
#  'Islands. The Venerable   Archdeacon Reginald  Basil Ney, MBE.   For',
#  'in  the   list of "100  Essential  Rock ',
#  'media reports,  citing   defence   sources, said that special   forces  of the Indian  ',
#  'Kansas Paleontology  in   Nebraska   The   Bureau   of Investigative   Journalism  (typically  ',
#  'at   the 2002 Pan Pacific Swimming',
#  'Championship  Taylorsville  is  a   town  located in',
#  'June  2000,  by   the then   Minister  for Education   and Training, the   Hon.  John ',
#  'life storey,  written  more  than  a   century  later   by her granddaughter,   Nancy',
#  'Robert  Hawkins   who  assumed   the surname   of Magill.  The  ',
#  'between  the   Up (Salwick bound)  Fast  and the  ',
#  'and international   market   as   a  center   of',
#  'but no  goal  was awarded   as  the  ball  had gone  straight   in   without  touching ',
#  "Street and  one   in Gregg's   Lane  (now ",
#  'the part   of   the  individual.  There is,   then,  no  "mind or   thought without  ',
#  'base   coach   for  2008. On  October 14, ',
#  'his   new studio was   to  return   animation   to   its glorious  past, concentrating  ',
#  'with   a  half-hourly service  north',
#  'West  Berlin and  East   Berlin   during the  Cold  War.  All  the  differences between ',
#  'context-aware  store to  search  the  entire   asserted   universe  (the conjunctive graph).',
#  "that  is  dioecious. Androlaechmea 'Crateriformis'   Androlaechmea  'Cyclops'   Androlaechmea  ",
#  'is   difficult.  The  first   editorial efforts to  change',
#  'residents,  living in  429   households, with   an  average age   of 40.8  years.   Of  ',
#  'boundary   in Chaprar   and   Harpal  sectors   and  ',
#  'and  J.  J.  Gibson,   the   key  is not simply  human ',
#  'results  in   a Ni(0)   intermediate which can   disproportionate into   LnNiIX.  If the',
#  'a   major employer in  the  town,   employing',
#  'thereafter. There  were   no  fair events  in',
#  'Court   in  Snepp v.   United States  (1980)',
#  "form several  local area  networks. The SUN's   design   was   inspired by  that of  ",
#  'mother   mourns  for lose   of  her  ',
#  'three clubs  appealed. However,   the French Football  Federation  rejected the appeal',
#  'eventually   won   promotion,  winning  the league ',
#  'Professional  Development)   hours of   learning each  year.',
#  'callacallaense  D.E.Benn.   &   Christenson   2001  (Peru) Odontoglossum   cirrhosum ',
#  'in  a   party room  ballot   on   2   December. 3  December -   Former  Queensland  Chief  ',
#  'contested   between   all   sixteen teams   of  the National   Rugby League.  The   draw',
#  '2Pac from   the album  2Pacalypse  Now  "Bumpy\'s   Lament"   "Drugs"  by   Lil\'  Kim  ',
#  'and   skills   in  prosthodontics.   The   Prosthodontic Forum  represents  19 member',
#  'Frank,   Lizzie,   Syd   and   the gang   try   to secure   his freedom.  Once   again,',
#  "1975,  1977, 1978, 1980, 1981,  1982,   1983Women's ",
#  'northwest of  Kismayo.   This  was  reported  to  ',
#  'further reaching   consequences  than   those of  ',
#  '(Mollendorff, 1875)  ',
#  'Di Fingleton   is   sent  to jail for  six months ',
#  'and   people.   One  such, called  "We  are",  appeared in Life   and   Letters   Today,',
#  'Press   Association  Ltd.   Frederick   John  Lowden,   Senior Executive Officer,   Department ',
#  'p://calphotos.berkeley.',
#  'in the state   of   Amazonas, Brazil,   eastern Peru,   southern   Colombia,  and   north-eastern  ',
#  'in the creation  of   counter-cultures   and trans-national relations  in   the   21st  ',
#  'when no financial   loss  flows from   the infringement',
#  'Bay cricket   ground,   skateboard  ramps',
#  'of   intense   development   followed. A College  Administration  Centre   was set  up ',
#  'to controlling  seizures  through anti-epileptic and   anti-convulsant medications.  ',
#  'of  Florentine  Art.  New  Haven (CT):   Yale  University Press,   2001. ISBN   0-300-08543-5. ',
#  'Radio  Canada (1997) If A  Tree   Falls Earthbeat!  Records   Compilation  CD (1996) New ',
#  'the  value  for the  buyer, while   the  buyer   must   recognize',
#  'plus  three trains   per hour to  Blackpool North.   Train',
#  'on  strong stories, and  using   traditional  animation   techniques',
#  'that six Pak civilians  were  killed  while  26 others  including   15 women  and   5  ',
#  'subject to   the Holy   See) Roman Catholic   Diocese of  Laghouat   GCatholic Catholicism',
#  'implemented  as  follows:  Amortized O(1) time   appends   (or  ',
#  'also   childcare, and  nursing  home  facilities   nearby.  ',
#  'the  device  helped  to   give more immersion  to   the  game,   as   opposed  to  the  ',
#  'Victoria.  For   public   service as  a  training officer.   Kaye   Mary  Lette,  of ',
#  'The   three-sided   columned  verandah   is  under   the  same roof of  the house.   The ',
#  'fantasy   world,   who  goes on  a   quest  to   get the  moon  back  from   a giant ',
#  '1869 a  lease  or  sale   advertisement  ran  in the Sydney  Morning  Herald.   In   August  ',
#  'to   limited knowledge  of   its   population and  distribution, and  potential   for  ',
#  'Drive   in Lexington, Kentucky.  Don',
#  'at   the   1989 FIFA   Futsal  World Championship. Robert   Van  Sickle   McKeen   (November  ',
#  '"Exactly   Like You"   (Dorothy  Fields,   Jimmy',
#  'ordained   a bishop  on  7   May  2016  by  the archbishop  of  Santiago, Julin   Barrio  ',
#  'were  philosophy   and   psychology.  At Harvard,  Mead studied   with   Josiah  Royce,  ',
#  "He  wrote Gifts   of   the Night  for  DC Comics' Vertigo imprint, with   art   by  John",
#  'a "type  of   survey, the kind  of overview  ',
#  'defeat   of   Tahiti   in  the  second  leg ',
#  'and   approved   by  the   African Union  at ',
#  'world boundaries. Closed   world  boundaries can be  made   transparent  by   federated  ',
#  "the   Earth:  The Long   Family's 500 Year ",
#  '1943, Keppel was involved   in the   battle  around  ONS 18,  which   saw six ships  and ',
#  "the  Republic Party   (PR).   In   spite of  the Governor's   support for  Cardoso,  the",
#  'Fair near Cheyenne.  After   events  in   Laramie,  ',
#  'battalion completed first phase training  only   in  ',
#  'site include woodturning,  broom-making,  walking  stick-making and  the work  ',
#  'because  of the   illegal  brandy   smuggling   that   took place through the   area. ',
#  'Frustrated  he  confronted   Louisa,  since   she   was  ',
#  '(Viennese   singspiel) 1921   Die   Kohlhaymerin 1923 Das',
#  'run  in   devices with   limited  memory   and  processing   power.   By  June 2015 Inview',
#  'Regiment,  Colonel  Commandant  Corps of   Royal Military ',
#  'who   claim  to   have   been  summoned   there   precisely   for   this   purpose,  he ',
#  'works better  here   than it did   almost anywhere ',
#  'condom,  spermicide,  emergency contraception  (Plan  B/morning-after pill),   and   emergency ',
#  'Force (4 Seasons, 21   Episodes   from 2002  2006) The  ',
#  'Connor  -  Angus   Kilbourn   Natasha  La  Force -',
#  'European-American   settlers.   In  1813,   when  the Cherokee raised up   636 men against',
#  'Bump  Wills  (born 1952), American  Major  League Baseball   second basemen  All',
#  'by  the Soviet  lunar   probe   Luna 3 in   1959  were fake, and  that there   were cities,',
#  'killed as a   result   of ceasefire   violation in   Samba sector of   Jammu  and Kashmir.On',
#  '2008.A   motorised   combat  team  from 6 RAR ',
#  "John's   beat Kentucky, 6457.  They later ",
#  'known  as the "Wonder   Five",  made   up   of   Matty   Begovich,  Mac   Kinsbrunner, ',
#  'the spring  of   2007, the band   was featured  on the   season   finale  of  The Simple ',
#  'to  the   community.State of Western   AustraliaHenry William Dettman,  of   Swanbourne. ',
#  'to gauge   voting intention  in Poland. Results of  such  polls  ',
#  'from   something  Ringo  had   said. I had   used ',
#  'solely on match  reports   in   Matches sections   above and  the ',
#  'indirectly   elected  by  the   state legislators, since  year 1956.   Keys: BJP  (2)',
#  'Affairs and  his own personal  attorney,  Michael',
#  'Graph   class  works  with   instances of  this   API   (as the  first argument  to  ',
#  'Member, Borders   Health  Board. Roderick  James  Rogers Armstrong,   Chief Engineer  ',
#  'to  Australian  multiculturalism.   In August 2011, the   Federal  Government,  acting',
#  'from   2013.  The  Hindu shrine, constructed near  to   the stupa mound, was  officially  ',
#  'a   rinse   with tap  water.   Application  of a corrosion inhibiting ',
#  'in   the  Somali   capital;  Bancroft   International,  who provide training  to   TFG',
#  'Warrane  barracks  of  the   12th/40th   battalion  of the   Australian   Army Reserve.',
#  'are   standard   to   most   database management systems (Oracle,   MySQL,  Berkeley ',
#  'in their  area of   operations   had  been so   badly   weakened that  they  were   forced',
#  'Mini-Moog   synthesizer; piano  on "Gospel  Truth" Clive  ',
#  'Partner   Store  in 2011.   In 2011, MiNT released ',
#  '2   (10): 70416. doi:10.1038/35094565.   PMID   11584308. S2CID 13224138.   Engel AK, ',
#  'their   religion and to   contest  the   Catholic presence  there. Huguenot pirates  ',
#  "According  to  Sgt.  Jessie  Schatz,  Nicholson's  driver, ",
#  'Fame in   1981   and   the Oregon State ',
#  'on   the  1983  novel   of   the   same name by   Pirro.   It stars  Giancarlo   Giannini,  ',
#  'on  the Billboard  Top  10 charts  for  the  first  ',
#  'making   the  postseason  6 out ',
#  'plot  was  developing a few   kinks.  Walter  and  Kurt  were  having trouble   with ',
#  'ships   and  would  have required  dredging 17   acres of sea   bottom,   which  includes',
#  'in  June   and  took in  ',
#  'of   the   Warped  Tour  in 2008   in  2008   and 2009.The   band  played   the  Bamboozle  ',
#  'claimed  that   two   of its  civilians   were killed in  a   ceasefire  violation  in',
#  'from  achieving  their  stated   aims of forcing   the ',
#  'second-place   finishes in  the Royal Owl  Handicap  at  Santa Anita in  January  and  ',
#  'the  sender automatically   resends   any  segments that  have not   been   acknowledged.  ',
#  'and   Ingrates  I Have Known  (Morrow, 1984, ISBN   978-0-688-02215-0)   Hemingway  and ',
#  'cause   for   canonization by  the  Diocese  of  Springfield (archived)   Lasname   Airfield  ',
#  'the   Ministry   around   50,000  a  year.  The',
#  'often  raunchy advice  columns  might seem  at  odds   with  this  self-revelatory  memoir ',
#  'He then  served in   the Iowa State  Senate  from   2003   to 2005. Daniel  A.   Shirley  ',
#  'instances.   RDFLIb  supports   a   majority of the  ',
#  'and   definite  personalities  start  to   emerge.   Children  begin to  become   able  ',
#  'and added  to   the National   Register of   Historic   Places in   1983.  Grove Township  ',
#  'by Max  Vangeli and DJ  Eco  and a reprise of the song. A  music  video was released ',
#  "charity   food company  Newman's   Own   with   actor  Paul  Newman. Hotchner   was born  ",
#  'by the   African   Union Peace   and   Security   Council   have  also  ',
#  'engaging  the  Australians in   combat   only   when it  was  necessary to   survive.',
#  'wrote   a   poem   titled   A   Venetian   Pastoral,   by   Giorgione,   in the  Louvre,  ',
#  '- Furthermore,   there   are   also   a  small',
#  'Roger  Waters,  and   co-produced, orchestrated  and   conducted  the',
#  'went  a  step further   and   "gave  the American   Legion  of  Alabama  ',
#  'class   designation   and  academic degrees.  Some of  the  ',
#  'Libby Dam backs up huge  Lake Koocanusa  (combination  ',
#  'a section of  Leeds   fans.  197374   League  champions Leeds United reached  the  European ',
#  'developed   on   a  case-by-case  basis by',
#  'a  significant  profit,  suggesting   Finch   had   built on  the ',
#  'Cold War,   an era   associated  with  a   heightened  concerns   about  national   security,  ',
#  'October  2000,   the   battalion  also assisted',
#  'of Victoria  Irrigation Area   established  in  ',
#  'exhibit  a small   positive   alpha albeit  a   statistically  insignificant one. Fundamentally  ',
#  'For  two  decades, Gould  has  been an active board  member   of',
#  'Navy   also said that   none   of   its ships are ',
#  "1939   as the   second Imperator   of  AMORC.   One   of Ralph   Lewis's  many books is ",
#  'Pocahontas   II: Journey   to  a   New   World   and  later  ',
#  '20, 1868, and   was   buried in   Robbinsville.  His  grave was',
#  'S. Pet,  D.  Hulme, M. du   Plessis   (eds) Civil   Procedure:   A   Practical Guide.  ',
#  'Physicians ',
#  'art   in  Washington,   D.C., Ward   2   National   Register   of   Historic   Places  ',
#  'was   decommissioned and in July 1945 was sold',
#  'the E.  B. Wilson   Medal.   He  had   been elected  to   the  National Academy  of  ',
#  'in Spain in   2009, and  Oxford  and London',
#  'community   in  Freetown. Ernest   John   Evans, Vice-Consul,   British',
#  'pilot) Nick  &   Noel  (1993)  A  Cool Like That Christmas  ',
#  'in   Japan   and  having  to   have  a  different ',
#  'his   races.   Horse   racing  in  Great  Britain List   of   British  flat   horse  races  ',
#  'appointed   Board Directors  of  Inview   Technology.  In   2014   their partners   included:  ',
#  'lyrics  written by Chi.   Udaya   Shankar. The musical score  by   T.  G.  Lingappa  was  ',
#  'film   Space   Chimps follows   anthropomorphic  chimpanzees ',
#  'in the  central   western   district   of New   South   Wales,   Australia. The  river  ',
#  'Butt-Head  (2011)Puppet/CGI shows:  The  Mr.  Potato   Head Show   (1998) Tripping  the ',
#  'injured   after  Pakistani military  opened  fire   on   Indian   military  positions.On ',
#  'in   Palestine of   a Jewish  state, and   of   the ',
#  'and now regard   the  official   final score of   the 1877  final   as 21.   GeneralWarsop,',
#  'Canticum   B. Simeonis Herr,   nun  lssest du  deinen   DienerHenry  II had planned the',
#  'States   of the African Union  to  maintain the   deployment of ',
#  'no prisoners   taken; no  documents  captured;   no   weapons  or  ',
#  'space of  six  24-hour   days.   believes  in   complementarianism  and  rejects  the ',
#  'law  to have   no possibility of a   conflict   of   interest  World   Wide   Fund for  ',
#  'Jackson   on November   10,  1978,  which  gave  Jackson  control  of  the business and ',
#  'an interest in  the band,   securing   funding  for  a new album. With   Harlow  serving ',
#  "earned him numerous   awards  including   the Endocrine Society's  Robert  H. Williams ",
#  'offered   non-concrete  proof.   (398) Franklin then  admits  he   loves Louisa   and',
#  'out in an  analytic  setting   potentially   offered valuable  insights  to  the  therapist; ',
#  'King   Jr.   and James  Bevel   took the  Civil Rights Movement   north  and  encouraged  ',
#  'Territory.   For   public service. Richard  George Fry, OBE,  of  ',
#  'communication to take  place,  each organism  must  have   knowledge   of how  the   other',
#  'operates  a  bus   between Campuses.The   College, in   its  final   configuration,  ',
#  "to the   defendant's   profit obtained   from the  infringement.",
#  'of  Bristol   in 171011. He   invested in  ',
#  'had ridden for Noel   Murless  in   the  1950s and',
#  'of North  America   (1716).  Regarding  its  doctrine,   the  WPCUS:   rejects all   perceived',
#  'Darren   Hare   signed a  two-year deal   to become  manager   from 2016-17 with   Steven',
#  '#1   in Spain. Empty',
#  '1,300   people were  made   redundant   by the ',
#  'who  suffered   splinter injuries in Poonch  district succumbed  to  his   wounds   on ',
#  'Unit   Citation by  the   then  President Lyndon   B.   Johnson.   While  the men  of ',
#  'for  not spending   more  time  with ',
#  '& Lyle Engineering Ltd. For services   to   Export.  William George Speakman,  lately',
#  'of two gay  young  adult   novels:  Act   Well Your   Part (1986) and   Lucky in Love',
#  'which   also  starred Mollie   Sugden.  It was ',
#  'the province   to  form the   Metropolitan  Manila  Area   on ',
#  'Hopkins,  and when   Wilkins   retired  in 1960,   Migeon was  appointed  co-director',
#  'screen  credit as "supervised  by  Cecil B.   Demille",   though   students of his   films',
#  'foot.   In   1847,  after   a  plea by   Col.   William',
#  'Western film Mattie, which   was  released   on  DVD   under  the title  Renegade.  In  ',
#  'lvarez   de  Toledo   Osorio  (March  1553 10   July 1576),   more  often   known as "Leonora"',
#  'of  a  light electric shock to   the soles  of  his   feet,  while  a  correct response',
#  "as  a  short   story  in August 1983's ",
#  '"Love Knows  Everything"   and   "Take You Into  ',
#  'sent to investigate.   The Travis  Walton abduction case',
#  'is axiomatic.   It  is   equally  well  established that  an   award ',
#  'Junction Railway,  linking   Salisbury  with the   line to Poole  and   Bournemouth,  ',
#  'oligodeoxyribonucleotides  that are   attached   to a   carrier',
#  'Memory.Over   the   course  of   the next  few  years,  the  band built up  a   small',
#  '21,   2018) was an   American  activist in the  civil  ',
#  'the musician  spent   two  months  working  between ',
#  'of  action  in  contract   for breach  of  contract  in   that he   failed  in 1989  ',
#  'under   attack,   losing four ships  to   U-34. In October  SC   6   had three  ships  ',
#  'of  JRF  and   JRHT  from January   2007 to ',
#  'La  Vierge  (2,641   m).  Rochers  de Gagnerie  on Hikr  80,000  Suspects  is  a  1963 ',
#  'and   2,274   metres  in   altitude,   and is  covered   largely   by',
#  'bit error  rate   (BER), unstable  channel characteristics,  and  user   mobility." ',
#  'before  turning  back,   giving   Minx  time to   maneuver his submarine  over   to  the  ',
#  'started  directing,   mostly  associated  with   Producer',
#  'in this   country  should break away  from ',
#  'Band.   By   1971,   for   the  album  "Making Whoopee", the   band\'s   membership   consisted  ',
#  'senior   executives   claim  that  they   can  get  UK  prime  ',
#  'since the  Vietnam   War. 22  February - Cricketer   Shane   Warne   is   suspended  ',
#  'these towns  are located  in   the  western  part  of the  Central Highlands  usually ',
#  'the   attractive valley   of   Karlstal   through   which   the   Moosalb  stream   flows.',
#  'retained   ownership   of   the estate  until   the end   of   the   19th   century. By ',
#  'casualties  were reported on  the   Indian   side.  On   13 February   2017,   Pakistan ',
#  'Trailblazer  in Space   Newsreel/Documentary   about   Ham ',
#  "Education Association's Department of  Superintendence   in Cleveland, Ohio  (First official",
#  'to   ensure that stale  packets   are eventually   delivered. ',
#  'the destination   of  the  League  title   is no clearer, as five  points   separate  ',
#  'serving as its   first   president.  He ',
#  'Air.   He  also was   host of The ',
#  'Charity   Awards.  The presenter said "...it\'s hard   to  overstate',
#  'Rome   - a diachronic  topography Late   Night Alumni is an American  house group  composed  ',
#  'between   Ireland  and South  Africa.   Both   countries  have',
#  'architect of the  time  in  Ireland.   Among   buildings  in  Dublin that  he decorated  ',
#  'up   him  up  on   August  7.  He  was  traded   to   the  Arizona  Diamondbacks  as  ',
#  'wrote  much   on  biblical prophecy. He  ',
#  'town. The summer home  of',
#  'As heirs   to Coburg,   the   children  remained  with their  father.  Louise   died ',
#  'Bay  and   Kwun  Tong,  Hong Kong. MiNT Camera  has',
#  'Calfeisental. Hangsackgrat  on   Hikr Blackout:   Tomorrow   Will  ',
#  'Cup.  On  home soil, the   Russians   easily won  their   first Under-21  World  Cup,  ',
#  'He   began his education at   the nonconformist  academy of  Samuel  Cradock,   at   Geesings,  ',
#  'smock mill.   It   was   powered  by a   beam engine   and  drove two  pairs  of millstones.  ',
#  'on   apartheid  in  South  Africa,  SADC   embraced  the newly   democratic  South   Africa',
#  'was  $51,071. Males  had   a   median  income  ',
#  'attended Westside  high School   in  Anderson,  South Carolina, ',
#  '"Slashdot".   Cambia  Health  Solutions  (April   18,   2012) "Cambia Health  Solutions  ',
#  'to  the  community   in  Scotland.  Marjorie   Ethel  Ferris. For  services   to the  ',
#  'around  250300   meters   inside  the  Pakistani side  of   the   LoC, killing   at  least ',
#  'guitar with   an   open wah pedal.  The',
#  'a  New  Zealand  cricketer. He   played  in  seven first-class  ',
#  'the Whigs,   as   an  unexpected   late entrant.  He  was  duly  elected   to   serve  ',
#  'Basel   and  the   Swiss  led to   the  destruction   of   the castle  some   time between ',
#  'for illegally  buying   guns.  On   January 20,  2001,  the  day   he left office, President',
#  'name  GoldNation.  Gold  has written   songs for   #1   Billboard  dance  recording  artist  ',
#  "the  'Bono' Kingdom,  who  currently   resides in   la  Cte   d'Ivoire.  The  township  ",
#  'New   York   City  where   he began working with   Steve   Skinner   and Grammy Award-winning ',
#  "1902,   the   America's Cup   race   of  1903,   the  Great  Baltimore   Fire   of 1904,  ",
#  'hallmark of Venetian  Art. It  is  proposed that   this   painting could  be   an artistic  ',
#  'involvement   in  the  2002  Bali bombings.   10   September  -  Imam Samudra  is found ',
#  '23  March 2010.  As of  1  August 2011, female  contraception  was   added to  a list',
#  'Distillery   and   Winery,  stands  on   a  30-metre   sandstone   cliff near   Pump Hill.',
#  'was $30,823   and the median  income  ',
#  'dental laboratory  technician   and  members  of   the prosthodontic academic   community ',
#  'the  Bureau  of   Investigative   Journalism   started  a  crowdfunding   exercise  to  ',
#  'Area,   located   in   southern   Pennsylvania.   As   of   the',
#  'published material  regarding the so-called  "Fascist  UFO   Files",  which',
#  'file with unformatted text. This  process',
#  'of   Pasig and   Marikina were   grouped   into  a   single   parliamentary  ',
#  'option.   Laser  roughening   of  titanium surfaces for ',
#  'is  a   class  war  -  and there is   -   it   is   important  that   it should   be  ',
#  'points  systemPoints  are  awarded  to  the top 5   fastest qualifying times.   Race ',
#  'a third.   There are   fairly obvious   signs of',
#  'teams  played  much   fewer   games   during  a typical  ',
#  'Jones  (2618267).  Squadron   Leader   John   McRae (4231976).  Squadron  Leader ',
#  'its  cognitive   and   theoretical  implications.   As  a postdoctoral   researcher with  ',
#  'by   the  Church  of   Scotland (164548)   and the  colonies',
#  'felt   he would   be   less  of',
#  'a  painting by   Palma  Vecchio,   another ',
#  'outside   the  porta Esquilina   and the   Servian ',
#  'diameter of around  13  mm (0.51 in)   and   contain 40   to  50 densely packed   pale',
#  'October  a   suicide   bomber   drove   a car into  an EU (Italian)  military convoy ',
#  "Dizzy's  [Disraeli's]   favourite   maxim that  'race ",
#  'endangered South  African species of  ',
#  'who  controlled and mobilized  American cities. ',
#  'started   unprovoked   mortar shelling  at   forward ',
#  'that  is   a consequence   of a   sui generis  society.  The  self   arises when   the  ',
#  'the  Cleveland   Browns,   Mike   McCormack.  Additional  notable ',
#  'of   Commons of  Canada since   2004.   The Member',
#  'act. Here   the   gestures are  significant  symbols.  A   significant  symbol   is  ',
#  "painting.The  painting   itself   fits  closer   to  Titian's   artistic style   because  ",
#  'despite   sporadic  violations, leading   to cautious   optimism  among  Indian',
#  'is not   generally  considered  credible  in mainstream  science.   There was,   in  ',
#  'created  by Mr. Lawrence)   Grandma   Got   Run Over   by',
#  'Hamburg.   Albert  ',
#  'seven   people. On 29  September   Somali',
#  'specialize   to  particular  niches   within  the   sponsorship-marketing   field.  A',
#  'time), after   that   he  continued creating,   but  ',
#  "Ham's   name is   an  acronym   for   the   laboratory  that prepared   him  for his historic ",
#  'renewable   energy,   which   planning   authorities  should   have   regard  to when',
#  "plan to   use  Max's   brain  to  recollect the ",
#  'are often   twins  and  decreases the  cost',
#  'the movement. On   25 June,   the   Beatles   performed   the song  on the   Our World  ',
#  'Bob Kerr, John "The Professor"   Percival,  Malcolm  Sked, Bert Lamb   and Henri   Harrison. ',
#  'transportation  infrastructure  (interstates,  railroads,  intermodal ports,  airports,',
#  'city  near   DjiboutiAmbouli International  Airport,  it   serves   as  the terminus for  ',
#  'sports  complex, funded  by   the   selling',
#  'pattern  used by engines   such as Unity.   A-Frame   was originally   developed  within ',
#  '2016),  better  known  by  his   ring name',
#  '1950s. Gallup Polls  rank   UFOs  near the  top   of lists',
#  'National   Championships   Under 18   National  Championships  Under',
#  'the   elementary school; total   is  190 students.   Deaf students from   Canada often',
#  'Finnish surname.   Notable  people  with   the surname  include:   Aino   Lohikoski  (18981981),  ',
#  'theater  after him  in  1771-1787,   while  touring East',
#  'won   the  coin   toss   and  chose  to   begin   the  match  defending   the   Harleyford',
#  'a   turbulent  period   of  history  in ',
#  '-  3:48 "Take  You   into  My  Home" -  3:11Side   Two"Gospel Truth"  -   5:03 "Rain" ',
#  '120)  Winnebago   Correctional Center   (capacity 250) Wisconsin Department of ',
#  'a full  assistant who  helped her   commit  the  murders and  threatens to  reveal   the',
#  'both a painter   and a   sculptor,  as  ',
#  'Valley,  near  Triangle   Swamp, and   flows generally   north,   west, and  north-west,',
#  'to   provide  peacekeeping  forces  for   the   latest phase  of the',
#  'Khuiratta,  Kotli and  Battal   in Rawalakot.On  4   February,   four   Indian  Army  ',
#  'perimeter   fence  north and rear   of the house  and over the trellis   fence   including ',
#  'heard   yelling   the  phrase  "don\'t ',
#  'Blast, Schuldiner   agreed   to   make   one  last  Death album  before moving   forward  ',
#  "with  his   radical  pragmatism.   Disproving   Tolstoy's  dictum  that  'happy   families  ",
#  'Forest  formations  of   Holdridge.  B.   guifarroi has been found  in  rainforest  and  ',
#  'who  would  otherwise be   officiating at  the ',
#  'University intellectuals under   the influence of  Maurice   Cowling,   an historian. ',
#  'sales,  book   value, dividends,  earnings,  or  employees. If  a  stocks  price  gets  ',
#  'the Bhopal   district   of  Madhya  Pradesh,  India.  It  is located   in   the Berasia  ',
#  'before the  House.  But,',
#  'Twelve 22-foot (6.7  m)  tall  fluted  Doric marble  ',
#  'of the   area   goes  back  to first   settlement  where  the area   was  part of  Kangaroo  ',
#  'State School of  Forestry   from   1960 to 1980. In ',
#  'to  have  a   European power   as  ',
#  'in which   many   animals  exhibited  extremely strange  behaviors   and  high mortality',
#  'founded in  Patagonia  in   1991.Spectrum   wrote  that   the   beginning   of   the ',
#  'historian (19071990)   Merc   Mor  - dancer. Jaume  Morera  -   Artist   (18541927)  Joan  ',
#  'to  build   up a charge, a   glow was visible   if   he   placed   his   hand   on the  ',
#  'Y.   Masasa, who had been captured   in September   2015   when the AMISOM base  at  Janaale  ',
#  'semi-professional   football   club based   in  Hastings,   East   Sussex.   They ',
#  'Bologna.   He   was   Vice-Chancellor   of the',
#  'county of   Nottingham   at cricket   and played youth football  until  the age   of  ',
#  'school  in Hosadurga   in   Chitradurga   district. ',
#  'Hall   of   Fame   in Alamogordo, New Mexico. Colonel  John  Stapp gave the   eulogy at ',
#  'early  in January 1831   as a  free  settler   widow,   she   took up residence in  Concord  ',
#  'fiduciary  by  requiring   him   to   account   for  any   profits   he   derives  from ',
#  "or  anger.   It's  important  to   be   patient",
#  'of  water that also  shows   up in Propertius\'s  work.  The   concept  of a   "mystical ',
#  "Brave (1984) biography No  Mean   Destiny :  The Story   of  the   War   Widows'  Guild  ",
#  'The   Dangerous   American   (Random   House, 1958)  Papa Hemingway  (Random ',
#  'that   even   before   the federal   mandate  was  ',
#  'on   9 March 1934  by  John  Brown ',
#  'John   Alexander McConnell,   Chief   Superintendent, Royal Ulster  Constabulary. Evelyn',
#  'Bluth   Films,   Inc. Themes from  Aladdin and His Wonderful  Lamp  is an   extended  ',
#  'Wall  and   north   of  the   via Tiburtina vetus. Probably  the   horti extended   north',
#  'Classic   American Love   Songs  compilation) "Mary,   Did   You   Know"[14] (from  Merry',
#  'to   My   Love   (Palo   Alto,  1982) For   Every  Heart  (TBA  & Tapes,  1984)   Ballerina  ',
#  'the  Battle  of New  Orleans and   how he  had   to  choose  between fighting   for  America ',
#  'an  occasional  bowler   in  a   few matches in  the early   1860s,  and then   returned ',
#  'States military   involvement in  Lebanon   and   Grenada.  ',
#  'guidance of   schools by   the   states.   He   inaugurated  surveys   of  educational',
#  'discouraged  motion   picture   and   television  filming on   location ',
#  'from  World   War   I   veterans  in the  American Legion. Alabama   took   a  unique  ',
#  "in 1961. Hotchner's   biography   of  Hemingway, Papa Hemingway ",
#  '4), and  Jon "Jonny   Fairplay"   Dalton.  Corkscrewed,   follows  American',
#  'Housley, Royal Army  Medical Corps.   22794307   Staff  Sergeant   (Local  ',
#  'Kingdom   to be converted to   natural   gas, which   was  supplied   from  the North',
#  'nations,  along with   isolated reports   from  France, Portugal, Italy ',
#  'all-electric  vehicles and  plug-in  hybrids,  and 5,000   for ',
#  'studies   include GEPAN/SEPRA/GEIPAN (1977), within  CNES  (French  ',
#  'Finals   and the   Southern  Amateurs.   SoccerData. ISBN 1-899468-78-1.Specific  FA Cup',
#  'in   the  world,   outdoing the Guinness  ',
#  'used  to  destroy  the Stupa. The  bulldozer   had   been brought  to the  Hindu shrine  ',
#  'Love"  and "I  Believe in  You"  ',
#  'the   largest   canvases   in the  ',
#  "the  Mississippi.  France's   colonial presence  north   of  the   Caribbean  was reduced",
# ...
#  'primary  author  of   nine of   the thirteen',
#  'by the   Lake   (2001)  (TV) ....  Alison Gaddis New   Port  South (2001)   ....   Kameron  ',
#  '2010. ISBN  0786462329 Alice Hyatt  at  the   Internet   Movie   Database  Chad  Zdenek',
#  '8   Boorowa   Street, Young.   On 24 November   1978 an Interim Heritage  Order   was',
#  'government. Hizb  ut-Tahrir,   which   won   a  single   seat,  was   later  banned. Suleiman  ',
#  'motion, and   declined  to  renominate  for   the party  leadership.  White   was  elected',
#  'as the  National  Grid   Code  in   UK. For wind turbines,   the FRT  testing is   described',
#  'daughter  Lucrezia, from whom she  became   inseparable,  when   Lucrezia  was   apart',
#  'cruise   service   to   and from   Miami,  Tampa, Jacksonville,  Fort Myers,   Port Everglades, ',
#  'circles   in France.He  died   at Dublin ',
#  'and the  street   in   South  Central   Los   Angeles where  they  began  their   rehearsals.',
#  'and  orchestra  from   the   Guildhall   School  of',
#  'estate was sequestrated. The Parramatta  properties were not   released   for  another  ',
#  'Maxwell  Clark,  MVO, QPM,  CPM, Commissioner  of  Police,   Bermuda.  John   Gavin Alexander',
#  'Denis (acting)  20142015   Richard   Fujarczuk  -  May  2013  -  February   2014 Richard ',
#  'from a   nasty sea  beast.  Jason and',
#  "Using  Ginsberg's   methods,  the protest   received   positive  attention and the ",
#  'the  Uganda   Cup.  In   June   2018  Wadada  signed a  contract   with  Tanzanian   club  ',
#  'Airport  with   Johannesburg and Dar-es-Salaam. In  June 2000, the   Fokker   F28 was ',
#  'for   local   governments   to  become   home   rule   units.Daley   was ',
#  'diving or  just  spending   some   outdoor   time  at   the beach.   There  also is a',
#  'treated   as supernatural   portents,   angels,   or other',
#  'retiring in  1923.  He  played   one  season   for  the Quebec  Bulldogs  (191920)  and  ',
#  'river.It  is   Martyrs   Memorial   which   is  dedicated',
#  'in  1893  to "ChamblyVerchres".   In   1933,   it   was  amalgamated into   the ChamblyRouville  ',
#  'much quoted words  of Baron   Parke,  the rule of   the   common  law   is that where  ',
#  'carrier   of  Eswatini. Swaziland Airlink   started   operations  in   July 1999 with ',
#  'Love"  served  as an   anthem  for  ',
#  'the  score of  the  match   as  20.   In',
#  'Technician George   Arthur Young. F0594139 Sergeant  Geoffrey  Ralph Bunce.  F4250930',
#  'years.   Its  purpose  was   to   "raise awareness  and understanding"   about  multiculturalism.  ',
#  'tabloid talk   shows  such  as  Sally   Jessy   Raphael ',
#  'and  "pop-culture  phenomenon".   Fox worked   on   the entire   game  independently, ',
#  "part of the U.S. space  program's   Project  Mercury.  ",
#  'Islam:',
#  'with  a 0.7   liter, two-cylinder  5 hp   engine. G.N. Georgano (1968). The   Complete ',
#  'Florence   (1975).  Hopley   Yeaton\'s U.S. Revenue  Cutter  Scammel, 1791-1798.   "The ',
#  '31,   1961,   Ham flew  a suborbital  flight  on   the Mercury-Redstone  2  mission,  ',
#  'Ken  McIntyre  who  totaled 101 points in   his',
#  'sheriff   on   the   emoluments attachment',
#  'The  discovery of   this   previously  unknown   form  of  ',
#  'in   buildings.   List   of  fossiliferous  stratigraphic units  in ',
#  'and the  Draycot   Estate  in Wiltshire,  ',
#  'often   contrasted   to  capitalization-weighted  indices.  Fundamentally  based  indices  ',
#  'they   should have   annulled',
#  'of Council  Executives.   In   the  aftermath of ',
#  'of   six churches  in   Wiltshire  and Hampshire.   There  were  Baptists in  Downton',
#  'have  a   base that is  reddish,   puberulent,   with',
#  'Empire  and   the Creation of the Modern  Middle  East.   Avon  Books.   ISBN  978-0-380-71300-4.  ',
#  'Works,',
#  '(including   7   Ugandans) and 13+  injured  during the Bakaara   market   offensive ',
#  'pastoral  landscape  in   the Italian   countryside. It is  not   explicitly stated  or',
#  'Lomax   as   Eliza and Louis  Morales,  his children,   and   Viviana   Chavez  as   Miranda ',
#  'incidental   music   to  plays  by Shakespeare,  and   for popular   plays  by  ',
#  'standard to listen  to,   over  2000   in total.  ',
#  'earliest   government  studies to come   to   a   secret extraterrestrial conclusion.',
#  'of Chancery  at  its   discretion,  in all  cases ',
#  'attachment  orders are signed   by the judgment  creditor, or',
#  'Crown  instead. The   Crown   has ',
#  'band  Forest  City  Lovers   from 2006-2012,  releasing  three   full-length  albums and  ',
#  'players squad numbers, playing positions,   nationalities   and  statistics  are   based',
#  'latter  two,   the   "Upper Well"   and',
#  'and  Repetto started  their   murisc career  at   the ',
#  'in the   actual causes   of the  observed  phenomena   to   which   the  theory is   fitted. ',
#  'religion Ufology  Unidentified  submerged  object   or  USO "Government  Reports on  UFOs"  ',
#  "the   United  Nations  Security  Council extended   the  African Union's  authorisation ",
#  'inventors,   no  family   or business  connection has been found   between them. Charles',
#  'record   deal with  Sub Pop   in   1998.   Their first album, Whatcha   Doin featured ',
#  'make his  MMA  debut against   Oumar',
#  'a  pilot reported  six   "flying   manhole  covers"   between Wichita,  Kansas,  and ',
#  'the   painting   to   a   semblance  of  the   original.  ',
#  'Young; all   songs   except  "Star   of Bethlehem" and   "Will to  Love"  Comes   a Time ',
#  'The ',
#  'Aircraft   Projects Department,   Airworthiness  Division,  Civil Aviation Authority.',
#  'a  good product   choice  to   soften and moisturize  cleansed skin.   The  dogs seem',
#  'destroyed.  1  August At  least two AMISOM soldiers  ',
#  'feel  are  also   part of the  UFO phenomenon.   Biological  effects',
#  'part   of  its relationships  with  its family  members   and  is  a   major  part of ',
#  'Anderson (468934),  Royal   Regiment of Artillery. Major   John  Michael  Beckingsale, ',
#  'for our   future   generations.  Dimethylmercury  Ethylmercury  Methylmercury Mercury ',
#  'The Leibniz Review  is  a  peer-reviewed   academic  journal devoted  to   scholarly examination ',
#  'as  F.R.O.71989  How   to  Get  Ahead in Advertising1987 Withnail  and I  2014 Jonathan  ',
#  'the Atlantic   Ocean off  Senegal   and  Gabon.   Bernard,   P.A. (Ed.)   (1984). Coquillages ',
#  'State. This  gave  him the   opportunity to  attract the   attention   of Catherine  ',
#  'in Laurel. The   city  has   no   public transit  ',
#  'This prompted Lomax   to   arrange for   Iron Head to   be   paroled   so  that he   could  ',
#  'and  the  second  largest  in   South   America.',
#  'Ghost  rather  than relying  on a complex hierarchy.  Churches   in the tradition   of',
#  'Obtaining  the ROM   data  by  oneself  directly  from the  hardware   being emulated ',
#  '"serious   misconduct" but   believed  she  had  not acted corruptly.In  2016, Scaffidi',
#  'Senior Campus, a  co-educational  senior   secondary  school,   from',
#  'Bambury,   MVO,   First  Secretary   (Administration)  British   High   Commission,  New ',
#  'society  is   based   on ritual cannibalism, a   friendly   chat',
#  'USC Trojans   to the  wire  in a   memorable  game in Los Angeles. The  season fell  ',
#  'dark in the black.:264The legs ',
#  'of Orsini  for  political   reasons, to   strengthen   his position  on  the borders of ',
#  'Metropolitan  District  Council.   John Alexander Cowe, Professional and   Technology',
#  'allowing   him   to rent jet skis   along the Willamette  River to earn   an  income.  ',
#  'to   marry Matilda  McKay, daughter  of   Captain ',
#  'Raiffeisenverband  Zentralverband  deutscher  Konsumgenossenschaften  e.V Venus Flytrap ',
#  'securely   within the  Sumerian cultural   milieu.   The tutelary',
#  'retired   Air  Force   and  FAA  personnel,  intelligence   officers  and  ',
#  'France Asie   and Asia,   to  Tokyo. Hindu   World   is  ',
#  'Finn  Bjarnson  stumbled   upon   Becky   Jean  Williams   (sister  to R. John  Williams, ',
#  'Hudson,   Craftsman I,  Royal  Signals and  Radar   Establishment, Christchurch,   Ministry ',
#  'by William Witney and   starring   Roy Rogers.   Filmed in   the  San Bernardino Mountains',
#  'won  32   on   aggregate.   The final   was   played   on 14 May 2015  at in Berlin, ',
#  'Prosthodontics  certifies   individuals   who  have   demonstrated  special   knowledge',
#  'Louise  Claiborne,  was only   two  years   old at  the time  ',
#  'The   median   income for   a  ',
#  'in the  animation industry.   The eleven  animators  who  left represented',
#  '(born September 23,   1986)  is an   American  former  actress.  She  is  known   for ',
#  'the  sweet  spot   in a  wine. Which   is   the point at   which   "wine"  has  achieved',
#  'Sports   Council and   earned   his  Level',
#  '(Milwaukee) Member-at-Large  MASL   official website  World  Minifootball Federation Mackie ',
#  'prototype proved inadequate  to   the  task  and was later found   by   the   police,',
#  'guarantees  in the  event  of   a router   failure.  Reliability is also not needed  for  ',
#  'best   mayor  in  American history.  On  the   50th',
#  'in   Ngrd   County,   Hungary   with   464   inhabitants (2015).   Peter  James   Armitage  ',
#  'the  latter\'s  tour  "Une guitare,   un   piano et Renaud". He   composed   music  for  ',
#  'and ED  III  for  the  ancient   Near',
#  'James Ley  as   MP   for   Westbury  in   1621 when Ley was appointed to   a   post  ',
#  'the  end   of   1947,  one of   the ',
#  'when the  best available  evidence   indicates that   the ',
#  'the heart" instead  of the  head, and was characterized ',
#  'as Vendor   Ken Terrell  as Pirate Majel Barrett   as  Townswoman  #1   Ty Hardin  as  ',
#  'Ltd   v Harlow & Jones   GmbH  [1995]',
#  "which  later   evolved  into the current   NCAA  women's  ",
#  'January   2005.   Announced   in   January  2008, Nanula  joined   Colony Capital,   LLC,',
#  'parse(source,   publicID=None, format="xml") function.  The  first   argument   can be ',
#  'was   probably the  main reason   why   Gustav  Larson   asked',
#  'submarines   of   the  China, "either  the  Pakistan ',
#  'Devon in 1911  at  the  age  of',
#  'Papua New   Guinea.   The   Honourable   Kingsford   Dibela,  MP,  Speaker of   the National  ',
#  'known locally, were   a major supplier of   munitions   during  World War   II.  The ',
#  'regional   release in  October   1994.   Like',
#  'united  with   Standlynch  to form the  civil  parish   of   Standlynch with Charlton ',
#  'are only folklore  and   give ',
#  '(5)  1950,  1952,   1953,   1954,  1957Big  Eight Conference',
#  'Odontoglossum  ariasii   Dalstrm 2001  (Peru) Odontoglossum armatum   Rchb.f.   1876  ',
#  'die Anfnge   des Pietismus. Tbingen  2002.   Willi Temme:   Krise der   Leiblichkeit.',
#  'in  the finale   "Slaughterhouse", but  he returns  ',
#  'a   wandering   conspecific, a  courting',
#  'attributed   to a  fatal  overdose of  alcohol  and ',
#  'McParland, Sub-Officer,   Fire   Authority   Northern   Ireland.   Katherine Steele Macphte,',
#  'or no  sum, justice would   manifestly  not   have   been  done. He  assessed the damages  ',
#  'Lindl.  x   Odontoglossum  Kunth   x Trichocentrum  Poepp.   &   Endl.).   xMorrisonara',
#  'largely   due   to  work under  his  rule. He  is chiefly remembered   for   the economic,',
#  'than   5,000   km  (1,930  mi),   estimates  ',
#  'at   least in part,  by local  Democratic politicians.   Daley   made his mark   there, ',
#  'on   the  town   leading  down   the   Ryburn  and',
#  'Southern  Electricity  Board. William   Henry   Walton,   lately   Deputy  Director,  ',
#  'Capitol  1978  Left   for Dead, Capitol  1989   Gone  Dead Train: The   Best   of   Crazy ',
#  'a single lake,  it is   sometimes referred  to  as two  lakes, East   Jefferson   Lake',
#  "Holland-Dozier-Holland   (who  composed  the  group's first   five hit  singles)   and ",
#  'Collections.  Exam candidates   find  past papers   valuable in   test preparation. Some',
#  'place   on   campus   throughout  the year,  including   theater   productions,   gallery',
#  'of   Maecenas" in   modernity,   was   most  likely  a ',
#  '//web.archive.org/web/20091',
#  'war   of   19041905. A   series   of  military   officers   had  been assigned  to   the',
#  'bar   displays tools  to adjust   opacity, show',
#  'and was treated  by national politicians',
#  'and   a  tail of   172   to   229   mm  (6.8 to   9.0  in).  The   average  adult   body',
#  "Australia.  Hansard   18032005:  contributions in Parliament by Crawford Greene  Who's  ",
#  'performed on  it. The following  Notation 3  document:  ',
#  'watching   it carefully  went  back   and   rose  ',
#  '(1977)  M.A.   Tulane  University  (1986) The   Wealth  of  the   Poor,  Abilene, Texas:  ',
#  'season,   played in the   WISL in   the  201415 season and then rejoined   the MASL  ',
#  'Calcutta  Troop.   This later ',
#  'Ray Lyman Wilbur  was  Secretary of   the Interior  during   the  Hoover  administration.',
#  'on   the  chart. It   reached   number ',
#  'perpetrators,   at the same time  reassuring  that  elections  would   still   take place, ',
#  'plant manager  Mr. Fitzhugh,  Peter  Fronzcyk, brother of   Maddie  Fronzcyk  replaces',
#  'of Mantua,  a noble   Italian city-state, owned   the   work.',
#  'attention. By   1907   the zouave uniforms had   been replaced   by khaki   drill   for  ',
#  'started   writing   for  The Willimantic Daily',
#  'in the eponymous   village in  the   German   state  of   Rhineland-Palatinate.   The ',
#  'compound. On  23   July  Somali   forces reportedly   repulsed   an  ',
#  'in August,   noting  that the band   had  come up  with   the title  and   cover  art',
#  'from   The Aquarian Gospel of Jesus   the  Christ  by  Levi  H.   Dowling. Rosicrucian',
#  'Rathame,  which  was  eventually completed  by his',
#  'historians   placing  more  conventional  religious  interpretations on   such ',
#  '1945, but   escaped  back  to   Germany.   There,  he',
#  'those  on   the Maculay  Board Of  Trustees,  ',
#  'York Knicks),  the   team  moved  back ',
#  'Sylvia Creek Road.   Bogong High   Plains  High Plains  of  ',
#  'and  16.5%   had someone  living alone who was   65   years  of age  or  older. The  average ',
#  'material  from  the  Dorking  Greystone  Lime   Company  and   also  from   the   Groudle  ',
#  'Emery   Major,   of Cohuna.  For   services to the  community.  Graeme John Manifold, ',
#  'Mary  ',
#  'He  was   ordained  there   on  Easter   Sunday   of   1886  at   the   Archbasilica  ',
#  'with  the   approval of   the United Nations  Security  Council.',
#  'State University  people  Lohikoski   is a',
#  'North,   and  Pacific South regions. The Omaha Kings   FC,   Sunflower   State ',
#  'Chinese  hibiscus (Hibiscus  rosa-sinensis   cv.),  cumquat   (Fortunella sp.),  horned ',
#  '/planetgreen.discovery.c',
#  'of   Fir   trees on  a  red   and ',
#  'funneling   large   sums of   cash outside  of Colombia  with   the help  of  his  brother  ',
#  'Memoir  about  Loving (Harper   &   Row,  1975, ISBN 978-0-06-011965-2)   Doris   Day,  ',
#  'rivalry   between Kansas   and  Missouri  began with open ',
#  'official  true stereo   remixes.  True stereo   versions  of most',
#  'Donovan   to the   San   Diego Sockers, Jermaine   Jones   to   the  Ontario Fury,  and',
#  'Father, opposite  Al Pacino,   and her Broadway  debut   as the   understudy  for   the  ',
#  'a  commune in the   Tarn   department in southern France. Communes of   the  Tarn department  ',
#  'downwards. This  number  also makes  Hastings United  the best  supported   non   league',
#  'person  is  guilty of   an   offence  if   without   lawful   authority he discloses  ',
#  'Davie managed  the   Sears   stores in   Milwaukee  and  Minx  figured   that "...a  fellow',
#  'pathway,   shifting   his  abdomen  to the   other ',
#  'creating   a  move   towards  unorthodoxy.  John   Milbank,  speaking  from the   perspective',
#  ...]

# %% [markdown]
# # Split data #

# %%
train_split = int(0.9 * len(dataset))
val_split = int(train_split + 0.09 * len(dataset))
# test_split = int(train_split + 0.1 * len(dataset))

train_labels = dataset[:train_split]
val_labels = dataset[train_split:val_split]
test_labels = dataset[val_split:]

# val_labels = dataset[train_split:val_split]
# test_labels = dataset[val_split:]

print('Len train: ' + str(len(train_labels)))
print('Len val: ' + str(len(val_labels)))
print('Len test: ' + str(len(test_labels)))
# Out:
# Len train: 31313
# Len val: 3131
# Len test: 349

# %% [markdown]
# # Model #

# %%
timesteps = 512

width = 4096
height = 64

max_label_len = longest_label + 2
max_label_len
# Out:
# 117

# %%
from tensorflow.keras import applications, backend as K
from tensorflow.keras import models, losses, optimizers, Model, utils
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, MaxPooling2D, Dropout
from tensorflow.keras.layers import Flatten, Dense, Lambda, Reshape, Bidirectional, LSTM, GRU
from tensorflow.keras.layers import Activation, add, concatenate

def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

def build_model(num_classes=94, timesteps=timesteps, max_label_len=max_label_len, input_shape=(4096, 64, 1), training=False):
    inputs = Input(name='the_inputs', shape=input_shape, dtype='float32')
    
    # Convolution layer (VGG)
    inner = Conv2D(32, (3, 3), padding='same', name='conv1-1', kernel_initializer='he_normal')(inputs)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(32, (3, 3), padding='same', name='conv1-2', kernel_initializer='he_normal')(inputs)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(2, 2), name='max1')(inner)

    inner = Conv2D(64, (3, 3), padding='same', name='conv2-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(64, (3, 3), padding='same', name='conv2-2', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(2, 2), name='max2')(inner)

    inner = Conv2D(128, (3, 3), padding='same', name='conv3-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(128, (3, 3), padding='same', name='conv3-2', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(2, 2), name='max3')(inner)

    inner = Conv2D(256, (3, 3), padding='same', name='conv4-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(256, (3, 3), padding='same', name='conv4-2')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(1, 2), name='max4')(inner)

#     inner = Conv2D(512, (2, 2), padding='same', kernel_initializer='he_normal', name='con5-1')(inner)
#     inner = BatchNormalization()(inner)
#     inner = Activation('relu')(inner)
#     inner = Conv2D(512, (2, 2), padding='same', kernel_initializer='he_normal', name='con5-2')(inner)
#     inner = BatchNormalization()(inner)
#     inner = Activation('relu')(inner)

    # CNN to RNN
    inner = Reshape(target_shape=((timesteps, 1024)), name='reshape')(inner)
    inner = Dense(64, activation='relu', kernel_initializer='he_normal', name='dense1')(inner)
    inner = Dropout(0.2)(inner)

    # RNN
    lstm1 = Bidirectional(LSTM(256, return_sequences=True, kernel_initializer='he_normal', 
                               name='lstm1'))(inner)
    lstm2 = Bidirectional(LSTM(512, return_sequences=True, kernel_initializer='he_normal', 
                               name='lstm2'))(lstm1)
    rnn = Dropout(0.2)(lstm2)
    
    # RNN output -> character activations:
    outer = Dense(num_classes + 1, kernel_initializer='he_normal', name='dense2')(rnn)
    y_pred = Activation('softmax', name='softmax')(outer)

    labels = Input(name='the_labels', shape=[max_label_len], dtype='float32')
    input_length = Input(name='input_length', shape=[1], dtype='int64')
    label_length = Input(name='label_length', shape=[1], dtype='int64')

    # Keras doesn't currently support loss funcs with extra parameters
    # so CTC loss is implemented in a lambda layer
    loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([y_pred, labels, input_length, label_length]) #(None, 1)
    
    y_func = K.function([inputs], [y_pred])
    if training:
        return Model(inputs=[inputs, labels, input_length, label_length], outputs=loss_out), y_func
    else:
        return Model(inputs=[inputs], outputs=y_pred)

# %%
model, y_func = build_model(timesteps=timesteps, max_label_len=max_label_len, training=True)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_inputs (InputLayer)         [(None, 4096, 64, 1) 0
# __________________________________________________________________________________________________
# conv1-2 (Conv2D)                (None, 4096, 64, 32) 320         the_inputs[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 4096, 64, 32) 128         conv1-2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 4096, 64, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max1 (MaxPooling2D)             (None, 2048, 32, 32) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2-1 (Conv2D)                (None, 2048, 32, 64) 18496       max1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 2048, 32, 64) 256         conv2-1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 2048, 32, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2-2 (Conv2D)                (None, 2048, 32, 64) 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 2048, 32, 64) 256         conv2-2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 2048, 32, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max2 (MaxPooling2D)             (None, 1024, 16, 64) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv3-1 (Conv2D)                (None, 1024, 16, 128 73856       max2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1024, 16, 128 512         conv3-1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1024, 16, 128 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv3-2 (Conv2D)                (None, 1024, 16, 128 147584      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 1024, 16, 128 512         conv3-2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1024, 16, 128 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max3 (MaxPooling2D)             (None, 512, 8, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv4-1 (Conv2D)                (None, 512, 8, 256)  295168      max3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 512, 8, 256)  1024        conv4-1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 512, 8, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv4-2 (Conv2D)                (None, 512, 8, 256)  590080      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 512, 8, 256)  1024        conv4-2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 512, 8, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max4 (MaxPooling2D)             (None, 512, 4, 256)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 512, 1024)    0           max4[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 512, 64)      65600       reshape[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512, 64)      0           dense1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 512, 512)     657408      dropout[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 512, 1024)    4198400     bidirectional[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512, 1024)    0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 512, 95)      97375       dropout_1[0][0]
# __________________________________________________________________________________________________
# softmax (Activation)            (None, 512, 95)      0           dense2[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         [(None, 117)]        0
# __________________________________________________________________________________________________
# input_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# label_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           softmax[0][0]
#                                                                  the_labels[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 6,184,927
# Trainable params: 6,183,071
# Non-trainable params: 1,856
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

plot_model(model=model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %% [markdown]
# # Data generator #

# %%
import itertools

def return_classes(string):
    text = [' '] + list(string) + [' ']
    classes = [data.index(x) if x in data else 1 for x in text]
    return np.asarray(classes)

def return_text(classes):
    text = ''
    for c in classes:
        if 0 <= c < len(data) and c != 1:
            text += data[c]
    return text

def decode_batch(out, callback=False):
    ret = []
    for i in range(out.shape[0]):
        out_best = list(np.argmax(out[i, 2:], 1))
        out_best2 = [k for k, g in itertools.groupby(out_best)]
        outstr = return_text(out_best2)
        if callback:
            print(f'{out_best} -> {outstr}')
        ret.append(outstr)
    return ret

def gen_text_image(text, padding=16):
    font = random.choice(fonts)
    font_size = random.randrange(30, 61)
    fnt = ImageFont.truetype(font, font_size)
    width, _ = fnt.getsize(text)
    img = Image.new('L', (width + (padding + 1) * 2, 64), color=255)
    d = ImageDraw.Draw(img)

    if 'calibri' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'verdana' in font:
        d.text((padding + 2,-8), text, font=fnt, fill=0)
    elif 'constan' in font:
        d.text((padding + 2,0), text, font=fnt, fill=0)
    elif 'corbel' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'consola' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'cour' in font:
        d.text((padding + 2,-4), text, font=fnt, fill=0)
    elif 'tahoma' in font:
        d.text((padding + 2,-8), text, font=fnt, fill=0)
    else:
        d.text((padding + 2,-6), text, font=fnt, fill=0)
        
    image = np.array(img)
    image = add_salt_and_pepper(image, 0.2)
    image = otsu_thresholding(image)
    image = inverse(image)
    image = (image / 255.) * 2. - 1.
    return image

def inverse(image):
    return cv2.bitwise_not(image)

def add_salt_and_pepper(image, amount):
    output = np.copy(np.array(image))
    # add salt
    nb_salt = np.ceil(amount * output.size * 0.5)
    coords = [np.random.randint(0, i - 1, int(nb_salt)) for i in output.shape]
    output[coords] = random.randint(50,200)

    # add pepper
    nb_pepper = np.ceil(amount * output.size * 0.5)
    coords = [np.random.randint(0, i - 1, int(nb_pepper)) for i in output.shape]
    output[coords] = random.randint(0,100)
    return np.asarray(Image.fromarray(output))

# %%
class TextImageGenerator:
    def __init__(self, labels, img_w=4096, img_h=64,
                 batch_size=16, timesteps=timesteps, training=True, max_text_len=max_label_len):
        self.dim = (img_w, img_h, 1)
        self.batch_size = batch_size
        self.max_text_len = max_text_len
        self.labels = labels
        self.n = len(self.labels)
        self.indexes = list(range(self.n))
        self.training = training
        self.cur_index = 0
        
    def next_sample(self):
        self.cur_index += 1
        if self.cur_index >= self.n:
            self.cur_index = 0
            random.shuffle(self.indexes)
        return self.labels[self.indexes[self.cur_index]]
            
    
    def next_batch(self):
        while True:
            X = np.zeros((self.batch_size, *self.dim))
            y = np.zeros((self.batch_size, self.max_text_len), dtype=int)
            input_length = np.full((self.batch_size, 1), timesteps, dtype=np.float32)
            label_length = np.zeros((self.batch_size, 1), dtype=np.float32)
            
            for i in range(self.batch_size):
                label = self.next_sample()
                # Store sample
                image = np.swapaxes(gen_text_image(label), 0, 1)
                image = np.expand_dims(image, -1)
                X[i, 0:image.shape[0], :] = image

                # Store class
                label_classes = return_classes(label)
                y[i, :len(label_classes)] = label_classes
                label_length[i] = len(label_classes)

            inputs = {
                'the_inputs': X,  # (bs, 4096, 64, 1)
                'the_labels': y,  # (bs, longest_label + 2) - 2 spaces added: before and after
                'input_length': input_length,  # (bs, 1)
                'label_length': label_length  # (bs, 1)
            }
            outputs = {'ctc': np.zeros([self.batch_size])}   # (bs, 1)
            yield (inputs, outputs)

# %% [markdown]
# # Callbacks #

# %%
import editdistance
from datetime import datetime
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.callbacks import TensorBoard, ReduceLROnPlateau, Callback

class VizCallback(Callback):
    def __init__(self, y_func, text_img_gen, text_size, num_display_words=10):
        self.y_func = y_func
        self.text_img_gen = text_img_gen
        self.num_display_words = num_display_words
        self.text_size = text_size

    def show_edit_distance(self, num):
        num_left = num
        mean_norm_ed = 0.0
        mean_ed = 0.0
        while num_left > 0:
            word_batch = next(self.text_img_gen.next_batch())[0]
            num_proc = min(word_batch['the_inputs'].shape[0], num_left)
            # predict
            inputs = word_batch['the_inputs'][0:num_proc]
            pred = self.y_func([inputs])[0]
            decoded_res = decode_batch(pred)
            # label
            labels = word_batch['the_labels'][:num_proc].astype(np.int32)
            labels = [return_text(label) for label in labels]
            
            for j in range(num_proc):
                edit_dist = editdistance.eval(decoded_res[j], labels[j])
                mean_ed += float(edit_dist)
                mean_norm_ed += float(edit_dist) / len(labels[j])

            num_left -= num_proc
        mean_norm_ed = mean_norm_ed / num
        mean_ed = mean_ed / num
        print('\nOut of %d samples: \nMean edit distance:'
              '%.3f \nMean normalized edit distance: %0.3f \n'
              % (num, mean_ed, mean_norm_ed))

    def on_epoch_end(self, epoch, logs={}):
        batch = next(self.text_img_gen.next_batch())[0]
        inputs = batch['the_inputs'][:self.num_display_words]
        labels = batch['the_labels'][:self.num_display_words].astype(np.int32)
        labels = [return_text(label) for label in labels]
         
        pred = self.y_func([inputs])[0]
        pred_texts = decode_batch(pred)
        
        for i in range(min(self.num_display_words, len(inputs))):
            print("label: {} - predict: {}".format(labels[i], pred_texts[i]))

        self.show_edit_distance(self.text_size)

# %%
batch_size = 16
train_generator = TextImageGenerator(train_labels, training=True, batch_size=batch_size)
val_generator = TextImageGenerator(val_labels, training=False, batch_size=batch_size)
test_generator = TextImageGenerator(test_labels, training=False, batch_size=batch_size)

log_dir = "logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
output_dir = './models/VGG'
weight_path = f'{output_dir}/ocr_model_{datetime.now().strftime("%Y%m%d-%H%M%S")}' + '_epoch_{epoch:02d}.h5'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

tensorboard = TensorBoard(log_dir=log_dir)
checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
vis = VizCallback(y_func, test_generator, len(test_labels))
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='min')

initial_learning_rate = 0.001
epochs = 100

callbacks = [early_stop, tensorboard, vis, checkpoint]
# callbacks = [early_stop, tensorboard, vis, LearningRateScheduler(lr_time_based_decay, verbose=1)]

# %% [markdown]
# # Training #

# %%
def train(callbacks, batch_size, epochs, initial_epoch=0):
    print('Training process starting...')
    H = model.fit(train_generator.next_batch(),
                  steps_per_epoch=train_len//batch_size,
                  validation_data=val_generator.next_batch(),
                  validation_steps=val_len//batch_size,
                  epochs=epochs, 
                  initial_epoch=initial_epoch,
                  callbacks=callbacks,
                  verbose=1)
    return H

# %%
train_len = len(train_labels)
val_len = len(val_labels)

# %%
from tensorflow.keras import optimizers

opt = optimizers.Adam(learning_rate=initial_learning_rate)

# %%
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer='adam')

train(callbacks, batch_size, epochs)
# Out:
# Training process starting...
# Epoch 1/100
# C:\Users\lukas\AppData\Local\Temp/ipykernel_13444/3188806586.py:66: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   output[coords] = random.randint(50,200)
# C:\Users\lukas\AppData\Local\Temp/ipykernel_13444/3188806586.py:71: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   output[coords] = random.randint(0,100)
#    6/1957 [..............................] - ETA: 17:18 - loss: 821.5693WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2202s vs `on_train_batch_end` time: 0.2602s). Check your callbacks.
# 1957/1957 [==============================] - 998s 506ms/step - loss: 50.4929 - val_loss: 6.0185
# label:  initiative  in the   title race  to Derby                                                                            - predict:  initiative in the   the race  to Derby
# label:  service  to   sculpture  and  to the community.  Josephine  Holloway,   of  Kirribilli,                              - predict:  service  to   soculpture  and  to the community.  Josephine  Aolloway,   of  Kirribilli,
# label:  Rhapsody   (1998)   Kid Loco's  official   website was active  up  until 2012   Official                             - predict:  Rhapsody   (1998)   Kid Loco's  official   website was active  up  until 2012   Official
# label:  for  the first time,   not  six  feet                                                                                - predict:  fo   the frst Aime,   po  sx  feet
# label:  the most   deadliest  incidents  were:   22 February  2009 11   Burundian   soldiers                                 - predict:  the most   deadliest incidents  were:   2 February  2009 11   Burundian   soldiers
# label:  (at   Wood   Green  Job Centre)                                                                                      - predict:  (at   Wood   Green  Job Centre)
# label:  canton  of St.   Gallen.  It lies                                                                                    - predict:  canton  of St.   Gallen.  It lies
# label:  was born in   Tema,  Ghana  to  Ghanaian                                                                             - predict:  was born in   Pema,  Ghana  to  Ghanaian
# label:  and   two civilians   were   killed   in  ceasefire                                                                  - predict:  and   bwo cvilans   were   Mled   n  ceasefire
# label:  in   circles. Cleaning   up  the   existing   mercury                                                                - predict:  in   circles. Cleaning   up  the   existing   mercury
#
# Out of 349 samples:
# Mean edit distance:45.759
# Mean normalized edit distance: 0.391
#
#
# Epoch 00001: val_loss improved from inf to 6.01853, saving model to ./models/VGG\ocr_model_20210929-080211_epoch_01.h5
# Epoch 2/100
# 1957/1957 [==============================] - 986s 504ms/step - loss: 4.2424 - val_loss: 2.4726
# label:  synchronization".  Science. 272   (5259):   2714.  PMID   8602512. S2CID  10399718.                                  - predict:  synchronization".  Science. 272   (5259):   2714.  PMID   8602512. S2CID  10399718.
# label:  mandate   of the United Nations  Mission for  the  Referendum   in Western Sahara  (MINURSO)                         - predict: miandate   of the United Nations.  Mission (or  the  Reterendum   in Westert Sahara   (MINUESO)
# label:  resistant   role  of a   solid object,  an  individual   obtains  cognition                                          - predict:  resistant   role  of a   solid object,  an  individual   obtains  cognition
# label:  Locey took  over as  the  head   football   coach                                                                    - predict: Locey took  over as  the  head   football   coach
# label:  Head  was   irredeemable   and   ungrateful. On his  return  to Texas,   Iron   Head was                             - predict:  Head  was   iredeemable   and   ungrateful. On his  return  to Texas,   Iron   Head was
# label:  and   the  members  renegotiated  the arrangement in   2001. The   new  structure                                    - predict: and   the  members  renegotiated  the arrangement in   2001. The   new  structure
# label:  Corni high   school of Modena,   where his                                                                           - predict:  Corni high   school of Modena,   where his
# label:  House  of Orlans'   sole,  constitutional   king, Louis   Philippe: Jean-de-Dieu  Soult                              - predict:  House  of Orlans'   sole,  constitutional   king, Louis   Philippe: Jean-de-Dieu  Soult
# label:  he  was  nominated  on the  Liberal  ticket   for  the  New York  Court  of  Appeals;                                - predict: he  was  nominated  on the  Liberal  ticket   for  the  New York  Court  of  Appeals;
# label:  replaced   the reference with   "...  and   Bilandic's                                                               - predict: replaced   the reference with   "..  and   Bilandic's
#
# Out of 349 samples:
# Mean edit distance:45.057
# Mean normalized edit distance: 0.385
#
#
# Epoch 00002: val_loss improved from 6.01853 to 2.47259, saving model to ./models/VGG\ocr_model_20210929-080211_epoch_02.h5
# Epoch 3/100
# 1957/1957 [==============================] - 984s 503ms/step - loss: 2.8274 - val_loss: 1.5514
# label:  the   race   for   the First Division title   remains  remarkably  close,   with   five                              - predict: the   ace   for   the First Division tite   remains remarkably  clos,   with   fie
# label:  replaced   the reference with   "...  and   Bilandic's                                                               - predict: replaced   the reference with   "...  and   Bilandic's
# label:  variance,   by individual   calling. Research based on  audio  playback  tests   shows                               - predict: variance,   by individual   calling. Research based on  audio  playback  tests   shows
# label:  (North  Africa,   Southern   Europe),   the  Middle East, India,   and Pakistan. Dogs                                - predict:  (North  Africa,   Southern   Europe),   the  Middle East, India,   and Pakistan. Dogs
# label:  House  of Orlans'   sole,  constitutional   king, Louis   Philippe: Jean-de-Dieu  Soult                              - predict: House  of Orlans'   sole,  constitutional   king, Louis   Philippe: Jean-de-Dieu  Soult
# label:  into   adulthood   expressing his   sentiment about   the   world                                                    - predict: into   adulthood   expressing his   sentiment about   the   world
# label:  Views   of  the   National Parks National  Park  Service  Historic                                                   - predict: Views   of  the   Nationel Edrks Natlonal  Park  Sctvice  Historlc
# label:  his role  in   September   2017  and  was  taken                                                                     - predict:  his role  in   September   2017  and  was  taken
# label:  officially left   the U.S.  Army  on   May 31,  1936.  Hagood's decorations  include                                 - predict: officially left   the U.S.  Army  on   May 31,  196.  Hagood's decorations  include
# label:  to   govern for  the   nine weeks  until the  1983   election,  free                                                 - predict: to   govern for  the   nine weeks  until the  1983   election,  free
#
# Out of 349 samples:
# Mean edit distance:44.387
# Mean normalized edit distance: 0.379
#
#
# Epoch 00003: val_loss improved from 2.47259 to 1.55144, saving model to ./models/VGG\ocr_model_20210929-080211_epoch_03.h5
# Epoch 4/100
# 1957/1957 [==============================] - 984s 503ms/step - loss: 2.1796 - val_loss: 1.3691
# label:  ISBN 9780226690445. Remembering  Richard   J.   Daley - UIC Library  Mayor  Richard                                  - predict:  ISBN 9780226690445. Remembering  Richard   J.   Daley  UlC Library  Mayor  Richard
# label:  of  any game   supported by   Mame/Mess,  including past   versions. There                                           - predict:  of  any game   supported by   Mame/ Mess,  including past   versions. There
# label:  and   the  members  renegotiated  the arrangement in   2001. The   new  structure                                    - predict:  and   the  members  renegotiated  the arrangement in   2001. The   new  structure
# label:  his role  in   September   2017  and  was  taken                                                                     - predict:  his role  in   September   2017  and  was  taken
# label:  make a  statement   about another statement                                                                          - predict:  make a  statement   about another statement
# label:  contemporary articles  and reviews, as  well   as original Leibniz  texts. The Leibniz                               - predict:  contemporary articles  and reviews, as  well   as original Leibniz  texts. The Leibniz
# label:  Scientists,   of  which  Condon   was   a   member.  On the other   hand,   a  scientific                            - predict: Scientists,   of  which  Condon   was   a   member.  On the other   hand,   a  scientific
# label:  bomber  plane  armed with nuclear  bombs, so   the player   must destroy  him and  his                               - predict:  bomber  plane  armed with nuclear  bombs, so   the player   must destroy  him and  his
# label:  from his birthplace. They  had three  daughters and   four   sons,  in   that  order.                                - predict:  from his birthplace. They  had three  daughters and   four   sons,  in   that  order.
# label:  the South  Pacific  to photograph the  Transit of Venus.                                                             - predict:  the South   Pacific  to photograph the  Transit of Venus.
# Out of 349 samples:
# Mean edit distance:45.980
# Mean normalized edit distance: 0.393
#
#
# Epoch 00004: val_loss improved from 1.55144 to 1.36906, saving model to ./models/VGG\ocr_model_20210929-080211_epoch_04.h5
# Epoch 5/100
# 1957/1957 [==============================] - 984s 503ms/step - loss: 1.8844 - val_loss: 1.0718
# label:  bomber  plane  armed with nuclear  bombs, so   the player   must destroy  him and  his                               - predict:  bomber  plane  armed with nuclear  bombs, so   the player   must destroy  him and  his
# label:  number   of   celebrities.   The video created an Internet   buzz and  appeared  on                                  - predict: number   of   celebrities.   The video created an Internet   buzz and  appeared  on
# label:  and   two civilians   were   killed   in  ceasefire                                                                  - predict:  and   two civilians   were   killed   in  ceasefire
# label:  contemporary articles  and reviews, as  well   as original Leibniz  texts. The Leibniz                               - predict: contemporary articles  and reviews, as  well   as original Leibniz  texts. The Leibniz
# label:  box office,   grossing just   over   $11   million.The   studio's   next  feature   suffered                         - predict: box office,   grossing just   over   $11   million.The   studio's   next  feature   suffered
# label:  research  professor of astronomy and astrophysics  at   LAPAN   stated:  "We                                         - predict: research  professor of astronomy and astrophysics  at   LAPAN   stated:  "We
# label:  since Danny Whitten died."  After   a five-year  hiatus  Neil Young  and Crazy  Horse                                - predict:  since Danny Whitten died."  After   a five-year  hiatus  Neil Young  and Crazy  Horse
# label:  (1972)   -   Russian  Boxer   The  Spectre   of                                                                      - predict:  (1972)   -   Russian  Boxer   The  Spectre   of
# label:  made   from its  use   of   the   wire for commercial   purposes.  In  British   Motor                               - predict:  made   from its  use   of   the   wire for commercial   purposes.  In  British   Motor
# label:  Valley"  came to fruition after  a Gastr   del Sol  show  in  Atlanta,   where  Grubbs                               - predict:  Valley"  came to fruition after  a Gastr   del Sol  show  in  Atlanta,   where  Grubbs
#
# Out of 349 samples:
# Mean edit distance:43.630
# Mean normalized edit distance: 0.373
#
#
# Epoch 00005: val_loss improved from 1.36906 to 1.07178, saving model to ./models/VGG\ocr_model_20210929-080211_epoch_05.h5
# Epoch 6/100
# 1957/1957 [==============================] - 984s 503ms/step - loss: 1.5080 - val_loss: 1.0416
# label:  resistant   role  of a   solid object,  an  individual   obtains  cognition                                          - predict:  resistant   role  of a   solid object,  an  individual   obtains  cognition
# label:  Head  was   irredeemable   and   ungrateful. On his  return  to Texas,   Iron   Head was                             - predict:  Head  was   irredeemable   and   ungrateful. On his  return  to Texas,   Iron   Head was
# label:  case  the  Crown seeks to   go further.   The claim  is for  all the profits   of   Blake's                          - predict:  case  the  Crown seeks to   90 further.   The claim  is for  all the profits   of   Blake's
# label:  now   ras  an   Uachtarin,   official   residence   of  the President                                                - predict:  now   ras  an   Uachtarin,   official   residence   of  the President
# label:  the  Nintendo 64   in  1999.  A   fifth   sequel  provisionally   titled   Future Strike                             - predict:  the  Nintendo 64   in  1999.  A   fifth   sequel  provisionally   titled   Future Strike
# label:  near  the capital   of  Mongadishu. It is   stated  that   AMISOM was preparing  for an                              - predict: near  the capital   of  Mongadishu. It is   stated  that   AMISOM was preparing  for an
# label:  Behavioral  responses to   trills   were  greatest   when   the                                                      - predict:  Behavioral  responses to   trills   were  greatest   when   the
# label:  Edgar  Allan Poe (1974) - Joseph Zebra Force (1976)   - Peter  High   Rolling (1977) -                               - predict:  Edgar  Allan Poe (1974) - Joseph Zebra Force (1976)   - Peter  High   Rolling (1977) -
# label:  Park, almost   complete  at   the  time   of   the  Merlin deal, was given   a limited                               - predict:  Park, almost   complete  at   the  time   of   the  Merlin deal, was given   a limited
# label:  of New Rover   Cricket  Club,  in Adel,                                                                              - predict:  of New Rover   Cricket  Club,  in Adel.
#
# Out of 349 samples:
# Mean edit distance:45.183
# Mean normalized edit distance: 0.386
#
#
# Epoch 00006: val_loss improved from 1.07178 to 1.04158, saving model to ./models/VGG\ocr_model_20210929-080211_epoch_06.h5
# Epoch 7/100
# 1957/1957 [==============================] - 984s 503ms/step - loss: 1.3184 - val_loss: 0.7598
# label:  Mead  enrolled  at  the Oberlin Academy at  Oberlin   College   and then   the college                               - predict: Mead  enrolled  at  the Oberlin Academy at  Oberlin   College   and then   the college
# label:  box office,   grossing just   over   $11   million.The   studio's   next  feature   suffered                         - predict:  box office,   grossing just   over   $11   million.The   studio's   next  feature   suffered
# label:  capital and as  such  growth   capital   is provided                                                                 - predict:  capital and as  such  growth   capital   is provided
# label:  part of British  Steel although  the  works   continued  to                                                          - predict:  part of British  Steel although  the  works   continued  to
# label:  made   from its  use   of   the   wire for commercial   purposes.  In  British   Motor                               - predict:  made   from its  use   of   the   wire for commercial   purposes.  In  British   Motor
# label:  had  been   lost   or  at  least   obscured by the  time  KU's  bird mascot  was   invented                          - predict:  had  been   lost   or  at  least   obscured by the  time  KU's  bird mascot  was   invented
# label:  first mayor elected  to   a  four-year term.   Tyler   had been  instrumental  in drafting                           - predict: first mayor elected  to   a  four-vear term.   Tyler   had been  instrumental  in drafting
# label:  CMP  replaced),   this body numbered   about 700 men,                                                                - predict:  CMP  replaced),   this body numbered   about 700 men,
# label:  of New Rover   Cricket  Club,  in Adel,                                                                              - predict:  of New Rover   Cricket  Club,  in Adel,
# label:  and   two civilians   were   killed   in  ceasefire                                                                  - predict:  and   two civilians   were   killed   in  ceasefire
#
# Out of 349 samples:
# Mean edit distance:45.183
# Mean normalized edit distance: 0.386
#
#
# Epoch 00007: val_loss improved from 1.04158 to 0.75977, saving model to ./models/VGG\ocr_model_20210929-080211_epoch_07.h5
# Epoch 8/100
# 1957/1957 [==============================] - 984s 503ms/step - loss: 1.2790 - val_loss: 0.7888
# label:  having   fun and  seeing   chicks' asses                                                                             - predict:  having   fun and  seeing   chicks' asses
# label:  be associated  with such qualities.  The                                                                             - predict:  be associated  with such qualities.  The
# label:  from  the  social  process  of  communication  by  signs   founded   the   symbolic interactionist                   - predict:  from  the  social  process  of  communication  by  signs   founded   the   symbolic interactionist
# label:  box office,   grossing just   over   $11   million.The   studio's   next  feature   suffered                         - predict:  box office,   grossing just   over   $11   million.The   studio's   next  feature   suffered
# label:  (1992,  co-production   with   Turner  Entertainment Co.,   distributed by   Miramax                                 - predict: (1992,  co-production   with   Turner  Entertainment Co.,   distributed by   Miramax
# label:  Sleeps  (1979)   Weld  (1991)   Sleeps With   Angels (1994,  promo only)                                             - predict: Sleeps  (1979)   Weld  (1991)   Sleeps With   Angels (1994,  promo only)
# label:  field  of   employment. Mary Madelaine   Theodora   O'Sullivan, of                                                   - predict: field  of   employment. Mary Madelaine   Theodora   O'Sullivan, of
# label:  shelling   in   Rajouri sector.   Two   other Indian soldiers  were  also  reported injured                          - predict:  shelling   in   Rajouri sector.   Two   other Indian soldiers  were  also  reported injured
# label:  giving  them an  apparent   feeding priority.  This   priority   may  serve   to compensate                          - predict: giving  them an  apparent   feeding priority.  This   priority   may  serve   to compensate
# label:  One   of   his   most influential   ideas  was   the  emergence   of   mind   and   self                             - predict:  One   of   his   most influential   ideas  was   the  emergence   of   mind   and   self
# Out of 349 samples:
# Mean edit distance:44.158
# Mean normalized edit distance: 0.377
#
#
# Epoch 00008: val_loss did not improve from 0.75977
# Epoch 9/100
# 1957/1957 [==============================] - 983s 502ms/step - loss: 1.1651 - val_loss: 0.7299
# label:  more quickly when your kid  is  sitting   at  the kitchen  table   in   his  Incredible                              - predict:  more quickly when your kid  is  sitting   at  the kitchen  table   in   his  Incredible
# label:  be four  sectors:   Uganda responsible  for Sector  One   (the   Shabelles  and  Banadir),                           - predict:  be four  sectors:   Uganda responsible  for Sector  One   (the   Shabelles  and  Banadir),
# label:  are   not   recommended for  beginners.  They learn  fast,   and   they  are  very smart,                            - predict:  are   not   recommended for  beginners.  They learn  fast,   and   they  are  very smart,
# label:  in  a 33 comeback   draw;  this also made him                                                                        - predict: in  a 33 comeback   draw;  this also made him
# label:  (1992,  co-production   with   Turner  Entertainment Co.,   distributed by   Miramax                                 - predict:  (1992,  co-production   with   Turner  Entertainment Co.,   distributed by   Miramax
# label:  - RDFLib   defines  the following   kinds of  Graphs:                                                                - predict: - RDFLib   defines  the following   kinds of  Graphs:
# label:  was added.   On July 13,  1925,   SH 108  was extended  south   to San Antonio,  with                                - predict:  was added.   On July 13,  1925,   SB 108  was extended  south   to San Antonto.  with
# label:  Willows  (1987;  ink/paint, additional visual effects   and   animation)  The                                        - predict:  Willows  (1987;  ink/paint, additional visual effects   and   animation)  The
# label:  (214),  hits (277),   and   at bats   (767),  and   was                                                              - predict:  (214),  hits (277),   and   at bats   (767),  and   was
# label:  from   participating in   bubbles  and  crashes and   thus   reduces its  volatility                                 - predict:  from   participating in   bubbles  and  crashes and   thus   reduces its  volatility
#
# Out of 349 samples:
# Mean edit distance:45.120
# Mean normalized edit distance: 0.386
#
#
# Epoch 00009: val_loss improved from 0.75977 to 0.72987, saving model to ./models/VGG\ocr_model_20210929-080211_epoch_09.h5
# Epoch 10/100
# 1957/1957 [==============================] - 985s 504ms/step - loss: 1.0483 - val_loss: 1.4701
# label:  Locey took  over as  the  head   football   coach                                                                    - predict:  Locey took  over as  the  head   football   coach
# label:  when   she was   young,  leaving   her   to  live   with  her grandmother.  Her   grandmother                        - predict: when   she was   young,  leaving   her   to  live   with  her grandmother.  Her   grandmother
# label:  for   the  webcomic Homestuck,   as well   as   for                                                                  - predict: for   the  webcomic Homestuck,   as well   as   for
# label:  are   not   recommended for  beginners.  They learn  fast,   and   they  are  very smart,                            - predict: are   not   recommended for  beginners.  They learn  fast,   and   they  are  very smart,
# label:  the phenomenon  include  the   MUFON, a grassroots   organization whose  investigator's                              - predict:  the phenomenon  include  the   MUFON, a grassroots   organization whose  investigator's
# label:  the American   Civil War, Napoleon  III   positioned                                                                 - predict: the American   Civil War Napoleon  III   positioned
# label:  stars. All tracks  are  written   by                                                                                 - predict: stars. All tracks are  written   by
# label:  keep.   Without   optimum   water conditions, they  are   susceptible   to bacterial                                 - predict: keep.   Without   optimum   water conditions, they  are   susceptible   to bacterial
# label:  Slack.   Most   of   the  developers   are  also on Twitter.                                                         - predict:  Slack.   Most   of   the  developers   are  also on Twitter.
# label:  Sweden".   Title: Volvo Personvagnar frn   20-tal till   80-tal, by                                                  - predict:  Sweden".   Title: Volvo Personvagnar frn   20-tal till   80-tal, by
#
# Out of 349 samples:
# Mean edit distance:44.264
# Mean normalized edit distance: 0.378
#
#
# Epoch 00010: val_loss did not improve from 0.72987
# Epoch 11/100
# 1957/1957 [==============================] - 983s 503ms/step - loss: 0.9898 - val_loss: 0.6849
# label:  any race were 0.96%   of   the                                                                                       - predict: any race were 0.96%   of   the
# label:  Views   of  the   National Parks National  Park  Service  Historic                                                   - predict:  Views   of  the   National Parks National  Park  Service  Historic
# label:  Leon  Taylor (216503), Royal  Australian  Army   Dental  Corps.   Gunner (Temporary                                  - predict:  Leon  Taylor (216503), Royal  Australian  Army   Dental  Corps.   Gunner (Temporary
# label:  Crown  Court on  9  November 1979.  The   fourth,                                                                    - predict:  Crown  Court on  9  November 1979.  The   fourth,
# label:  to abandon, and  finally   resolved  to  make  a stand   back in   France,  centering                                - predict: to abandon, and  finally   resolved  to  make  a stand   back in   France,  centering
# label:  the American   Civil War, Napoleon  III   positioned                                                                 - predict:  the American   Civil War, Napoleon  III   positioned
# label:  reveals  to  her suspicion   about                                                                                   - predict:  reveals  to  her suspicion   about
# label:  that must have immediate  attention ...   Sightings   of   unexplained   objects   at                                - predict:  that must have immediate  attention ...   Sightings   of   unexplained   objects   at
# label:  position   at the Centre national de la   recherche scientifique  in 1951,   and completing                          - predict:  position   at the Centre national de la   recherche scientifique  in 1951,   and completing
# label:  contemporary articles  and reviews, as  well   as original Leibniz  texts. The Leibniz                               - predict:  contemporary articles  and reviews, as  well   as original Leibniz  texts. The Leibniz
#
# Out of 349 samples:
# Mean edit distance:45.203
# Mean normalized edit distance: 0.386
#
#
# Epoch 00011: val_loss improved from 0.72987 to 0.68489, saving model to ./models/VGG\ocr_model_20210929-080211_epoch_11.h5
# Epoch 12/100
# 1957/1957 [==============================] - 983s 502ms/step - loss: 0.9900 - val_loss: 0.7661
# label:  section  and   as the  scouts tracked the   footprints   of   the militiamen through                                 - predict: section  and   as the  scouts tracked the   footprints   of   the militiamen through
# label:  He   also collaborated with  writer  David  Levin  and wrote  six                                                    - predict: He   also collaborated with  writer  David  Levin  and wrote  six
# label:  as far as   we   can understand,  made   a  very strong   defence,  as was   seen by                                 - predict:  as far as   we   can understand,  made   a  very strong   defence,  as was   seen by
# label:  dedicated Donaldson  fan   should search  for this record;  even  if   it   doesn't  reach                           - predict: dedicated Donaldson  fan   should search  for this record;  even  if   it   doesn't  reach
# label:  femur foreleg was transplanted   to   a proximal   level   of  a   hindleg tibia. This                               - predict: femur foreleg was transplanted   to   a proximal   level   of  a   hindleg tibia. This
# label:  University, and an honorary doctorate  of management  degree  from   the Claremont Graduate                          - predict:  University, and an honorary doctorate  of management  degree  from   the Claremont Graduate
# label:  (1972)   -   Russian  Boxer   The  Spectre   of                                                                      - predict:  (1972)   -   Russian  Boxer   The  Spectre   of
# label:  OBE,  ED, of  Clayfield.  For services   to  the community.State                                                     - predict: OBE,  ED, of  Clayfield.  For services   to  the community.State
# label:  served  as a  personnel   director for  the  Chicago  Bears   from  1968-1975,   overseeing                          - predict: served  as a  personnel   director for  the  Chicago  Bears   from  1968-1975,   overseeing
# label:  is  scored   for   double  choir  SATB SATB,   and part  III  for   SATTB   choir   and                              - predict:  is  scored   for   double  choir  SATB SATB,   and part  III  for   SATTB   choir   and
# Out of 349 samples:
# Mean edit distance:44.926
# Mean normalized edit distance: 0.384
#
#
# Epoch 00012: val_loss did not improve from 0.68489
# Epoch 13/100
# 1957/1957 [==============================] - 983s 502ms/step - loss: 0.9274 - val_loss: 0.6590
# label:  the years   leading   up  to   the                                                                                   - predict:  the years   leading   up  to   the
# label:  focused   on computational  biology   models   of interactions                                                       - predict: focused   on computational  biology   models   of interactions
# label:  one of   the  government   troops.   On   21  September                                                              - predict:  one of   the  government   troops.   On   21  September
# label:  for  Clear   Rock  is summarised by Szwed:  [He]  "seemed  to  possess an endless body                               - predict:  for  Clear   Rock  is summarised by Szwed:  [He]  "seemed  to  possess an endless body
# label:  was added.   On July 13,  1925,   SH 108  was extended  south   to San Antonio,  with                                - predict:  was added.   On July 13,  1925,   SH 108  was extended  south   to San Antonio,  with
# label:  ON  CYXU   -   London International  Airport  in London, ON                                                          - predict:  ON  CYXU   -   London International  Airport  in London, ON
# label:  chronology   Mari   (ally)  Andarig (ally)   Chubb, Mary  (1999).  City  In   the   Sand                             - predict:  chronology   Mari   (ally)  Andarig (ally)   Chubb, Mary  (1999).  City  In   the   Sand
# label:  or  for  those   who have  a   friend  or                                                                            - predict: or  for  those   who have  a   friend  or
# label:  Simultaneously,  the  Doyle  group  and   a  group   at Pfizer                                                       - predict: Simultaneously,  the  Doyle  group  and   a  group   at Pfizer
# label:  are   three schools  in the  district:  Union  Local  Elementary School,  Union   Local                              - predict: are   three schools  in the  district:  Union  Local  Elementary School,  Union   Local
#
# Out of 349 samples:
# Mean edit distance:44.811
# Mean normalized edit distance: 0.383
#
#
# Epoch 00013: val_loss improved from 0.68489 to 0.65905, saving model to ./models/VGG\ocr_model_20210929-080211_epoch_13.h5
# Epoch 14/100
# 1957/1957 [==============================] - 984s 503ms/step - loss: 0.9297 - val_loss: 0.5039
# label:  The   Lost  Boys  (1978)  TV   Series                                                                                - predict:  The   Lost  Boys (1978)  TV   Series
# label:  Released   in 1963  on  Motown's   Gordy imprint,   intended to capitalize   on  the success                         - predict: Released   in 1963  on  Motown's   Gordy imprint,   intended to capitalize   on  the success
# label:  the   Sale   of Goods   Act,  e.g.  UK  1979 s57(2).   The   court   held  that  Mr Cave                             - predict:  the   Sale   of Goods   Act,  e.g.  UK  1979 $57(2).   The   court   held  that  Mr Cave
# label:  was born in   Tema,  Ghana  to  Ghanaian                                                                             - predict: was born in   Tema,  Ghana  to  Ghanaian
# label:  was  suddenly   sacked   and  Tony Dolby   returned  as                                                              - predict: was  suddenly   sacked   and  Tony Dolby   returned  as
# label:  He   also collaborated with  writer  David  Levin  and wrote  six                                                    - predict:  He   also collaborated with  writer  David  Levin  and wrote  six
# label:  for  Vocational and  Technical   Center   at  Lesser  Level The                                                      - predict: for  Vocational and  Technical   Center   at  Lesser  Level The
# label:  initiative  in the   title race  to Derby                                                                            - predict:  initiative  in the   title race  to Derby
# label:  Camarillo   State   Mental   Hospital. From 1964  to 1969,   he   was the executive                                  - predict: Camarillo   State   Mental   Hospital. From 1964  to 1969,   he   was the executive
# label:  to   GNM   Programme.  1999-   Started  Global   Health  Exchange   Programme                                        - predict: to   GNM   Programme.  1999-   Started  Global   Health  Exchange   Programme
#
# Out of 349 samples:
# Mean edit distance:44.249
# Mean normalized edit distance: 0.378
#
#
# Epoch 00014: val_loss improved from 0.65905 to 0.50393, saving model to ./models/VGG\ocr_model_20210929-080211_epoch_14.h5
# Epoch 15/100
# 1957/1957 [==============================] - 987s 504ms/step - loss: 0.8099 - val_loss: 0.4464
# label:  the   winning   goal  in extra   time.   Oxford's goal was  struck  from  the   official                             - predict: the   winning   goal  in extra   time.   Oxford's goal was  struck  from  the   official
# label:  these days   part of  the  Arts                                                                                      - predict: these days   part of  the  Arts
# label:  now   ras  an   Uachtarin,   official   residence   of  the President                                                - predict:  now   ras  an   Uachtarin,   official   residence   of  the President
# label:  was married   there to  her cousin   William Forlonge.In   1836 Harvey  leased lots                                  - predict: was married   there to  her cousin   William Forlonge.In   1836 Harvey  leased lots
# label:  the   Amana Colonies (1855-today).  In   Sweden, a group   of  radical pietists formed                               - predict: the   Amana Colonies (1855-today).  In   Sweden, a group   of  radical pietists formed
# label:  near  the capital   of  Mongadishu. It is   stated  that   AMISOM was preparing  for an                              - predict:  near  the capital   of  Mongadishu. I is   stated  that   AMISOM was preparing  for an
# label:  He received   the rank   of regimental clerk  in   1773.  Being                                                      - predict:  He received   the rank   of regimental clerk  in   1773.  Being
# label:  In other Phidippus species, the                                                                                      - predict:  In other Phidippus specles, the
# label:  New   World countries,  especially  over   the  issue of  agricultural subsidies   and                               - predict:  New   World countries,  especially  over   the  issue of  agricultural subsidies   and
# label:  mandate   of the United Nations  Mission for  the  Referendum   in Western Sahara  (MINURSO)                         - predict:  mandate   of the United Nations  Mission for  the  Referendum   in Western Sahara  (MINURSO)
#
# Out of 349 samples:
# Mean edit distance:44.427
# Mean normalized edit distance: 0.380
#
#
# Epoch 00015: val_loss improved from 0.50393 to 0.44639, saving model to ./models/VGG\ocr_model_20210929-080211_epoch_15.h5
# Epoch 16/100
# 1957/1957 [==============================] - 985s 503ms/step - loss: 0.8471 - val_loss: 0.4366
# label:  mandate   of the United Nations  Mission for  the  Referendum   in Western Sahara  (MINURSO)                         - predict: mandate   of the United Nations  Mission for  the  Referendum   in Western Sahara  (MINURSO)
# label:  variance,   by individual   calling. Research based on  audio  playback  tests   shows                               - predict: variance,   by individual   calling. Research based on  audio  playback  tests   shows
# label:  director-general  George  Entwistle  resigned later  that day.  The Bureau's   Managing                              - predict: director-general  George  Entwistle  resigned later  that day.  The Bureau's   Managing
# label:  Graphs)   rdflib.graph.update()  - used  to  change  graph content or  return  RDF   using                           - predict: Graphs)   rdflib.graph.update()  - used  to  change  graph content or  return  RDF   using
# label:  to provide  consultative  and planning  support to  the allied                                                       - predict:  to provide  consultative  and planning  support to  the allied
# label:  for disgorgement  of profits  against Blake.  The   decision of  the  United States Supreme                          - predict:  for disgorgement  of profits  against Blake.  The   decision of  the  United States Supreme
# label:  notes Mrs   J.   B.  Hillis   as   living  at   Roseneath.                                                           - predict: notes Mrs   J.   B.  Hillis   as   living  at   Roseneath.
# label:  Camarillo   State   Mental   Hospital. From 1964  to 1969,   he   was the executive                                  - predict:  Camarillo   State   Mental   Hospital. From 1964  to 1969,   he   was the executive
# label:  R.  Br.  1813  Cochlioda Lindl.   1853 Miltonia Lindl.  1837                                                         - predict:  R.  Br.  1813  Cochlioda Lindl.   1853 Miltonia Lindl.  1837
# label:  House  of Orlans'   sole,  constitutional   king, Louis   Philippe: Jean-de-Dieu  Soult                              - predict:  House  of Orlans'   sole,  constitutional   king, Louis   Philippe: Jean-de-Dieu  Soult
# Out of 349 samples:
# Mean edit distance:45.367
# Mean normalized edit distance: 0.388
#
#
# Epoch 00016: val_loss improved from 0.44639 to 0.43664, saving model to ./models/VGG\ocr_model_20210929-080211_epoch_16.h5
# Epoch 17/100
# 1957/1957 [==============================] - 985s 503ms/step - loss: 0.8199 - val_loss: 0.4860
# label:  focused   on computational  biology   models   of interactions                                                       - predict: focused   on computational  biology   models   of interactions
# label:  CMP  replaced),   this body numbered   about 700 men,                                                                - predict:  CMP  replaced),   this body numbered   about 700 men,
# label:  20   January, the  European   Union  followed  with   a                                                              - predict:  20   January, the  European   Union  followed  with   a
# label:  has   composed music  for   the   2017  Homestuck video   game Hiveswap,   Undertale                                 - predict:  has   composed music  for   the   2017  Homestuck video   game Hiveswap,   Undertale
# label:  and   two civilians   were   killed   in  ceasefire                                                                  - predict:  and   two civilians   were   killed   in  ceasefire
# label:  and   the  members  renegotiated  the arrangement in   2001. The   new  structure                                    - predict:  and   the  members  renegotiated  the arrangement in   2001. The   new  structure
# label:  in the back   of his shop, starting  with                                                                            - predict:  in the back   of his shop, starting  with
# label:  reveals  to  her suspicion   about                                                                                   - predict:  reveals  to  her suspicion   about
# label:  due   to  the  proximity   of  its release   to   the recently   ended  Gulf War.   Desert                           - predict:  due   to  the  proximity   of  its release   to   the recently   ended  Gulf War.   Desert
# label:  Maryland.  His  self-described "day job" was   with  the                                                             - predict:  Maryland.  His  self-described "day job" was   with  the
#
# Out of 349 samples:
# Mean edit distance:44.186
# Mean normalized edit distance: 0.378
#
#
# Epoch 00017: val_loss did not improve from 0.43664
# Epoch 18/100
# 1957/1957 [==============================] - 984s 503ms/step - loss: 0.7006 - val_loss: 0.4713
# label:  in  a 33 comeback   draw;  this also made him                                                                        - predict:  in  a 33 comeback   draw;  this also made him
# label:  status   of   the Mead-Cooley   hypothesis."  Symbolic  Interaction  27:26786.   Miller,                             - predict: status   of   the Mead-Cooley   hypothesis."  Symbolic  Interaction  27:26786.   Miller,
# label:  (214),  hits (277),   and   at bats   (767),  and   was                                                              - predict:  (214),  hits (277),   and   at bats   (767),  and   was
# label:  Pakistan also rejected India's  claims  that   there  had   been additional casualties.                              - predict:  Pakistan also rejected India's  claims  that   there  had   been additional casualties.
# label:  ravines   are  often  dominated  by  Leucosidea  sericea  shrubs.The   area is  home to                              - predict:  ravines   are  often  dominated  by  Leucosidea  sericea  shrubs.The   area is  home to
# label:  was added.   On July 13,  1925,   SH 108  was extended  south   to San Antonio,  with                                - predict:  was added.   On July 13,  1925,   SH 108  was extended  south   to San Antonio,  with
# label:  synchronization".  Science. 272   (5259):   2714.  PMID   8602512. S2CID  10399718.                                  - predict:  synchronization".  Science. 272   (5259):   2714.  PMID   8602512. S2CID  10399718.
# label:  and   Bang   Masters. The  second  disc  contains  the notorious   "Contractual  Obligation"                         - predict:  and   Bang   Masters. The  second  disc  contains  the notorious   "Contractual  Obligation"
# label:  a browser's   companion,  and  an invaluable   introduction to  the art form", adding                                - predict: a browser's   companion,  and  an invaluable   introduction to  the art form", adding
# label:  of  student progress.   Other  laboratories  devoted   to arts  and   sciences  and large                            - predict:  of  student progress.   Other  laboratories  devoted   to arts  and   sciences  and large
#
# Out of 349 samples:
# Mean edit distance:44.628
# Mean normalized edit distance: 0.381
#
#
# Epoch 00018: val_loss did not improve from 0.43664
# Epoch 19/100
# 1957/1957 [==============================] - 984s 503ms/step - loss: 0.7273 - val_loss: 0.3722
# label:  Bowden,                                                                                                              - predict:  Bowden,
# label:  from his birthplace. They  had three  daughters and   four   sons,  in   that  order.                                - predict:  from his birthplace. They  had three  daughters and   four   sons,  in   that  order.
# label:  John Perry Wall   died   from   heart failure   in                                                                   - predict:  John Perry Wall   died   from   heart failure   in
# label:  Isabella   and Leonora   and  to   the  complaints  of their  spouses,  for whom  their                              - predict:  Isabella   and Leonora   and  to   the  complaints  of their  spouses,  for whom  their
# label:  pH,  a water   hardness of 225   dGH, and   a temperature range  of   7279   F   (2226                               - predict:  pH,  a water   hardness of 225   dGH, and   a temperature range  of   7279   F   (2226
# label:  driver  is mostly  only  possible   with                                                                             - predict: driver  is mostly  onlr  possible   with
# label:  on alleged disease   grounds  and  refuses  to                                                                       - predict:  on alleged disease   grounds  and  refuses  to
# label:  side of  which was   brilliant  from the   sun."   Another  description  by Roerich was                              - predict: side of  which was   brilliant  from the   sun."   Another  description  by Roerich was
# label:  part of British  Steel although  the  works   continued  to                                                          - predict: part of British  Steel although  the  works   continued  to
# label:  Graphs)   rdflib.graph.update()  - used  to  change  graph content or  return  RDF   using                           - predict:  Graphs)   rdflib.graph.update()  - used  to  change  graph content or  return  RDF   using
#
# Out of 349 samples:
# Mean edit distance:44.536
# Mean normalized edit distance: 0.381
#
#
# Epoch 00019: val_loss improved from 0.43664 to 0.37217, saving model to ./models/VGG\ocr_model_20210929-080211_epoch_19.h5
# Epoch 20/100
# 1957/1957 [==============================] - 984s 503ms/step - loss: 0.7865 - val_loss: 0.5571
# label:  for  the first time,   not  six  feet                                                                                - predict:  for  the first time,   not six  fet
# label:  these days   part of  the  Arts                                                                                      - predict: these days   part of  the  Arts
# label:  Rhapsody   (1998)   Kid Loco's  official   website was active  up  until 2012   Official                             - predict: Rhapsody   (1998)   Kid Loco's  official   website was active  up  until 2012   Official
# label:  Players may hold   more   than   one   non-FIFA nationality.  For                                                    - predict:  Players may hold   more   than   one   non-F1FA nationality.  For
# label:  be  added   with the  add   function: add((subject,                                                                  - predict:  be  added   with the  add   function: add((subject,
# label:  the most   deadliest  incidents  were:   22 February  2009 11   Burundian   soldiers                                 - predict:  the most   deadliest  incidents  were:   22 February  2009 11   Burundian   soldiers
# label:  fit-out in Banyuwangi, and  was completely destroyed.                                                                - predict:  fit-out in Banyuwangi, and  was completely destroyed.
# label:  (2009)   (TV) ....   Mabel  Mcqueen Castle  (1   episode, "The   Fifth   Bullet",  2009)                             - predict:  (2009)   (TV) ....   Mabel  Mcqueen Castle  (1   episode, "The   Fifth   Bullet",  2009)
# label:  first mayor elected  to   a  four-year term.   Tyler   had been  instrumental  in drafting                           - predict:  first mayor elected  to   a  four-year term.   Tyler   had been  instrumental  in drafting
# label:  - RDFLib   defines  the following   kinds of  Graphs:                                                                - predict:  - RDFLib   defines  the following   kinds of  Graphs:
# Out of 349 samples:
# Mean edit distance:44.742
# Mean normalized edit distance: 0.382
#
#
# Epoch 00020: val_loss did not improve from 0.37217
# Epoch 21/100
# 1957/1957 [==============================] - 985s 503ms/step - loss: 0.7349 - val_loss: 0.3881
# label:  immigrant, at ASM   Auto Upholstery,   a   business   that was                                                       - predict:  immigrant, at ASM   Auto Upholstery,   a   business   that was
# label:  more quickly when your kid  is  sitting   at  the kitchen  table   in   his  Incredible                              - predict: more quickly when your kid  is  sitting   at  the kitchen  table   in   his  Incredible
# label:  Powerhouse   Rail,   the line from   Manchester  to Blackpool  North  was   approved                                 - predict:  Powerhouse   Rail,   the line from   Manchester  to Blackpool  North  was   approved
# label:  Slack.   Most   of   the  developers   are  also on Twitter.                                                         - predict:  Slack.   Most   of   the  developers   are  also on  Twitter.
# label:  focused   on computational  biology   models   of interactions                                                       - predict:  focused   on computational  biology   models   of interactions
# label:  and   the   semantics   of   these   triples,                                                                        - predict:  and   the   semantics   of   these   triples,
# label:  had  incredibly  topped the  First   Division  in late   August   after   winning   their                            - predict:  had  incredibly  topped the  First   Division  in late   August   after   winning   their
# label:  from   participating in   bubbles  and  crashes and   thus   reduces its  volatility                                 - predict:  from   participating in   bubbles  and  crashes and   thus   reduces its  volatility
# label:  Vienna. Tat-cho  Yuen.   For  public services in Hong   Kong.  Patricia                                              - predict: Vienna. Tat-cha  Yuen.   For  public services in Hong   Kong.  Patricia
# label:  Its   clearest form is an  order  for                                                                                - predict:  Its   clearest form is an  order  for
#
# Out of 349 samples:
# Mean edit distance:43.564
# Mean normalized edit distance: 0.372
#
#
# Epoch 00021: val_loss did not improve from 0.37217
# Epoch 22/100
# 1957/1957 [==============================] - 987s 504ms/step - loss: 0.7260 - val_loss: 0.5873
# label:  a cross-LoC  raid,  during  which  they  went                                                                        - predict:  a cross-LoC  raid,  during  which  they  went
# label:  House  of Orlans'   sole,  constitutional   king, Louis   Philippe: Jean-de-Dieu  Soult                              - predict:  House  of Orlans'   sole,  constitutional   king, Louis   Phllippe: Jean-de-Dieu  Soult
# label:  stars. All tracks  are  written   by                                                                                 - predict:  stars. All tracks  are  written   by
# label:  Lanka cricket team  toured   India from October  to   December   1975.  Sri Lanka did                                - predict:  Lanka cricket team  toured   India from October  to   December   1975.  Sri Lanka did
# label:  December 2016.   Previous roles include   being   a  freelance  consultant   between                                 - predict:  December 2016.   Previous roles include   being   a  freelance  consultant   between
# label:  A tradable  credit  system was  created for   those carmakers  not fulfilling   their                                - predict: A tradable  credit  system was  oreated for   those carmakers  not fulfilling   their
# label:  the family  moved  to   Paris but                                                                                    - predict:  the family  moved  to   Paris but
# label:  1867. His  father,  John   Naylor,   was organist of  York   Minster.  He   won a   choral                           - predict:  1867. His  father,  John   Naylor,   was organist of  York   Minster.  He   won a   choral
# label:  John Perry Wall   died   from   heart failure   in                                                                   - predict:  John Perry Wall   died   from   heart failure   in
# label:  has   composed music  for   the   2017  Homestuck video   game Hiveswap,   Undertale                                 - predict:  has   composed music  for   the   2017  Homestuck video   game Hiveswap,   Undertale
#
# Out of 349 samples:
# Mean edit distance:44.221
# Mean normalized edit distance: 0.378
#
#
# Epoch 00022: val_loss did not improve from 0.37217
# Epoch 23/100
# 1957/1957 [==============================] - 985s 503ms/step - loss: 0.7110 - val_loss: 0.6667
# label:  of  living  soil.   His popular class on   Fundamentals  of Wine Chemistry has been  attended                        - predict: of  living  soil.   His popular class on   Fundamentals  of Wine Chemistry has been  attended
# label:  after   being   seen   as a   close  confidante   to                                                                 - predict:  after   being   seen   as a   close  confidante   to
# label:  (214),  hits (277),   and   at bats   (767),  and   was                                                              - predict:  (214),  hits (277),   and   at bats   (767),  and   was
# label:  canton  of St.   Gallen.  It lies                                                                                    - predict:  canton  of St.   Gallen.  It lies
# label:  Vienna. Tat-cho  Yuen.   For  public services in Hong   Kong.  Patricia                                              - predict: Vienna. Tat-cho  Yuen.   For  public services in Hong   Kong.  Patricia
# label:  pH,  a water   hardness of 225   dGH, and   a temperature range  of   7279   F   (2226                               - predict:  pH,  a water   hardness of 225   dGH, and   a temperature range  of   7279   F   (2226
# label:  served  as a  personnel   director for  the  Chicago  Bears   from  1968-1975,   overseeing                          - predict:  served  as a  personnel   director for  the  Chicago  Bears   from  1968-1975,   overseeing
# label:  Grey   was  acting editor until  the  appointment  of  Iain   Overton as   its   first                               - predict:  Grey   was  acting editor until  the  appointment  of  lain   Overton as   its   first
# label:  Pakistan also rejected India's  claims  that   there  had   been additional casualties.                              - predict:  Pakistan also rejected India's  claims  that   there  had   been additional casualties.
# label:  path   through the  mountains,   is   named   so                                                                     - predict:  path   through the  mountains,   is   named   so
#
# Out of 349 samples:
# Mean edit distance:45.662
# Mean normalized edit distance: 0.390
#
#
# Epoch 00023: val_loss did not improve from 0.37217
# Epoch 24/100
# 1957/1957 [==============================] - 985s 503ms/step - loss: 0.6229 - val_loss: 0.3982
# label:  this   idea for  a  seven   inch.  We                                                                                - predict: this   idea for  a  seven   inch.  We
# label:  Sweden".   Title: Volvo Personvagnar frn   20-tal till   80-tal, by                                                  - predict:  Sweden".   Title: Volvo Personvagnar frn   20-tal till   80-tal, by
# label:  to grant   an  injunction  means that in   practice the defendant is   thereby  permitted                            - predict: to grant   an  injunction  means that in   practice the defendant is   thereby  permitted
# label:  placed   four  members.  First Division Malcolm Macdonald  (Newcastle                                                - predict:  placed   four  members.  First Division Malcolm Macdonald  (Newcastle
# label:  held   at   the  Family  Kingdom                                                                                     - predict:  held   at   the  Family  Kingdom
# label:  the   Sale   of Goods   Act,  e.g.  UK  1979 s57(2).   The   court   held  that  Mr Cave                             - predict:  the   Sale   of Goods   Act,  eg.  UK  1979 $57(2).   The   court   held  that  Mr Cave
# label:  in 1637.  In  1641, Louis   XIV  gave   it   and  the manor  to   the   Vignacourts,                                 - predict:  in 1637.  In  1641, Louis   XIV  gave   it   and  the manor  to   the   Vignacourts,
# label:  her. Frightened,  she  and Tommy  flee  to  Tucson,   Arizona,  where   she finds   a                                - predict:  her. Frightened,  she  and Tommy  flee  to  Tucson,   Arizona,  where   she finds   a
# label:  of  andesite   and dacite material.   Old  growth  Ponderosa pines   flourish  on Pine                               - predict:  of  andesite   and dacite material.   Old  growth  Ponderosa pines   flourish  on Pine
# label:  ban   from football,  but   Manchester   United manager   Tommy Docherty                                             - predict: ban   from football,  but   Manchester   United manager   Tommy Docherty
# Out of 349 samples:
# Mean edit distance:43.493
# Mean normalized edit distance: 0.372
#
#
# Epoch 00024: val_loss did not improve from 0.37217

# %% [markdown]
# # Testing #
