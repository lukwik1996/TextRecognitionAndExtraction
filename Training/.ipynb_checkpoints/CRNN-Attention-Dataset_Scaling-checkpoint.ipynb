# %% [markdown]
# # Test tensorflow gpu #

# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
  except RuntimeError as e:
    print(e)
# Out:
# C:\Users\lukas\anaconda3\envs\ML\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\lukas\anaconda3\envs\ML\lib\site-packages\numpy\.libs\libopenblas.QVLO2T66WEPI7JZ63PS3HMOHFEY472BC.gfortran-win_amd64.dll
# C:\Users\lukas\anaconda3\envs\ML\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# # Dataset #

# %%
import os
import codecs

data = {}
classes_file = './TextData/classes.txt'
with codecs.open(classes_file, 'r', encoding='utf-8') as cF:
    data = cF.read().split('\r\n')
len(data)
# Out:
# 94

# %%
import os
from PIL import Image, ImageDraw, ImageFont

text_source = './TextData/text_full.txt'
fonts_path = './TextData/Fonts'
fonts = [f'{fonts_path}/{f}' for f in os.listdir(fonts_path)]
fonts
# Out:
# ['./TextData/Fonts/arial.ttf',
#  './TextData/Fonts/arialbd.ttf',
#  './TextData/Fonts/arialbi.ttf',
#  './TextData/Fonts/ariali.ttf',
#  './TextData/Fonts/calibri.ttf',
#  './TextData/Fonts/calibrib.ttf',
#  './TextData/Fonts/calibrii.ttf',
#  './TextData/Fonts/calibriz.ttf',
#  './TextData/Fonts/cambria.ttc',
#  './TextData/Fonts/cambriab.ttf',
#  './TextData/Fonts/cambriai.ttf',
#  './TextData/Fonts/cambriaz.ttf',
#  './TextData/Fonts/consola.ttf',
#  './TextData/Fonts/consolab.ttf',
#  './TextData/Fonts/consolai.ttf',
#  './TextData/Fonts/consolaz.ttf',
#  './TextData/Fonts/constan.ttf',
#  './TextData/Fonts/constanb.ttf',
#  './TextData/Fonts/constani.ttf',
#  './TextData/Fonts/constanz.ttf',
#  './TextData/Fonts/corbel.ttf',
#  './TextData/Fonts/cour.ttf',
#  './TextData/Fonts/courbd.ttf',
#  './TextData/Fonts/courbi.ttf',
#  './TextData/Fonts/couri.ttf',
#  './TextData/Fonts/impact.ttf',
#  './TextData/Fonts/Roboto-Black.ttf',
#  './TextData/Fonts/Roboto-BlackItalic.ttf',
#  './TextData/Fonts/Roboto-Bold.ttf',
#  './TextData/Fonts/Roboto-BoldItalic.ttf',
#  './TextData/Fonts/Roboto-Italic.ttf',
#  './TextData/Fonts/Roboto-Regular.ttf',
#  './TextData/Fonts/tahoma.ttf',
#  './TextData/Fonts/tahomabd.ttf',
#  './TextData/Fonts/times.ttf',
#  './TextData/Fonts/timesbd.ttf',
#  './TextData/Fonts/timesbi.ttf',
#  './TextData/Fonts/timesi.ttf',
#  './TextData/Fonts/trebuc.ttf',
#  './TextData/Fonts/verdana.ttf',
#  './TextData/Fonts/verdanab.ttf',
#  './TextData/Fonts/verdanai.ttf',
#  './TextData/Fonts/verdanaz.ttf']

# %%
dataset = []
sequence_len = 20

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import cv2

def draw_img(img):
    plt.imshow(np.asarray(img), cmap='gray', vmin=0, vmax=255)
    plt.show()

def load_img(img):
    return cv2.imread(img, cv2.IMREAD_GRAYSCALE)

def dilate_img(img):
    return cv2.dilate(img, np.ones((2,2), np.uint8))

def otsu_thresholding(img):
    norm_img = np.zeros(img.shape)
    img = cv2.normalize(img, norm_img, 0, 255, cv2.NORM_MINMAX)
    blur = cv2.GaussianBlur(img, (3,3), 0)
    _, img = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    img = dilate_img(img)
    return img

# %% [markdown]
# ## Load dataset ##

# %%
with open(text_source) as txt:
    word_count = 0
    sequence = ''
    dataset = []
    for i, line in enumerate(txt):
        words = line.split(' ')
        for single_word in words:
            word = ''.join([c for c in single_word if c in data])
            word.replace('\n', ' ')
            
            if len(word) < 1:
                continue
            
            if len(word) > 30:
                split_count = len(word) // 30 + 1
                for i in range(split_count):
                    start = i * split_count
                    end = start + len(word) // split_count
                    dataset.append(word[start:end])          
                continue
                
            sequence = sequence + word + ' '
            word_count = (word_count + 1) % sequence_len
            if word_count == 0 or len(sequence) > 85:
                dataset.append(sequence[:-1])
                sequence = ''
                
dataset = list(set(dataset))
len(dataset)
# Out:
# 34791

# %% [markdown]
# ## Shuffle dataset ##

# %%
sorted_data = sorted(dataset, key=len)
longest_label = len(sorted_data[-1])
longest_label
# Out:
# 115

# %%
import random

random.seed = 1234567

random.shuffle(dataset)
# dataset = dataset[:20000]
dataset
# Out:
# ['It  separated   from  the mainstem  of  the River   Brethren due   to  its allowance of  ',
#  'not  sit well   with Edwards,  who   promptly   sacked  White   as Welfare  Minister, ',
#  'Carolina   Agricultural and  Technical State University in  the 1999 ',
#  "battalion   might depart for the   Horn   'some  time in  September  [2012].'In   addition,",
#  'of Justice Ramon   Magsaysay Award: Public  Service  to ',
#  'average birthrate of   2:1,   hairless',
#  '2,  2016 at  the MIAA Football ',
#  'head   coaches are  Tom   Selvik.   Among   its chairmen  of the board   are Gerhard ',
#  'Horse Comics in Dark   Horse   Presents   #1 (July   1986).',
#  "post   office opened on 16 August 1909.  In   1912   the irrigation  settlement's  name ",
#  'killing   10-12 Pakistani  Rangers.On   10  January   2018,   India ',
#  'Festival  honors  heritage   in   Walk   of  History   Yeaton biographical  ',
#  'also played   for  Wrexham  and played four  times   for   Wales,  scoring   once, against  ',
#  'was   wrecked.   The mill was   worked',
#  'his  wife Harriett   Johnson, Mack had three   children.   She  died in  2016.Mack   was',
#  'is  expected to   compete   in  the heavyweight ',
#  'Association  (NBA),   and  the Nets  were one  of   four  franchises that   joined  the  ',
#  'he   gave   in  1944.  As already  observed, it is recognised  by   Blake that   the Crown',
#  "to know WebGL.  A-Frame's first   public release  was on December   16,   2015.  On December",
#  'of  Swiss National League  A in the 198990 football season.   It  was contested by   12  ',
#  'jump   in house  prices over the last few   years.  ARIA Music Awards of  2003  Alex ',
#  'In April   1944, with JW  58,  Keppel ',
#  'is not always  the fastest  emulator   for  any one   particular   system.  Its  accuracy  ',
#  'China. Habib  Sissoko   (born   24   May',
#  'tolerated  as long   as   discretion   was  maintained  and the  ',
#  'the  archaeology department carried   out',
#  'of  the mayor  later   stated   that   he ',
#  'is  also   a  light  transverse   anterior',
#  'Isaac   Kamien  (August   15,  1938  November 18, 2011)   was ',
#  'Herbert Edward Charles Tuck, Salvage  Worker, Bilsthorpe  Colliery,  North   Nottinghamshire',
#  'attract  people to another   denomination. He organized  ',
#  'army  targeted   one  of  the military vehicles of  Pak  army which  eventually  fell  ',
#  'a  B.A.  and moved   to Leipzig,   Germany  to',
#  'Neurology,  UKE).  Andreas   Engel   has become   known  by ',
#  'Augustin   (Viennese  singspiel)  1921   Die Kohlhaymerin   1923 Das',
#  'on   the   Bath and   North East Somerset',
#  '1940,   he ran  in the 8th   district   for Congress  but was  defeated   by  Democrat  ',
#  "The  sub's  operator  navigated  via   a  conning tower  featuring   clear  celluloid",
#  'It   is   rated   among  the top  hospitals  in Ghana.  Camilo da  Silva  Sanvezzo   (born',
#  'the   ABL followed   by   the ABA   created   professional opportunities  for   the  ',
#  'The   original phase of  the garden was constructed by  the   conclusion of  the 30s ',
#  'included  the   Early   Dynastic  Archaic  Shrine,  ',
#  'Meyrick   in 1913.   It   is found ',
#  'States   decided   to  review   the  case',
#  '(December 22,  1863 March 10,   1936)',
#  'release simultaneously, but   work had   not yet  started, and   there  was  no  estimated ',
#  'Germany  toward  the   end   of   World   War  II.  ',
#  'athletic',
#  'their   work",   his  classic   text. Roseneath   was  included   and   he included architectural',
#  'Terence Dove, Grenadier   Guards. 24177995   Corporal Thomas  Reginald Forrester, The',
#  'Union.  Gladys   Dora   Cremer,   Administrative  Officer,   The  Fabian  Society.  Kenneth ',
#  'to  Heaven),   as  the critical   reception   was',
#  'for  undisclosed  reasons.   Marcus ',
#  'the   smallest primate  in the world.   New-born pygmy ',
#  'of   VictoriaMalcolm  Earl Atkinson, of Mount  Eliza. For   services  to',
#  'hardware design  to several  vendors, but was  frustrated that  ',
#  '350-250  2000-2015 -   250-200  2015-2019  - 200-190  The  Ernest  C.   Drury   School ',
#  'State  Teachers   College when  it   relocated from  Paterson  ',
#  "agreed to   provide  the   money   under the  condition   that the Ladies'  Land   League ",
#  'St.  Helena.   Riteti  Eritama, Water   Superintendent,  Public  Utilities Board,  ',
#  "and his  wife  Catherine   Thynne  of   Longleat. He succeeded   to   his father's estates,",
#  'not  fully replaced by  adult teeth as they  naturally fall out,  leaving them   with',
#  'drawn   from the minority Turkish   Cypriot   population, although  ',
#  'Ghati   sector.On   16 April,   India claimed',
#  'and  Dr A. L.  Geyer, who  was a  guest  of   Taoiseach   amon de  Valera in 1952. While ',
#  'trains   systemwide  came   to   a   stop  for  one   minute at   3:00 PM   Eastern  Time',
#  'the platforms  similar  to   that   at   Poulton-le-Fylde  station. This  was   removed  ',
#  '15  and   temporal/spatial  at  25. Demetrius   Grosse   at IMDb Demetrius Grosse   at',
#  'legal,   same-sex   marriage  and huge fans of   the   traditional family  without   wanting',
#  'Somerset Free  Press.  John   Mervyn  Sanders.  For   services',
#  'of  businesses including Hop   Back  Brewery, Revive',
#  'White   fell in with   a  group of  MPs   known  as the   "ginger  group". This group ',
#  'received  treatment   by   Michael  J.  Nelson,   Kevin   Murphy  and  ',
#  'Australian Air  ForceSergeant Peter   Laurie  Watson (A57911). Royal  Australian Air ',
#  'Massachusetts: www.glreview.com.  13   (2): 42. ISBN   9780452287631.  OCLC',
#  'Betts,  Gilbert   L; Benjamin   W   Frazier;   Guy C',
#  'United   States   Army.   He graduated   from Yale University   and  Harvard Law   School. ',
#  'years   for  Roman  to   decide   developing   and  producing the   program  before  it  ',
#  'Wollert, Victoria. For   service  to   the  meat industry. Robert  Evelyn   Porter, of  ',
#  "demonstrate   the   AMORC's principle   of sympathetic  vibration.  ",
#  'he  appeared in  seven  games  without  ',
#  'on  the',
#  'on to produce   and  direct  all',
#  '//web.archive.org/web/',
#  'Undersea   Museum Naval   War   College Museum  Patuxent   River  Naval',
#  'port   and   shipbuilding   center   from   the ',
#  'and   as   a result  of  resistance to  any  form of suppression  or oppression.   During',
#  'by their   use  of   the   terms   "PAN"   (French)  ',
#  'including physical   therapy,   occupational therapy, and  speech and  language  pathology. ',
#  'a   very  active  worldwide   ambassador  of his ',
#  'operations  focused  upon  securing  the   task',
#  'episodes)1992   Sam   Saturday (6   hour  episodes)1991 Sleepers  (4  hour  episodes)  ',
#  'began the game  in  relative disarray,   which  the   correspondent   from The Sportsman ',
#  'they   fall in  love.   They   nearly   break  up when ',
#  'G.I. Joe: The   Rise   of  Cobra.   He   was   also  featured  in the video for  singer-songwriter  ',
#  'football Missouri leads  by a  very   small  margin  (56-55-9   MU)  and   baseball  ',
#  'in a  game (e.g. between  hiding  and  seeking or buying and selling)   we   come  to',
#  'after   he  taunted   her.   Disguising herself  as  a boy with  the help   of   her  ',
#  'La  Vierge (2,641  m). Rochers  de  Gagnerie  on   Hikr   80,000 Suspects  is a 1963 ',
#  'granite   was   used  to   make  the base ',
#  'United   supporters,  "smashed  subway   trains"   and  fighting in  the   ground.24 August  ',
#  'exported to  South  Africa,  Zambia,   Zimbabwe,  ',
#  'use of   arcades, pergolas,  trellising,  and  garden   pavilions. Ceramic   elements  ',
#  'Hansen (November 18, 1891 November   18, 1965)  was  an  American   lawyer, judge,   and',
#  'forces  that landed  in Normandy during   D-Day,  and  participated   in the   subsequent  ',
#  'event was   run   and   sanctioned by',
#  'functional  role  of neural   synchrony for  sensorimotor   coupling. In   the   past',
#  "Hyde   Park's   population  was   84.8% Black,  ",
#  '1952   team lost  to Kentucky  8140   in December   1951. In  the NCAA tournament,  St ',
#  'Brendan   Kelly  - bass guitar,  vocals, guitar  on   "The Redness  in  the West" Neil  ',
#  'Andreas  Karl   Engel  (born  7 January 1961)   is   a  German  neuroscientist. He is',
#  'a  car  assembly plant   in  Botswana   from  1994 to 2000.  Botswana  seeks  to  further  ',
#  'the  opinions  and   actions   of  the group  are  divided."   Producer   Gale Anne Hurd  ',
#  'use of  "flower  power"   became  an  integral symbol   in the   counterculture  movement.',
#  'American business  executive, investor, and philanthropist.   He   served as the chairman ',
#  'Director, Clinical   Section, Toxicology Unit,  Medical  Research Council.   Professor  ',
#  'side one   containing   songs from   the  soundtrack to   their  film  of   the same name.',
#  'like  "fetch". The   lack   of  hair leads  to  a  reputation   for  being  easy  to wash',
#  "between   the   'I'   and the   'Me'. Mead   rooted",
#  'musical  expressions   and numerous  recordings. He is the  brother   of bass  player  ',
#  'discovery   concluded   then  that   some insects  are  ',
#  'his career   he   had to  live ',
#  'jitter  during congestion.   In   cases where  quality   of  service   is  rate  limiting',
#  'female regional chairman in   Denmark. She  did not  run   for  election   in   November  ',
#  'Alexander Lawrence,   CPM,  Deputy   Commissioner of Police,  Royal   St.  Lucia  Police ',
#  'been documented.   The goal was   to tell a story   with your cards.Designed by Alexander ',
#  'Decisions  under  The   1948   Protocol  Modification  of   List of ',
#  'Hereford and  Worcester   County  Council.   Hugh   Ebenezer  Prance, Professional  and ',
#  "aimed to  include cinematic   scenes, similar   to The  Revenge of   Shinobi's  introduction ",
#  'from   his   debut EP,  Live from  Nkrumah   Krom   (2017).   The  record   was  released  ',
#  "Kahn's  first   novel).  The  Hartford Courant.  February  28,  ",
#  'agent  preventing   loggers  from',
#  'Reverend  Father  Aramis  Mirzaian,   of Artarmon,  New   South  Wales. ',
#  'Hubert Fleming-Smith,  TD,   Chartered Surveyor,  Smiths   Gore  & Associates. Philip ',
#  'were  about 4,000  members   within   the   WFL,   most',
#  'Police Force.   Edric   Kenneth   Potter,  CPM, Commissioner of Police, Royal  Turks  ',
#  '19038226. S2CID  19010227.   Donner TH,  Siegel   M,  Fries  P, Engel   AK   (September ',
#  'Brazil."  Sydowia66.2   (2014):  313-323. Lima, Ruy   Anderson   Arajo  ',
#  'and  glossa (tongue),   referring to  the two tooth-like calluses on the  base  of  the ',
#  'Midlothian.  Michael  Charles  Martin,  Head,   Scientific and Technical Department, Royal',
#  'September   1962)   is  a Spanish   former  swimmer   who competed   in the 1980 Summer',
#  'castle. Sowerby  was  the   centre of  the',
#  'ISBN   81-7476-505-0,  pp. 4751  V.   M.   Muddiah   at  ',
#  'were  philosophy and psychology. At  Harvard, Mead  studied   with Josiah  Royce,   a ',
#  '100. Lyrics  of this  song at MetroLyrics Albert   Jenkinson  (first  1884  death unknown) ',
#  '18601864, and   the  mayor   of   Charlotte   in   1871.   He was   also trustee of  the  ',
#  'Laureate  of Kansas from   2015-2017. McHenry   graduated   from  Topeka   High   School.  ',
#  'Hoberg   "Hear Me"   (Late   Night Alumni   Remix)   2014 -  Colette  "Physically" (Late',
#  'interpret these  calls  not   only   by   type but   also,  through   subtle  sonic',
#  'Charlemagne  on his   campaign  into',
#  'as   Organist of  this Parish,   and   particularly  for playing   the  ',
#  "St.   John's  would finish the season 218 and go   on   a remarkable  run  in  the  1965 ",
#  '"Slashdot". Cambia  Health  Solutions  (April   18,  2012) "Cambia Health   Solutions  ',
#  "a  LOMOcean's   trimaran   hullform.  The  mockup was built  in approximately  six  ",
#  'to  and   encouraged one   another,  thus giving   Lomax an',
#  'It is recommended   to degrease the titanium  surface   and remove  any  corrosion  by ',
#  'under  the  name  Bluth  Group, the',
#  'Creswick,  Daylesford,   Gisborne,  Kyneton and  Woodend.  All',
#  'is always   brown,  but   dogs with   light  colors   can   have   clearer eyes  than  ',
#  'Secondary   school which  he ',
#  'it  to Prussia  in  1834.In   1825, Frederick   IV,',
#  'interglacial.  It  is   described   by  Natural  England  as ',
#  'miles   (6.0   km)  west-southwest of  Halifax and 7.6  miles (12.2 km)   west-northwest ',
#  'on   BSF   posts   in   Poonch   and Jammu   districts.On   14 September, the  BSF said ',
#  "on  September 7,   2014. He   was  the   Chiefs'  first  sixth-round  pick to  start  ",
#  'and  to   do   basic  arithmetic  ',
#  'broker   and   enthusiast of   traditional  animation,   who quickly   saw   the   potential  ',
#  'Board. In   1958   the   station comprised   a 35   kW  water turbine  driven   by  the ',
#  'began and  endorsed Corky   Evans.  Labour  activist  Len',
#  'Park  in   August.   He  ended his  racing  career   by   running fourth in  an  allowance',
#  'Field Recordings Vol 13 Texas  Louisiana Arkansas Mississippi ',
#  '24 May, India   claimed   that   had  killed',
#  'Support  Team (FAST)   was   established in   2013 by the',
#  '2002  Canadian  made-for-television   thriller  film  directed',
#  'distinguishable   from   URI   references,   Literals,   and   BNodes  by  ',
#  'producer, mixing, sampling, arranger, sequencing, artwork,  design   Robin Aub  engineer  ',
#  "the website 'Allafrica.com')  and   news reports on  the  AMISOM",
#  'Meshed,   he   was  involved  in   supervising  the transport  of ',
#  'churches of St   Mary  Woolnoth   and   St Mary ',
#  'successor  to   the  Southern   African   Development  Coordination   Conference  (SADCC),',
#  'Bluth Studios   has   also   been   regarded   as  a  major influence   in   the   development ',
#  'industry.   It  was  later  purchased, enlarged  ',
#  'it carefully  went  back  and rose',
#  'Of  Song: Black   Texicans -   Balladeers   and   Songsters   of  ',
#  'Paris. She  began  her  studies  in   1938   at  the   cole  normale   suprieure   de',
#  '2017,   "We   Fight"   premiered on Beats 1.  Alongside  ',
#  'The seal   is   of  the   Office   of the House   of   Representatives and  not  to  ',
#  'to Mentally   Handicapped Young  People.  Mair  Evelyn Reed, Probation Officer,   Norfolk ',
#  'most  recently  in   Fukushima, in   the wake  of  the  2011   tsunami  and  earthquake ',
#  'the  book  as,  "a witty,  ribald memoir  with  his trademark  zingers".  Marshall   commented,',
#  'former   chairman   of the board and  CEO for',
#  'prove  that   they   were  the  legal   heirs   of   their deceased   half-sister Praskovya  ',
#  'John   Williamson  Soutar,  MBE, QHS.Civil Division Australian   StatesState  ',
#  'they are   not  available now   to',
#  "of Repetto did   not stop  the   group's   productivity:   they   continued to perform,  ",
#  'no   interest  in   (or   appropriate storage   for) the material.   She   disposed of',
#  'second   solo  album, Time Out,   was released during  in 2007. It   proved   to   be',
#  'Pula.  There  was   a further   12%  devaluation   in  May   2005 and  the policy of a  ',
#  'but  never built  due  to the',
#  'and  early   promotion  for  All  Dogs   Go  to   Heaven',
#  'took 5  for 2  ',
#  'There have  only been  six  holders of   this  title  in  the   history   of   France: ',
#  'and innovators   in the',
#  '("Professions   Australia"),   the   peak  body  for professional   associations  ',
#  'year Mrs Allen  brought   the   property  into  ',
#  'National   Fat  Stock Club.   Betty   Barnes  Westgate,   Secretary,   The   Mastectomy  ',
#  'study  with psychologist   Wilhelm   Wundt,  from   whom   he   learned  the   concept ',
#  '2018, a   BSF  head constable   was ',
#  '194243  During her  service Enchantress was   credited with   the  destruction of one ',
#  'manager   (something   like that  of   the   Niagara   plant) - Louisa has   her  suspicions',
#  '2010  the China Ministry   of   Education  approved  the  name  ',
#  'forces were   withdrawing   from to  be   directed by',
#  'skiing. As  Ben  is  leaving  town',
#  'Intermixed  with  this idyllic  landscape ',
#  'physics  to work  out the   anisotropic   dielectric  tensor  ',
#  'of   starting a life   with  Franklin Fiske   for  a   brief  moment,  but  later  on  ',
#  'a Somali  soldier   was   assassinated in  a market  in  Afgoye. During   8 and   9  June',
#  'village in  the   province of Alicante and  autonomous community  of Valencia,   Spain.  ',
#  'Gallardo  -   underground  comic  book  artist,  especially  known for ',
#  '1995 Trends, Myths   and  Realities: Funding  Policy  and the  Local   Voluntary  Sector;',
#  'Oncidium  xCambria  :   Brassia  x   Cochlioda  x Miltonia  x   Oncidium   x   Odontoglossum',
#  'scene, as  all   of the  members   were',
#  'priest in the United States  publicly   known to be  black  when  he was  ordained   in  ',
#  'South Wales,   Australia, the son  of   George  Henry ',
#  '-   RDFLib defines the  following kinds of Graphs: ',
#  'Movement   with  the  previous parliamentary   government at the behest   of   Governor-General  ',
#  'degree, present  in his   own  make-up. In  the  game,  then, there is  a set   of   responses  ',
#  'the history of  NK Maribor   and   the',
#  'sources   they need in  order to   survive.  In   the  ',
#  'the charts  in  five countries. "Ready 2 Go"   was released   as  the   album\'s   second',
#  'this effect.Hauksbee  continued   to  experiment with   electricity, ',
#  'Forester,  East   Scotland Conservancy,  Forestry Commission. Joseph Norman  Gass,',
#  '2 (10):  70416.  doi:10.1038/35094565.  PMID 11584308.   S2CID   13224138.  Engel AK,  ',
#  'there has been  considerable  objection to   loyalist  band  parades  in  the  town.  ',
#  'early Christchurch venue.   As',
#  'and the  repertoire   comprises  music from  the  Renaissance   to  ',
#  '85:26187.  Lundgren,  D.  C. 2004. "Social  feedback   and   self-appraisals:   Current  ',
#  'Lee  Mendelson.   Years  later,   the  studio moved',
#  'degree).   Clinton Wheeler,   former NBA  player.   Ian   Ziering,   class',
#  'R.C.Harris, Ladd &  Printzen (2004) Australia;   North America   Hertelidea wankaensis  ',
#  'today   based   in the Amana Colonies,  are  known   for  ',
#  'of   Health Sciences (KUHS)  was   implemented. Inaugurated a multipurpose',
#  'sisters born  to  a family of Russian-Ukrainian Jewish   immigrants  to  ',
#  'portal  to information   about  performing arts   programs  produced   and  presented',
#  'and   outline  and list   creation. Users  can  collaborate  with  others ',
#  'any of   the  surviving  buildings   are  from  this  early  period,  as   there  was  ',
#  'Elementary  School Ashti   (Shahid)  is  ',
#  'prominent  Irish  stuccodore,   son   of   Michael   Stapleton.  ',
#  "Who's  Who in  Europe, 1983, International Publication   Service;  5th  edition   (April  ",
#  '1930  to   1933.  He was   a  member of the  National   Education  Association (NEA) ',
#  'Molyneux;  Published by  the   Joseph   Rowntree   Foundation;   2005   Fruitful  funding:',
#  'championship,   batting  .305  with   a  homer',
#  'money for the  Malcolm  Sargent   Cancer   Fund  for  Children.   One of his   other great',
#  'around  Sydney  for  at   least 25,000   years.   The  ',
#  'Coast   Guard.  Many  of the ',
#  'for  30   days.   On   March  1,  2017 ',
#  'stayed at  the top of the  chart  for three   weeks   and   spent a total   of   twenty-two',
#  'Overseas  ListAnthony ',
#  'of   1977 the   party obtained  6   deputies   within ',
#  'ICU  towards the   proposed  IGASOM   mission.Though  IGAD   and the ICU met   and  published ',
#  'recommended  immediate  consideration   for CITES protection, given its likely demand ',
#  'in  1969   she finished  her   education   as',
#  'and still  be  audible  to   communicate the desired  message.  Since   the   pygmy  ',
#  '22 September, the   Pakistan  military   said  ',
#  'germ shield   morphology. It   was  first  isolated in  ',
#  'by  the  steamer  Donau off  Bergen, suffering  minor damage.In June 1941,  Bremse was',
#  'are  paternal mouthbrooders,   with the male   carrying  the  eggs',
#  'and   later the   Habsburgs.   A   war with  ',
#  'South   Africa  Melanie Verwoerd   Irish embassy   in  Pretoria South   African  embassy',
#  '1st Armoured   Personnel  Carrier   Squadron,   during  the  fighting around   Long  ',
#  '"brilliant playability".  Amiga   Format commended   the "Successful  cross   between  ',
#  'Roseneath,  Parramatta. In  May   1842 the   Sydney   Herald',
#  'However,  other  breeders (especially  in   Peru)   think   the opposite ',
#  'flags,   emblems, etc.  or   play   national anthems.   The  go-ahead  was given  after ',
#  'Robert  Alfred   Warwick   (3500718).   Acting  Wing Commander Roy  Kenneth ',
#  '"In  Conversation   with   Dianne   Reeves", Jazz.com,  June  15,  2008 Felix  ',
#  'The   Sunday   Times.   Perth,   WA.   Retrieved 7 April',
#  'for   the  coming fiscal year.   The State Board  of ',
#  'State  at #1.On  August  15,   the   American Football  ',
#  'metal  matching   the bomb fragments. ',
#  'the Liberal   Party  of Australia.   White  was  first',
#  'with  sharp, tufted   leaves  and firm  awns.   This  grass  may be   dioecious, with  ',
#  'or  lose   packets in   transit,   such as radio frequency   interference (RFI), radio ',
#  'from   Lotte.   However,  Shin   was allowed  to  remain   free   given   his  poor health. ',
#  '"Statement by the   President  Announcing a Forthcoming White  ',
#  'Russian pressure,  since  his   sister Juliane  was   married   to',
#  'Moozhikkal  Madathil   Kunnummal  Maha Vishnu Temple  Moozhikkal purayidam   sarppakavu ',
#  'on  the Ekeberg Line,   the  Simensbrten   Line  and the  connection   to  the   city ',
#  "Talbot, Molina   and  Keith  at  Chicago's  Chess ",
#  'said   Princess   Ingrid   Alexandra   would  walk to ',
#  'States  at  St.   Boniface   church  in Quincy.   He',
#  'only child of  Michael   and   Lillian (Dunne)   Daley, whose  families had both   arrived ',
#  'do   not contribute  to fuel taxes   that are  used to  fund  highway  maintenance.  ',
#  'Club History   Database Hastings  Football   History Combe  Valley  ',
#  'J-calls for  intermediate  distances, and long calls   for   long  ',
#  'half with a   re-worked version of the b-side   "Ansum";  "Twist"  contains an extended  ',
#  'when total  goals are  equal. Last   updated  on  1   June  2014   Includes  all   competitive  ',
#  'Wilson   Bremner,   Audio  Typist, Board   of  Inland Revenue. Richard   John   Brenton, ',
#  'Johnson   Hagood   who   commanded  the troops   at  Fort Wagner during  the attack  ',
#  'Cup semi-finals over   Chester  and   Manchester   United  respectively.25 January  1975: ',
#  'Trevor   Bailie, Secretary, County Londonderry Savings Committee. John  Carter  Baily,  ',
#  'SX-70-type cameras. The   flash   has a   half-power setting  for',
#  '11  April  U.S.   forces destroyed  a  Shebaab vehicle-borne  ',
#  'by   Grooverider from   the   album Mysteries ',
#  'which  are  often arranged in  conspicuous clusters,   are  lecideine, ',
#  'only   colored   student to  attend, and   therefore is   often assumed to  be   attending  ',
#  'at  least  as  perceived  by  critic and  fellow editor Otto  Penzler,   was Svengali-like:  ',
#  'Fash   coach Junel   Baculi   now   match  former ',
#  'film  [3] Retrieved  2010-03-11.  "Bath  Movie  Map"   (PDF).  Visitbath.co.uk.  p. 3.  ',
#  'that  explores  gay  marriage and  the   meaning  of',
#  'attention. By 1907  the  zouave uniforms   had been   replaced by   khaki  drill  for',
#  'of  the   subgenital plate with   his  phallomere.   The  ',
#  'devices  (IUDs),  are  underused  in the   United   States.  Increasing  use  of  ',
#  'Dudley  Bowhay   Nowell   (tenor  banjo),   "Evil"  John   Gieves Watson,  Biff   Harrison,  ',
#  'Srinagarindra  the  90th Anniversary  of   BMA  Medical  College  ',
#  'year, Catherine  II   took  a  trip   to the  ',
#  'in  1962   and   1963,   becoming a   leader   of   the centre  for   innovation  in  ',
#  'He   composed   his  first   song in  1973,  titled  "Este  tiempo  feliz" (This  happy  ',
#  'Olympics in Montreal,  Twombly  broke a   major story  exposing Russian   cheating   at  ',
#  'North,  and   Pacific   South   regions.   The Omaha Kings FC,   Sunflower State',
#  'her  artillery   director was removed.In   1939,  the',
#  '2003.   26  February - Victorian   MP and former Olympic skier,   Kirstie Marshall, is  ',
#  'It   was located  5   km (3.1  mi)   east  of  the   city  centre  on the hill of   Lasname. ',
#  '2007  and in  2009  to   European  Parliament.  Film   Roman',
#  'well  as  other   exams   worldwide. Previous year  question   papers   are  to  assess  ',
#  'Higher Executive  Officer,  Department   for  National  Savings.  Alice  ',
#  'was  $30,823   and   the  median income ',
#  'the residence. He was also priest  ',
#  'psychology,  mysticism,  history,  and English  literature,  always  avoiding',
#  'to Blake  to  the   Crown.   Lord   Nicholls  said the   following.  Breach of   trust',
#  'California  - Santa Barbara.   Kennedy, John F. (April  4,  1963). "Letter   to   the  ',
#  "in the   Seven   Years' War  (17561763), known  ",
#  '6,  1990, federal judge Harold   H.   Greene sentenced  Laura Whitehorn  and Linda  Evans ',
#  "Karlshamn,   at  the southern  part of   Sweden.   Kreativum's   Portal   Antony Passage ",
#  'giant   slalom,   super   G, downhill and',
#  '"the   stores   are  all closing  and   Daley   is   dozing". Following  Daley\'s death,',
#  'December  27,  2008.   Fox  Reality Channel  Reality  Awards MyNetworkTV',
#  'inch   (1999, Studio !K7)  "The   Love & Dope  & etc.  Dream  Suite"  CD/12   inch   (2001,',
#  'al-Shebaab  terrorists   detonated   a car  bomb  outside  ',
#  'Jones,   85, ALP  politician 23   August  Jack  Dyer,   89, Australian rules   football',
#  'were  first released  on   May 14,   2008, to  The   National  Archives  by the  Ministry ',
#  'it was  confirmed   that   1700 Burundian  peacekeepers',
#  'in   the  1960s.   In  2018  lifts  were   also   installed.Fast ',
#  'same section.  The house appears to   have ',
#  'the   Charvel  brand.  In  1980  he also  ',
#  'with an  understorey   of  ferns  and mosses.  They may   also  contain   eucalypt trees',
#  'Andrew Fotheringham,   of   Dandenong,  Victoria.  For  service  to  the  local government ',
#  'Burleigh  Taylor, Senior Scientific Officer, Department  of  Transport.   Glenys Mary',
#  'a  toxic   heavy  metal which  cycles   through   the   atmosphere, water  and   soil',
#  'of   additional returns  per  annum far  outweigh   the  additional  ',
#  'heavenly  signs proclaiming the return of   Christ.  As  for the  social  barriers,  ',
#  "of the   artist's   use of  symbolic  minute   detail  and Rubenesque ",
#  'The  eastern part of  the   Central   Highlands   referred   to  as  the   East Central  ',
#  'where to  start.   Thankfully,  there  are  many  preventative ',
#  'Slack.  Most   of   the developers  are   also on  Twitter.',
#  '978-1-904130-22-2.   Bill  Henderson,  ed. (2004).  The  Pushcart Prize  Xxviii   2004:  ',
#  'comes under   the  authority   of   The Adjutant   General  (TAG)  of Alabama.   The ASDF  ',
#  "world's  largest   stage   at the  Reno  Hilton.   In   September   2005,  Gold released",
#  'Dragoon Guards. ',
#  'and  the  dialogues and  ',
#  'they   were   not  connected  to   they  ',
#  'England.   Gerald   Bernard Kaufman,  MP, Minister  of  State,  Department  of  Industry.',
#  'And  So It  Goes by   Linda Ellerbee, and  ',
#  'Stanford,  convinced  Bechtolsheim  along   with  Scott  McNealy to',
#  'to   Ecuador)   Odontoglossum  cristatum   Lindl.  in G.Bentham   1845  :   Comb-Like',
#  'or  unusual features,  does  not   conform  to any  presently  known',
#  "camp  when   the zombies   attacked, and Lori   didn't do  much   to   make her   husband ",
#  'that surround it hanging   in   thick   festoons',
#  'the southeastern  part   of   the Montes Cordillera range, near  the   southwest  limb  ',
#  'reissued  on   LP  and  CD (These  ',
#  'the   first  permanent   theatre  in Finland,   the  first   years  after  its foundation  ',
#  'cows,   making  charcoal,  assisting   on   the   family   farm,  ',
#  'existing campuses located  in   the northern  beaches region.   The   College  caters  ',
#  'being   infected   with smallpox and  sets   in motion  a   citywide  quarantine to contain ',
#  'his  compositions  have a seriousness of   purposefar   from  the   frivolity suggested ',
#  'The   Jay Treaty convinced Paris   that  the  United   States was   no longer   a   friend.',
#  'Charles Gilbertson,  Assistant   Accountant   and   Comptroller   General,  Board of',
#  'Hawkins   who assumed  the surname of  Magill.   The  ',
#  'both the  Lehigh   and   the Pennsylvania   Railroad,   and  ',
#  "County   Durham, Women's  Royal   Voluntary  Service.  Stanley Halsall,   Constable, Cheshire",
#  'and   delivering many lectures on   this   topic.   She  worked as  a professor at   the  ',
#  'Francis  McAuliffe, Superintendent   3rd  Class.   Jack  McNeill, Superintendent  3rd ',
#  "fourth.   Chelsea's 11   draw   with Everton   sees  them",
#  'house dating   from 1838.  Its   origins   are  older ',
#  'to   serve.  In 1990 he  published his autobiography, ',
#  'musical  career  (19922002), 883   released   six  studio  albums,  released   over 25  ',
#  'the  tower was  originally the Rooftop  Restaurant,  which   was  open to   the  public  ',
#  'coal to  it.  The   Morupule  mine  exports   coal  to   Zimbabwe, Zambia  and  the  ',
#  'within Presbyterianism in   the   United  States and in particular  with Federal  Vision',
#  '5  October The   2003  NRL grand final  is   won   by the Penrith Panthers, who   defeated ',
#  "Minister,   Tony Abbott,   unveils   the   Government's  medical  indemnity   insurance",
#  'be positively  identified  as  a   familiar ',
#  'and  equipment   were   brought   in from  Wally  Heider  Studios in Los Angeles, including',
#  'in   all   its diverse  variety. The  Hindu',
#  'is   one   of   the most   successful   artists in   Ghana,  with  his  music   being ',
#  'the Football  Federation   of   Kosovo.   On  6 February',
#  'coast   run (the   first run  in  over   2  ',
#  'outstanding  sprinter-miler   Chief   Singer  and   he   went on   to  sire  several  ',
#  'is  a very  old village ashore  the   lake',
#  'or attempt   to   find   another path.  For  example,  ',
#  'River  to   Port Phillip.Janet   Templeton  (c. 1790-1857)   had brought her   eight  ',
#  'were  suspended  on   2   March 2018,',
#  'viewers, but received generally   negative reviews   from  critics.   The   series  ran ',
#  'in   about 1858,   during   the  Kansas   territorial   period. The  term  was used to  ',
#  'this class built as  flotilla leaders   by J I Thornycroft of   Woolston, Hampshire  to',
#  'ForceReginald James   Douglass, Superintendent   1st Class. Maxwell   Alexander   Fyffe,  ',
#  'Kim Baryluk  (1990present) (all recordings)   Nancy   Reinhold   (19902002)   (vocals  ',
#  "later   evolved   into the  current NCAA  women's",
#  'Peter Le  Cheminant, KCB, DFC. Military DivisionRoyal   NavySurgeon  ',
#  'is placed   into  a chip   reader   device connected  to a   USB  or   serial   port of',
#  'home  near Rockhampton.   Leonard  John   Fraser  ',
#  'mol%  of   [(dppf)Ni(cinnamyl)Cl)]  ',
#  'Pollard Harding, Chief   Education Officer, Buckinghamshire   County   Council.   Wilfrid  ',
#  'on   Namespace instances:   RDFLib graphs   also   override  __iter__   in   order  to ',
#  'play  in   2008. On August  8,   2008,   the  Aztex announced  2008  PDL  Goalkeeper ',
#  'to   My   Love   (Palo Alto,  1982)   For Every Heart   (TBA &  Tapes,  1984)  Ballerina  ',
#  'endorsed  Stupich.  Second ballot: David   Vickers   308  William   Stewart King   263',
#  'is  a   species   of  cicada   in the family Cicadidae.   It  is found  in   Central America ',
#  'in 15   games,  starting   12 at   center and at  both   guard spots   throughout   the  ',
#  'food for the  infants as well   as helping   the  father watch   for predators.The  pygmy ',
#  'retained   their seats. They  faced the ',
#  'two,  the   "Upper   Well"  and ',
#  'towards that object.   This   is  what  Mead means by ',
#  'the   Line of   Control"  relating to the incident. The Indian envoy   at  UN   Syed Akbaruddin',
#  'reactive   current   of   the  positive sequence  of   the   fundamental)  A   variety  ',
#  'in   South  Africa since   before  1860.The   opening  of   bilateral relations was  strongly ',
#  "about 17% of  the  studio's animation staff,   a loss   that   delayed the  release  of",
#  'Peters,  Gerhard;  Woolley, John   T.   "John F.  Kennedy:  "Executive  ',
#  'Equal  Employment Opportunity  Commission  ruled   that   companies  that provided   prescription ',
#  "The  greatest impact of  France's  ties to   the ",
#  'remembered   that  some cashiers cages  had  been built',
#  'of Austria   in   1615, support  for the  colony  was  discontinued  and the  colonists ',
#  'son  of Steve Irwin  11   January  Maurice Gibb,  53,  Bee   Gee   20 January   John ',
#  "under   AMISOM's  allowance   budget.  It   is  believed that the  Ethiopian  military's ",
#  'high-altitude  grassland, broken  in places  by rocky outcrops.  The northern slope  ',
#  'He   faced  Alexandre   Pantoja in   his  debut  ',
#  'in  Mudubugu,   Burundi. SPMAGTF-12 has  also  sent  its trainers   to Djibouti, another  ',
#  "from Sears   Holdings into   Seritage Growth Properties   in 2015.  Dick's opened October ",
#  'In   the   interim   period,   advances   in infusable vinylester   resin   chemistry ',
#  '(Inview   Technology Ltd   or  simply Inview)  is a   UK-based   digital  ',
#  "the  infant  asylum,   where   Abigail Rushman's  child ",
#  'keep.  Without   optimum   water   conditions,   they are susceptible  to  bacterial  ',
#  '"A Hard   Day\'s Night"   did  not   appear in  true stereo  in the   US until the 1982',
#  "previously held.   By 1708 he was   organist   of  St  John's,  Hackney   in   London, ",
#  'after Milan,   Italy.  He   lived   in   Nashville,',
#  'grey   duiker,   mountain  reedbuck,   grey rhebuck and   steenbok. Also   occurring ',
#  '"great   band and their   singer  Jack   is  a  wonder"   when sharing   the   video for  ',
#  'II,   and   ED III for  the ancient  Near ',
#  'Mitchell. ',
#  'and  parliamentary service.   Lyndon  Raymond  Dadswell,   of Paddington,  New   South  ',
#  '(in   English).  TRANS: Internet-Zeitschrift  fr   Kulturwissenschaften.   Research  Institute',
#  'Florence Jean  "Flo"  Castleberry (Diane  Ladd). ',
#  'in   the highlands   of   the   Sierra   Madre   del ',
#  'fundamentally based   indices   experience most of  their turnover  in   large,   liquid',
#  'Air  Force (RAF) reconnaissance   aircraft   returning   from a  mission   in France or',
#  'Council Resolution  1720   at   Wikisource   Text  of the Resolution  at undocs.org  ',
#  'John Cabot had already  explored   Labrador   to   the ',
#  'Bagnall  Ltd.  For services to Export.  Mervyn   Victor Osmond, lately Secretary,   Council',
#  'vote   will determine   the  successor to',
#  '(2012). His  string   arrangements   can   be  heard  on   tracks   from artists  including',
#  "recovered  it,  Papierwaite attempted to use Maximus'  ",
#  'to  the   needs of   the Muslim Ummah   in ',
#  "The agreement   is designed to generate  greater use  of  the  Park's historical,  cultural  ",
#  'spoke of  her interest in   the ocean   and climate   change, which  motivated her   in  ',
#  '(30.7   sq   mi).   The town   is   230 metres  (750  ft)   high, on a hill   that was ',
#  "classes  for St.   Ronan's  young  ladies almost ",
#  'the time;  two  other convoys lost  ships after  dispersal.  In May   1941   Enchantress',
#  'the exact card   list   for the   set.  The   company   announced   the set   had   234',
#  'based  largely   on the   collection   of   the  former   Brockham   Museum   (relocated ',
#  'Niyonguruza,  from   Burundi. Also, one of the',
#  'Empty Streets,   was released as a  digital  download  on',
#  'of the  interstitial  retinol binding  protein nuclear   gene   (IRBP)   in   three marmoset  ',
#  'and   claw.   There   are large   spurs  behind each',
#  'Air  Force   Volunteer Reserve (Training   Branch).  Flight   Lieutenant  George David',
#  'DivisionJean   Phyllis Mary   Austin, of Pymble, New  South  Wales. For service  in  ',
#  'greatest  mystery   editor  who  ever lived,  Joan Kahn. She   painstakingly  worked ',
#  '0.9%  American Indian,   0.3% Asian,   0.1% black or  ',
#  'said that four   Indian soldiers  including  an army   major  were killed in  Keri   sector ',
#  'preselected intervals.   The  results   showed   that   chromic   acid anodizing   with ',
#  'season,   102nd  consecutive   season  in   the  OTP Bank',
#  'ACS is also a  member organisation   of the  Federation of ',
#  'portmannii  Bockemhl,  1988 (Colombia, Ecuador,   Peru) Odontoglossum   portmannii   subsp.  ',
#  'automated   testing   tool, with  support  for   functional  testing, regression  testing, ',
#  'before the male, sometimes  with  a few   steps to  one  side and then the other.   In  ',
#  'Mark  McGowan  called  on   Scaffidi to ',
#  'Championship   Wrestling. In 1970  Milano wrestled  for   the  World  Wide Wrestling  ',
#  'Legal   Aid   Centre   (LAC)   Moot  Court  Society  (MCS)  Debating  Society  (DEBSOC) ',
#  "The  response further  noted that efforts,   like   SETI and NASA's Kepler space  telescope  ",
#  'its counterpart  about  the  unprovoked   firing   by   Pakistani troops   to  provide ',
#  'City  10 in the   all-Second   Division final  of ',
#  'Knows Everything"   and "Take  You Into  ',
#  'first  album,   Colorado,   was   credited to Neil Young   and Crazy  Horse   and   released',
#  'acquainted with   the  giants   of   the   modern ',
#  'built.   The  mall now  hosts   144  ',
#  'an   Indian   army Junior commissioned   officer  (JCO)',
#  'is  a  former   Australian  rules   footballer  who played  for   the  Sydney Swans  ',
#  'the Spanish  Renaissance,  Spanish  Gothic,   and   Spanish   Baroque periods;   for ',
#  'the upgrade   works. Since   the May   2018  timetable   change,  the   station was  ',
#  'chart. It  took  the top   position   on   the   Top   R&B  Albums   chart  for 14 weeks. ',
#  'the   number  and   the sound level  of  vocalizations. Pygmy marmosets can also  be  ',
#  'of   these   two   to  the  University of   Technology,  Sydney, the ',
#  'explosions  in  Mogadishu killed  at   least   38',
#  'will  read   the  bearing  to your destination,  regardless  of',
#  'artists   from  the Venetian Renaissance   include Giorgione, Titian, Giovanni Bellini,',
#  "reported  to  be   injured as  result   of  Pakistan's army shelling   of  hamlets and ",
#  'species of   beetle  in the   family  Cerambycidae. It   was  described  by Stephan von ',
#  'wounded   when a   car   bomb ',
#  'Luminosity Gaming.   Magisk   eventually transferred to Dignitas,  replacing   Jesper  ',
#  'place  as   non-conformists,   then Zionism   would obviously  die  ',
#  "1174 the village was   called Eya, meaning   'island',   though  by   1192  it   had  ",
#  'is a  species  of  crown   jellyfish found   off the   southeastern   coast of Brazil.',
#  'means  big cheeks. Almeida   competes for  the  Checkmat  team.  Almeida  was  born  and  ',
#  '12   Cromer High  School   co-educational;   Year   7   -',
#  'New  York. He  was   born on  January ',
#  "the  museums exhibits.   This   was  the  museum's fifth  move   in 52   years   of  ",
#  'Scotty   Wilbanks,  Regie  Hamm  /  Produced',
#  'Bowl   XVII MVP   with   the  Washington Redskins;   Pro   Football  Hall   of   Famer',
#  'Street built   here   on which  Roseneath   was  built   and   another   block  in  the  ',
#  'is   a   small  genus  of New   World monkey   native',
#  'Burnell  ',
#  '1953 to  1969.   In September   1960,  ',
#  'other  record   of   that year.   They   were  ',
#  'tape   as   the  original United  Artists  LP  ',
#  'Beattie   Opposition Leader   Mike Horan   (until  4  February),   then',
#  "of   the film's   concepts  later   went into  the French   animated   film  Mune:  Guardian  ",
#  "that   took  place  after  King's  assassination. Displeased with  what   he   saw as",
#  'toxic  compound  gets  biomagnified   through  marine  food  chains  to   the   top  ',
#  'antibiotic resistant  bacteria. In December 2016 Madlen   Davies   working   with   the',
#  'Burroughes has been   responsible  for   a   number   of technology   innovations,',
#  'end  of   September.   They  lead   Manchester',
#  'Valley"  came   to fruition after   a  Gastr   del   Sol  show   in  Atlanta,  where Grubbs  ',
#  'for  suicide prevention. Richie   Adubato (born',
#  'part   of the  Tirunelveli Lok  Sabha   constituency.  "Statistical reports  of   assembly  ',
#  'a   German sculptor  and medallist.  He   was  born  in Augsburg, Germany  and according ',
#  "and  vocalist,  He   sings   baritone  for the  men's  chorus Sonoma   Chanson,  was ",
#  'of them were   found   reduced   to ',
#  'in   skirmishing   along the  Line   of  Control.On   17 ',
#  'the   MS Paint  Adventures forums.  Fox',
#  'His  World (Vendome,   1989, ISBN   978-0-86565-115-9)  Blown Away: The',
#  'on  5   October 2010. Retrieved  8  July  2010.  "The Big Sky"  is a  song  by English',
#  'HMS   Keppel was  a   Thornycroft   type  flotilla  leader built  ',
#  'and  public  utilities   (electricity,  substations,  natural   gas,  water, sewage, ',
#  'in disorders of  sex  development  including   congenital  adrenal  hyperplasia  and  ',
#  'teams of the countries   of  the',
#  'the   Eisner Award   for  Best   Writer/Artist for 1989, and  was nominated   for  Harvey ',
#  'by the  town   for the ',
#  'the  Illinois  Senate.  That  year  Gormley and  Jezierny  were   successfully   reelected ',
#  'sheriff.  Lillian  wanted   more  than  this   for  her  son, telling  a friend,  "I ',
#  "Rupp's   Kentucky   Wildcats  and  Ray",
#  ':   coated. According   to Hans  Rber  "Enzyklopdie   der Rassehunde"   T.I   33%  of ',
#  'at  a   Tesco  supermarket on the  Castle  Vale   estate  in Birmingham.   Hickey and ',
#  'British  neoconservatives,  New   Statesman,   12   May 2003. Category:UK   - Neocon Europe, ',
#  'of  the  tribe who   created   Benjamin Walker,  his name  is   spelt   Bianjiamian  ',
#  'disrupt the   Peruvian general  elections. San   Miguel  del Ene attack Mohd  Hashim ',
#  'Hynek,   a trained astronomer   who   served  as   a  scientific   advisor for  Project ',
#  'In   1995  she was   the  guest   curator  ',
#  'the 69th  meeting   of   the  Peace   and   Security   Council.On  22 January  2007  Malawi ',
#  'Buffalo,  and  Detroit  experienced   during the  ',
#  'own daughter.   He was charmed   by her vivacity   and   physical vigourshe   delighted ',
#  "while  staying  at   her  father's   ranch  ",
#  'the Little   Rock   metropolitan area  with  southern   gospel  and   talk  programming. ',
#  'DNA or   RNA.   Although the   Feulgen stain for DNA  was not   sensitive  enough to stain',
#  'troops were on  their  way  back into   the Frankish realm. The  battle  in   824,   sometimes ',
#  'politician   Amin  Amidu   Sulemana,  Ghanaian   diplomat   and   politician Emmanuel ',
#  'Steve  Biko. The   first healthcare   institution  for  Pretoria,   was ',
#  'Galloway,   of   Forrest,  Australian  Capital Territory.  For service  to   music.  ',
#  'on June  26,   2007,   as  a pinch   hitter  in   the   10th inning   to key  the Dodgers  ',
#  'joining the singer for Sleeps   with  Angels  (1994),  Broken   Arrow (1996), the live',
#  'of  which are  scriptural and   others of  which  are   from   16th-century Lutheran ',
#  "the   studio's second   feature,   The   Land  Before  Time.   Again,  Amblin  and  Spielberg",
#  '(Kolkata),   the   son of   Dr.  Simeon ',
#  'Works  by   or about   Edward Naylor   at   Internet Archive Vinatamm is the  name of',
#  'Major   Dudley Clive  Lever   (14703), Royal   Australian Electrical  and Mechanical  ',
#  '1329 ',
#  'Bush  gives  his  address to   Australian  Parliament   on  22   October,  while',
#  'Wilfrid Airey at ESPNcricinfo   Gustavo  Torrijos (born   23  ',
#  'as having rich color schemes that  create   a  "warm   glow" and ',
#  'pumps  and churns   so  suggestively;  it  somehow   evokes the   blues  of the  otherwise ',
#  'Y.  Masasa, who   had been captured   in  September 2015 when   the AMISOM   base  at  ',
#  'professional  astronomers or  other   telescope users  (such   as  missile trackers  or ',
#  'Margaret Alton,   of Albany Creek, Queensland.  For services   as   postmistress.   Edgar ',
#  'keen  on   several  sports   as  a   child.  He   represented  the ',
#  'of  Oulujrvi   in the  town of   Kajaani, Finland.   The   village  has   a  population  ',
#  "of Periodical   Literature,   the   Leibniz-Bibliographie,  The  Philosopher's  Index,",
#  "of Gray's Anatomy (1918)   Diagram at   UMich Plymouth   Civic Centre  is a  former  ",
#  'asked,  Mr Fox,   will   you   state the   facts   of   Payne v  Cave?,   then,  Mr  Rawle',
#  'When Young returned   to   his  solo   album  ',
#  'City.26 April 1975: Derby   County   lie two  ',
#  'first  working day   thereafter,   the ',
#  'petals  are   free  or  sometimes  fused',
#  'best."   The   Newsweek   review stated  without ',
#  'the   1997 WTA  Tour. It   was   the',
#  'of   Melbourne,  west  of   the Alpine  areas  ',
#  'M943983M.  Chief   Ordnance   Electrical   Artificer  Douglas  Michael Beck, M857494F.',
#  'Price, OBE,   of Red   Hill, Victoria.   For',
#  'career in   July   2013, upon   compiling an  impressive  112  record during his amateur  ',
#  'of  CTU,   the theology faculty, and representatives  of   the   Archdiocese  ',
#  'Senior  Scientific  Officer, British   Antarctic Survey,  Natural Environment Research ',
#  'Wales.   It   was  first  published in   1949,  ',
#  'These lists   are   updated through  the  end   of',
#  'Tri-State  Racetrack and Gaming   Center   before   the  addition  of  ',
#  'by, and  takes   its  name from,  the Morimont family,   vassals of   the  Ferrettes ',
#  "output,  and  while the   next   feature   after   Bluth's  departure, ",
#  'Newsweek   and  many  other   media   outlets. The Bureau working   with   the   Sunday  ',
#  'the School   of   Fine Arts of San  ',
#  'matrimony  as   it  is   actually   practiced by   friends,  his  raucously affectionate  ',
#  'is considering additional   policies   to  enhance  competitiveness, including a new ',
#  'them   equal   rights with   regard  to workplace  health  and safety, social security ',
#  'individual,   but  is  emergent  in   "the   dynamic,   ongoing  social   process"  that',
#  '(2012)  directed   by  Kat  Burns. Vichada  (2012) directed by Kat',
#  'Law College   Dehradun/Department   of   Law-  ',
#  'for   the German   Black Falcon  team.   The list   below  contains   the confirmed  teams',
#  'cortical  neurons  and   is  a   glycogen  metabolism disorder.  Lafora   disease,   is ',
#  'of  the   American  and Canadian  ',
#  'services  to the   education of  the  physically   handicapped. Philippa   Winifred  ',
#  "of  the President's Advisory   Commission on  Narcotic   and  Drug Abuse -  April  4,",
#  'Boy.   The game was   also   ported  to the  ',
#  'to   1935,   and from 1968  to 2015.   Created   by the   British  North  America  Act',
#  'retirement in  2011.  The  youngest   son,   William ',
#  'officer   of CPD   taking  bribes. ',
#  'Irish   Minister  for Foreign   Affairs,   promised  South African  President ',
#  'at  the  Crystal  Cup in  Anchorage, ',
#  'Life,   Vol.   18,   No.   5.   Cooper,  William  John.  1933. The Office  of Education.  ',
#  "spy who  holds  important  information about   Kilbaba's   next  ",
#  'geography,  more than 70%  of   the ',
#  'postseason  as   the  No.  1 team, the  Bearcats  earn a',
#  'reelected   mayor  for a  (then-record)  sixth term in  1975. Shortly  after  2:00  p.m.  ',
#  'is  covered by  some 150   privately  owned farms. Steenkampsberg, Northern Cape List  ',
# ...
#  'a   BMG  import   in 2005. ',
#  'patients.   Since  the   discovery  of Lafora Disease  in  early ',
#  'native of  New   Rochelle,   who  became   a sea   captain   at eighteen   years of age.',
#  'Transparency   International. It  has   the   fourth highest gross   national income ',
#  'station and various  public departments  are  located here.   It  is the business   hub  ',
#  'shore, home   to Eastlands Shopping   Centre, now  the biggest  in the  state.   The  ',
#  'object   crash in   the  area.  Police  officers,   and possibly military personnel,  ',
#  "Jersey.  He received  a   master's",
#  '1995  (number 81);  and   Uncut, in  2016  (number 149).  It   was   a  featured   album',
#  'Glamour  Model,  in which  she   explains   why   she ',
#  'the   coat of  arms  in   the  1990s   with a more  simplified   version.  A   silhouette ',
#  'and  animators. Some senior   staff at  ',
#  'married   to  Anna   Walker, granddaughter of   founder ',
#  'Holland  Thomas,   a white  man who  had been adopted   into the  Cherokee   tribe,  the  ',
#  'electrons), adsorption   processes  (binding to   solid   particles),   methylation  and ',
#  'Cleopas   Primary  School,  Liverpool.  John   Frederick  Tilly,   Technical  Manager, ',
#  'a representative  publication  utilizing   these  salts.  Empirically,   these  precatalysts',
#  'for developing  the   games Undertale  and   Deltarune. He   has  also   composed music',
#  'released   a  live   LP  from   the bands   1999 lineup  featuring   Jack  White.   The ',
#  'extremely small, given  the distances involved." Following the  ',
#  'pore, which lies on the   ventral abdomen, is  thus   exposed,  the male inserts  his ',
#  "a violation of  a   party's contractual   rights   should attract a  lesser  degree  of",
#  'permanent   residency but   had  to   wait   to  gain  full  citizenship before he  could  ',
#  'is  the  largest   shopping  mall in  the state ',
#  'received nine honorary degrees  during   his career,   including',
#  'probably  the  main reason  why   Gustav  Larson  asked ',
#  'structure.  He  was   awarded   the   2006  Albert   Lasker Special  ',
#  'hired as the coach   of   the basketball team and',
#  'Bob  Doidge  engineer  Andrew   Gilchrist  engineer Mark   Hallman   engineer  Marty',
#  'Bassett, Post Instructor, No.  14  Group  (Winchester),  Royal  Observer   Corps.   Rose ',
#  "registration  number  4907.  It   is an example  of Francis  Petre's domestic   work,  ",
#  'on  the point, and  he   named  it   after  his  ancestor,   the   Duc   de  Maximilien ',
#  "explores the country's  technological  and   scientific   progress  and  it  contains ",
#  'to the   see of  Iesi  to   deal',
#  'and in 1968 joined the Revolutionary   Communist  League,  ',
#  'dismissed this  statement,  saying   "facts  ',
#  'and 1938-19, the  Sussex Senior Cup  in  1935-36  and  1937-38   and the  Amateur  Football  ',
#  'of distress, tantrums   prove an effective   and achievable   method of alerting parents ',
#  'representing the 81   provinces  of  the  Philippines.  ',
#  'psychic powers  and  the   Toybox  to   summon  the   Elder  God,  Yog-Soggoth,  and ',
#  'books.google.com/books?id=9',
#  'have resulted  in many   new   pieces dedicated  to  him.  Bok   has been   professor ',
#  'as   observers with the land   and   naval  forces   of   Russia   and  ',
#  'out  Axis  forces,   but   few   Latin American   nations   sent  troops  to  Europe.',
#  'being in   control.   Many people  who   suffer  with  addiction,  either   refuse to',
#  'stage  of East Prussia   in   the  second   half   of  ',
#  'to  an  explosive  climax. Milo   Gibson ',
#  'charity,  receiving good   reviews from local  newspapers,  but   he  felt he   was  not',
#  'his Twitter account he  had   hope he would complete the  rest of Deltarune,   saying: ',
#  "have   come   to agree   that   this   'thing' cannot  be scientifically   proven. Scientists ",
#  'building   erected   by the   college on the ',
#  'ink-and-paint  work had  to  be  farmed   out to  Hungarian animation   studio  Reflex  ',
#  'Walter Afanasieff 3:20 "The Way"/"Solitaire"  was  released  ',
#  'of   Arts,   Master  of Arts,  and   Doctor   of Psychology.   The College of Science ',
#  'so closely  related;  they have   been   reclassified   in   the  orders  Podicipediformes  ',
#  'Jew,   wherever  he  might be,  would   be   ennobled.  The sordid ',
#  '1974.   She also   attended the Sorbonne. She  lives in',
#  'release  in   fake stereo,  despite the   availability of  several tracks  with official ',
#  'be   either of   :   URIRef, Blank  Node,   Literal,  ',
#  'lifeblood   of   these   services. In   the 1950s  Blake deliberately ',
#  'Series ....   Tim  Derby   (1991)   Young Charlie  ',
#  'in  architectural engineering in   1923.  Completed  in 1930,',
#  'Ex  Control  Balad,   are after that  in  Government hands.  20   October   At  least',
#  'to the   community in  Lincoln. Richard   John Eden,   Head   of Energy  Research Group, ',
#  'State   Archives Nickel(II) precatalysts are   a type   of  ',
#  'Education (TAFE), were  invited to  be   part of  this ',
#  'claimed that   1 of its civilian   was  killed  ',
#  'for   the   Scots  Dumpy, which  is  usually   cuckoo,  black   or   white;   the breed ',
#  'an interest   in the  band, securing   funding for   a new album.  With Harlow  serving',
#  'Jazz, 2005)   When You   Know (Blue   Note, 2008) Beautiful   Life   (Concord,   2013) ',
#  'by  Larry Fonacier  in   the  last quarter  ',
#  '44Second  ballot:  Thomas R.   Berger  411 Dave ',
#  'Yohan  Ramasundarah,  2018 2019 Anthony Wong, 2016   2017  Brenda  Aynsley,  2014   2016  ',
#  'they   changed  substantially. To  be  grandfathered,   a ',
#  'or Nittur  Srinivasa  Rao (24  August   1903 12  August  ',
#  'Battalion   Kenya   Rifles,  was  overrun by  ',
#  "Iron Works   at  Brierley  Hill  under the supervision of   the estate's  mineral   agent,",
#  'also   being   advanced by   the   Diocese of Springfield,  Illinois,   where  Tolton  ',
#  'ground   maintenance,   particularly on   the   main stand, ',
#  'the early-modern Italian  court".   Born   at   the Florentine  court  in   March   1553,  ',
#  'old   photographs.  Redcliffe   Press.  ISBN  1-872971-61-X. Janes, Rowland  (ed)   (1987).',
#  'industry  and  community.State  of  Western   AustraliaFlora   McCrae',
#  'that   lasted  until   late  1962.   One  of ',
#  'good   writer. Clark  attended MIT briefly,  declined program completion, and  went  ',
#  'of  Epping North, New  South   Wales. For  public  service to  the   CSIRO.   Eric   Harold ',
#  'owned the  Brockwell   estate   at  ',
#  'undergraduates  courses   was  Mathematical  and   Data  Processing.  Today   IMESA have  ',
#  'account  of profit,  were appropriate. I  cannot join   your Lordships ',
#  "'C'   Company and  then finally  'A' Company.  Later in the  deployment,  as  the other ",
#  'from   2001   to  2003 and  was   a Republican.',
#  'state.  Officially,  Chicago   has  a  "weak-mayor" system,  in   which  most  of  the ',
#  'Earlville, Queensland.  For service to  industry.  Godfrey Alan  Letts,   of  Batchelor,  ',
#  'Animal  Place (Grass Valley,   CA)  won   first   prize in   the   Best  Sanctuary  category,  ',
#  'concern   of  the  stimuli of gestures   and social objects with  rich  meanings, rather  ',
#  'offshoot of  the eclectic  Bonzo   Dog  Doo-Dah   Band,   and   shared  many   similarities  ',
#  'among  genes  and proteins in  cells,  with  a   focus  on   cancer drug  discovery.GNS  ',
#  'Mayer Foundation. The   restored   print  was  screened   in March 2017   at the   Festival  ',
#  '1990.  Locey enrolled at   Oregon  State  in 1915  and   played   competitive   football ',
#  'by typing  executable  English into   browsers.  This   contrasts  with ',
#  '-',
#  'founded   on 31   January 1881  with   Anna',
#  'Batuhka  before   going  to the  front approaching ',
#  'Inventions   of  Dr.   Lewis   Harvey Spencer   Lewis  in   a  San   Francisco  Buddhist ',
#  'in 24   hours.   The  following day,',
#  'headquartered  in   Chicago,  Illinois.  Just   one',
#  'Operator,  Ministry of  Agriculture,   Fisheries   & Food.  John   Scott,  Sergeant,',
#  'fair,   a   maximum  of  455   camping   places  are available on  the  south  side  of',
#  'Down  Fast   line  was  demolished  during  resignalling   operations in  1977.   The ',
#  'lime for  use   in mortar   and  cement,   and remaining  on  site are  several  kilns, ',
#  'storyline  and the   various  possibilities  of  interaction   with non-player',
#  'seven people. On  29 September Somali',
#  'as  a result of  the   heat   wave in Chicago in  1897. After a  funeral   which   included  ',
#  'Encyclopedia.com. ',
#  'has the  ability   to act   as   a  storage   closet   for  mercury. According  to  a  ',
#  'as a  new opportunity as  it  "really ',
#  'Shield   happened. We were watching  CNN  at  three   in   the afternoon   and  all of  ',
#  'controlling   seizures  through   anti-epileptic   and  anti-convulsant  medications.',
#  "elements from  'D'   Company  deployed first,  arriving  ahead   of the  take   over time ",
#  'They   invited him   to  stay   in  the Jesuit',
#  "assistant at St.  John's   since 1958,   given  the   difficult   task   to   follow ",
#  'Rogers. For services  to  the   Scout  Association  in  Hertfordshire. Maurice  ',
#  'Cathedral.On  16  March 2016   it was  announced',
#  'from 36 to   39   which  includes BaseFM.  Subscription  television in   New Zealand ',
#  'Rhynchostele,  Rossioglossum   and   Ticoglossum.   This new   genera occurred  outside',
#  'The  Westminster  Presbyterian Church   in  the United  States,',
#  'Howard Roberts,   OBE, of  Balwyn. For services to  the   handicapped. ',
#  'that the flying  objects   might   be a  celestial  ',
#  'relations with the  Kennedy  family  and that   he  declined an   offer to   vote   against ',
#  'commendation from Ronald   Reagan   for  helping  to   build ',
#  'respectively. Local   lottery   winner   Mark  Gardiner,  previously involved   at   local',
#  'on   this issue:   "While some  Americans  may not   feel  ',
#  'was selected for the  Outfest 2013 Screenwriters  Lab  for  her  feature   screenplay ',
#  'not then called   "Roseneath" but "St.   Ronans", ',
#  'to win  the   Royal Lodge Stakes).In  the  Solario Stakes  ',
#  '2007:   Transport  Systems   2011:  Between  the Spirit ',
#  'bishopric at  Constantine)   suffragan   Roman Catholic  Diocese of   OranExempt(Immediately ',
#  'Sherman Booth  and  broke  into a Milwaukee   jail to free escaped  slave Joshua   Glover.  ',
#  'An appeal in  March   1989 was  ',
#  'Minneapolis   Lakers   was   one of  them,  ',
#  'Peak, a  mountain   range   in  Phoenix,  Arizona"   in ',
#  'Defense  Support  to   Civil   Authorities missions   to mitigate and/or   alleviate ',
#  'Empire  under   Charles   V,   and especially   its   control',
#  'at the newly established   International  School   for  Advanced Studies   (SISSA), where',
#  'Register   of   Historic  Places   in 1978.  Oleszewski,  ',
#  'Johns  as   Buckridge  Kay   Walsh   as Matron  Norman   Bird  ',
#  'unexplained  clinical signs   of  iron  deficiency anemia.  List   of ',
#  'Sign in  1948   produced a   highly classified finding  (see   Estimate  of   the   Situation)  ',
#  'remain in   contention.   Tottenham Hotspur   have slipped back into the  relegation ',
#  'Micheli Borzi,   of   Mareeba.  For  services to  local   government  and the   community. ',
#  'seasons,  turned to Brian  Clough   in   hope  of turning  the  ',
#  'Odontoglossum  (Colombia  to  Ecuador)(sometimes   terrestrial)   Odontoglossum constrictum ',
#  'George   Washington University  in   Public  Policy   in  2004. He   went on to serve',
#  'Exchange  programme   in  nursing with   West Chester   University,   Pennsylvania, ',
#  'geographic   range,  in  the form of  extent  of  occurrence,  is  estimated to   be  ',
#  'John  Anderson   Strong,  MBE,   Professor of  Medicine,  University of   Edinburgh. ',
#  'be   inactivated   by   phosphorylation  at  various  amino  acid residues  by  many ',
#  'J.   Daley bio at the  Chicago  7   Trial   Page',
#  'pursued  a career in   law.  Until 1920  he   was  a judge  in Wolkersdorf  im  Weinviertel,  ',
#  '1842,   and  then  to  Eaton  County',
#  'Than   Life". The  Toledo  Blade.  November 9,   1969. Kahn, ',
#  'a   village   and   civil  parish on  the   River Avon  in southern   Wiltshire,  England,  ',
#  'WrexhamWelsh  Cup   finalist:   1891 International   career details  ',
#  'summoning   words himself and then  tasked the  ',
#  '6:11  "Bumpy\'s   Blues"   4:04  "Shaft  Strikes Again"  3:04   "Do Your  Thing"  (Vocal  ',
#  'Bryn Terfel,  Paul  Groves and',
#  'this   possible.   Working   under Goldcrest  also   afforded director  ',
#  'Society  Johannes  Kelpius  Jean  de   Labadie  Labadists   George   Rapp Schwarzenau ',
#  'to  win in  twelve  starts. His  best   performances  were',
#  'John  Alexander McConnell, Chief   Superintendent, Royal   Ulster  Constabulary. Evelyn  ',
#  'was founded  in  1893',
#  'to  be  a  young  ',
#  'his   1926  address  on  the   origin of  the   Jayhawk,  Blackmar   specifically  referenced  ',
#  'so.   An  award   of damages,  assessed  by  reference   to financial loss,  will  not  ',
#  'a  deal  that  sent  pitcher Jon  Garland  to the   Dodgers. The   deal  was   held up ',
#  'recommended  its immediate classification  as  Critically   Endangered due ',
#  'message has passed,   and how  to control the  amount   of   bandwidth   consumed  to',
#  'Zionist   Organization, and   later  the  first  President   of   Israel. Samuel was then',
#  'of  SH   46.   On   March   8,   1926,   SH  108   was   extended north to   Strawn. ',
#  'of   New  South  WalesKenneth  Leo   Brodziak. For services to   the  theatre.  ',
#  'radioing  Morgan   Jones   that   Atlanta   is ',
#  'controversy   following the  publication of   his third ',
#  "had   been   seconded   to  the  BBC   by  the Bureau.  Stickler's broadcast  report included",
#  "wireless   networks  even  when they   aren't  ",
#  'Berliet  vehicles.  From  1927 to 1931,   the  ',
#  'of   the  Committee for  Economic  Development   of  ',
#  'of a   potential merger  between the   company ',
#  'of  the tribal  name Hernar is an island   in   ygarden   municipality  in   Vestland  ',
#  'James Yagi  as Dr.   Paul Nakamura   The',
#  "Stuff   depicts  Ham's spaceflight,   as do  the   subsequent  film   and TV adaptations. ",
#  'two   of  those for   female  inmates. Black River  Correctional  Center (capacity',
#  'boat.   Interceptor  -  designed  for  patrol  and  fast  interception. Sports RHIB -  ',
#  'Woodall   Naylor (February 9, 1867 May  7, 1934) was an   English organist  and  composer.',
#  'C.   Drury   School for  the   Deaf is   a provincial  school  in  Milton,  Ontario, Canada ',
#  'order  to  exhibit   simple  graph behaviour,  such   as   simple   graph merging  via',
#  'Museum Bern. Kleine  Mitteilungen.  2(3): 1-8  Gofas,  S.;   Le Renard, J.;  Bouchet,  ',
#  'transportation infrastructure  (interstates,  railroads, intermodal  ports,  airports, ',
#  'version  was  produced  and   directed  by   Cecil   B.',
#  'the   Church   of Scotland  (164548)   and   the colonies ',
#  'and   exploitation   by  the pet trade.  Kryt,   Jeremy  (Winter   2012).',
#  'may  be   so reduced  in width and  ',
#  "Antinori   and another associate   of Leonora's, ",
#  'cafe   and   hotel   on Maka al  Mukarama  Street. On   20 September   a   Somali   intelligence',
#  'Rosemary   Ainsworth, Inspector  Higher Grade, Board  of Inland  Revenue.  Derek  John',
#  'into Somalia   to   attack   Al-Shabaab. On  12   November, the  ',
#  "the  game's  greatest   professional  players  (including  Clyde Lovellette,  Wilt  Chamberlain,  ",
#  'Riverside and  San Bernardino  Counties  in the   Southern   California.  ',
#  'with standing water   for  more   than  three months of  the   year. This   monkey has  ',
#  'RAN   Reserve.Australian ArmyMajor   Kevin ',
#  'unincorporated  portions  of  the  township. ',
#  ...]

# %% [markdown]
# # Split data #

# %%
train_split = int(0.9 * len(dataset))
val_split = int(train_split + 0.09 * len(dataset))
# test_split = int(train_split + 0.1 * len(dataset))

train_labels = dataset[:train_split]
val_labels = dataset[train_split:val_split]
test_labels = dataset[val_split:]

# val_labels = dataset[train_split:val_split]
# test_labels = dataset[val_split:]

print('Len train: ' + str(len(train_labels)))
print('Len val: ' + str(len(val_labels)))
print('Len test: ' + str(len(test_labels)))
# Out:
# Len train: 31311
# Len val: 3131
# Len test: 349

# %% [markdown]
# # Model #

# %%
timesteps = 256

width = 4096
height = 64

max_label_len = longest_label + 2
max_label_len
# Out:
# 117

# %%
from tensorflow.keras import applications, backend as K
from tensorflow.keras import models, losses, optimizers, Model, utils
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, MaxPooling2D, Dropout
from tensorflow.keras.layers import Flatten, Dense, Lambda, Reshape, Bidirectional, LSTM, GRU
from tensorflow.keras.layers import Activation, add, Concatenate, Attention, Embedding

def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

def build_model(num_classes=94, timesteps=256, max_label_len=max_label_len, input_shape=(4096, 64, 1), training=False):
    inputs = Input(name='the_inputs', shape=input_shape, dtype='float32')
    
    # Convolution layer (VGG)
    inner = Conv2D(32, (3, 3), padding='same', name='conv1-1', kernel_initializer='he_normal')(inputs)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(32, (3, 3), padding='same', name='conv1-2', kernel_initializer='he_normal')(inputs)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(2, 2), name='max1')(inner)

    inner = Conv2D(64, (3, 3), padding='same', name='conv2-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(64, (3, 3), padding='same', name='conv2-2', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(2, 2), name='max2')(inner)

    inner = Conv2D(128, (3, 3), padding='same', name='conv3-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(128, (3, 3), padding='same', name='conv3-2', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(4, 2), name='max3')(inner)

    inner = Conv2D(256, (3, 3), padding='same', name='conv4-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(256, (3, 3), padding='same', name='conv4-2')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(1, 2), name='max4')(inner)

    inner = Conv2D(512, (2, 2), padding='same', kernel_initializer='he_normal', name='con5-1')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(512, (2, 2), padding='same', kernel_initializer='he_normal', name='con5-2')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)

    # CNN to RNN
    inner = Reshape(target_shape=((timesteps, 2048)), name='reshape')(inner)
    inner = Dense(128, activation='relu', kernel_initializer='he_normal', name='dense1')(inner)
    inner = Dropout(0.2)(inner)

    # RNN
    # encoder
    encoder = Bidirectional(LSTM(256, return_sequences=True, return_state=True))
    encoder_outputs, forward_h, forward_c, backward_h, backward_c = encoder(inner)
    state_h = Concatenate()([forward_h, backward_h])
    state_c = Concatenate()([forward_c, backward_c])
    encoder_states = [state_h, state_c]

    # decoder
    decoder_lstm = LSTM(512, return_sequences=True, return_state=True)
    decoder_outputs, _, _ = decoder_lstm(inner, initial_state=encoder_states)
    
    attention = Attention()([encoder_outputs, decoder_outputs])
    attention = Dropout(0.2)(attention)
    # RNN output -> character activations:
    outer = Dense(num_classes + 1, kernel_initializer='he_normal', name='dense2')(attention)
    y_pred = Activation('softmax', name='softmax')(outer)

    labels = Input(name='the_labels', shape=[max_label_len], dtype='float32')
    input_length = Input(name='input_length', shape=[1], dtype='int64')
    label_length = Input(name='label_length', shape=[1], dtype='int64')

    # Keras doesn't currently support loss funcs with extra parameters
    # so CTC loss is implemented in a lambda layer
    loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([y_pred, labels, input_length, label_length]) #(None, 1)
    
    y_func = K.function([inputs], [y_pred])
    if training:
        return Model(inputs=[inputs, labels, input_length, label_length], outputs=loss_out), y_func
    else:
        return Model(inputs=[inputs], outputs=y_pred)

# %%
model, y_func = build_model(timesteps=timesteps, max_label_len=max_label_len, training=True)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_inputs (InputLayer)         [(None, 4096, 64, 1) 0
# __________________________________________________________________________________________________
# conv1-2 (Conv2D)                (None, 4096, 64, 32) 320         the_inputs[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 4096, 64, 32) 128         conv1-2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 4096, 64, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max1 (MaxPooling2D)             (None, 2048, 32, 32) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2-1 (Conv2D)                (None, 2048, 32, 64) 18496       max1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 2048, 32, 64) 256         conv2-1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 2048, 32, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2-2 (Conv2D)                (None, 2048, 32, 64) 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 2048, 32, 64) 256         conv2-2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 2048, 32, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max2 (MaxPooling2D)             (None, 1024, 16, 64) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv3-1 (Conv2D)                (None, 1024, 16, 128 73856       max2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1024, 16, 128 512         conv3-1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1024, 16, 128 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv3-2 (Conv2D)                (None, 1024, 16, 128 147584      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 1024, 16, 128 512         conv3-2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1024, 16, 128 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max3 (MaxPooling2D)             (None, 256, 8, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv4-1 (Conv2D)                (None, 256, 8, 256)  295168      max3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 256, 8, 256)  1024        conv4-1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 256, 8, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv4-2 (Conv2D)                (None, 256, 8, 256)  590080      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 256, 8, 256)  1024        conv4-2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 256, 8, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max4 (MaxPooling2D)             (None, 256, 4, 256)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# con5-1 (Conv2D)                 (None, 256, 4, 512)  524800      max4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 256, 4, 512)  2048        con5-1[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256, 4, 512)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# con5-2 (Conv2D)                 (None, 256, 4, 512)  1049088     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 256, 4, 512)  2048        con5-2[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 256, 4, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 256, 2048)    0           activation_9[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 256, 128)     262272      reshape[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256, 128)     0           dense1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   [(None, 256, 512), ( 788480      dropout[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 512)          0           bidirectional[0][1]
#                                                                  bidirectional[0][3]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 512)          0           bidirectional[0][2]
#                                                                  bidirectional[0][4]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 256, 512), ( 1312768     dropout[0][0]
#                                                                  concatenate[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# attention (Attention)           (None, 256, 512)     0           bidirectional[0][0]
#                                                                  lstm_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 512)     0           attention[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 256, 95)      48735       dropout_1[0][0]
# __________________________________________________________________________________________________
# softmax (Activation)            (None, 256, 95)      0           dense2[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         [(None, 117)]        0
# __________________________________________________________________________________________________
# input_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# label_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           softmax[0][0]
#                                                                  the_labels[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 5,156,383
# Trainable params: 5,152,479
# Non-trainable params: 3,904
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

plot_model(model=model, show_shapes=True)

# %% [markdown]
# # Data generator #

# %%
import itertools

def return_classes(string):
    text = [' '] + list(string) + [' ']
    classes = [data.index(x) if x in data else 1 for x in text]
    return np.asarray(classes)

def return_text(classes):
    text = ''
    for c in classes:
        if 0 <= c < len(data) and c != 1:
            text += data[c]
    return text

def decode_batch(out, callback=False):
    ret = []
    for i in range(out.shape[0]):
        out_best = list(np.argmax(out[i, 2:], 1))
        out_best2 = [k for k, g in itertools.groupby(out_best)]
        outstr = return_text(out_best2)
        if callback:
            print(f'{out_best} -> {outstr}')
        ret.append(outstr)
    return ret

def gen_text_image(text, padding=16):
    font = random.choice(fonts)
    font_size = random.randrange(30, 61)
    fnt = ImageFont.truetype(font, font_size)
    width, _ = fnt.getsize(text)
    img = Image.new('L', (width + (padding + 1) * 2, 64), color=255)
    d = ImageDraw.Draw(img)

    if 'calibri' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'verdana' in font:
        d.text((padding + 2,-8), text, font=fnt, fill=0)
    elif 'constan' in font:
        d.text((padding + 2,0), text, font=fnt, fill=0)
    elif 'corbel' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'consola' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'cour' in font:
        d.text((padding + 2,-4), text, font=fnt, fill=0)
    elif 'tahoma' in font:
        d.text((padding + 2,-8), text, font=fnt, fill=0)
    else:
        d.text((padding + 2,-6), text, font=fnt, fill=0)
        
    image = np.array(img)
    image = add_salt_and_pepper(image, 0.2)
    image = otsu_thresholding(image)
    image = inverse(image)
    image = (image / 255.) * 2. - 1.
    return image

def inverse(image):
    return cv2.bitwise_not(image)

def add_salt_and_pepper(image, amount):
    output = np.copy(np.array(image))
    # add salt
    nb_salt = np.ceil(amount * output.size * 0.5)
    coords = [np.random.randint(0, i - 1, int(nb_salt)) for i in output.shape]
    output[coords] = random.randint(50,200)

    # add pepper
    nb_pepper = np.ceil(amount * output.size * 0.5)
    coords = [np.random.randint(0, i - 1, int(nb_pepper)) for i in output.shape]
    output[coords] = random.randint(0,100)
    return np.asarray(Image.fromarray(output))

# %%
class TextImageGenerator:
    def __init__(self, labels, img_w=4096, img_h=64,
                 batch_size=64, timesteps=500, training=True, max_text_len=max_label_len):
        self.dim = (img_w, img_h, 1)
        self.batch_size = batch_size
        self.max_text_len = max_text_len
        self.labels = labels
        self.n = len(self.labels)
        self.indexes = list(range(self.n))
        self.training = training
        self.cur_index = 0
        
    def next_sample(self):
        self.cur_index += 1
        if self.cur_index >= self.n:
            self.cur_index = 0
            random.shuffle(self.indexes)
        return self.labels[self.indexes[self.cur_index]]
            
    
    def next_batch(self):
        while True:
            X = np.zeros((self.batch_size, *self.dim))
            y = np.zeros((self.batch_size, self.max_text_len), dtype=int)
            input_length = np.full((self.batch_size, 1), timesteps, dtype=np.float32)
            label_length = np.zeros((self.batch_size, 1), dtype=np.float32)
            
            for i in range(self.batch_size):
                label = self.next_sample()
                # Store sample
                image = np.swapaxes(gen_text_image(label), 0, 1)
                image = np.expand_dims(image, -1)
                X[i, 0:image.shape[0], :] = image

                # Store class
                label_classes = return_classes(label)
                y[i, :len(label_classes)] = label_classes
                label_length[i] = len(label_classes)

            inputs = {
                'the_inputs': X,  # (bs, 4096, 64, 1)
                'the_labels': y,  # (bs, 51)
                'input_length': input_length,  # (bs, 1)
                'label_length': label_length  # (bs, 1)
            }
            outputs = {'ctc': np.zeros([self.batch_size])}   # (bs, 1)
            yield (inputs, outputs)

# %% [markdown]
# # Callbacks #

# %%
import editdistance
from datetime import datetime
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.callbacks import TensorBoard, ReduceLROnPlateau, Callback

class VizCallback(Callback):
    def __init__(self, y_func, text_img_gen, text_size, num_display_words=10):
        self.y_func = y_func
        self.text_img_gen = text_img_gen
        self.num_display_words = num_display_words
        self.text_size = text_size

    def show_edit_distance(self, num):
        num_left = num
        mean_norm_ed = 0.0
        mean_ed = 0.0
        while num_left > 0:
            word_batch = next(self.text_img_gen.next_batch())[0]
            num_proc = min(word_batch['the_inputs'].shape[0], num_left)
            # predict
            inputs = word_batch['the_inputs'][0:num_proc]
            pred = self.y_func([inputs])[0]
            decoded_res = decode_batch(pred)
            # label
            labels = word_batch['the_labels'][:num_proc].astype(np.int32)
            labels = [return_text(label) for label in labels]
            
            for j in range(num_proc):
                edit_dist = editdistance.eval(decoded_res[j], labels[j])
                mean_ed += float(edit_dist)
                mean_norm_ed += float(edit_dist) / len(labels[j])

            num_left -= num_proc
        mean_norm_ed = mean_norm_ed / num
        mean_ed = mean_ed / num
        print('\nOut of %d samples: \nMean edit distance:'
              '%.3f \nMean normalized edit distance: %0.3f \n'
              % (num, mean_ed, mean_norm_ed))

    def on_epoch_end(self, epoch, logs={}):
        batch = next(self.text_img_gen.next_batch())[0]
        inputs = batch['the_inputs'][:self.num_display_words]
        labels = batch['the_labels'][:self.num_display_words].astype(np.int32)
        labels = [return_text(label) for label in labels]
         
        pred = self.y_func([inputs])[0]
        pred_texts = decode_batch(pred)
        
        for i in range(min(self.num_display_words, len(inputs))):
            print("label: {} - predict: {}".format(labels[i], pred_texts[i]))

        self.show_edit_distance(self.text_size)

# %%
batch_size = 8
train_generator = TextImageGenerator(train_labels, training=True, batch_size=batch_size)
val_generator = TextImageGenerator(val_labels, training=False, batch_size=batch_size)
test_generator = TextImageGenerator(test_labels, training=False, batch_size=batch_size)

log_dir = "logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
output_dir = './models/VGG with Attention/'
weight_path = f'{output_dir}/ocr_model_{datetime.now().strftime("%Y%m%d-%H%M%S")}' + '_epoch_{epoch:02d}.h5'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

tensorboard = TensorBoard(log_dir=log_dir)
checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
vis = VizCallback(y_func, test_generator, len(test_labels))
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='min')

initial_learning_rate = 0.001
epochs = 100

callbacks = [early_stop, tensorboard, vis, checkpoint]
# callbacks = [early_stop, tensorboard, vis]
# callbacks = [early_stop, tensorboard, vis, LearningRateScheduler(lr_time_based_decay, verbose=1)]

# %% [markdown]
# # Training #

# %%
def train(callbacks, batch_size, epochs, initial_epoch=0):
    print('Training process starting...')
    H = model.fit(train_generator.next_batch(),
                  steps_per_epoch=train_len//batch_size,
                  validation_data=val_generator.next_batch(),
                  validation_steps=val_len//batch_size,
                  epochs=epochs, 
                  initial_epoch=initial_epoch,
                  callbacks=callbacks,
                  verbose=1)
    return H

# %%
train_len = len(train_labels)
val_len = len(val_labels)

# %%
from tensorflow.keras import optimizers

opt = optimizers.Adam(learning_rate=initial_learning_rate)

# %%
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer='adam')

train(callbacks, batch_size, epochs)
# Out:
# Training process starting...
# <ipython-input-14-ed1a10243b71>:66: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   output[coords] = random.randint(50,200)
# <ipython-input-14-ed1a10243b71>:71: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   output[coords] = random.randint(0,100)
# Epoch 1/100
#    6/3913 [..............................] - ETA: 43:54 - loss: 598.2991WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1279s vs `on_train_batch_end` time: 0.4558s). Check your callbacks.
# 3913/3913 [==============================] - 1009s 255ms/step - loss: 219.7034 - val_loss: 133.5027
# label:  to the   church.  Summerfield   United  Methodist Church   of  Milwaukee,                                            - predict: to the   burh.  ommer ed   Coirad  Cehodst ohurph  o  aue.
# label:  agree  that it   was Gaius Lusiuss   advances   towards  Trebonius   that   led   to his                             - predict: agre  that it   was Caius Cusiuas   adcances   tocards  fPrebomlus   that   fd   to hls
# label:  remarking  that  they were   very  impressive given  the  limitations  of  Game   Boy                                - predict: memoaring   ton   te   sgn  osias sien  the   otationa  of   aoe   o
# label:  to   Rupp  Arena,  Hamburg  Shopping Center,   Lansdowne   Shoppes, and  Southland  Drive.                           - predict: to   Com  Cremna.  Cambuc  Cnoppindg Centen  Cansdocm   Choppes. and  Couhand  Crtve.
# label:  office   in  1982.Rosny   Park   has grown   dramatically                                                            - predict: of foe    an   e
# label:  the  State. In terms of   section   65J(2)(a)   and   (b), an   emoluments attachment                                - predict: the  tate. fn terms of   sectiom   11 Tal   and   bh. an   emoluments atapnnemt
# label:  victory.  The squadron   re-equipped with   new  Royal   Aircraft   Factory   SE.5as,                                - predict:  onen. oepaonmn  eaoraan  pre  ond   e
# label:  could  publish  past   examination   papers   in   the form  of  books,  the  publisher                              - predict:  ould  oublsn  past  cnminarion  popers
#
# Out of 349 samples:
# Mean edit distance:74.126
# Mean normalized edit distance: 0.634
#
#
# Epoch 00001: val_loss improved from inf to 133.50275, saving model to ./models/VGG with Attention\ocr_model_20210922-080734_epoch_01.h5
# Epoch 2/100
# 3913/3913 [==============================] - 986s 252ms/step - loss: 118.7838 - val_loss: 90.8427
# label:  population were below  the poverty   line, including                                                                 - predict: population were below  the powerty   fne  iuiun
# label:  CU Amiga praised   the  Amiga version's improved   graphics   and sound,   particularly                              - predict: C1 Amiga praised   the  Amiga wersion's improved   graphics   and sound,   particularly
# label:  details of his  lyrics.  It   was titled   Stessa Storia, Stesso   Posto,   Stesso  Bar.                             - predict: details of his  lyrics,  Ii   was titled   Stessa Storia, Stesso   Posto.   Stesso  Bar,
# label:  same  period. He  had a strong base   of support  in   Chicago's  Irish   Catholic  community                        - predict: same  period, He   had a strong base   of support  in   Chicago's  lrish   Catholic  community
# label:  Reading's early   life. He was   probably                                                                            - predict: Peading"s early   1ife. He was   probably
# label:  from  the album 2001   "Back  At  You" by   Mobb   Deep  from   the album   Sunset  Park                             - predict: from  the album 9001   Cack  At  Mou by   Mobb   Bep  from   the album   Sunsrt  Park
# label:  to   his  death.  Agent Matheson, his   assistant  agent  Williams  (Clarke)   and   the                             - predict: to   his  death.  dgent Matheson, his   asistant  agent  Wiliams  (CSlarke)   and   the
# label:  in acting   towards   objects  humans simultaneously  take  the   perspectives of   others                           - predict: in acting   towards   obiects  humans simultaneously  take  the   perspectives of   others
#
# Out of 349 samples:
# Mean edit distance:66.989
# Mean normalized edit distance: 0.573
#
#
# Epoch 00002: val_loss improved from 133.50275 to 90.84271, saving model to ./models/VGG with Attention\ocr_model_20210922-080734_epoch_02.h5
# Epoch 3/100
# 3913/3913 [==============================] - 987s 252ms/step - loss: 98.4087 - val_loss: 75.4387
# label:  the district wherein  the   employer  (that  is,  the   garnishee) resides, carries on                               - predict: the district wherein  the   employer  Chat  is,  the   ganishee) resides, caries on
# label:  but,   given   his  public  standing, McGovern   later  made   amends   by putting Daley                             - predict: but,   ven   his  public  sanding, McJovern   later  made   amends   by puting Daley
# label:  base  in   Mogadishu   was   targeted  by  a  car   bomb,  killing   three   and wounding                            - predict: bas   n   Moab  the annwunwundng
# label:  night  time  harvesting and published   ground-breaking                                                              - predict: night  time  harvesting and published   groundbreaking
# label:  "Wondering". The album   was  produced by Matt   Mahaffey   and   self-released.   A Cursive                         - predict:  onderiny Th rdcredaa e eie
# label:  [carried]  by six   brothers  and  four                                                                              - predict: tarced bs  otesn
# label:  Executive,   Oxfordshire   County  Council. William   Whitehill   Brown,   Treasury                                  - predict: Cxecutive,  Oxfordshire   County Counci. Wllam   Whitehil  roun,   Teasury
# label:  on  Higher Education granted   William   Paterson university status  in                                              - predict: on  Migher Education granted   Milliam   Paterson university status  in
#
# Out of 349 samples:
# Mean edit distance:65.639
# Mean normalized edit distance: 0.561
#
#
# Epoch 00003: val_loss improved from 90.84271 to 75.43867, saving model to ./models/VGG with Attention\ocr_model_20210922-080734_epoch_03.h5
# Epoch 4/100
# 3913/3913 [==============================] - 988s 253ms/step - loss: 83.6261 - val_loss: 163.5987
# label:  and  in 1889, to Frances, youngest   daughter                                                                        - predict: p  n
# label:  - Banjo,  Biff  Harrison   - Clarinet,  Saxophone,   Jim   "Golden  Boots"  Chambers                                 - predict: rm eme     hobe
# label:  1   (Lt. Col.  Abubakar  Conteh),   850   strong,  deployed                                                          - predict:     br oteh.
# label:  Austria and  she  "later  worked  on   Miocene  forms, and  made  a  major   contribution                            - predict: Austrioand she  leter worked  on   Moenme forms and mde a  m ior   conhrtbuton
# label:  of  up to $8,000  beginning on January  1,  2012, for the purchase  of new plug-in  electric                         - predict: of pto80.000  be inning n nuay  ,   forthe urchse  ofnewpuin  ertic
# label:  on  Higher Education granted   William   Paterson university status  in                                              - predict: m mpmm Phm Pppn
# label:  in Lancaster  County  after  a group   of  Mennonites   came                                                         - predict: Ln Camrater  County  after   a rpop   of  Mnmpmtea   cm
# label:  three-member  board  of trustees,   who  are   elected in November  of   odd-numbered                                - predict:  hremempber Mord  re  ho r  eo ebroF oAnumbere
#
# Out of 349 samples:
# Mean edit distance:81.358
# Mean normalized edit distance: 0.695
#
#
# Epoch 00004: val_loss did not improve from 75.43867
# Epoch 5/100
# 3913/3913 [==============================] - 989s 253ms/step - loss: 93.9824 - val_loss: 64.8262
# label:  Mendhar  and  another   was injured in  firing                                                                       - predict:  wendhar  and  another   was iniured in  firing
# label:  midstems that  are   glabrous   to subglabrous. The  leaf  blade  is round to   pentagonal                           - predict: midstmes  hattag gulaubgabrousThelad  ia n pnognal
# label:  Revolutionary   War. France successfully  contributed in expelling                                                   - predict: euoaoyaanacesicestcontbueinpeling
# label:  government  programmes.  In   early  1990,   the government  changed its   official                                  - predict: enrern rrn naty290tegornenchang dfial
# label:  and  understanding towards   those   who   suffer with   addiction, and  to realize                                  - predict: and   ndrsadnsufwith adiconandrealive
# label:  and  I  hold  my   hands   up."   He  later  added:  "I  went  into   my office on  the                              - predict: and o tonds pf adeedeninhe
# label:  member   of  her   high school  band, and                                                                            - predict: member   of  her   high school  band, and
# label:  hunting behavior  to still   prey,  and                                                                              - predict: htunting behatototiland
# Out of 349 samples:
# Mean edit distance:65.777
# Mean normalized edit distance: 0.562
#
#
# Epoch 00005: val_loss improved from 75.43867 to 64.82618, saving model to ./models/VGG with Attention\ocr_model_20210922-080734_epoch_05.h5
# Epoch 6/100
# 3913/3913 [==============================] - 989s 253ms/step - loss: 78.4370 - val_loss: 95.8924
# label:  Hemingway's  The  Snows   of   Kilimanjaro, The  Killers,                                                            - predict: Heningwapy.  The  S hows   o   inia, The  Allsi
# label:  Free scores  by John   Reading  in   the   Choral Public  Domain Library  (ChoralWiki)                               - predict: Frescore  y  hholb Doman h hh
# label:  but,   given   his  public  standing, McGovern   later  made   amends   by putting Daley                             - predict: bt,   phn  h n Hedoen   tad   n deDae
# label:  years,   Pezzali  was held back for  one  year because he did not   achieve the  required                            - predict: yeara,   Pexqal  was held back for  one  year becauae he did not   ahieve the reauired
# label:  Sowerby parliamentary constituency   until the 1983 general  election,  when the constituency                        - predict: Sowerby  parliaentary  constitiuency   until the J998 general  election  when  the constituency
# label:  Somali   Civil   War.At that   time,   the  Islamic  Courts   Union   (ICU)   had  not                               - predict: Somal   Cil   Mar.At that   time,   the  Iadamic  Courts   Union   (CU)   had  not
# label:  is  a   resident  of  North  Adelaide,  South Australia.   On  Australia   Day   2016,                               - predict: i  a   eident  of Morh  Adelaide,  South Australa   Bn  Australa  Bay   Do
# label:  on  Higher Education granted   William   Paterson university status  in                                              - predict: on   igr  Auraton granre   dlin   ern nt in
#
# Out of 349 samples:
# Mean edit distance:65.819
# Mean normalized edit distance: 0.563
#
#
# Epoch 00006: val_loss did not improve from 64.82618
# Epoch 7/100
# 3913/3913 [==============================] - 989s 253ms/step - loss: 89.4323 - val_loss: 82.8172
# label:  A  California  League   affiliate of the   Anaheim Angels).  He  held   that  job  through                           - predict: 4  Cafri   aa   t
# label:  Early Years with Billy  Childs   and   Snooky   Young Grammy                                                         - predict: Early Years with Bily  Childs   and  Snoky  Young Grammy
# label:  of  graphite, later   useful   in  the   context   of   graphene.  After  serving as a                               - predict: of  graphite, later useful   in  the   contet   of   grphene.  After  serving as a
# label:  a white  beard   and   wild   hair, and  proclaims  to   have   a  list of   New York                                - predict:  whie   be  a  a aa
# label:  Revolutionary   War. France successfully  contributed in expelling                                                   - predict: Revolutionary  War. France sucesfiuly  contrbuted in expeling
# label:  Battalion (Maj. Adolphe   Kaguruka). Deployed   May  2016,   replacing  31  Battalion?                               - predict: Batalion 1Mai. Adolphe   Kaguruka). Deployed  May  2016,   replaing  31  Battalione
# label:  the defense   research   and development  community.   It  also urged   the   DCI   to                               - predict: the defense  research   and development  community.  It  also urged   the  DCI   to
# label:  a non-governmental organization  (NGO)   with the  World  Health                                                     - predict:  mongovermental. orgn  n wth the  Korld  Health
#
# Out of 349 samples:
# Mean edit distance:70.026
# Mean normalized edit distance: 0.599
#
#
# Epoch 00007: val_loss did not improve from 64.82618
# Epoch 8/100
# 3913/3913 [==============================] - 989s 253ms/step - loss: 79.5496 - val_loss: 77.2022
# label:  Brazil  began   receiving from the   Aeronautical   Documentation  and                                               - predict: rat  ben revi
# label:  a  degree  in  sociology  from   Georgia.  After                                                                     - predict:   degre in oyorr
# label:  the  CPDM won all 180 seats  with  a 90.3%                                                                           - predict: he  CPDM won al 80seats  with a03M
# label:  - Banjo,  Biff  Harrison   - Clarinet,  Saxophone,   Jim   "Golden  Boots"  Chambers                                 - predict: - Banjo, Bif " Harison   Carinet, Saxophone,  (im   Clen  Bos' " Cambers
# label:  James   Cheetham, ED,   (267669), Royal  Australian   Infantry  (Australian  Citizens                                - predict: Jlames   Cheetham, ED,   207669), Royal  Australian   Infantry  Australian  CGtizens
# label:  Tunisia  which   obtained the  release from                                                                          - predict: unisa  wich obhaiaier
# label:  Free scores  by John   Reading  in   the   Choral Public  Domain Library  (ChoralWiki)                               - predict: Fre scores  by John   Reading in  the  ChraPubic Domain Lhry CoralNi)
# label:  of   her   predecessor,   Peter   Nattrass,   who   served   a  record   twelve                                      - predict: f   her   predecessor.   Peter   Natras,   who   served   a  record   welve
#
# Out of 349 samples:
# Mean edit distance:63.470
# Mean normalized edit distance: 0.542
#
#
# Epoch 00008: val_loss did not improve from 64.82618
# Epoch 9/100
# 3913/3913 [==============================] - 990s 253ms/step - loss: 81.2403 - val_loss: 64.3287
# label:  on  23 August   1949,  the   eldest of  three boys, in   Chingford, London,   England.                               - predict: n   1ug, h el hr be,nn Engn
# label:  and the   average family  size   was   3.05. In   the town,   the   population  was                                  - predict: and the   average family   size   was   3.OS. In   the town,   the   population  was
# label:  contraception   (a                                                                                                   - predict: ontracepton  2a
# label:  In 1991   the company   name   changed                                                                               - predict: In 99   the company   name   changed
# label:  of  late   one  sadly  looked   out                                                                                  - predict: of  lat   one   aky  lakd  out
# label:  on  Higher Education granted   William   Paterson university status  in                                              - predict: on  Higher Education granted   William   Paterson university status  in
# label:  a  frequency   on  the multiplex R3                                                                                  - predict:   freguey    oipeutiple
# label:  Hemingway's  The  Snows   of   Kilimanjaro, The  Killers,                                                            - predict: Hemingway's  The  Snows of  KiKimiara, The  Kilers
#
# Out of 349 samples:
# Mean edit distance:63.444
# Mean normalized edit distance: 0.542
#
#
# Epoch 00009: val_loss improved from 64.82618 to 64.32867, saving model to ./models/VGG with Attention\ocr_model_20210922-080734_epoch_09.h5
# Epoch 10/100
# 3913/3913 [==============================] - 989s 253ms/step - loss: 83.5342 - val_loss: 78.5973
# label:  Warrant Officer   Class 2   Peter Anthony  Broome,   Intelligence  Corps.   Major                                    - predict: Warant Ofice  Class 2   Peter Anthony  Brome,   Ineliene Cors.  Majo
# label:  (Ecuador)   Odontoglossum   kraenzlinii  O'Brien,  1893   (O. naevium O.  schillerianum)                             - predict: Ecuador)  OBntgosum kaenl   r   B
# label:  1918  Labour   Party  candidate   in   Battersea   in   the   election  after  World                                 - predict: pd labour Pary candecndte  ndte
# label:  Conference  Men's  Basketball Hall of  Honor.Following                                                               - predict: ontence   Mens  askbl  Hoo
# label:  details of his  lyrics.  It   was titled   Stessa Storia, Stesso   Posto,   Stesso  Bar.                             - predict: etlals  is wics   was  Sasd  Ss
# label:  Awards,  awarded   in 2010,  were   given   by   the                                                                 - predict: wards,  award   in 2010, we  ive   b
# label:  "the generalized  other" the   individual understands  what   kind                                                   - predict: "the generalized   other" the   individual understands  what   kind
# label:  agree  that it   was Gaius Lusiuss   advances   towards  Trebonius   that   led   to his                             - predict: qare tai   was  as ass asas
# Out of 349 samples:
# Mean edit distance:66.914
# Mean normalized edit distance: 0.572
#
#
# Epoch 00010: val_loss did not improve from 64.32867
# Epoch 11/100
# 3913/3913 [==============================] - 990s 253ms/step - loss: 77.0899 - val_loss: 88.1265
# label:  on  the  MLS   opening  weekend. A fifth exhibition  match was   scheduled against the                               - predict: on  the  MiS   opeing  wend. A ithexehin match was   scheled against the
# label:  Nitrogen                                                                                                             - predict: Nitrogen
# label:  border firing in   Rajouri.On  16   July,   Indian                                                                   - predict: atd figi Aiui
# label:  to remember the previous reality  and                                                                                - predict: o remember the previous reality  and
# label:  "the generalized  other" the   individual understands  what   kind                                                   - predict: lthe generalized   other'l the   individual understands  what  kind
# label:  Thomson   and   Sony,   alongside  the   Teletext  Extra   EPG                                                       - predict: Thomson   and   Son,   aolngsde  the   Telet  Etre  EPE
# label:  friend  of Kaufman's and owner  of KC's   Paint   Shop,                                                              - predict: friend  of Kaufiman's  and owner  of KC'  Paint  Shop,
# label:  January 8, 1990 in Santos,   So  Paulo,                                                                              - predict: anuary 3, 190 in Santos,  So  Paulo,
#
# Out of 349 samples:
# Mean edit distance:63.633
# Mean normalized edit distance: 0.544
#
#
# Epoch 00011: val_loss did not improve from 64.32867
# Epoch 12/100
# 3913/3913 [==============================] - 990s 253ms/step - loss: 81.7973 - val_loss: 99.0893
# label:  In  1985, Thompson was  traded   to                                                                                  - predict: En  19256 Tomecon zeas  raded to
# label:  .pages  files elected to   include a   preview.  The  user   will   also find   a .xml                               - predict:  pages  files elcted to   include a   preview.  The  user  wil   alol find   a  Oml
# label:  the movie  Treasure   Planet. On  8 April                                                                            - predict: he movie  Treasure   Rant. On 8Apil
# label:  neighbour  of Bridgewater,   living  five  houses   away. He   was   investigated by                                 - predict: neighbour  of Bridgewater,   living  five  houses   away. te   was   investigated by
# label:  the  cups  for Corvette  and   Porsche respectively. The   other cup, for  Audi   drivers,                           - predict: the  cups  for Corvete  ad   Porsche respectively. The   other cup, for  Audi   drivrse
# label:  which  requires  to   be   filled   by a new remedy. He  accepts   that   the  term  "restitutionary                 - predict: which  requires  to  be  fild   by new remedy. He  accepts  that  the  term  "frestititionary
# label:  Holy Roman Church   during  the papacy   of  Eugene  IV.  Pope   Nicholas   V made him                               - predict: oy Roman Church   durig  thepay  of ugege N ie  ioo   mae
# label:  the   Federal Government of Somalia's  forces  in  their battle   against Al-Shabaab                                 - predict: the  Federal Government of Somalia's  frces  in  their battle  against Al-Shabaab
#
# Out of 349 samples:
# Mean edit distance:65.648
# Mean normalized edit distance: 0.561
#
#
# Epoch 00012: val_loss did not improve from 64.32867
# Epoch 13/100
# 3913/3913 [==============================] - 991s 253ms/step - loss: 86.7896 - val_loss: 53.6393
# label:  Maatschappij   De   Schelde in   Flushing. O                                                                         - predict: aschpi De Shedein Fiushig0
# label:  or   injury  flowing   from   a  cause   of action   which  had accrued before  the writ                             - predict: or  inurny  (owing   fron  a  cse  ofaction  which  thad accrued before  Ihe wri
# label:  of   Bentleigh.  For services to the   Presbyterian   Church.   Francis   John  Edwards,                             - predict: of   Benteigh.   For services to the  Presbyterian  Church.  Francis  John  Fdwards,
# label:  in 2006.   In 1990, Sister Jamie  T.                                                                                 - predict:  in 206. In 19, Sister Jamie  T.
# label:  (September 1999).  "Peter Rosei   A  Case  Study"                                                                    - predict: (September 1999).  "Peter Rosei  A  Case  Study"
# label:  the last 3040  years so   it   is not strange  that   they  might   beat  the   market.                              - predict: he ast 3040  years s   it   t sg e  tht  thyh t  ht th   kekt
# label:  New  Zealand  rifle   companies   attached  to  them   at this   time,  along  with  two                             - predict: New  Aealand  rfle   comanies   atached   to  the at t   tme, alog tih to
# label:  and  five wounded during  clashes  in  Mogadishu.  An  AMISOM tank   was  also   destroyed.                          - predict: nd ie woundeduridg  cashes in Mogadishu. An AMS0 ant waslod.
#
# Out of 349 samples:
# Mean edit distance:60.734
# Mean normalized edit distance: 0.519
#
#
# Epoch 00013: val_loss improved from 64.32867 to 53.63932, saving model to ./models/VGG with Attention\ocr_model_20210922-080734_epoch_13.h5
# Epoch 14/100
# 3913/3913 [==============================] - 990s 253ms/step - loss: 87.7304 - val_loss: 54.9358
# label:  Conference  Men's  Basketball Hall of  Honor.Following                                                               - predict: Conference  Men's  Basketbal Hal of  Honor. Folowing
# label:  district  of   Pasig   Legislative district of   Marikina The   20162018   IndiaPakistan                             - predict: district  of   Pasig   legislative district of   Marikina The   20162018   TndiaPakistan
# label:  and   play in local   parties   and  family   gatherings with  his father. In  those                                 - predict: and   play in Local   parties   and  famdiky   gatherings with  his father. In  those
# label:  "'The  Commitment' also considers important  human questions:                                                        - predict: "The  Commitment  also considers important  human guestions:
# label:  in 2006.   In 1990, Sister Jamie  T.                                                                                 - predict: n 2006.  In90, Sstr Jamie T
# label:  Don't  Love  Me  (No,  No,  No)"                                                                                     - predict: ont  Lov   Me Mo, Mo
# label:  U.S.   in December   1969,   following the  statement  by   the   government  scientist                              - predict: s  I ber  olowing the  atemnt by he oermen t
# label:  border firing in   Rajouri.On  16   July,   Indian                                                                   - predict: orde  igin   RinRaiou On 1 Luly, Indian
#
# Out of 349 samples:
# Mean edit distance:59.739
# Mean normalized edit distance: 0.511
#
#
# Epoch 00014: val_loss did not improve from 53.63932
# Epoch 15/100
# 3913/3913 [==============================] - 991s 253ms/step - loss: 69.8911 - val_loss: 53.8603
# label:  work  for the City Club   of Chicago.   Mead believed that science could  be used  to                                - predict: work  Cor the City Club   of Chicago.  Mead beieved that science could be used to
# label:  Evanston,   Illinois   and  is  interred   in   Maple  Hill Cemetery, in  Charlotte,                                 - predict: an ton. lind is intered in  Maple  il Gemeter,. in Charlote
# label:  and  five wounded during  clashes  in  Mogadishu.  An  AMISOM tank   was  also   destroyed.                          - predict: and  ive wounded during  clashes  in  Mogadishu. An  AMSMN tank   was  also   dstroyed.
# label:  Free scores  by John   Reading  in   the   Choral Public  Domain Library  (ChoralWiki)                               - predict: Ee scores  by John   Reading  in   the   Choral Public  Oomain Liborary  (ChoralWiki)
# label:  to remember the previous reality  and                                                                                - predict: o remember the poreviousreality and
# label:  in 2026 BCE. Shu-ija's successors   used the   title  of                                                             - predict: n 2026 BCEC. Shu-ija's sucesrs used the e   tile of
# label:  the  cups  for Corvette  and   Porsche respectively. The   other cup, for  Audi   drivers,                           - predict: he ps fff Coete and ancatherectey, he othe cup , or Aud dve.
# label:  image   was  the   result of   an   optical effect   called   a bokeh   which can  make                              - predict: mage   was  the   resultof  an   optcalefe   caled    h   bc ah  which ca makek
# Out of 349 samples:
# Mean edit distance:63.083
# Mean normalized edit distance: 0.539
#
#
# Epoch 00015: val_loss did not improve from 53.63932
# Epoch 16/100
# 3913/3913 [==============================] - 991s 253ms/step - loss: 56.3113 - val_loss: 83.2301
# label:  that   temporal synchrony   serves   for   dynamic coordination                                                      - predict: that  temporal synchrony  serves  for  dynamic coordination
# label:  and   development squad,  with a   view                                                                              - predict: nd  dewelopmen  snuad, wth   w
# label:  the prior season.Camilo  rebounded from a mediocre 2012   season  to   be   considered                               - predict: he ios esono miod ondes
# label:  singles independently.   For   its first  full-length   record,                                                      - predict: iglsey denty frtfr
# label:  remarking  that  they were   very  impressive given  the  limitations  of  Game   Boy                                - predict: remarking  that  they were   very  impressive given  the  limitations  of  Game   Boy
# label:  (September 1999).  "Peter Rosei   A  Case  Study"                                                                    - predict:  (September 1999) .  IPeter Rosei  A  Case  Study"
# label:  border firing in   Rajouri.On  16   July,   Indian                                                                   - predict: order frig i  RajouriOn  16 July,Indn
# label:  and  five wounded during  clashes  in  Mogadishu.  An  AMISOM tank   was  also   destroyed.                          - predict: and  five wounded during  clashes  in  Mogadishd. An   AMSOM tank   ws  also   desroyed.
#
# Out of 349 samples:
# Mean edit distance:67.304
# Mean normalized edit distance: 0.575
#
#
# Epoch 00016: val_loss did not improve from 53.63932
# Epoch 17/100
# 3913/3913 [==============================] - 991s 253ms/step - loss: 75.1159 - val_loss: 58.5325
# label:  He was   the   master   hunter (Obristjgermeister)                                                                   - predict: He was  the  master  hunter (Obristigermeister)
# label:  agree  that it   was Gaius Lusiuss   advances   towards  Trebonius   that   led   to his                             - predict: agre  that it   was Gaius Lusiuss  advances   towards  Trebonius  that  led  to his
# label:  on  the  MLS   opening  weekend. A fifth exhibition  match was   scheduled against the                               - predict: on  the  MLS  opening  wekend. A fifh exhibition  match wes  scheduled against the
# label:  Advanced   Grant  ULTRADISS 2019-2024   .  More details  of  his   current   and  past                               - predict: dvanced  Grant UL20OS 20124  .  Mre d dls f his curen an  st
# label:  Revolutionary   War. France successfully  contributed in expelling                                                   - predict: Revolutionary  War. France sucesfiuly  contributed in expelling
# label:  turned  to his  left  just  a   split   second later to  do  the same  to   Berra, completing                        - predict: turned  to his  left  just  a   slt   second later to  o  the same  to   Bera, ompletingg
# label:  of  graphite, later   useful   in  the   context   of   graphene.  After  serving as a                               - predict: f  rcetie eueuse heore of gche fe ea
# label:  in   tune  with   Durkheim   that  the  individual  is  a product   of   an   ongoing,                               - predict: n  tune  with  Durkheim  that  the  individual  is  a prduct   of  an  onoing,
#
# Out of 349 samples:
# Mean edit distance:65.527
# Mean normalized edit distance: 0.560
#
#
# Epoch 00017: val_loss did not improve from 53.63932
# Epoch 18/100
# 3913/3913 [==============================] - 991s 253ms/step - loss: 68.3985 - val_loss: 49.6429
# label:  to   his  death.  Agent Matheson, his   assistant  agent  Williams  (Clarke)   and   the                             - predict: o   his  death.  Agent Matheson, his   assistant  agent  Wiliams  (Clarke)   and  the
# label:  usually   somber with  ominous  dark   undertones and  a  raw, gritty production style                               - predict: sualy   sombewitonous drundrones and aw ity poducionsste
# label:  as  manager   by veteran   player   Johnny                                                                           - predict: as  manager  by veteran  player  Johnny
# label:  disorder  characterized   by  the presence  of   inclusion  bodies, known as   Lafora                                - predict: isorder  charactried   by  thresence ofinclusion  bodies, owa Lafra
# label:  will   he  'begged   pardon  of  the Lady   Anne'. Long   married  secondly,  Elizabeth                              - predict: ill   he   beged padpaof the ayAne ". on maried Fiabh
# label:  the district wherein  the   employer  (that  is,  the   garnishee) resides, carries on                               - predict: he dis trict wherein  the   employer  (that  is,   the  garnishe) ress, cris on
# label:  details of his  lyrics.  It   was titled   Stessa Storia, Stesso   Posto,   Stesso  Bar.                             - predict: etails of  his  lyrics. titled Ssesa Storia, Seso Pos, Bar.
# label:  Don't  Love  Me  (No,  No,  No)"                                                                                     - predict: on't  Love Me  o)  Wo,Mo)
#
# Out of 349 samples:
# Mean edit distance:64.398
# Mean normalized edit distance: 0.550
#
#
# Epoch 00018: val_loss improved from 53.63932 to 49.64288, saving model to ./models/VGG with Attention\ocr_model_20210922-080734_epoch_18.h5
# Epoch 19/100
# 3913/3913 [==============================] - 991s 253ms/step - loss: 47.9113 - val_loss: 43.4217
# label:  on  September  21,  many   local volunteers joined                                                                   - predict: nSeptemember 21, many  local wolunters joined
# label:  population were below  the poverty   line, including                                                                 - predict: opulation werebeow the poverty  line including
# label:  popular attraction   in the town   is  Royal                                                                         - predict: pular ataction in the town  is Royal
# label:  will   he  'begged   pardon  of  the Lady   Anne'. Long   married  secondly,  Elizabeth                              - predict: will  he  beged  pardon  of  the Ldy  Anel. Long maried sedcondly Elizabeth
# label:  trams (SSB).   At   the   same   time, SSB gave                                                                      - predict: rams (SB).   At thee same  time, SB gave
# label:  heavy mortars  and   machine  guns   were  used  in the   attack on  Pakistani army posts.                           - predict: heavy mortars  and  machine  guns  were  used  in the  attack on  Pakistani army posts.
# label:  CU Amiga praised   the  Amiga version's improved   graphics   and sound,   particularly                              - predict: U Amigapraised  theAmiga version's improved  grahics and sound, paricullry
# label:  in 2006.   In 1990, Sister Jamie  T.                                                                                 - predict: n 206.In 19 Sister Jlamie  .
#
# Out of 349 samples:
# Mean edit distance:59.636
# Mean normalized edit distance: 0.510
#
#
# Epoch 00019: val_loss improved from 49.64288 to 43.42165, saving model to ./models/VGG with Attention\ocr_model_20210922-080734_epoch_19.h5
# Epoch 20/100
# 3913/3913 [==============================] - 991s 253ms/step - loss: 46.1010 - val_loss: 56.5742
# label:  a  coach-house.   The cottage overlooked  the                                                                        - predict:   coach-house.   The cottage overloked   the
# label:  Hospital. Marjorie Lily  Shaw, Assistant  Catering  Adviser,  Essex  County Council.                                 - predict: Hospital.  Mariorie Lily  Shaw, Assistant  Catering  Adviser,  Esex  County Council.
# label:  killed   in   firing by   Indian   forces,  with 6  civilians  being  injured.Pakistani                              - predict: illed   in  fing by   Indian   forces, with 6  civians  bing  inured.Pakistani i
# label:  Jackson,   of  North Sydney,   New  South Wales.  For  service  to  education,  particularly                         - predict: ackson,   of  Norh Sydney,   New  Souh Wales.  For  service o  ducatio,  ptticularly
# label:  communication.  The   extreme  quiet   of this   spot                                                                - predict: communication.  The   extreme  quiet   of ths   spot
# label:  Roy Rogers   filmed  in  Trucolor.  Despite                                                                          - predict:  Roy Rogers  filmed  in  Trucolor.  Despite
# label:  in acting   towards   objects  humans simultaneously  take  the   perspectives of   others                           - predict: n acting   towards  objects  humans simultaneously  take  the   perspectives of  others
# label:  the prior season.Camilo  rebounded from a mediocre 2012   season  to   be   considered                               - predict: he prior season.Camilo  rebounded rom  meore   2  season o  b cod
# Out of 349 samples:
# Mean edit distance:61.564
# Mean normalized edit distance: 0.526
#
#
# Epoch 00020: val_loss did not improve from 43.42165
# Epoch 21/100
# 3913/3913 [==============================] - 992s 253ms/step - loss: 48.8703 - val_loss: 37.4344
# label:  Brazil.   Currently,  this collection gathers cases  between  1952  and 2016.  In Canada,                            - predict: rail.   Curntytclecion gathers cas beten 19 and 201. In Canada,
# label:  5%   of   the   area's  economy. The  region   is also working  on alternative sources                               - predict: X  of of  the aras ecomomy. The region isalsoworkng on aternatesorces
# label:  the defense   research   and development  community.   It  also urged   the   DCI   to                               - predict: he defense  rech  andeveloment cmunity. t aso urged the  to
# label:  and Rubber Stamps:   The Politics  of the Chicago City   Council   from 1863  to the                                 - predict: and Ruber Stamps:   The Politics  of the Chicago City   Council   from 1863  to the
# label:  Gainsbourg  Revisited   (Tribute   to   Serge Gainsbourg)   (2006)  (producer) Party Animals                         - predict:  Gainsbourg  Revisited  (Tribute  to  Serge Gainsbourg)  (2006)  (producer) Party Animal's
# label:  neighbour  of Bridgewater,   living  five  houses   away. He   was   investigated by                                 - predict: eighbour  ofBridgewater, iving  five hous ay H  was ivestigated by
# label:  Gordon, Richard Reeve,   Gilchrist and  Alexander,   Finch,                                                          - predict: Gordon, Richard Reve,   Gilchrist and  Alexander,   Finch,
# label:  Czech-majority   constituencies  in Bohemia   and   Moravia   boycotted  the election,                               - predict: Ceech-majority  constituencies  in Bohemia   and  Moravia   boycoted  the election,
#
# Out of 349 samples:
# Mean edit distance:57.576
# Mean normalized edit distance: 0.492
#
#
# Epoch 00021: val_loss improved from 43.42165 to 37.43444, saving model to ./models/VGG with Attention\ocr_model_20210922-080734_epoch_21.h5
# Epoch 22/100
# 3913/3913 [==============================] - 992s 253ms/step - loss: 42.1320 - val_loss: 45.9804
# label:  build management and  continuous  integration  application.  AQtrace,  a  new                                        - predict: uild management and  continuous  integration aplication.  A9trace, aa new
# label:  allowed  for  a high-level  of   hardware functionality to  be  included   in                                        - predict: alowed  for  a high-level  of  hardware functionality to  be  incuded  in
# label:  of  the   United  States   into  the  war   was   major                                                              - predict: of  the  United  States  into  the  war  was major
# label:  the district wherein  the   employer  (that  is,  the   garnishee) resides, carries on                               - predict: the district wherein  the   employer  (that  is,  the   garnishee) resides, carries on
# label:  at the  nearby   Government House  in   Parramatta Park.   In   1838   there   is  mention                           - predict: t te  nearb   Govrnmen ouse   Prata Prk. o  1  there  is mention
# label:  will   he  'begged   pardon  of  the Lady   Anne'. Long   married  secondly,  Elizabeth                              - predict: il  he  beged  pardon  of  the Lady  Ane'. Long  maried  secondly,  Elizabeth
# label:  nostalgia  and memories   from the   past while dealing with   change in  the  present,                              - predict: ostalgia  and memories  from the  pat while dealin wng with  change in the  present,
# label:  Little Laureate   products   are distributed  in the  United                                                         - predict: itle Lurateproducts re distiued in the Unied
#
# Out of 349 samples:
# Mean edit distance:59.046
# Mean normalized edit distance: 0.505
#
#
# Epoch 00022: val_loss did not improve from 37.43444
# Epoch 23/100
# 3913/3913 [==============================] - 992s 253ms/step - loss: 38.4012 - val_loss: 37.8585
# label:  Congress  and served  until  his   resignation on   May  15,   1820. He  was   not a                                 - predict: ongres  and srved  until  his resignation on  May i,  1820. He was  nota
# label:  "Bumps" Bump   Elliott  (19252019),   American   college  football  player,   coach, and                             - predict: oumps"urmp  lit 19501)  Ameican  colege fotbal plyrc,, and
# label:  late 2018. Unwin was  appointed   Officer  of the                                                                    - predict: late  2018. Unvin was  appointed   Officer  of the
# label:  La   Passione   (1996)  ....   John MacIlroy   To                                                                    - predict: a   Passione   (1096)  1.   John Macllroy   To
# label:  population were below  the poverty   line, including                                                                 - predict: opulation. were below  the  poety  line,. inluding
# label:  600  film and  a   full  power setting for   SX-70  film. If  desired,  users can choose                             - predict: 0   (ir ndaai  puer setitg for S (iln. ds cose
# label:  "'The  Commitment' also considers important  human questions:                                                        - predict: "The  Commitment also considers important  human auestions:
# label:  for our   future generations.   Dimethylmercury  Ethylmercury Methylmercury  Mercury                                 - predict: or our   fituregeneratius.  Uinethlylnery  ithylinercury Ccthylnecury Lercury
#
# Out of 349 samples:
# Mean edit distance:57.097
# Mean normalized edit distance: 0.488
#
#
# Epoch 00023: val_loss did not improve from 37.43444
# Epoch 24/100
# 3913/3913 [==============================] - 992s 253ms/step - loss: 92.5599 - val_loss: 62.1074
# label:  "'The  Commitment' also considers important  human questions:                                                        - predict: "The  Comninent  lso  cnriders inrtnt  human gquestions:
# label:  required) CYYZ   -   Toronto Pearson International  Airport   in                                                     - predict: eavured)CFZ  Toroto easonternational Airot  in
# label:  base  in   Mogadishu   was   targeted  by  a  car   bomb,  killing   three   and wounding                            - predict: ase  in  Nogadishiu  vas  targeted  by  a  car  bomb,  Nilling thre  and iwunding
# label:  is  a   resident  of  North  Adelaide,  South Australia.   On  Australia   Day   2016,                               - predict: s  a   reld oe d d Adlde Sd d ustralia  On  Australi  Day 016
# label:  to   Wholesaling  and  Retailing,   Tourism and   Information Technology.  To   date,                                - predict: o  thlesa  ag n ed   e nisn and niormation Techogy To dte,,
# label:  Drivecenter   Arena, and  will   conclude  on 9 October  at Ring   Knutstorp after seven                             - predict: rivecenter   Arena, and  wil   conude On Otbe a in   knutstorp aftersevent
# label:  friend  of Kaufman's and owner  of KC's   Paint   Shop,                                                              - predict: riend  of Kaufmnan's and owner   of KCIs  Paint   Shop,
# label:  of an append   method   that  is   worst-case  O(log  n)                                                             - predict: of an anppend  method  that  is  worst-case  O7(1lo3  n)
#
# Out of 349 samples:
# Mean edit distance:63.759
# Mean normalized edit distance: 0.545
#
#
# Epoch 00024: val_loss did not improve from 37.43444
# Epoch 25/100
# 3913/3913 [==============================] - 991s 253ms/step - loss: 59.4336 - val_loss: 36.1579
# label:  there   have  been  chapters in   every  state and                                                                   - predict: here  have  ben  chapters in  every  state and
# label:  symptoms  and  baggage   that  come  with   addiction,  but   don't   know   how  or                                 - predict: ypton  and bag  Hhat  comne with  adictio,  but  on Nnow  ho or
# label:  at the   family's property,   Seven Creeks,                                                                          - predict: at  the   familys property,   Seven Creks,
# label:  requested  the  Secretary-General to  explore   the  option  of   replacing  AMISOM                                  - predict: euested the  Secredry Genera o explore  the  oplon of  pacinAS
# label:  Czech-majority   constituencies  in Bohemia   and   Moravia   boycotted  the election,                               - predict: Cech-magioriy  constuencies  iniBohemia  and  Moravia  boycoted the election
# label:  age.   In extremely rare   cases,  symptoms   may   not  show   at all until  as late                                - predict: age.   In extremely rare   cases,  symptoms   may  m not  show  at al until as late
# label:  the movie  Treasure   Planet. On  8 April                                                                            - predict: he movie  Treasure  Planet.  8 Ari
# label:  Holy Roman Church   during  the papacy   of  Eugene  IV.  Pope   Nicholas   V made him                               - predict: oly Roman Church  during  the paacy  of  Eugene . Pope  ithols Vadem
# Out of 349 samples:
# Mean edit distance:56.868
# Mean normalized edit distance: 0.486
#
#
# Epoch 00025: val_loss improved from 37.43444 to 36.15790, saving model to ./models/VGG with Attention\ocr_model_20210922-080734_epoch_25.h5
# Epoch 26/100
# 3913/3913 [==============================] - 992s 253ms/step - loss: 46.5965 - val_loss: 54.2958
# label:  late 2018. Unwin was  appointed   Officer  of the                                                                    - predict: ate 2018. UTnwin wos  apointed   Ofcer of the
# label:  disagreed  with  Bjelke-Petersen  and  Liberal                                                                       - predict: disagred   with  Bjelkeeren ad  Liberal
# label:  Bark   Hide  and Horn, a folk-rock  band from   Portland, Oregon,   released  a song                                 - predict: ark   Hide andMorn,a flkrck  ad ror  Prtad, rgon, resed s
# label:  a goalless   draw by Upton Park, but  emerged  victorious  after   a  replay   two   weeks                           - predict: a goalless   draw by Upto Park but ermerged r tr wvictorious  afer a y
# label:  Grayson Hugh  (1989) "Jealousy"   Pet  Shop   Boys  (1991)  "Giving  Him  Something  He                              - predict: rayson Hugh  17989) ealoy hop Boys 191) ing im mehing He
# label:  Hospital. Marjorie Lily  Shaw, Assistant  Catering  Adviser,  Essex  County Council.                                 - predict: ospital. MarioeLiySaw Asistnt aterng Aisr, se ounty Counci
# label:  which  requires  to   be   filled   by a new remedy. He  accepts   that   the  term  "restitutionary                 - predict: hicth   reoires  t   be  l by re. e ceps t the tr rt
# label:  of  the  other.   In the  game stage, organization  begins                                                           - predict: of the  otther.   In the  game stage, oganiation begins
#
# Out of 349 samples:
# Mean edit distance:64.828
# Mean normalized edit distance: 0.554
#
#
# Epoch 00026: val_loss did not improve from 36.15790
# Epoch 27/100
# 3913/3913 [==============================] - 992s 253ms/step - loss: 84.0092 - val_loss: 46.2125
# label:  For   two   decades, Gould  has  been   an   active board  member  of                                                - predict: For   two   decades, CGSould  has  ben   an   acive board  member of
# label:  of   Joseph  Hiester  and served  from  December                                                                     - predict: f  Joseh Hieste eand served from December
# label:  Roy Rogers   filmed  in  Trucolor.  Despite                                                                          - predict: Roy Rogers   fied  in  Truclo.  Dspiee
# label:  Blind  (La  mise l'aveugle)  -   2012  The Fireflies   Are  Gone (La disparition des                                 - predict: Blind   (tsa   mise 1 aveugle)   -   2012   mhe Firerlies   dre   Gsone (tia dispearition  des
# label:  from  the album 2001   "Back  At  You" by   Mobb   Deep  from   the album   Sunset  Park                             - predict: rom th alm0Back  t Hou by  Mob De from healbum Snst Pad
# label:  Somali   Civil   War.At that   time,   the  Islamic  Courts   Union   (ICU)   had  not                               - predict: onali  ivl  Far that  ine  the  Islanic Courts Un  ao
# label:  Ltd. John Fairnington Corkhill.   For service to the   community  in  the                                            - predict: td John Fairnington Corkhi.  orsericetoth   comunity  in  t
# label:  In 1991   the company   name   changed                                                                               - predict: n 191he company  name  chnged
#
# Out of 349 samples:
# Mean edit distance:60.401
# Mean normalized edit distance: 0.516
#
#
# Epoch 00027: val_loss did not improve from 36.15790
# Epoch 28/100
# 3913/3913 [==============================] - 991s 253ms/step - loss: 80.1578 - val_loss: 93.1369
# label:  CBS,   NBC, The   CW and   MyNetworkTV), as  well                                                                    - predict: Ci,   HC, The  he   h C
# label:  Alice finds  out  that Ben   is married;   when she   tries  to break  it  off  with                                 - predict: lice finds  out that Ben   imaried,   wheshe   tries to break  it  f  it
# label:  Gordon, Richard Reeve,   Gilchrist and  Alexander,   Finch,                                                          - predict: Cordon, Richard  Reeve.   Cilehrist and  Alevander,   Finch.
# label:  at the   family's property,   Seven Creeks,                                                                          - predict: t h   amiypi SSv
# label:  which  requires  to   be   filled   by a new remedy. He  accepts   that   the  term  "restitutionary                 - predict: which  requires  to   be   filled   by a new remedy. He  acepts   that   the  tem  "restutionary
# label:  border firing in   Rajouri.On  16   July,   Indian                                                                   - predict: order fringin  Najui
# label:  Brazil  began   receiving from the   Aeronautical   Documentation  and                                               - predict: razil   bean   receiving from the   Aeronautical   Documentation and
# label:  Free scores  by John   Reading  in   the   Choral Public  Domain Library  (ChoralWiki)                               - predict: Free scores  by Jmohn   Reading  in   the   Choral RPublic  Domain Library   (Choralkiki)
#
# Out of 349 samples:
# Mean edit distance:67.115
# Mean normalized edit distance: 0.574
#
#
# Epoch 00028: val_loss did not improve from 36.15790
# Epoch 29/100
# 3913/3913 [==============================] - 991s 253ms/step - loss: 78.2149 - val_loss: 59.3006
# label:  recording two minor  wins   in  twenty-three starts  over the next two seasons. He was                               - predict: ecording two minor  wins  in wenty-tre tarts over the nextwo seasons. Ke was
# label:  three-member  board  of trustees,   who  are   elected in November  of   odd-numbered                                - predict: hre-member  bord of tuste,   wh  ere   elced in Hovmber of   oddmnumbered
# label:  in 2006.   In 1990, Sister Jamie  T.                                                                                 - predict: n 20.  In 19, ister Jamie  T.
# label:  600  film and  a   full  power setting for   SX-70  film. If  desired,  users can choose                             - predict: 600  film and a   ful  power seting for   SXK-70  flm. f  desired,  users can choose
# label:  on February 24, 2018   at  UFC  on Fox:   Emmett   vs.   Stephens.  At   the  weigh-ins,                             - predict: n February 24, 2018   at UFE on ok  Emet   Sehe.  . A te is,
# label:  Mandala,   Mantras,  Mystery Religions,  Physical   Powers, Tantrism,  Yoga.  Fate                                   - predict: Mandala,   Mantras,  Mystery Religions,  Physical   Powers, Tantrism, Yoga. Fate
# label:  government  programmes.  In   early  1990,   the government  changed its   official                                  - predict: overnment  programmes. In  eal  190,  the government changed its   ofi
# label:  Brazil.   Currently,  this collection gathers cases  between  1952  and 2016.  In Canada,                            - predict: rasl   Cueny hicoloicoin as besbetwen 1 andada
#
# Out of 349 samples:
# Mean edit distance:60.699
# Mean normalized edit distance: 0.519
#
#
# Epoch 00029: val_loss did not improve from 36.15790
# Epoch 30/100
# 3913/3913 [==============================] - 992s 253ms/step - loss: 59.3776 - val_loss: 44.9944
# label:  Florida in   the United States.   They can be                                                                        - predict: oridain  the United State.    They can be
# label:  the   Federal Government of Somalia's  forces  in  their battle   against Al-Shabaab                                 - predict: he   Federal Government of Somalia's  forces in  their bale   against Al-Shabab
# label:  Smart  meter  Security   Official   website Blackout   (Marc  Elsberg                                                - predict: mart meter Secury Securilwebste Backout  acber
# label:  January 8, 1990 in Santos,   So  Paulo,                                                                              - predict: anuary 8, 191 in Santos,   So   Paulo,
# label:  Constance   Lawson, of Carlton   North.   For services to   nursing. Mervine   James                                 - predict: Constance   Lawson, of Carlton   North.   For services to   nursing. Mervine   James
# label:  Warrant Officer   Class 2   Peter Anthony  Broome,   Intelligence  Corps.   Major                                    - predict: arant Oficer Cls PerhoyBome Intelige CorMjo
# label:  and onwards),  and will find  either   a   .jpg                                                                      - predict: and onwards),  and will find  either   a   -ipg
# label:  600  film and  a   full  power setting for   SX-70  film. If  desired,  users can choose                             - predict:  fIm ad a fu puer etin fr Sk f fede user s m ehomse
# Out of 349 samples:
# Mean edit distance:59.307
# Mean normalized edit distance: 0.507
#
#
# Epoch 00030: val_loss did not improve from 36.15790

# %% [markdown]
# # Testing #
