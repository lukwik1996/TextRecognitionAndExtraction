# %% [markdown]
# # Test tensorflow gpu #

# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
  except RuntimeError as e:
    print(e)

# %% [markdown]
# # Dataset #

# %%
import os
import codecs

data = {}
classes_file = '../Dataset/classes.txt'
with codecs.open(classes_file, 'r', encoding='utf-8') as cF:
    data = cF.read().split('\r\n')
len(data)
# Out:
# 94

# %%
import os
from PIL import Image, ImageDraw, ImageFont

text_source = '../Dataset/source.txt'
fonts_path = '../Dataset/Fonts'
fonts = [f'{fonts_path}/{f}' for f in os.listdir(fonts_path)]
fonts
# Out:
# ['../Dataset/Fonts/arial.ttf',
#  '../Dataset/Fonts/arialbd.ttf',
#  '../Dataset/Fonts/arialbi.ttf',
#  '../Dataset/Fonts/ariali.ttf',
#  '../Dataset/Fonts/calibri.ttf',
#  '../Dataset/Fonts/calibrib.ttf',
#  '../Dataset/Fonts/calibrii.ttf',
#  '../Dataset/Fonts/calibriz.ttf',
#  '../Dataset/Fonts/cambria.ttc',
#  '../Dataset/Fonts/cambriab.ttf',
#  '../Dataset/Fonts/cambriai.ttf',
#  '../Dataset/Fonts/cambriaz.ttf',
#  '../Dataset/Fonts/consola.ttf',
#  '../Dataset/Fonts/consolab.ttf',
#  '../Dataset/Fonts/consolai.ttf',
#  '../Dataset/Fonts/consolaz.ttf',
#  '../Dataset/Fonts/constan.ttf',
#  '../Dataset/Fonts/constanb.ttf',
#  '../Dataset/Fonts/constani.ttf',
#  '../Dataset/Fonts/constanz.ttf',
#  '../Dataset/Fonts/corbel.ttf',
#  '../Dataset/Fonts/cour.ttf',
#  '../Dataset/Fonts/courbd.ttf',
#  '../Dataset/Fonts/courbi.ttf',
#  '../Dataset/Fonts/couri.ttf',
#  '../Dataset/Fonts/impact.ttf',
#  '../Dataset/Fonts/Roboto-Black.ttf',
#  '../Dataset/Fonts/Roboto-BlackItalic.ttf',
#  '../Dataset/Fonts/Roboto-Bold.ttf',
#  '../Dataset/Fonts/Roboto-BoldItalic.ttf',
#  '../Dataset/Fonts/Roboto-Italic.ttf',
#  '../Dataset/Fonts/Roboto-Regular.ttf',
#  '../Dataset/Fonts/tahoma.ttf',
#  '../Dataset/Fonts/tahomabd.ttf',
#  '../Dataset/Fonts/times.ttf',
#  '../Dataset/Fonts/timesbd.ttf',
#  '../Dataset/Fonts/timesbi.ttf',
#  '../Dataset/Fonts/timesi.ttf',
#  '../Dataset/Fonts/trebuc.ttf',
#  '../Dataset/Fonts/verdana.ttf',
#  '../Dataset/Fonts/verdanab.ttf',
#  '../Dataset/Fonts/verdanai.ttf',
#  '../Dataset/Fonts/verdanaz.ttf']

# %%
dataset = []
sequence_len = 20

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import cv2

def draw_img(img):
    plt.imshow(np.asarray(img), cmap='gray', vmin=0, vmax=255)
    plt.show()

def load_img(img):
    return cv2.imread(img, cv2.IMREAD_GRAYSCALE)

def dilate_img(img):
    return cv2.dilate(img, np.ones((2,2), np.uint8))

def otsu_thresholding(img):
    norm_img = np.zeros(img.shape)
    img = cv2.normalize(img, norm_img, 0, 255, cv2.NORM_MINMAX)
    blur = cv2.GaussianBlur(img, (3,3), 0)
    _, img = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    img = dilate_img(img)
    return img

# %% [markdown]
# ## Load dataset ##

# %%
with open(text_source) as txt:
    word_count = 0
    sequence = ''
    dataset = []
    for i, line in enumerate(txt):
        words = line.split(' ')
        for single_word in words:
            word = ''.join([c for c in single_word if c in data])
            word.replace('\n', ' ')
            
            if len(word) < 1:
                continue
            
            if len(word) > 30:
                split_count = len(word) // 30 + 1
                for i in range(split_count):
                    start = i * split_count
                    end = start + len(word) // split_count
                    dataset.append(word[start:end])          
                continue
                
            sequence = sequence + word + ' '
            word_count = (word_count + 1) % sequence_len
            if word_count == 0 or len(sequence) > 85:
                dataset.append(sequence[:-1])
                sequence = ''
                
dataset = list(set(dataset))
len(dataset)
# Out:
# 34354

# %% [markdown]
# ## Shuffle dataset ##

# %%
sorted_data = sorted(dataset, key=len)
longest_label = len(sorted_data[-1])
longest_label
# Out:
# 109

# %%
import random

random.seed = 1234567

random.shuffle(dataset)
# dataset = dataset[:20000]
dataset
# Out:
# ['on the provision of secondary education',
#  'The British Army has been credited with the spread of hockey throughout the world, but',
#  'The sponsor earns popularity this way while the sponsored can earn a lot of money and/or',
#  'used to prepare titanium for epoxy',
#  'and the publishers should pay any money owing',
#  '. In 2020, Killarmy released',
#  'her imprisonment or periodical',
#  'using a one-inch metal pipe, gunpowder collected from 35 12-gauge shotgun shells, a wind-up',
#  "(ETH), but their Steering Committee's clear position",
#  'the Premier Division after winning the',
#  'earlier when Mackovic took the',
#  'logistics (J4), Uganda operations (J3)',
#  'river -',
#  'in Exercise Distant Bridge to Ross',
#  'pay and daily food rationsparticularly after they learned that their fellow sailors on',
#  'This riding has elected the following Member of Parliament: Note: Conservative vote is',
#  'for those not commercially available, and the methods for their reduction to Ni(0) complexes.',
#  '(AMIB). As early as 25 March 2005 Sheikh Hassan Dahir Aweys of the Union of Islamic Courts',
#  '1 September 1 Border Security Force (BSF) soldier was Killed in Pakistani Sniper Fire',
#  'legislation that obliges any carmaker who',
#  'columns support the entablature and dome. In September 2008, Rep. Ted Poe of Texas, with',
#  'is known to have been kept during the Inca Empire (the Spaniards classified them as one',
#  'well known ailment of lawyers, a hardening of the categories, ought not to be an obstacle:',
#  'debtor also has an',
#  'district of Jammu and Kashmir.On 22 June, Pakistan Border action team (BAT) sneaked 600',
#  'White was inducted into the Queensland Business Leaders Hall of Fame in 2011, for his',
#  'faced criticism for deterring',
#  'King of the Hill movie review by Richard Harrington, Washington Post, September 10, 1993',
#  'North Dakota Studies (nd). "A Brief History of Woman Suffrage in North Dakota" (PDF).',
#  'were injured by Indian shelling in',
#  'Chili, New York and moved with his parents to Branch County, Michigan, in October 1842,',
#  'Rose. G4240067 Acting Sergeant George Lowes.Civil Division United KingdomHarry Abraham,',
#  'Downs is a 209.8-hectare (518-acre) biological Site of Special Scientific Interest north-west',
#  'six days after being hospitalized in the Carlos J. Finlay Military Hospital, as a result',
#  '1943. "\'Open House\' Second Novel of Joan Kahn". The Lewiston Evening Journal. July 20,',
#  'Science Department, as well as other universities that were developing the early Internet.',
#  'and renamed Enchantress',
#  'have shown that this segregation does not affect surface adhesion. The increase of laser',
#  '(March 21, 1791) under',
#  'state of Jammu and',
#  'city with',
#  'as bands they enjoy.In the chorus,',
#  'three days after his 47th birthday. RuPaul, whom Gold had described as a mentor, was among',
#  'Krech with the first release in November, 2002. A number of other Python projects use',
#  'Vernon Dudley Bowhay-Nowell Ian Howarth Frankie Tomes Sam Spoons Hugh Crozier Evil John',
#  'President Bill Clinton. Another son, John P. Daley, is a member of the Cook County Board',
#  "eight years as organist of London churches St. Michael's Church, Chester Square (1889)",
#  'International Business District Stanford Research Park Silicon Valley Base Realignment',
#  'readily in KOH. The asci are eight-spored and Micarea-like,',
#  'for Clear Rock is summarised by Szwed: [He] "seemed to possess an endless body of songs.',
#  "have come to agree that this 'thing' cannot be scientifically proven. Scientists have",
#  '16, 1445 until May 25, 1449. In September 1447, he became papal governor of Bologna. He',
#  '& Brothers, Rochdale. Arnold Frank Bailey, Professional and',
#  'to provide water".In 1837 a Templeton family wedding was held at Roseneath Cottage. The',
#  'Bay, which had been given to France in an earlier Treaty, and to inform the English they',
#  'Italy. In 1889, he accompanied travel writer John Lawson Stoddard on a tour of Mexico.Rau',
#  'army Junior commissioned officer (JCO)',
#  'of Colombo in the Sinhala',
#  'for this purpose." In addition, in the late 1960s a chapter on UFOs in the Space Sciences',
#  'son. During these three',
#  'as Federico FelliniGiuliano Montaldo has an uncredited',
#  'capabilities to Microsoft Equation Editor (plus 2D and 3D rendering tools only Grapher',
#  'of chill that is easily distinguishable',
#  '65 years of age or',
#  'resurgence in 1960, and Walston went 14 out of 20 in field goal kicking (70 percent) and',
#  'teacher at Maculay, who lures him onto the thin ice of the ornamental lake at Delaware',
#  'Peters, Gerhard; Woolley, John T. "John F. Kennedy: "Executive',
#  'make the headlines. For these merits the Spirit of Abdus Salam award was also bestowed',
#  'retirement as a player, he managed Cowdenbeath. The 2005 Fresno State football team represented',
#  'employment of the garnishee, the judgment',
#  '... (2 episodes, 1990, 2001) Doctors .... Dan Armstrong (1 episode, 2001) Birds of a Feather',
#  'late 1993 to set up',
#  'Planeta Xuxa), and was also widely publicized on the Sexto Sentido and T de Bem com a',
#  'Don Bluth met Morris Sullivan, a mergers and acquisitions',
#  'there and sent to Dublin for Xerography and painting.All Dogs Go to Heaven was completed',
#  'tickets to the game in Pasadena, the attack on Pearl Harbor by Japan on December 7 soon',
#  'the Astra Museum, located in Astra neighbourhood, about 20 kilometres away from the downtown.',
#  'the Cycles of Life system, similar in nature to biorhythm. An iPhone application for this',
#  'For more a more explicit Python',
#  '1952. "Esoteric sexuality", Critique, Santa Rosa, California,',
#  'use of the terms "PAN" (French)',
#  'any known types of aerial vehicles. The matter was considered so urgent that OS/I drafted',
#  'The tribe is travelling toward the equator ahead of glaciers that are descending from',
#  'an injunction',
#  'lead singer James LaBrie).',
#  'in digital TV in the UK',
#  'Sign and Project Blue Book.',
#  'damaged by two',
#  'used to make the base',
#  'of Maquarie, Australian Capital Territory. For public',
#  'Judges noted that in the light',
#  'Mississippi River, and into the Free State of Illinois. According to descendants of the',
#  'probably refers to Lot',
#  'Edgar Samuel Bridgewater, MBE. For public services in St. Kitts-Nevis-Anguilla. James',
#  'kiosk. Johann Nikolaus Forkel (22 February 1749 20 March 1818) was a German musician,',
#  'Murray rivers. Produce farmed in Merbein',
#  'Middlesbrough respectively, to draws.7 January 1975: Third Division underdogs',
#  'returned to California, where he served as the',
#  "to Bob Dylan's contemporaneous Rolling Thunder",
#  'and Galloway Region Savings Committee. James Graeme Berry',
#  'Cooper), and impulsively marries him.',
#  'Indian posts in Dewra village of Rajouri\'s Sunderbani district and in retaliation it "shot',
#  'explores the relationship between the people and the environmental impact of their towns.',
#  'of Espasa-Calpe and Enciclopedia Espasa (18401911) Adolf Florensa - architect, urban planner',
#  'Area Adams County population 101,407 YorkHanover, PA Metropolitan Statistical Area York',
#  '(October 17, 1928 October 7, 1987) was an American football wide receiver and placekicker',
#  'through the tour with',
#  '1971) is a French-born Malian former professional footballer who played as a forward.',
#  'Jackson on November 10, 1978, which gave Jackson control of the business and the Charvel',
#  'Jayhawks have also captured 28 Conference Tournament',
#  'the Chew Valley in',
#  'shortly after her retirement, she recalled: I was',
#  'developer. Soon after',
#  'Disney project, The Fox and the Hound 2 is his first film without co-direction from Brian',
#  "there. There is no known response to Morris' letter and it is likely that the original",
#  'University of Illinois at Chicago, numerous expressways and',
#  'campaign. The WFL organization as',
#  'stepped up',
#  'Assyriological Studies 22, Oriental Institute, 1987 [12] I.J. Gelb, "Sargonic Texts from',
#  'Leader Robert C.',
#  '4\'s "Loose Ends", broadcast on 13 April and on John Kennedy\'s Xposure show on Radio X,',
#  'Addington. Then 2012 saw the',
#  'The series has been featured on national and metropolitan-area media, including recorded',
#  'my noble and learned friend explores what is the "just response" to the defendant\'s conduct.',
#  'Hector, Commissioner of Police, St. Christopher-Nevis-Anguilla Police Force. Eusebe Alexander',
#  '1935 to 1937 during the Depression and none in 1942 to 1945 because of World War IIThe',
#  'consulship of Rome. For some, the results of the trial showed that Marius was a man who',
#  'Selective website Erio Tosatti (born 9 November 1943 in Nonantola) is an Italian theoretical',
#  'were looking at him with curiosity and hauteur. With much trepidation he began speaking',
#  "the museums exhibits. This was the museum's fifth move in 52 years of operation. See:",
#  'associated to the Cathedral School of Lund, but is independent today. It is used as a',
#  'She also won the gold medals in the C-2 200 metres and C-2 500 metres events. As a result',
#  'and eventually serving as the',
#  'Mead and Modernity: Science, Selfhood and Democratic Politics.',
#  'assumpsit on a foreign bill payable in pounds sterling. Interest on affirmance is to be',
#  'and all public productions in the Shea Center for Performing Arts and the Hunziker Black',
#  'naval contribution against German submarines. Following the',
#  'with David Nessling, Tony Cosens and David Ormerod departing the club by resignation.',
#  'spent so much time at Draycot House with',
#  'on elliptic functions and geometry. Karl Bobek',
#  'in each of his four seasons. He',
#  'and processed for lime on site for',
#  'decision in the',
#  'Head and Clear Rock were the first two convicts that Lomax was permitted to record in',
#  'Waiting for Primetime: The Women of Television News by Marlene Sanders and Marcia Rock.',
#  'play. Yankees',
#  'the replacement engineer. She',
#  'matter-of-fact, non-apologetic approach to a subject that the rule book said had to be',
#  'Brightman J. made an award of',
#  'club. He joined the Pittsburgh Pirates shortly afterward, spending all of the 1989 season',
#  'of generating units. Depending on the application the device may, during and after the',
#  'July 2007 to assist in the',
#  'radicals like Robert Blum and Arnold',
#  'seen the track layout remodelled (with the non-platform lines removed), a third platform',
#  'lobbed between six and eight mortar rounds at the military side of Mogadishu International',
#  'and two thirds of this',
#  'Mead enrolled at the Oberlin Academy at Oberlin College and then the college itself, graduating',
#  'Institution (capacity 541) Dodge Correctional Institution Fox Lake Correctional Institution',
#  'District Elementary (BDES). Graham Lloyd Stokoe (born 17 December 1975) is an English',
#  'and attacked by the British cruisers HMS Nigeria and Aurora. Bremse was able to draw the',
#  "O'Neill, of Lake Placid, via Cairns, Queensland. For public service in the field of employment.",
#  'TR Fund charges 1.14%',
#  'by the Indian forces.On 20 January, India claimed that one Indian Army soldier and two',
#  '"the father of cell biology" in his citation for the Lasker award. Gall was a major contributor',
#  'and Max to specific locations, interacting with the environment, collecting and using',
#  'Island albums" featured in Greil Marcus\'s 1979 book Stranded. In 2000, Q magazine placed',
#  'is now identified as a global problem',
#  'the paper animation completed',
#  'on 29 September 1957 on the HaarlemUitgeest railway. The station has 2 platforms. As of',
#  'allowing the Model S to rank',
#  'Way in Burbank, which it shared with the former Hub Network and Hasbro Studios, and finally',
#  'accustomed to. On December',
#  'regime came to the Americas',
#  'Reitz\' "Historie der Wiedergebohrnen" und ihr geschichtlicher Kontext (Palaestra 283).',
#  "From 1859 until his death he was rector of the parish of St Cuthbert's Church, York.In",
#  'The present college building was inaugurated',
#  'luteopurpureum) (Colombia to Venezuela) Odontoglossum lends itself to the production of',
#  'March 12, 1978 in Tullahoma, Tennessee. All Things',
#  'Minx and his wife Eleanor moved',
#  'National Park in',
#  'East Sussex Football League',
#  'victory1530.com URL. Vern 1530AM - Official',
#  'to the point of no return." They noted',
#  'the apps SSB Move, Moovel and the DB Navigator. The mobile phone tickets are partly discounted',
#  'HHS regulation to a list of preventive services covered by the ACA per regulation that',
#  'Regiment, 1st Expeditionary Brigade, Coast Artillery Corps, July 16, 1917. He arrived',
#  'The 2002 Global Mercury Assessment concluded that "International actions to address the',
#  '2008,',
#  'with opposing forces in the field;',
#  "college basketball. The Jayhawks' first coach was the inventor of the game, James Naismith.",
#  'of money by the person unjustly enriched to the person at whose expense that enrichment',
#  'are sound approaches to reduce mercury emissions in the long term-large scale plan. Public',
#  'actress and psychologist whose career',
#  'and jet interceptors, and investigated by',
#  "Generally, a Pygmy Marmoset's life-span is from 15 to 20 years, they are known to have",
#  'News series, set in the NSW South Coast town of Ulladulla, as the proprietor of the Bluebird',
#  'court and the Speert Hall dining facility,',
#  'of Bristol from',
#  'it adopted its final name. In 1967, it merged with the Norwegian Lithographic and Chemographic',
#  'Godfrey (1990). Islamic Spain. Chronicle Books. ISBN 0-87701-692-5. Jordan Kessler is',
#  "the lower end of St Peter's Avenue, contributed to the construction of several notable",
#  'theater which ended up being named after her as a thanks. It was filmed at the Chelsea',
#  'the composers associated with the genre used a string orchestra for applying warmth and',
#  'in synthesizing this material are;',
#  '18th century. Listed buildings in Ryburn Sowerby, North Yorkshire Sowerby Website Sowerby',
#  'game E.T. the Extra-Terrestrial. List of computer system emulators List of video game',
#  'West Indies, and Central America. It has also been introduced into southern Florida in',
#  'and Annalong set out for the usual fishing stations, and were caught in a gale. 14 boats',
#  'not reckoned as',
#  'tiny islands of Saint Pierre and Miquelon,',
#  'Asia and Altai. It was first detected in',
#  'the Greendale tour. Although Sampedro was',
#  'org/web/20140607004505/http',
#  'Montreal in the Quebec region of Montrgie. The neighbouring ridings are BrossardLa Prairie,',
#  'is or has been in his possession by virtue of his position as a member of those services.',
#  "With the end of the war in 1945, Walker's services were transferred to the new Republic",
#  'is a science center located at',
#  'and northern Mexico (Baja California peninsula, and Sonora).',
#  'gesture of the second organism in turn calls out a response in the first person. On this',
#  'power over their environment. The notion of a physical object arises out of manipulatory',
#  'belong to Tolton. Also found were the corpus from a crucifix, part of a Roman collar,',
#  'Limited. The works were nationalised by the British Government in 1951, but were sold',
#  'Goldcrest involved in its distribution. The Samuel Goldwyn Company picked up the rights',
#  'charted lowly at 125 on the U.S. albums chart. "Heat Wave" (Lamont Dozier, Brian Holland,',
#  'the Final by winning Semi-final',
#  'Edward Flinn Reid. For services to British commercial interests',
#  'West Africa and the Muslim Word in general, by producing and promoting a new generation',
#  'Arizona Diamondbacks, Kansas City Royals and',
#  'local government administration office in Mogadishus Wadajir district. On 22 June a police',
#  'of Allotments. Troshchinsky is also known',
#  'by the nozzle can be varied depending on the roughness requirements and repeatability.',
#  'in North America. The efforts of the Jesuits in North America were paralleled by the Jesuit',
#  'Guitars official website Grover Jackson Interview - NAMM Oral History Library (2008) Jon',
#  'MBE, Director of Studies, Britannia Royal Naval College,',
#  "assets in Singapore. Initially, the battalion's personnel consisted of a mixture of National",
#  'still based in Manchester. The company',
#  'of detective novels by Alexander McCall Smith and the American dramatisation that followed',
#  'University of British Columbia University of',
#  'highest-grossing animated film on an initial',
#  'require prescription coverage.After the',
#  'Newcastle was fortunate enough to escape',
#  'Ltd. For services to Export. Walter Leopold Milner-Barry. For services to the National',
#  'collegiate player in the New York',
#  'Constable Donald William Jarvis, Metropolitan Police. F194S038 Sergeant',
#  'was becoming too expensive to maintain',
#  'psychic power that Max gained in each episode, such as the ability to read minds, see',
#  'with Please Please Me, With the Beatles, and Beatles for Sale. Having been available only',
#  'of agriculture and industrial development. Doctor The Right Honourable Sir Seewoosagur',
#  'second solo album, Time Out, was released during in 2007. It proved to be a great success,',
#  'new artists. After The Land',
#  'fuel cell vehicles and plug-in hybrids with battery capacity of 15.0 kWh and above are',
#  'who served in the Great',
#  'has had a similar investigation since 1989. Project',
#  "Cottage is a heritage-listed former residence and now school building at 40-42 O'Connell",
#  'Fried Chicken. Hurt came up with the idea of chocolate-covered potato chips, which did',
#  'Ablett, formerly Headmaster, Hemsworth High School, Wakefield. James Cecil Akerman, Managing',
#  'super G, downhill and',
#  'Graves in the Diyala Region", Oriental Institute Publications 88, Chicago: The University',
#  'the welfare of senior citizens. He was also interested in music, and was the President',
#  'guifarroi was named after Honduran environmental activist Mario Guifarro. Guifarro was',
#  'reported or recorded. Typical categories include: Saucer, toy-top, or disk-shaped "craft"',
#  'in the German National Library catalogue Works by Johann Nikolaus Forkel at Project Gutenberg',
#  'Co., LLC (ARTCO) is a subsidiary of Archer Daniels',
#  'Stupa during an excavation',
#  'Thrones. In 2015 it',
#  'park Hsinchu Science and Industrial Park Songdo',
#  'the end, and the entrance',
#  'to 20 minute halves with a',
#  'follows the personal lives of the staff and friends at a remote ski resort. The series',
#  'realize their potential for significantly symbolic behavior,',
#  'was also the author',
#  'Raknes, Kjersti Stub (91-97), Tone se, Anna Sundstrm (91-94) and',
#  'or of',
#  'remaining game element is determining',
#  'a liability so his CIA handler',
#  'north to Nunton and southeast beyond',
#  'In a suitable case damages for breach of contract may be measured by the benefit gained',
#  'As of 2001 India census, Puldinni had a',
#  'violations, leading to cautious optimism among Indian',
#  "School For Girls. Although tall, slender and blond, she is considered 'unmarriagable'",
#  'Professional and the Certified Technologist. Each certification',
#  '\'em up and a flight simulator", graphics, sound, varied',
#  '104/3 - 26 BC), Roman politician, and consul in 53 BC Musonius Rufus, Roman Stoic philosopher',
#  'of that year. The party was',
#  'Hong Kong Police Force. Kwan-fu Chik, Chief Inspector of Police, Royal Hong Kong Police',
#  'Indian claims as farcical. On 29 May, India',
#  "1994, 1995, 1996, 2019Women's volleyball 2016 Kansas",
#  'work in 2003. In her conversations with Gall, when asked to explain his encouragement',
#  'agricultural imports (primarily cereals) exceeded',
#  'Japekrom strongly uphold the principles of truth, fairness, hard work, a welcoming heart,',
#  'Music and Drama. The choir has toured in Europe, Asia, and the United States of America',
#  'Post graduate course in nursing (M.Sc',
#  'a head on 4 August 1983, when',
#  'the College from a campus located on Harbord Road, Freshwater. The five campuses that',
#  'memorial. Work began in October',
#  'the entire family to coordinate their activities without seeing each other. Siblings also',
#  'queuing for packets waiting to go',
#  'device that was',
#  'an amateur basketball league that was created in 1897. It hosts the annual AAU National',
#  'Yorkshire.) West Langton is near Kibworth and Market Harborough, and the parish according',
#  'working with Burger Records, whose owners Sean Bohrman and Lee Rickard had long been fans',
#  'be killed while nine others were reported to be injured in Chaprar, Harpal and Bhimber',
#  'it includes the villages of Wick and Charlton-All-Saints, and the small ancient settlement',
#  'by true crime author, Simon W. Golding.',
#  'de Avila, O. de M. (died',
#  'Tudrick. Under the management of Howard Hertz, the band signed with Lizard King Records.',
#  'Foreman, Engineering Department, Kettering District, East Midlands Electricity Board.',
#  'tracking the Australians, trackers found signs of',
#  "Men's Bowling (1): 2004 (USBC",
#  'and its "churn \'em out" attitude',
#  'and then after two years',
#  'Salvador, the Dominican Republic, Honduras, Nicaragua participated in Multi-National Force',
#  'themselves against nature." The reviewer notes that while the film instead has a message',
#  'Commander Thomas Howard Jackson (53062), (Retd.) Wing Commander Patrick Howard Lewis,',
#  'Browser. The Media Browser provides quick access to media from iTunes, iMovie, and Photos.',
#  'One Hockey One 2019-Present (Men & Women) National',
#  'As with abrasives, a silane primer application is used to seal the laser roughened surface.',
#  'compositions, is a unique resource,',
#  'were also wounded. In addition, a Burundian',
#  'was acquitted of her murder. 22 April - Max Sica reports finding the bodies of the three',
#  "actually-accurate depiction of Lafitte sneaking into Andrew Jackson's window, Lafitte",
#  'for Single Parents. Robert Herman MacWilliam. For services to the Institution of Mining',
#  'de Buenavista. He formed a Revolutionary Provincial Government with Angel Salazar (Governor),',
#  "locations for hiring sales professionals. William Paterson's",
#  'in Poonch district were reported to',
#  'and continuing to the present day,',
#  "Ironmonger's shop, from Littlehampton Timber yard and Steam crane Village Garage, a reconstructed",
#  'most recently in Fukushima, in the wake of the 2011 tsunami and earthquake in the area.',
#  'said that "All things considered, Desert Strike couldn\'t',
#  'List of Threatened Species. Downloaded on 23',
#  'in heavy fighting at Derapet in Deh Rahwod on 24 August 2010.During an eight-month deployment,',
#  'convictions. In the United States, contraceptive use saves about $21 million in direct',
#  'Police, Northern Ireland. Violet Nancy Woodward, Supervisor, Adrema Section,',
#  'Games in Sochi. At',
#  'arts.State of VictoriaAlfred Dunbavin Butcher, of North Balwyn. For services to the Zoological',
#  'and File on 4 at the BBC, Channel 4 News and Dispatches, as well as the Financial Times,',
#  'For services to Music. Joseph Charles Asher, Administrative Director and Secretary, British',
#  'it was 5846 loss to the',
#  'responsible for killing Karl Speyer, whom she lured onto thin ice and then let drown,',
#  'in sociology from Georgia. After',
#  'chasuble and reburied.On March 8, 2018, historians who consult the Congregation for the',
#  'clarinet, alto and bass flutes, saxello, percussion Jim Horn flute, saxophone Ernie Watts',
#  "1978, having published over 300 articles, Migeon was considered one of the world's most-cited",
#  'North America in 2016. Rhagoletis cerasi can reach a body length of about 3.55 mm (0.140.20',
#  'only one',
#  'Finn Bjarnson and Ryan Raddon (Kaskade). They are primarily known for mixing dance music',
#  'IMDb Pagophagy or pagophagia is',
#  'through the platforms. These were the last vestige of the four track which originally',
#  'military officer who retains their commission while serving in an embassy. Opportunities',
#  'mainland and covers an area of around 133,000 km2 (51,000 sq mi). The Galpagos Islands',
#  'Amarna letter EA 369 is',
#  'extended west into the Tangi Valley following the Dutch withdrawal in August. Elements',
#  'the 2012 electoral redistribution. List of Canadian federal',
#  'Benedictson bass, Bill Spornitz soprano saxophone, Richard',
#  'fragments reused as building material within late-ancient walls, according to a well-established',
#  "downplayed the event (officially termed 'Unexplained Lights') to avoid damaging his career.",
#  'trains per hour to Blackpool North. Train',
#  'by ethical purity, inward devotion, charity, asceticism, and mysticism. Leadership was',
#  'mountain is drained by the Groot-Dwarsrivier, which',
#  'round, to set up a tie against Harrogate Town in the second round. The tie at Harrogate',
#  'finished unplaced behind Mister',
#  'fire damaged much of the',
#  'India and Pakistan continued to regularly exchange fire across the LoC in Kashmir, resulting',
#  'built-in Python object methods in',
#  'group released "You Can Be The One," their first single from the album, which was available',
#  'disrupting his relationship with Lori, attempts to',
#  'Sanders (uncredited) Bruce Lewis as Himself - TV Reporter (uncredited) Peter Madden as',
#  'and in 1968 joined the Revolutionary Communist League,',
#  'the Maccabees." According to Friedman,',
#  'expressed online.In 2013 she co-founded the non-profit Democracy Earth, based in Palo',
#  'the porch as a later addition. The hall is a Grade II* listed building. Its listing records',
#  'in raising awareness of the',
#  'Doctor Ulysses Telles Guariba Netto FEMA was created in 1985 and the first course of IMESA',
#  'Szabadka, in the Kingdom of Hungary (today, Subotica, Serbia). She moved',
#  'California to Patagonia, Chile retracing the 1968 trip that Yvon Chouinard and Doug Tompkins',
#  'sister, Fanny Parnell (18481882),',
#  'Northern Lighthouse Board. Richard Mons Namur Ringrose, Foreman,',
#  'generale e applicata, Padova, CEDAM, 2001, p. 745-746, ISBN 88-13-23135-0. (in Italian)',
#  'cost of the tariff reform 2019 was estimated at about 42 million euros per year. In April',
#  'rural holdings for 3500 pounds to Scottish-born agents John Gilchrist and John Alexander.',
#  'on 5 October 2010. Retrieved 8 July 2010. "The Big Sky" is a song by English singer-songwriter',
#  'between Papierwaite and a seemingly invisible',
#  'The Australian Computer Society (ACS) is an association for information and communications',
#  'several projects across the North & Eastern provinces to investigate and identify the',
#  'in each of the Australian States. The',
#  'to Folkestone Invicta in',
#  'of the 16th and 17th Centuries by Naylor, Edward W., New York: AMS Press, 1965. The Poets',
#  '"Blues Project" CD/12 inch (1996, Yellow / East West) "The Real Pop Porn Blue Sound" 10',
#  'the 1980s, after fresh research into contemporary reports of the game by football historians,',
#  'stands beside the tidal section of the River Lynher (a tributary of the River Tamar) on',
#  'law for two',
#  'strike some 40 km northeast',
#  'who is soon abducted by the clones,',
#  'and other coalition forces, operating from a number of patrol',
#  'Sakers said: By and large, it seems to me that most SF fans are fairly comfortable with',
#  'falling to eventual national',
#  'Crooked Lake, Epic 1972 Crazy Moon,',
#  'the Nationals. Two Liberals, Don Lane and',
#  'the neighbouring districts of Bblingen, Esslingen, Ludwigsburg and Rems-Murr, and parts',
#  'for the British Consulate-General. They had no children.',
#  'roughly made of the Coomealla and Sunraysia irrigation districts fed by the Darling and',
#  'announced the Project Light Rail scheme to',
#  'more beholden',
#  'at the Brooklyn Museum (acc. no.',
#  'has been removed for reading. However, if one has a working system, it may be far easier',
#  '3691), was commissioned in the artillery, and',
#  'initial story treatment. The movie',
#  "was unsuccessful, as John V. Kenny defeated Hague's nephew, Frank H. Eggers, in the Jersey",
#  'signed Fulton to a four-year, $28 million',
#  'and community services in Hong Kong.Australian StatesState of VictoriaRoderick Howard',
#  "bearing and managing the impulse to perform one's impulse is called acting in. The performed",
#  'in monetary terms, the',
#  'UFOs have constituted a widespread international cultural phenomenon since the 1950s.',
#  'the act from the standpoint of a social process involving the interaction of many individuals,',
#  'Kahn worked briefly at Ticknor & Fields, and then E.P. Dutton, before landing, in early',
#  'brought down his hammer.',
#  'and co-founder and chairman of Mutasian Entertainment,',
#  'Fiction?" Declassified CIA documents from the 1940s through the early 1990s. "UFO Reports',
#  'not listed here also operate, unless they also operate their own lines in the VVS. 1 The',
#  'Park in August. He ended his racing career by running fourth in an allowance at Bay Meadows',
#  '50% of the mercury content could be',
#  'left at the end',
#  'For Leonora, the marriage brought both advantages and disadvantages. On the one hand,',
#  'Kennedy in-law) Sargent Shriver on his',
#  'Control Act on October 27, 1970. 1946 Lake Success Protocol Narcotic Drugs Import and',
#  'and later',
#  'information about matters such as the',
#  'the community. Noel Edwin Warburton, of',
#  'missile attacks and ground operations. Unlike',
#  'formed his own company, where he works on Internet Business Logic, a system for social',
#  'including Gnomeo & Juliet, Ice Age: Continental Drift, Escape from Planet Earth, Epic,',
#  'Championships were discontinued. Open National Championships',
#  'Chicago: University of Chicago Press. Snchez de la Yncera, Ignacio. 1994. La Mirada Reflexiva',
#  'Hotel Eureka was built in 1933.',
#  'RAF Sealand, Ministry of Defence. Thomas Alan Fare, Postman, Liverpool Head Post Office,',
#  'suffragette. Despard was one of the original organizers for',
#  "be part managed by Tube Investments.By the 1970s, the factory's viability and profitability",
#  'and people. One such, called "We are", appeared in Life and Letters Today, London, August',
#  'comprises music from the Renaissance to',
#  'in July 1936 as',
#  'film in the United States, and at',
#  'This, was released in 1973 and featured Bobby Tench. At the beginning of 1974, Junior',
#  'particularly on the main stand,',
#  '(2011). In 2011, Speckmann was the first winner',
#  'available for streaming. Crooked Shadows was released on February 9 through Fueled by',
#  'the MASL for the 201920 season.',
#  'the management of five public hospitals, as well as a range of other healthcare facilities',
#  'There are many queuing disciplines',
#  'united with Standlynch to form the civil parish of Standlynch with Charlton All Saints,',
#  '& Lyle Engineering Ltd. For services to Export. William George Speakman, lately Director,',
#  '(P) Anthony John Heath Ray, D980671K. Chief Petty Officer (OPS)',
#  'complex. The complex will also contain educational',
#  'From 28 August 1932, the two original bus lines were combined and extended to Svrsvann.',
#  '- February 2015 - Richard',
#  'candidate registering. He officially took over as party leader May 4, 2014. List of British',
#  'and his wife Elizabeth Forster. He',
#  'Town and Burnley are one point behind.22 January 1975: Aston Villa and Norwich City complete',
#  'Township, southwest of Chicago. Daley',
#  'a special interest in aspects of',
#  'List of casino hotels Mardi Gras Casino and Resort',
#  'Marigold Joy Lewis, Senior Lecturer, School of Librarianship, Polytechnic',
#  'a great success for the town,',
#  'daily disembarkations, and prioritize cruise ships with superior public health and environmental',
#  'unspectacular reception for All Dogs',
#  'state of South Dakota. U.S. Roads portal Media related to Interstate Highways in South',
#  'Health & Social Security. Eveline Maud Kent, Inspector of Schools, Department of Education,',
#  'he had been mistaken. BBC',
#  'and Affordable Care Act (ACA) on',
#  'raid on Lawrence was led by William Quantrill, a Confederate guerrilla born in Ohio who',
#  'index funds assume somewhat irrational',
#  'Land League experiences in',
#  "Citharichthys darwini Victor & Wellington, 2013 (Darwin's sanddab) Citharichthys dinoceros",
#  'of the American Soccer Pyramid. In October 2010, the Aztex were relocated to Orlando,',
#  'accused her of defamation of character.Lumberg',
#  'to South Africa, Zambia, Zimbabwe,',
#  'because the accommodation offered to objecting non-profits would be a less restrictive',
#  '3 that go beyond the RDF model',
#  'in heavy clashes between',
#  'J.M.H.Shaw 2004 : (Odontoglossum Kunth x Oncidium Sw. x Zelenkoa M.W.Chase',
#  'The Belfast & County Down Railway Station and Clock Tower is a B1 listed, red brick building,',
#  'facility to the dam,',
#  'Company. It is rated as the least corrupt country in Africa in the Corruption Perceptions',
#  'use "without making any structural',
#  'She has released',
#  'Ward Sir Alan Buckley Phil Buckley Richard White Dave Turner Roscoe (The Binman) Birchmore',
#  'threats. The most',
#  'in a much weaker state than only two years prior. 26 June 2015: At least 50 Burundian',
#  '(Rt).In a chromic',
#  'may be a commentary on the paragone,',
#  'release simultaneously, but work had not yet started, and there was no estimated timeframe',
#  'dogs entered North America from',
#  'with memory, a parallel port controller and a serial port controller, were included on',
#  'became Dean of Faculty for the Department of Sinhala. Wijegunasinghe attended the University',
#  'US$100 million.In March 2013, after rebel fighters moved into Bangui, President Francois',
#  'two networks was a 10-metre (33 ft) section without an overhead wire at Oslo Hospital.',
#  'in May 2017, citing weak',
#  'A sleeper hit that peaked',
#  'and a higher castle ("Haut Morimont"). The former is located at the present Morimont farm',
#  'Sidgwick & Jackson, ISBN 0-283-99165-8.',
#  'CIA Office of Scientific Investigation (OS/I) study',
#  'radius of the city.',
#  'estate. Rosny',
#  'nationwide, and the only institution from New Jersey,',
#  'Midlands Serious Crime Squad, which was later disbanded',
#  "the state's first senator, its second governor, and a United States Supreme Court Justice",
#  'in violation of Title VII of the 1964 Civil Rights Act, which prevents discrimination',
#  'UFO flying near his home and took some photographs of the craft. Walters reported and',
#  'Flower Brigade participants, who carried flowers, flags and pink posters imprinted with',
#  'their first project. After four years of production, much of it part-time, Banjo the Woodpile',
#  'Benin on February 15, 2002,',
#  'and Music 1928.',
#  'are awarded to the top 10',
#  'early December 2017, the',
#  'the Americas (1984). Eccles, W. J. The Canadian Frontier, 15341760 (1983). Eccles, W.',
#  'was 1,671 at the 2000 census. Higganum is derived from an Indian name meaning "at the',
#  'quit on July 16, 2004; the',
#  'vehicles equipped with a',
#  'He also worked towards introducing Kannada as a medium of instruction in schools to educate',
#  'Democratic Republic Works related to United Nations Security',
#  'here than it did almost anywhere',
#  'Cerro Corcovado (the Corcovado volcano), an attempt that was halted 200 feet from the',
#  'quick access to the',
#  'Unidentified Aerial Phenomena Task Force, purportedly',
#  'the last 3040 years so it is not strange that they might beat the market. Thus, a fundamental',
#  'best selling all-electric car in Canada.The all-electric Renault Twizy 40 low-speed quadricycle',
#  'and Technology Officer, Department of the Environment. Archibald John Campbell Mitchell,',
#  'for themselves by insisting',
#  "modelling. Akinnuoye-Agbaje's modelling career led him to Hollywood, where he began his",
#  '"Gunslinger" series guitar model.In from 2014 to 2015, there was an IndieGoGo crowdfunding',
#  'into closer harmony with modern conditions." William John Cooper was the son of William',
#  'city are now preserved in',
#  'in a shop 350 ft. long by 90 ft. wide." The Bertrand-Thiel process of making steel was',
#  'to be arrested,',
#  'and unpretentious. The wide, panelled front door is',
#  '144364571. 7 BIOGRAPHIES at www.scoilnet.ie Patricia Groves, Petticoat Rebellion The',
#  'castles in France Base Mrime: Chteau fort de',
#  'text from a publication now in the public domain: "Goodwin, Timothy". Dictionary of National',
#  'standards such as "More"',
#  'Gilbert Blythe in the',
#  'Milton Glaser, Heinz Edelmann, and Peter Max',
#  'Notable MPs include Blessed John Story, an',
#  "of the country's main diamond",
#  'CBZ Holdings Janetta Rebold Benton is an American art historian. She is currently Distinguished',
#  'the 201112 season Wadada became a regular player and was part of the team that finished',
#  'Supreme Court was deadlocked on',
#  '1996 the Reformed Church in Zambia formed. It had more than 500,000 members in 154 congregations,',
#  'Public Security & Justice Public Works Tourism Attorney General The Ministry of Defence',
#  'and provided',
#  'the Nickelodeon sitcom Drake & Josh. She has since made a number of guest appearances',
#  "TCP's intentional throttling behavior prevents wireless networks from performing near",
#  'Despard was also the',
#  'de jardin" and "Mal barrs" for the Renaud album Boucan d\'enfer. In 2009, he was a judge',
#  'convertible and is valued against a basket of currencies heavily weighted toward the South',
#  'prison. A request for pardon was turned down by then-Governor Julius Heil. Walter Minx',
#  'He often petitioned government on mercantile',
#  "and Robert's adoptive mother Cecilia Price (Clare Richards),",
#  'of industrial mercury waste, and implementation of policies',
#  'heroic virtue.On December 10,',
#  'Phillips Vineyard for its',
#  'moving to Europe,',
#  'is responsible for maintaining this separation and ensuring that queries against the entire',
#  'Galway, in 1806, and they had five children: Michael, first surgeon in the Mater Hospital,',
#  'and Supplies, British Gas Corporation. Lettice',
#  'league MVP candidate in 2013. During',
#  'An Animated Epic "Prologue", "The Arrival", "Entry',
#  'Buried at Jama Masjid pethahmadpur, Ashti',
#  'British neoconservatism has also been directly influenced',
#  'the Ordinary Congress. Kosovo were accepted into UEFA after members voted 2824 in favor',
#  'sessions in other Southern prisons. This was the role fulfilled the previous year by Lead',
#  'Thomas Atkinson. Their house, known as Meerkat Meade, was featured in Weird Maryland.',
#  'plans, but mentioned that "perhaps the Temple may be rebuilt, as a symbol of Jewish unity,',
#  'the FA reinstated the Oxford goal,',
#  'margin (exciple) around the fruit body disc (apothecium), eight-spored, Micarea-type asci',
#  'such as Lyndon B. Johnson as a pre-eminent Irish-American, with special connections to',
#  'honour at the St.',
#  'a letter to Asquith on 16 March',
#  'the late 1970s was spent playing at Bulverhythe, home to Hastings Rangers, whilst the',
#  'B, Pt. II, the band continued to',
#  'University, Kishwaukee College, and McHenry County College, thus enhancing the academic',
#  '26.2% under the age',
#  'J-call is a series of fast',
#  'Baker was his prison name. He was generally referred to by his nickname Iron Head. His',
#  'while this was',
#  'corporation, Commander of',
#  'the University of Paris in 1966. When the university split in 1968, she moved to Paris',
#  'no benefit from his breach of',
#  'in Say, Niger west of Niamey.',
#  'of Macedonia ^ - ILO Convention C177 Text. Ratifications. Kingsey is a small village and',
#  'Lewin (1) NWA Austra-Asian',
#  'four junior high schools and one senior high school, as head of the Department of History',
#  'Zion Church Albert George Sandeman (21 October 1833 6 January',
#  'to manufacture and supply craft beer,',
#  'retired. Jan',
#  'The National Association of Television and Radio Announcers gave Shaft its Album of the',
#  'contributor to the A Profound',
#  'operations, an average of 13 per',
#  'defence at his trial, as well as his unwavering affirmation of Lusiuss attempts to seduce',
#  'who assumed the surname of Magill. The',
#  'The cottage overlooked the',
#  'A 1960s photographic archive Andrew McGovern (born 7 April 1968)',
#  'is considering additional policies to enhance competitiveness, including a new Foreign',
#  'two species are known only from coastal areas in South Africa. Workers are large (10.513.0',
#  'Supernatural, Stein & Day, New',
#  'different part of the world making mercury pollution a global concern. Mercury pollution',
#  'afterwards, Spencer shot dead 70-year-old',
#  'the bottom of the overgrown embankment. In 1984, Greater Manchester Council and GMPTE',
#  'was not until 1982 that Bluth, having left Disney, took a similar idea into pre-production,',
#  '1969 (including an unreleased take of Whitten\'s "Look at All the Things" and a performance',
#  'Nicaragua). This is one of the few Bromelioideae species',
#  'trace cases or crop circles) Electromagnetic interference (EM) effects. A famous 1976',
#  '1975. The film King of the Hill (1993), directed by Steven Soderbergh, is a screen adaptation',
#  'ties between the two countries were',
#  'his ranch in Ursula, Wyoming,',
#  'on September 22, 2019. NY Times Bobby Walston at Find a Grave Winding around the inferior',
#  'Guilty - to be transported for 15 years".On 18 March 1842 an adjoining grant previously',
#  "Women's Singles title at the 1972 French Open and complete a career Grand Slam in singles.The",
#  'to the community. Henry George Judkins, of',
#  'under-lieutenant (GARF) for his (then',
#  'detail by Titian to',
#  'as did other investigations, that less than one',
#  'Wall lived on the site',
#  'the list of foreign',
#  'Berkman (born 1947), president, Cleveland State',
#  'and glossa (tongue), referring to the two tooth-like calluses on the base of the lip.',
#  '33, he was named',
#  'Dowdell, of Katanning. For services to the community.',
#  'his second',
#  'Army Pay Corps. Major Colin Edward Grundy (443458), Royal Corps of Signals. Major Barry',
#  'in Uttarakhand. It offers a three-year LLB program, five-year BA LLB, BBA LLB programs,',
#  'which 35.0% had children under the age of 18 living with them, 53.2% were married couples',
#  'Riding of Yorkshire, Sowerby appears in the Domesday Book of 1086, and was an important',
#  'is the hub of campus life, providing a venue for the entire University community to gather',
#  "golfer. Award-winning children's author Martin Waddell, although born in Belfast has lived",
#  'the autumn of 1870, Professor',
#  'to the 2001 census had a population',
#  'to cover prescription contraceptives, but the federal mandate innovated',
#  "husband's. Leonora became part of Isabella's circle and renowned for her beauty and vivacity.",
#  'civilians were reported to have been killed',
#  'the club colours were red',
#  'to another denomination. He organized',
#  'in which she used the',
#  'from Stortorvet to Ster. The company also built a line to Simensbrten that was closed',
#  'After controlling for FamaFrench risk factors, fundamentally based indices exhibit a small',
#  'later he joined "Fri Flyt", and collaborated with Shetland musicians like Willie Hunter',
#  'services of Count Henry II,',
#  "An Elizabethan Virginal Book 1905. Fuller, J. A., 'Edward Naylor', Grove Dictionary of",
#  'Kent, St. John Ambulance Brigade. Richard Woffenden, Local Officer I, Department of Health',
#  'the pairing finished the season as champions, taking four victories to secure the title',
#  'through the merger and restructure of six',
#  'Century Fox.Although A Troll in Central',
#  'Nueva Generacin), created in 1972. By 1976 the party was part of the Democratic Convergence',
#  'the World Trade Organization (WTO), Botswana also joined; many of the SACU duties are',
#  'introduced. At its peak, thousands of people were employed at the works. The steelworks',
#  'Odontoglossum into Oncidium is followed, most of following nothogenus names are obsolete',
#  'Thomas Taylor, Chairman, Yeovil District Council. Ruth Thomas,',
#  'is a successful and rich architect, living',
#  'to the genus from Lecidea in 2005, while H. wankaensis was described as a new species',
#  'by Pakistan Army while 6 soldiers were injured. Pakistani authorities stated on 14 November',
#  'Nicky Dent. Transfer fee received: 50,000 from Nottingham Forest, for Paul Smith. Most',
#  "Whitten's escalating heroin abuse (partially attributable to the rhythm guitarist's severe",
#  'of Muslims, technically and morally',
#  'the arrondissement had a total population of 8979. The Galpagos Marine Reserve (GMR) lies',
#  "Major Lionel Allibone, Her Majesty's Bodyguard of",
#  'the plan was to have him',
#  'pastoral landscape in the Italian countryside. It is not explicitly stated or described',
#  'this "thinking man\'s',
#  'ruins of the stupa were found on land which is used by a recently built Hindu shrine.',
#  'injury-shortened yet Hall of Fame career with the Chicago Bears; John Riggins, another',
#  'Murray Pulver guitars, mandolin & additional vocals, Daniel Roy drums & percussion, Don',
#  'joint venture between ICI (48%), I.G. Farbenindustrie (30%) and F.A. Hughes & Co (22%).',
#  'the University of Denver from 1932',
#  'stratigraphic units in Mexico Various Contributors to the Paleobiology Database. "Fossilworks:',
#  'oto/cinema/Drammatico/1969/c',
#  'Deployed October 2015 (replacing 28 Battalion?) and returned',
#  'sermons, his beautiful singing voice, and his talent for playing the accordion."Several',
#  'to this doomsday scenario is very different in the two works. "History Lesson" was included',
#  'M. Pollock. Enos Stutsman. Henry Browne Blackwell. Lillie',
#  'She was awarded the Goldman Environmental Prize in 2001, for her contributions to the',
#  'friendly approach, charismatic stage performance, and his commitment to his music. In',
#  'Party leadership election (Held on April 17, 2011.) See 2014 British Columbia New Democratic',
#  'SmartBear Software and Pragmatic Software, which were acquired in 2007 and 2009. AutomatedQA',
#  'explain the results in hypertexted English. The subject knowledge needed to do this (e.g.',
#  '"I Should Have Known Better", "And I Love Her", "Ringo\'s Theme", and "A Hard Day\'s Night".',
#  'policy, White was appointed',
#  'George chose him to be the spokesmodel for his clothing line RUDE. Gold died from leukemia',
#  'policeman." Daley would later state that his wellsprings were his religion, his family,',
#  'In 1971, it was renamed William Paterson College of New Jersey. The change of name honored',
#  'heart attack and he was',
#  'asks for retransmission or',
#  'attacked and destroyed U-354, one of two accounted for, for the loss of one escort, HMS',
#  'John Hetherington & Sons at Internet Archive The Solomon Islands Alliance for Change is',
#  'Hamelin story. While',
#  'of complex enzyme driven metabolic pathways taking place inside microbial cells. In abiotic',
#  'Morrow, Royal Corps of Signals. 23674745 Staff',
#  'for Rotorua are',
#  "sextet recorded The Rockets' only album, a self-titled set released in 1968 on White Whale",
#  'up in Venezuela and began wrestling',
#  'tenth of eleven children of John Henry Parnell, a landlord and Delia Tudor Stewart Parnell,',
#  'gate and road on both',
#  'the original castle compound. The 3rd',
#  'Line (uncredited) Bruce Montague as Brooks (uncredited) Ian Parsons as Health Inspector',
#  'fields of orthopaedic surgery and paraplegic and',
#  'on the far side of the Moon. Among copycats was a shadowy British figure named Cedric',
#  'Sundance Film Festival. The film received almost unanimous critical praise and was described',
#  'of Eastbourne in East Sussex. The site includes',
#  'Council 19861992 Director, Homeless Network 19951998 Chair of Refugee Council 19982003',
#  'sector. On 29 June, Indian military reported that two Indian soldiers were injured after',
#  'it',
#  'to the ground being so',
#  'Arabia SPC. The magazine is based in Manama, the capital of Bahrain. Launched in 2001,',
#  "his lecture notes (Mead's Carus Lectures,",
#  'by Legacy Recordings. The',
#  'he or she begins taking',
#  'Lesbian and Gay Archives Australian Archives of the Dance Australian Data Archive Australian',
#  'during this time Julia undertook policy analysis,',
#  'Hollywood" 1:00 "Freaky If',
#  'Naval Staff Admiral Marsetio in a joint ribbon-cutting',
# ...
#  'of occasions, most notably as a UK No. 1 double A-side in 1977 with Cat Stevens\'s "The',
#  'Austria and she "later worked on Miocene forms, and made a major contribution on Pectinids.',
#  'a massacre of Protestants took',
#  'classic level of showmanship like',
#  'Ireland, Spring 1999. Margaret Ward, Unmanageable Revolutionaries: women and Irish nationalism,',
#  'Marty Mason and Steve',
#  'to save Chicago from the declines that other rust belt cities such as Cleveland, Buffalo,',
#  'winner Tim Elliott via unanimous decision after',
#  'Ringo had said. I had used',
#  'prevent it from participating in stock market crashes. When fundamentals change rapidly',
#  'work, is scored for SSATTB (2 sopranos, alto, 2 tenors, bass) chorus alternating with',
#  'put themselves in a position where their',
#  'The presenter said "...it\'s hard to overstate',
#  'communication from aircraft back to',
#  'Marion Lethbridge. For medical and welfare services to the community in the Ivory Coast.',
#  'disease. Most of the land under cultivation is in the eastern region. The principal crops',
#  'Zentralverband deutscher Konsumgenossenschaften e.V Venus Flytrap (also known as Body',
#  'US 4 near the center of Bridgewater village, which spills over into western Woodstock.',
#  'to live',
#  'Northwest university courses are mentioned below. Department',
#  'It was possibly Wilbur who suggested to President-elect Hoover that Cooper be appointed',
#  'Directory of Universities in OIC Member Countries. Islamic University in Niger. Website',
#  '(Semifinalist) Virginia Wade (Quarterfinalist) Helga Niessen Masthoff (Semifinalist)',
#  'the 81 provinces of the Philippines.',
#  'rules football. William Henry Desborough Rogers,',
#  'his body but they find themselves surrounded by an army of Sam clones, who recover the',
#  'spare couple of weeks between up-ending the British class system and conquering America,',
#  'the development of more constructive responses to',
#  'him on his second solo album. Although all',
#  'for the energetic costs of carrying and',
#  'marked the start of a',
#  'There are also club-level sports for',
#  'Various notables have also expressed such views.',
#  'Series (DLS), which brings speakers from the worlds of politics, government, the arts,',
#  'transferred to the Channel',
#  'has gained. In the present',
#  'card at just the right time." Eric',
#  "Junior Hanson in 1973 and were signed to Emerson, Lake and Palmer's record label Manticore.",
#  'The main settlement in the parish is Langton Hall (not to be confused with another Langton',
#  'days after the first match at Old Trafford ended in a goalless draw. 11 January 1975:',
#  'broadcasts. The university has produced the Distinguished Lecturer',
#  'station building was constructed, also drawn by Erik Glosimodt. This was to be the "main',
#  'their history. 10 August: On a rainswept Arena Joondalup, East Perth score only 0.9 (9)',
#  'Council for a negotiated peace. Live Acoustic Tour 2006 is the seventh album by American',
#  'a list of common Ni(II) salts and',
#  'Escobar Inc sent bogus product orders consisting of a book, allowing Escobar Inc to claim',
#  'final Cabinet meeting for the year. LPG',
#  'at least as perceived by critic and fellow editor Otto Penzler, was Svengali-like: Ball,',
#  "it did deliver a huge rush of action thrills at the end. It's stripping down the characters",
#  'and a steep',
#  'causes them to be insoluble, accumulate, and have a neurotoxic effect.For glycogen to',
#  'Lendinara Cathedral altarpiece is stylistically similar to',
#  'Lionsgate, and later by Waterman Entertainment, the production company of producer Steve',
#  'For services to the community in Downham',
#  "century, Botswana's economy registered strong levels of growth, with GDP growth exceeding",
#  'and reflect more of the boy\'s role than the girl\'s".Cooper and Lombard reportedly had',
#  'as a result of the heat wave in Chicago in 1897. After a funeral which included 100 priests,',
#  'and involved in the Battle for Mogadishu. 11 Battalion (Lt. Col. Gregoire Ndikumazambo).',
#  'Uganda Premier League. He played 30 games and scored 4 goals. In 201516 Wadada became',
#  'of Lawrence) and the western frontier towns of Missouri throughout the 1850s. The incidents',
#  'the ootheca is ejected',
#  'having "extraordinary stage presence". The Sound of Perseverance is the seventh and final',
#  'won 32 on aggregate. The final was played on 14 May 2015 at in Berlin, Germany. The "home"',
#  "Chicago, Tolton led the development and construction of St. Monica's Catholic Church as",
#  'Democratic Youth of Denmark. In 1974, she',
#  'remains of an ancient church and the old bridge which once carried the coast road can',
#  'colonial Governor of Maryland Francis Nicholson.',
#  "trainers who work with [AMISOM's] Ugandan and Burundian troops. Bancroft director Michael",
#  'finishes. Peter Sillett took charge of the club and built up a side that eventually won',
#  'Linda Tuero (First round) Q = Qualifier WC = Wild Card LL = Lucky Loser r. = retired 1972',
#  'Migeon became the sole director when Blizzard left in 1974, and held the role until 1994.',
#  'United States, setting up a studio in Burbank, California named West Olive, later to become',
#  'Lombard as Kay Dowling Helen Ware as Aunt Bessie Lester Vail as Herbert Forrest Charles',
#  'when the militants mutilated',
#  'committed to the peacekeeping mission, pledging up to 1,000 troops. By 27 March, it was',
#  'with a new vision of things to come, some changes in the band were made. Ahmad enlisted',
#  'high rate of HIV/AIDS infection (one in every three adults is seropositive) and unemployment',
#  'in his band the Puta Madres,',
#  'faculty at Carnegie Mellon University,',
#  'Poonch sector and killed two Indian soldiers. The same day, two Pakistani civilians were',
#  'MoD said it would continue to release UFO files to the public through The National Archives.',
#  'century it was the',
#  'career as a high school',
#  'on 8 May 1995 in Rome. Celluloide at IMDb Gunhill Road are an American rock band formed',
#  'included a presentation at the 1989 San Diego Comic-Con and sales of animation cels from',
#  'and rehabilitation services to Oklahoma, Logan, and',
#  'that he was able',
#  'results Space age pop is',
#  'Harrison Line. Joseph Geoffrey Roberts, Regional Pharmaceutical Officer,',
#  'meeting with Spencer, told him that he saw through Spencer\'s "kindly old grandfather schtick",',
#  'Americas were not a priority',
#  'of Buff Point, New South Wales. For services to the pig industry. Ian Castles, of Narrabundah,',
#  'Human Services Secretary Kathleen Sebelius announced a',
#  'reserves, with their abundant wildlife and',
#  'the 18th-century and with him referred to as one of the most noted actors of her time.',
#  'My Favorite Religion 2013: Play My F**kn Record 2013: Love Goddess (Remix) 2015: Sex Like',
#  'Paris and Sller. Sicilia was born in Madrid and grew up in Francoist Spain. He spent his',
#  '"Rescue Me" "What Am I" (acoustic) "Turn the Other Way" (acoustic) "Wartime" "Can\'t Find',
#  'the player must destroy several enemy',
#  'Kahn would produce over the following twenty',
#  'and his officers and attendants',
#  'a quick cooking ("instant") stuffing that is available in supermarkets. Unlike traditional',
#  'It was founded in 1999 in Las Vegas, Nevada, and is currently based in Somerville, Massachusetts.',
#  'Many customers, when ordering the',
#  'Readers Association. John Francis McClure, Secretary, Northern',
#  'executive producer Steve Waterman. As such, it now does',
#  'The Reverend Alfred Victor Smith. For welfare services to',
#  'primer like BR-127 has shown to produce adhesive joints comparable to ones produced by',
#  'and a primer application. Aluminium oxide or Alumina and Silicon carbide are most commonly',
#  'CAPM model are inefficient.If we assume',
#  'Planner, Department of the Environment. Dick Harry Walker, lately Deputy Chairman, Southern',
#  'is not generally considered credible in mainstream science. There was, in the past, some',
#  'when the New Statesman\'s issue of 4 January 2013 stated: "The Swilgate, the tributary',
#  'in 1996. Inview provided a chip based EPG, broadcast data service and a digital TV software',
#  'deployed to Afghanistan as part of Operation Slipper in 2010, with 6 RAR forming the basis',
#  'from office for up to five years. In the previous month Western Australian Premier Mark',
#  'Man) 2009: I Can Forgive You 2010: Mr. Mistress 2010: Make My Body Rock 2011: Sparkle',
#  'grid and unique fly system, the semi-circular thrust',
#  'services to the community in Belize. Thomas',
#  'out of this college, go out',
#  'thereafter, Talbot and Molina hired former',
#  'made appearances in The Inheritance (2011), and',
#  'bare physical objects which psychological behaviourists',
#  'great start to the year. He did not regain his consistent form until the final games of',
#  'Darling Wilson, QC, of Nedlands. For services to the community. Sir Hugh Maxwell Casson.',
#  'north-western Malaysia as a ready reaction force known as Rifle Company Butterworth, a',
#  'the Finest, opened in late 1978.New Zealand band Salmonella Dub will release the single',
#  'since 1960 voters had a choice of',
#  'this song at MetroLyrics David',
#  'and stop Lafora bodies from forming.Other researchers',
#  'Atlantic Coast, mainly Nantes, La Rochelle, Lorient and Bordeaux, became very active in',
#  'of Graphics along with Best use of Social Media, Instagram. WPSC also won for Best Sports',
#  '1960s portal Bennett M. Berger, "Hippie moralitymore old',
#  "Johannes Meyer as Pastor Mikael Rolff Lisbeth Movin as Troels' Girlfriend Sonja Ib Schnberg",
#  'Murre in North America. Nunavik',
#  'Bay Rowdies in front',
#  'US-backed, Western means to',
#  'waters. The class comprised O 9, O 10, and O 11. Its diving depth was 60 metres (200 ft).',
#  'having gone to bed, she was surprised by Lord Pietro [with] a dog leash at her throat,',
#  'coordination cell in Mogadishu at the request',
#  'the threat of German rearmament. Following the',
#  'in July 2000 for a period of three',
#  'government programmes. In early 1990, the government changed its official agricultural',
#  'after the trade of',
#  '2004 in London, England, aged 55. He is buried at the East London Cemetery and Crematorium.',
#  'Science and Applied Mathematics and Sessional',
#  'not initially respond when Hussie started',
#  'used by Nicolas Bernard Lpici to describe',
#  'to have made a',
#  '"Keeping up with the Joneses"',
#  'the canonical and symbolic character of such images is documented by art historians placing',
#  'Child magazine, November 2007 "Top 10 Best Audio Products," Dr. Toy "Top 100 Best Products,"',
#  'tour with Nek and Francesco Renga and released Max Nek Renga, Il Disco, which contains',
#  'at the London School of',
#  'money for the Malcolm Sargent Cancer Fund for Children. One of his other great passions',
#  'created a router. William Yeager wrote the software, which was later adopted and evolved',
#  'founded in Patagonia in 1991.Spectrum wrote that the beginning of the film was deceptive',
#  'companies that have',
#  'operations. It can also be used for law enforcement,',
#  'amblybregmatus Gutherz & Blackman, 1970 Citharichthys arctifrons Goode,',
#  'have taken four or five months',
#  'any organic food source available, including leaf matter. In captivity, it is recommended',
#  'channel also featured reality shows syndicated from other networks (such as ABC, CBS,',
#  'support came in the forms of',
#  'a hundred university and high',
#  'group that played in touristic areas of La Cordillera de los rganos. He lived in la Caada',
#  'song "Child of War". The split with Sampedro and Young proved relatively short-lived,',
#  'civilians were killed and two wounded',
#  'the studio became part-time instructors at the college. The success of the animation course',
#  'quasi-government and the private sector can',
#  'us out." John Lomax devoted a chapter to the two singers in his autobiographical Adventures',
#  'jitter during congestion. In cases where quality of service is rate limiting a connection,',
#  'Creeting St Mary Pits is a 5.4 hectare geological Site of Special Scientific Interest',
#  'context of the building includes an erotic epigram by the Greek poet Callimachus, painted',
#  'Don Bluth and Gary Goldman went on to head up Fox Animation Studios in Phoenix, Arizona',
#  'consistency on the field.Camilo signed a contract extension with Vancouver on 1 February',
#  'in 2019-20 season was',
#  'Note: The common law rule laid down in this case has now been codified in many countries',
#  'ISBN 978-1-84832-049-9. Gardiner, Robert; Gray, Randal, eds.',
#  'Spanish in the Philippine Revolution. On September 6, 1898, Fullon, now a general in the',
#  '(1): 1996 Premier 2 League (1): 1999 1987 SEA Games:Runners-up 1993 Premier 1 League:',
#  'Correct as of 25',
#  'upheld by the Court',
#  '73 on aggregate. Paris Saint-Germain',
#  'members of 15 Battalion Kenya Rifles, was overrun and up to 50 Kenyans killed. Kenyan',
#  'Civic Center) is a 32-floor',
#  'on four occasions, plus the Sussex Senior Challenge Cup twice. The club also saw success',
#  'a "field" (i.e. without claiming that there is "really" a field), with its own field quanta,',
#  'music. Max Pezzali was born',
#  'of this process at work is White v. Jones [1995] 2 AC 207 where by a majority the House',
#  'became engaged to Edna Curtis of Sacramento 10 days before the San Francisco earthquake',
#  'Store in 2011. In 2011, MiNT released',
#  'to a fatal overdose of alcohol and',
#  'a second dead militiaman was discovered.Four',
#  'I prefer to',
#  '750 yards, garnering 18.3 yards per reception, scoring five touchdowns. The next season,',
#  'the Second World War, however, as a',
#  'Prince Haakon, heir apparent to the throne, and the second granddaughter of King Harald',
#  'M. Daley, served as White House Chief of Staff under President Barack Obama and as US',
#  'year\'s Folk Musician 2019: "Bananasmjrhonor",for good Vossajazz 2008: Rio Aga (NorCD)',
#  'beat Cyprus 50 in a European Championship qualifier. He is the first England player for',
#  'the city of Salisbury. The parish is on the county boundary with Hampshire and is close',
#  'in their area of operations had been so badly weakened that they were forced to operate',
#  "who also plays guitar for Liam Gallagher. It's Not My Thing contains the riff from the",
#  '1927Big Six Conference (12) 1931, 1932,',
#  'who went on to do important work in cytology is Susan Gerbi. She cowrote an article about',
#  'occurred. The Inter-Services Public Relations said that there had been only "cross border',
#  'medical evacuations and rescue operations. The X18 Tank Boat is a catamaran design for',
#  'Hedgehog, a new anti-submarine weapon, which she was first to trial. Following this Enchantress',
#  'In 1996, the 16,500-acre (6,700 ha) Spring Fire burned through much of the Wilderness.',
#  'carrier of Eswatini. Swaziland Airlink started operations in July 1999 with a leased Fokker',
#  'Ceriomura is a genus of South American jumping spiders that was first described by Eugne',
#  'Wollert, Victoria. For service to the meat industry. Robert Evelyn Porter, of Gilberton,',
#  'Ki (born 16 December 1978 in Preov)',
#  'and has blue eyes with',
#  'Australian country outfits on the album "seem to bland out with their attempt at authentic',
#  "anecdotes of Gioia's experience of the tunes. He considers The Jazz Standards: A Guide",
#  "Uganda People's Defence Force. In the northern spring",
#  'Borders Health Board. Roderick James Rogers Armstrong, Chief Engineer',
#  "October 2019, Scaffidi's term as Lord Mayor expired",
#  'Armies in Manchuria during the Russo-Japanese War, Vol. I; (1907). Vol. II. Washington,',
#  'were all capable of both',
#  'industrial heritage museum at Amberley, near Arundel in West Sussex, England. The museum',
#  'covering the games attended the early morning cycling events, Twombly slept in; he claimed',
#  'on February 15, 2020 at the age of 102. The Boyhood Memoirs of A. E. Hotchner: King of',
#  'Wyoming Pioneer Association Wyoming State Fair: Official Website Oslo Kajakklubb is a',
#  ...]

# %% [markdown]
# # Split data #

# %%
train_split = int(0.9 * len(dataset))
val_split = int(train_split + 0.09 * len(dataset))
# test_split = int(train_split + 0.1 * len(dataset))

train_labels = dataset[:train_split]
val_labels = dataset[train_split:val_split]
test_labels = dataset[val_split:]

# val_labels = dataset[train_split:val_split]
# test_labels = dataset[val_split:]

print('Len train: ' + str(len(train_labels)))
print('Len val: ' + str(len(val_labels)))
print('Len test: ' + str(len(test_labels)))
# Out:
# Len train: 30918
# Len val: 3091
# Len test: 345

# %% [markdown]
# # Model #

# %%
timesteps = 256

width = 4096
height = 64

max_label_len = longest_label + 2
max_label_len
# Out:
# 111

# %%
from tensorflow.keras import applications, backend as K
from tensorflow.keras import models, losses, optimizers, Model, utils
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, MaxPooling2D, Dropout
from tensorflow.keras.layers import Flatten, Dense, Lambda, Reshape, Bidirectional, LSTM, GRU
from tensorflow.keras.layers import Activation, add, Concatenate, Attention, Embedding
from keras_self_attention import SeqSelfAttention


def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

def build_model(num_classes=94, timesteps=timesteps, max_label_len=max_label_len, input_shape=(4096, 64, 1), training=False):
    inputs = Input(name='the_inputs', shape=input_shape, dtype='float32')
    
    # Convolution layer (VGG)
    inner = Conv2D(32, (3, 3), padding='same', name='conv1-1', kernel_initializer='he_normal')(inputs)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(32, (3, 3), padding='same', name='conv1-2', kernel_initializer='he_normal')(inputs)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(2, 2), name='max1')(inner)

    inner = Conv2D(64, (3, 3), padding='same', name='conv2-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(64, (3, 3), padding='same', name='conv2-2', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(2, 2), name='max2')(inner)

    inner = Conv2D(128, (3, 3), padding='same', name='conv3-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(128, (3, 3), padding='same', name='conv3-2', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(4, 2), name='max3')(inner)

    inner = Conv2D(256, (3, 3), padding='same', name='conv4-1', kernel_initializer='he_normal')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(256, (3, 3), padding='same', name='conv4-2')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = MaxPooling2D(pool_size=(1, 2), name='max4')(inner)

    inner = Conv2D(512, (2, 2), padding='same', kernel_initializer='he_normal', name='con5-1')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)
    inner = Conv2D(512, (2, 2), padding='same', kernel_initializer='he_normal', name='con5-2')(inner)
    inner = BatchNormalization()(inner)
    inner = Activation('relu')(inner)

    # CNN to RNN
    inner = Reshape(target_shape=((timesteps, 2048)), name='reshape')(inner)
    inner = Dense(128, activation='relu', kernel_initializer='he_normal', name='dense1')(inner)
    inner = Dropout(0.2)(inner)

    # RNN
    lstm1 = Bidirectional(LSTM(256, return_sequences=True, kernel_initializer='he_normal', 
                               name='lstm1'))(inner)
    lstm2 = Bidirectional(LSTM(512, return_sequences=True, kernel_initializer='he_normal', 
                               name='lstm2'))(lstm1)
    
    attention = SeqSelfAttention(attention_width=15, 
                                 attention_activation='sigmoid', 
                                 name='Attention')(lstm2)
#     attention = Dropout(0.2)(attention)
    
    # RNN output -> character activations:
    outer = Dense(num_classes + 1, kernel_initializer='he_normal', name='dense2')(attention)
    y_pred = Activation('softmax', name='softmax')(outer)

    labels = Input(name='the_labels', shape=[max_label_len], dtype='float32')
    input_length = Input(name='input_length', shape=[1], dtype='int64')
    label_length = Input(name='label_length', shape=[1], dtype='int64')

    # Keras doesn't currently support loss funcs with extra parameters
    # so CTC loss is implemented in a lambda layer
    loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([y_pred, labels, input_length, label_length]) #(None, 1)
    
    y_func = K.function([inputs], [y_pred])
    if training:
        return Model(inputs=[inputs, labels, input_length, label_length], outputs=loss_out), y_func
    else:
        return Model(inputs=[inputs], outputs=y_pred)

# %%
model, y_func = build_model(timesteps=timesteps, max_label_len=max_label_len, training=True)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_inputs (InputLayer)         [(None, 4096, 64, 1) 0
# __________________________________________________________________________________________________
# conv1-2 (Conv2D)                (None, 4096, 64, 32) 320         the_inputs[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 4096, 64, 32) 128         conv1-2[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 4096, 64, 32) 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# max1 (MaxPooling2D)             (None, 2048, 32, 32) 0           activation_31[0][0]
# __________________________________________________________________________________________________
# conv2-1 (Conv2D)                (None, 2048, 32, 64) 18496       max1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 2048, 32, 64) 256         conv2-1[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 2048, 32, 64) 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2-2 (Conv2D)                (None, 2048, 32, 64) 36928       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 2048, 32, 64) 256         conv2-2[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 2048, 32, 64) 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# max2 (MaxPooling2D)             (None, 1024, 16, 64) 0           activation_33[0][0]
# __________________________________________________________________________________________________
# conv3-1 (Conv2D)                (None, 1024, 16, 128 73856       max2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 1024, 16, 128 512         conv3-1[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 1024, 16, 128 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv3-2 (Conv2D)                (None, 1024, 16, 128 147584      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 1024, 16, 128 512         conv3-2[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 1024, 16, 128 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# max3 (MaxPooling2D)             (None, 256, 8, 128)  0           activation_35[0][0]
# __________________________________________________________________________________________________
# conv4-1 (Conv2D)                (None, 256, 8, 256)  295168      max3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 256, 8, 256)  1024        conv4-1[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 256, 8, 256)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv4-2 (Conv2D)                (None, 256, 8, 256)  590080      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 256, 8, 256)  1024        conv4-2[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 256, 8, 256)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# max4 (MaxPooling2D)             (None, 256, 4, 256)  0           activation_37[0][0]
# __________________________________________________________________________________________________
# con5-1 (Conv2D)                 (None, 256, 4, 512)  524800      max4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 256, 4, 512)  2048        con5-1[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 256, 4, 512)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# con5-2 (Conv2D)                 (None, 256, 4, 512)  1049088     activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 256, 4, 512)  2048        con5-2[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 256, 4, 512)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 256, 2048)    0           activation_39[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 256, 128)     262272      reshape[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 256, 128)     0           dense1[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 256, 512)     788480      dropout_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 256, 1024)    4198400     bidirectional_4[0][0]
# __________________________________________________________________________________________________
# Attention (SeqSelfAttention)    (None, None, 1024)   65601       bidirectional_5[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, None, 95)     97375       Attention[0][0]
# __________________________________________________________________________________________________
# softmax (Activation)            (None, None, 95)     0           dense2[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         [(None, 111)]        0
# __________________________________________________________________________________________________
# input_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# label_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           softmax[0][0]
#                                                                  the_labels[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 8,156,256
# Trainable params: 8,152,352
# Non-trainable params: 3,904
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

plot_model(model=model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %% [markdown]
# # Data generator #

# %%
import itertools

def return_classes(string):
    text = [' '] + list(string) + [' ']
    classes = [data.index(x) if x in data else 1 for x in text]
    return np.asarray(classes)

def return_text(classes):
    text = ''
    for c in classes:
        if 0 <= c < len(data) and c != 1:
            text += data[c]
    return text

def decode_batch(out, callback=False):
    ret = []
    for i in range(out.shape[0]):
        out_best = list(np.argmax(out[i, 2:], 1))
        out_best2 = [k for k, g in itertools.groupby(out_best)]
        outstr = return_text(out_best2)
        if callback:
            print(f'{out_best} -> {outstr}')
        ret.append(outstr)
    return ret

def gen_text_image(text, padding=16):
    font = random.choice(fonts)
    font_size = random.randrange(30, 61)
    fnt = ImageFont.truetype(font, font_size)
    width, _ = fnt.getsize(text)
    img = Image.new('L', (width + (padding + 1) * 2, 64), color=255)
    d = ImageDraw.Draw(img)

    if 'calibri' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'verdana' in font:
        d.text((padding + 2,-8), text, font=fnt, fill=0)
    elif 'constan' in font:
        d.text((padding + 2,0), text, font=fnt, fill=0)
    elif 'corbel' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'consola' in font:
        d.text((padding + 2,2), text, font=fnt, fill=0)
    elif 'cour' in font:
        d.text((padding + 2,-4), text, font=fnt, fill=0)
    elif 'tahoma' in font:
        d.text((padding + 2,-8), text, font=fnt, fill=0)
    else:
        d.text((padding + 2,-6), text, font=fnt, fill=0)
        
    image = np.array(img)
    image = add_salt_and_pepper(image, 0.2)
    image = otsu_thresholding(image)
    image = inverse(image)
    image = (image / 255.) * 2. - 1.
    return image

def inverse(image):
    return cv2.bitwise_not(image)

def add_salt_and_pepper(image, amount):
    output = np.copy(np.array(image))
    # add salt
    nb_salt = np.ceil(amount * output.size * 0.5)
    coords = [np.random.randint(0, i - 1, int(nb_salt)) for i in output.shape]
    output[coords] = random.randint(50,200)

    # add pepper
    nb_pepper = np.ceil(amount * output.size * 0.5)
    coords = [np.random.randint(0, i - 1, int(nb_pepper)) for i in output.shape]
    output[coords] = random.randint(0,100)
    return np.asarray(Image.fromarray(output))

# %%
class TextImageGenerator:
    def __init__(self, labels, img_w=4096, img_h=64,
                 batch_size=16, timesteps=timesteps, training=True, max_text_len=max_label_len):
        self.dim = (img_w, img_h, 1)
        self.batch_size = batch_size
        self.max_text_len = max_text_len
        self.labels = labels
        self.n = len(self.labels)
        self.indexes = list(range(self.n))
        self.training = training
        self.cur_index = 0
        
    def next_sample(self):
        self.cur_index += 1
        if self.cur_index >= self.n:
            self.cur_index = 0
            random.shuffle(self.indexes)
        return self.labels[self.indexes[self.cur_index]]
            
    
    def next_batch(self):
        while True:
            X = np.zeros((self.batch_size, *self.dim))
            y = np.zeros((self.batch_size, self.max_text_len), dtype=int)
            input_length = np.full((self.batch_size, 1), timesteps, dtype=np.float32)
            label_length = np.zeros((self.batch_size, 1), dtype=np.float32)
            
            for i in range(self.batch_size):
                label = self.next_sample()
                # Store sample
                image = np.swapaxes(gen_text_image(label), 0, 1)
                image = np.expand_dims(image, -1)
                X[i, 0:image.shape[0], :] = image

                # Store class
                label_classes = return_classes(label)
                y[i, :len(label_classes)] = label_classes
                label_length[i] = len(label_classes)

            inputs = {
                'the_inputs': X,  # (bs, 4096, 64, 1)
                'the_labels': y,  # (bs, max_label_len)
                'input_length': input_length,  # (bs, 1)
                'label_length': label_length  # (bs, 1)
            }
            outputs = {'ctc': np.zeros([self.batch_size])}   # (bs, 1)
            yield (inputs, outputs)

# %% [markdown]
# # Callbacks #

# %%
import editdistance
from datetime import datetime
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.callbacks import TensorBoard, ReduceLROnPlateau, Callback

class VizCallback(Callback):
    def __init__(self, y_func, text_img_gen, text_size, num_display_words=10):
        self.y_func = y_func
        self.text_img_gen = text_img_gen
        self.num_display_words = num_display_words
        self.text_size = text_size

    def show_edit_distance(self, num):
        num_left = num
        mean_norm_ed = 0.0
        mean_ed = 0.0
        while num_left > 0:
            word_batch = next(self.text_img_gen.next_batch())[0]
            num_proc = min(word_batch['the_inputs'].shape[0], num_left)
            # predict
            inputs = word_batch['the_inputs'][0:num_proc]
            pred = self.y_func([inputs])[0]
            decoded_res = decode_batch(pred)
            # label
            labels = word_batch['the_labels'][:num_proc].astype(np.int32)
            labels = [return_text(label) for label in labels]
            
            for j in range(num_proc):
                edit_dist = editdistance.eval(decoded_res[j], labels[j])
                mean_ed += float(edit_dist)
                mean_norm_ed += float(edit_dist) / len(labels[j])

            num_left -= num_proc
        mean_norm_ed = mean_norm_ed / num
        mean_ed = mean_ed / num
        print('\nOut of %d samples: \nMean edit distance:'
              '%.3f \nMean normalized edit distance: %0.3f \n'
              % (num, mean_ed, mean_norm_ed))

    def on_epoch_end(self, epoch, logs={}):
        batch = next(self.text_img_gen.next_batch())[0]
        inputs = batch['the_inputs'][:self.num_display_words]
        labels = batch['the_labels'][:self.num_display_words].astype(np.int32)
        labels = [return_text(label) for label in labels]
         
        pred = self.y_func([inputs])[0]
        pred_texts = decode_batch(pred)
        
        for i in range(min(self.num_display_words, len(inputs))):
            print("label: {} - predict: {}".format(labels[i], pred_texts[i]))

        self.show_edit_distance(self.text_size)

# %%
batch_size = 16
train_generator = TextImageGenerator(train_labels, training=True, batch_size=batch_size)
val_generator = TextImageGenerator(val_labels, training=False, batch_size=batch_size)
test_generator = TextImageGenerator(test_labels, training=False, batch_size=batch_size)

log_dir = "logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
output_dir = './models/VGG/LocalAttention'
weight_path = f'{output_dir}/ocr_model_{datetime.now().strftime("%Y%m%d-%H%M%S")}' + '_epoch_{epoch:02d}.h5'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

tensorboard = TensorBoard(log_dir=log_dir)
checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
vis = VizCallback(y_func, test_generator, len(test_labels))
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='min')

initial_learning_rate = 0.001
epochs = 100

callbacks = [early_stop, tensorboard, vis, checkpoint]
# callbacks = [early_stop, tensorboard, vis]
# callbacks = [early_stop, tensorboard, vis, LearningRateScheduler(lr_time_based_decay, verbose=1)]

# %% [markdown]
# # Training #

# %%
def train(callbacks, batch_size, epochs, initial_epoch=0):
    print('Training process starting...')
    H = model.fit(train_generator.next_batch(),
                  steps_per_epoch=train_len//batch_size,
                  validation_data=val_generator.next_batch(),
                  validation_steps=val_len//batch_size,
                  epochs=epochs, 
                  initial_epoch=initial_epoch,
                  callbacks=callbacks,
                  verbose=1)
    return H

# %%
train_len = len(train_labels)
val_len = len(val_labels)

# %%
from tensorflow.keras import optimizers

opt = optimizers.Adam(learning_rate=initial_learning_rate)

# %%
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer='adam')

train(callbacks, batch_size, epochs)

# %% [markdown]
# # Testing #
